# %% [markdown]
# # CML to FAIRFluids Conversion - Composition-Based Approach
#
# This notebook demonstrates how to convert CML (Chemical Markup Language) files to FAIRFluids format using the `FAIRFluidsCMLParser` class with the new **composition-based approach**.
#
# ## Key Features
#
# - **Composition-based fluid creation**: $E_a$ch unique composition gets its own fluid block
# - **Automatic compound ID generation** with consistent naming
# - **Support for multiple property types** (viscosity, conductivity, density)
# - **Intelligent composition grouping** based on mole fraction combinations
# - **No filtering needed**: Only compounds present in each composition are included
#
# ## Overview
#
# The parser automatically:
# 1. Extracts compounds from CML data or uses provided compound definitions
# 2. Generates consistent compound IDs using cleaned common names
# 3. **Groups measurements by unique compositions** (mole fraction combinations)
# 4. **Creates separate fluid blocks for each unique composition**
# 5. **Only includes compounds with non-zero mole fractions in each fluid**
# 6. Creates parameter definitions specific to each composition
# 7. Assigns measurements to the appropriate fluid based on composition
#
# ## Important Notes
#
# - **Composition-Based Approach**: $E_a$ch unique composition becomes a separate fluid block
# - **No Zero Mole Fractions**: Compounds with zero mole fractions are automatically excluded from each fluid
# - **Consistent IDs**: Compound and parameter IDs use cleaned names for consistency
# - **Clean Data Structure**: No post-processing filtering needed - data is structured correctly from the start

# %%
# Import the FAIRFluids models
import sys
sys.path.append('/home/sga/Code/FAIRFluids')
from fairfluids import FAIRFluidsCMLParser
from fairfluids.core.lib import FAIRFluidsDocument, Version, Citation
from fairfluids.core.functionalities import FAIRFluidsCMLParser
from fairfluids import FAIRFluidsDocument, FluidIO, calculate_ratio_of_solvent
from fairfluids.core.visualization import extract_fairfluids_data, plot_dataframe

# Test the extended class
doc = FAIRFluidsDocument(
    version=Version(
        versionMajor=1,
        versionMinor=0
    )
)

# Add same data as example
doc.citation = Citation(Type="journal")
doc.citation.add_to_author(given_name="Gudrun", family_name="Gygli")

# Define the compounds as variables (dictionaries) for use in a compounds list
# Note: compoundID will be automatically generated using the new consistent naming convention
compound_water = {
    "pubChemID": 962,
    "commonName": "Water",
    "name_IUPAC": "oxidane",
    "standard_InChI": "InChI=1S/H2O/h1H2",
    "standard_InChI_key": "XLYOFNOQVPJJNP-UHFFFAOYSA-N"
}

compound_cholinechloride = {
    "pubChemID": 6209,
    "commonName": "Choline chloride",  # Updated to use proper spacing
    "name_IUPAC": "Choline chloride",
    "standard_InChI": "InChI=1S/C5H11ClNO2/c1"
}

compound_glycerol = {
    "pubChemID": 753,
    "commonName": "Glycerol",
    "name_IUPAC": "glycerol",
    "standard_InChI": "InChI=1S/C3H8O3/c1-2-3-4/h2-3H,1H3",
    "standard_InChI_key": "XLYOFNOQVPJJNP-UHFFFAOYSA-N"
}

compound_urea = {
    "pubChemID": 1176,
    "commonName": "Urea",
    "name_IUPAC": "urea",
    "standard_InChI": "InChI=1S/C2H4N2O/c1-2-4-3/h1H3,(H,2,4)"
}

compounds = [
        compound_cholinechloride,
        compound_glycerol,
        compound_water
    ]
    


# Path to the test CML file
cml_path = "/home/sga/Code/FAIRFluids/fairfluids/data/cml_xml/xu/CML_exp_sim.xml"
#cml_path = "/home/sga/Code/FAIRFluids/fairfluids/data/cml_xml/xu/CML_exp_sim.xml"




# Parse the CML file
parser = FAIRFluidsCMLParser(cml_path, compounds=compounds)
doc = parser.parse()

doc   = calculate_ratio_of_solvent(
    doc=doc,
    parameter_id_1="parameter_mole_fraction_glycerol",
    parameter_id_2="parameter_mole_fraction_cholinechloride",
    name="urea_cholinechloride",
    compound_id_1="compound_glycerol",
    compound_id_2="compound_cholinechloride",
    precision=1  # Round to 2 decimal places - ensures 2.0 instead of 2.0075...
)

# Save the model to a JSON file
with open('/home/sga/Code/FAIRFluids/Workflows/paper_outputs/Xu_Glycerol_Water.json', 'w') as f:
    f.write(doc.model_dump_json(indent=4))
    
print(f"\n📁 Output saved to: /home/sga/Code/FAIRFluids/Workflows/outputs/Xu_Glycerol_Water.json")
# Out:
# Fetching compound data from PubChem for CID 6209...
# Successfully fetched and merged data for CID 6209
# Fetching compound data from PubChem for CID 753...
# Successfully fetched and merged data for CID 753
# Fetching compound data from PubChem for CID 962...
# Successfully fetched and merged data for CID 962
# Found 52 unique compositions
# Composition (0.5, 0.5, 0.0): compounds ['compound_cholinechloride', 'compound_glycerol']
# Composition (0.333, 0.667, 0.0): compounds ['compound_cholinechloride', 'compound_glycerol']
# Composition (0.25, 0.75, 0.0): compounds ['compound_cholinechloride', 'compound_glycerol']
# Composition (0.05, 0.95, 0.0): compounds ['compound_cholinechloride', 'compound_glycerol']
# Composition (0.1, 0.9, 0.0): compounds ['compound_cholinechloride', 'compound_glycerol']
# Composition (0.15, 0.85, 0.0): compounds ['compound_cholinechloride', 'compound_glycerol']
# Composition (0.2, 0.8, 0.0): compounds ['compound_cholinechloride', 'compound_glycerol']
# Composition (0.3, 0.7, 0.0): compounds ['compound_cholinechloride', 'compound_glycerol']
# Composition (0.25, 0.5, 0.25): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.297, 0.595, 0.108): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.254, 0.508, 0.238): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.219, 0.438, 0.343): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.199, 0.399, 0.402): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.134, 0.268, 0.598): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.093, 0.187, 0.72): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.067, 0.134, 0.8): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.048, 0.095, 0.857): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.033, 0.066, 0.901): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.022, 0.044, 0.933): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.013, 0.027, 0.96): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.006, 0.012, 0.982): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.0, 0.0, 1.0): compounds ['compound_water']
# Composition (0.033, 0.067, 0.9): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.058, 0.117, 0.825): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.1, 0.2, 0.7): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.133, 0.267, 0.6): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.167, 0.333, 0.5): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.2, 0.4, 0.4): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.101, 0.202, 0.697): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.266, 0.532, 0.202): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.3, 0.6, 0.1): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.249, 0.496, 0.254): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.281, 0.562, 0.156): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.111, 0.222, 0.667): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.018, 0.035, 0.947): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.325, 0.65, 0.025): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.317, 0.634, 0.049): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.295, 0.59, 0.115): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.263, 0.526, 0.211): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.236, 0.472, 0.291): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.213, 0.427, 0.36): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.176, 0.353, 0.471): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.147, 0.295, 0.558): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.297, 0.593, 0.11): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.267, 0.533, 0.2): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.24, 0.48, 0.28): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.22, 0.44, 0.34): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.163, 0.327, 0.51): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.083, 0.167, 0.75): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.103, 0.207, 0.69): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.19, 0.38, 0.43): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.307, 0.613, 0.08): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# === Calculating Solvent Ratio: urea_cholinechloride ===
# Component 1: parameter_mole_fraction_glycerol
# Component 2: parameter_mole_fraction_cholinechloride
# Processing 52 fluids
#
# --- Processing Fluid 1 ---
# Added new parameter: parameter_solvent_ratio_urea_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 189edc73-edb5-4bf7-827d-d0d6dbd2c000: ratio = 0.5 / 0.5 = 1.0
# Added ratio value 1.0 to measurement 189edc73-edb5-4bf7-827d-d0d6dbd2c000
# Measurement fc8bdfc0-90d8-45f1-b114-e9bd66717b48: ratio = 0.5 / 0.5 = 1.0
# Added ratio value 1.0 to measurement fc8bdfc0-90d8-45f1-b114-e9bd66717b48
# Measurement 24c6f10e-1d06-4fae-9d23-03dc9df0f852: ratio = 0.5 / 0.5 = 1.0
# Added ratio value 1.0 to measurement 24c6f10e-1d06-4fae-9d23-03dc9df0f852
# Measurement 59728d14-2c1f-4908-a9c0-fd24d14140d0: ratio = 0.5 / 0.5 = 1.0
# Added ratio value 1.0 to measurement 59728d14-2c1f-4908-a9c0-fd24d14140d0
# Measurement 508406b8-d85b-40cf-91b1-fa32fb0bd603: ratio = 0.5 / 0.5 = 1.0
# Added ratio value 1.0 to measurement 508406b8-d85b-40cf-91b1-fa32fb0bd603
# Measurement 0514d29c-dc19-4f0e-8f75-3572d82a0389: ratio = 0.5 / 0.5 = 1.0
# Added ratio value 1.0 to measurement 0514d29c-dc19-4f0e-8f75-3572d82a0389
# Measurement 0bdbb3f0-f443-4b21-8f77-2ab916484729: ratio = 0.5 / 0.5 = 1.0
# Added ratio value 1.0 to measurement 0bdbb3f0-f443-4b21-8f77-2ab916484729
# Measurement ecf81455-da2f-4956-86c4-e72cbf3b4c83: ratio = 0.5 / 0.5 = 1.0
# Added ratio value 1.0 to measurement ecf81455-da2f-4956-86c4-e72cbf3b4c83
# Measurement 0e6e648d-1f5c-45ea-ae63-3d3c8d55f9cc: ratio = 0.5 / 0.5 = 1.0
# Added ratio value 1.0 to measurement 0e6e648d-1f5c-45ea-ae63-3d3c8d55f9cc
# Measurement bd0edeb5-844a-4a0e-9c08-7f48872847ec: ratio = 0.5 / 0.5 = 1.0
# Added ratio value 1.0 to measurement bd0edeb5-844a-4a0e-9c08-7f48872847ec
# Measurement 616e0c7b-9e64-417c-ae1f-c3c2a7c56448: ratio = 0.5 / 0.5 = 1.0
# Added ratio value 1.0 to measurement 616e0c7b-9e64-417c-ae1f-c3c2a7c56448
# Measurement bd01470c-16b0-4311-b3b0-bd2b11eb9fd5: ratio = 0.5 / 0.5 = 1.0
# Added ratio value 1.0 to measurement bd01470c-16b0-4311-b3b0-bd2b11eb9fd5
# Measurement f11ef297-008b-493e-a850-cc3aabf2f66e: ratio = 0.5 / 0.5 = 1.0
# Added ratio value 1.0 to measurement f11ef297-008b-493e-a850-cc3aabf2f66e
# Measurement 508d90d3-4af5-419a-9b12-678bdb4f9f94: ratio = 0.5 / 0.5 = 1.0
# Added ratio value 1.0 to measurement 508d90d3-4af5-419a-9b12-678bdb4f9f94
# Measurement a4dc17ed-134f-448f-b762-a9201138cac8: ratio = 0.5 / 0.5 = 1.0
# Added ratio value 1.0 to measurement a4dc17ed-134f-448f-b762-a9201138cac8
# Measurement 18fe0614-b6f4-4531-9eaf-7b0a8202da60: ratio = 0.5 / 0.5 = 1.0
# Added ratio value 1.0 to measurement 18fe0614-b6f4-4531-9eaf-7b0a8202da60
# Measurement 232a1219-275a-4351-9b4d-e1640e723445: ratio = 0.5 / 0.5 = 1.0
# Added ratio value 1.0 to measurement 232a1219-275a-4351-9b4d-e1640e723445
# Measurement c34eda12-a638-4ba5-8271-100937c4f417: ratio = 0.5 / 0.5 = 1.0
# Added ratio value 1.0 to measurement c34eda12-a638-4ba5-8271-100937c4f417
# Measurement aa3212db-af22-421b-9351-822c95245bc1: ratio = 0.5 / 0.5 = 1.0
# Added ratio value 1.0 to measurement aa3212db-af22-421b-9351-822c95245bc1
# Measurement 4f3eefdc-c2ff-4cfa-905e-ac3dbfb81176: ratio = 0.5 / 0.5 = 1.0
# Added ratio value 1.0 to measurement 4f3eefdc-c2ff-4cfa-905e-ac3dbfb81176
# Measurement d8d87946-9e37-45d8-b060-c301ebc2bd3a: ratio = 0.5 / 0.5 = 1.0
# Added ratio value 1.0 to measurement d8d87946-9e37-45d8-b060-c301ebc2bd3a
# Measurement af8a9ee1-f3b1-4c39-b794-6e5047d48682: ratio = 0.5 / 0.5 = 1.0
# Added ratio value 1.0 to measurement af8a9ee1-f3b1-4c39-b794-6e5047d48682
# Measurement 1de61e6e-d364-4408-9b01-2ab891c72b39: ratio = 0.5 / 0.5 = 1.0
# Added ratio value 1.0 to measurement 1de61e6e-d364-4408-9b01-2ab891c72b39
# Measurement e7638227-b32d-4a5f-a4e1-24af39874dc5: ratio = 0.5 / 0.5 = 1.0
# Added ratio value 1.0 to measurement e7638227-b32d-4a5f-a4e1-24af39874dc5
# Measurement 4c9ea983-c226-4109-bd2b-328d1dc9240d: ratio = 0.5 / 0.5 = 1.0
# Added ratio value 1.0 to measurement 4c9ea983-c226-4109-bd2b-328d1dc9240d
# Measurement 62342f22-f76b-428d-b88c-2f7697a642db: ratio = 0.5 / 0.5 = 1.0
# Added ratio value 1.0 to measurement 62342f22-f76b-428d-b88c-2f7697a642db
# Measurement c1b64ca3-6d92-415f-b1ea-bc9bb9705385: ratio = 0.5 / 0.5 = 1.0
# Added ratio value 1.0 to measurement c1b64ca3-6d92-415f-b1ea-bc9bb9705385
# Measurement 593ad332-e079-4171-888d-47d351552128: ratio = 0.5 / 0.5 = 1.0
# Added ratio value 1.0 to measurement 593ad332-e079-4171-888d-47d351552128
# Measurement 66fe0880-4655-45d5-a443-d37b67496805: ratio = 0.5 / 0.5 = 1.0
# Added ratio value 1.0 to measurement 66fe0880-4655-45d5-a443-d37b67496805
# Measurement 70f27f92-f028-4467-8d6d-fc02294b98ca: ratio = 0.5 / 0.5 = 1.0
# Added ratio value 1.0 to measurement 70f27f92-f028-4467-8d6d-fc02294b98ca
# Measurement 9b759d72-da07-49de-8f1c-386fa6543b5e: ratio = 0.5 / 0.5 = 1.0
# Added ratio value 1.0 to measurement 9b759d72-da07-49de-8f1c-386fa6543b5e
# Measurement 3ac51bab-8d18-455c-9598-51ac02066a29: ratio = 0.5 / 0.5 = 1.0
# Added ratio value 1.0 to measurement 3ac51bab-8d18-455c-9598-51ac02066a29
# Measurement a83dea6f-4f39-421b-a076-85145a55acc7: ratio = 0.5 / 0.5 = 1.0
# Added ratio value 1.0 to measurement a83dea6f-4f39-421b-a076-85145a55acc7
# Measurement 61bfa6e6-0ce6-46e9-8e9f-1c265b960fcf: ratio = 0.5 / 0.5 = 1.0
# Added ratio value 1.0 to measurement 61bfa6e6-0ce6-46e9-8e9f-1c265b960fcf
#
# --- Processing Fluid 2 ---
# Added new parameter: parameter_solvent_ratio_urea_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 8793e25e-3306-4a92-a52a-ce429d383a1c: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 8793e25e-3306-4a92-a52a-ce429d383a1c
# Measurement 3d75048c-ade1-4cd5-be4c-a0968883c938: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 3d75048c-ade1-4cd5-be4c-a0968883c938
# Measurement 29d2569d-cb82-40c7-9f0a-8a73adc53624: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 29d2569d-cb82-40c7-9f0a-8a73adc53624
# Measurement 4e9d11c1-941c-42db-ac80-10c979e48dcb: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 4e9d11c1-941c-42db-ac80-10c979e48dcb
# Measurement cad7d44e-7d1d-45bd-9ef6-56647ae7fd5a: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement cad7d44e-7d1d-45bd-9ef6-56647ae7fd5a
# Measurement ac787f1f-f79a-47b6-87d4-76e77215fc00: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement ac787f1f-f79a-47b6-87d4-76e77215fc00
# Measurement 7002d67d-14cc-42e6-8425-cd6574aee6c9: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 7002d67d-14cc-42e6-8425-cd6574aee6c9
# Measurement d5404799-322c-42e5-9f15-9b8625fcc91d: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement d5404799-322c-42e5-9f15-9b8625fcc91d
# Measurement 8159b2b7-2ad6-41b8-97ba-a175b0736370: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 8159b2b7-2ad6-41b8-97ba-a175b0736370
# Measurement 0bc6d526-df50-4df7-9768-2c6a84378561: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 0bc6d526-df50-4df7-9768-2c6a84378561
# Measurement b4f89656-47d0-49d1-8782-6814e9632b6c: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement b4f89656-47d0-49d1-8782-6814e9632b6c
# Measurement 8dde9206-07bc-42b3-b313-312b42be8966: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 8dde9206-07bc-42b3-b313-312b42be8966
# Measurement 29365b0a-ab42-46ed-af78-2be00e06d4e7: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 29365b0a-ab42-46ed-af78-2be00e06d4e7
# Measurement fea94839-496a-49e1-a28b-4ce05cee6233: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement fea94839-496a-49e1-a28b-4ce05cee6233
# Measurement f488014c-4113-441a-9e80-1be32b16c7be: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement f488014c-4113-441a-9e80-1be32b16c7be
# Measurement e89fb627-79cc-423d-80bf-d3781e5c0e82: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement e89fb627-79cc-423d-80bf-d3781e5c0e82
# Measurement ce6a57a0-5408-4c7b-87f9-b4e799302b2d: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement ce6a57a0-5408-4c7b-87f9-b4e799302b2d
# Measurement 832665a9-2730-47ef-8bf7-72e0a1404548: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 832665a9-2730-47ef-8bf7-72e0a1404548
# Measurement eb611a27-68de-4eaf-ae7a-cde4746cec73: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement eb611a27-68de-4eaf-ae7a-cde4746cec73
# Measurement 187d73b5-b3a7-40a2-ae57-20124180a291: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 187d73b5-b3a7-40a2-ae57-20124180a291
# Measurement 6ec9c3bb-5ca4-4234-9fe3-3e51b1676c22: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 6ec9c3bb-5ca4-4234-9fe3-3e51b1676c22
# Measurement cbe07f9f-5961-48be-9f82-2e88a0352dcb: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement cbe07f9f-5961-48be-9f82-2e88a0352dcb
# Measurement 772e26de-5c73-46ae-bf3c-2cb9f5e7bee3: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 772e26de-5c73-46ae-bf3c-2cb9f5e7bee3
# Measurement b1cfad2c-4387-4f94-af4c-1be419820b7d: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement b1cfad2c-4387-4f94-af4c-1be419820b7d
# Measurement d8e05a18-6ef7-4386-8eb1-75707165ac6d: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement d8e05a18-6ef7-4386-8eb1-75707165ac6d
# Measurement 838ad855-bbfc-471a-ad56-2f79f5ec249a: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 838ad855-bbfc-471a-ad56-2f79f5ec249a
# Measurement 3717e186-b59f-4d66-b170-f7776659ee9f: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 3717e186-b59f-4d66-b170-f7776659ee9f
# Measurement a0d6dbd0-3d17-44d6-9b6e-49b7dbb58b9d: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement a0d6dbd0-3d17-44d6-9b6e-49b7dbb58b9d
# Measurement 0372b8dd-29b9-4c39-8312-275bcf5528f9: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 0372b8dd-29b9-4c39-8312-275bcf5528f9
# Measurement 6c8237f7-9554-4c1c-b43c-08afa5b5ec01: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 6c8237f7-9554-4c1c-b43c-08afa5b5ec01
# Measurement 762f58c3-0cbc-4691-aa88-535d64750e12: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 762f58c3-0cbc-4691-aa88-535d64750e12
# Measurement c1f02531-7453-43ab-8c3f-40b70e1b8ed8: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement c1f02531-7453-43ab-8c3f-40b70e1b8ed8
# Measurement 811d228f-8cf0-4c8f-a2cd-005d3654ce6a: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 811d228f-8cf0-4c8f-a2cd-005d3654ce6a
# Measurement 622f7607-0c22-49ee-b6f6-ffad9a0702c2: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 622f7607-0c22-49ee-b6f6-ffad9a0702c2
# Measurement 677a5a06-8c86-4496-8081-3b3fe7e64cb4: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 677a5a06-8c86-4496-8081-3b3fe7e64cb4
# Measurement 400f3ec0-f97e-4e4d-8150-49a3f3a96255: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 400f3ec0-f97e-4e4d-8150-49a3f3a96255
# Measurement 15e31ea4-3176-474e-92a4-fd374bdefacc: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 15e31ea4-3176-474e-92a4-fd374bdefacc
# Measurement 615dee2e-f531-449c-ad5c-549861ed3562: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 615dee2e-f531-449c-ad5c-549861ed3562
# Measurement 867a2442-2a04-4899-8106-33360326811a: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 867a2442-2a04-4899-8106-33360326811a
# Measurement ac3380fe-4cab-439c-be07-f539ee91c9c4: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement ac3380fe-4cab-439c-be07-f539ee91c9c4
# Measurement 2797aba4-431a-4de5-822a-de30458f1d1f: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 2797aba4-431a-4de5-822a-de30458f1d1f
# Measurement 1ed4ecec-816d-4edd-9388-1de8a399b5e4: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 1ed4ecec-816d-4edd-9388-1de8a399b5e4
# Measurement 61712906-e614-4a72-8e94-8dff791f847a: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 61712906-e614-4a72-8e94-8dff791f847a
# Measurement 82a13efa-c281-435f-bf1b-3891f024dd89: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 82a13efa-c281-435f-bf1b-3891f024dd89
# Measurement 702dbca1-a334-4273-8d57-2795799c19ad: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 702dbca1-a334-4273-8d57-2795799c19ad
# Measurement c85bf35b-cd97-4c42-9cce-a57f6eba7096: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement c85bf35b-cd97-4c42-9cce-a57f6eba7096
# Measurement b8cfb9eb-58b7-48e9-847d-4d22637eca01: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement b8cfb9eb-58b7-48e9-847d-4d22637eca01
# Measurement f49ac608-8cf2-4566-9ce7-0a49979b0e34: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement f49ac608-8cf2-4566-9ce7-0a49979b0e34
# Measurement 5e91f110-6e8d-4af7-9b39-d21381042184: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 5e91f110-6e8d-4af7-9b39-d21381042184
# Measurement 3a20a90d-7a3c-465e-998d-af242cdfdf52: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 3a20a90d-7a3c-465e-998d-af242cdfdf52
# Measurement 59880f48-c853-4b41-9789-c4deac95d9f0: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 59880f48-c853-4b41-9789-c4deac95d9f0
# Measurement e8f8562a-d50e-49ce-abfb-8689d52f0f9f: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement e8f8562a-d50e-49ce-abfb-8689d52f0f9f
# Measurement 25d95947-99e8-4087-abfd-eff57be550ac: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 25d95947-99e8-4087-abfd-eff57be550ac
# Measurement a0936a40-d45a-4d0d-9aa4-3de28361d66f: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement a0936a40-d45a-4d0d-9aa4-3de28361d66f
# Measurement a69a525e-dcea-47e6-a7d0-4f303488d7ba: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement a69a525e-dcea-47e6-a7d0-4f303488d7ba
# Measurement e67d86c0-5c76-493e-9172-096dac710add: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement e67d86c0-5c76-493e-9172-096dac710add
# Measurement 69fd2649-e6cd-4398-bf09-115c8f81dc4b: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 69fd2649-e6cd-4398-bf09-115c8f81dc4b
# Measurement 360c0dab-53c1-44f3-b696-5bf2f2fde270: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 360c0dab-53c1-44f3-b696-5bf2f2fde270
# Measurement db66565c-fb39-4929-8398-b98d8ce66907: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement db66565c-fb39-4929-8398-b98d8ce66907
# Measurement c82d6935-b367-4608-a2ca-6423329c312d: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement c82d6935-b367-4608-a2ca-6423329c312d
# Measurement 70a997dd-dfa1-45fc-b24e-809f6861f985: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 70a997dd-dfa1-45fc-b24e-809f6861f985
# Measurement 94f979f4-97b8-4d6b-bc04-c8aecc9a166b: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 94f979f4-97b8-4d6b-bc04-c8aecc9a166b
# Measurement ccb9cedb-b225-4a26-ae4d-eb9553dae82a: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement ccb9cedb-b225-4a26-ae4d-eb9553dae82a
# Measurement 0f16a570-5d44-40cf-8fb1-60cf82aea821: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 0f16a570-5d44-40cf-8fb1-60cf82aea821
# Measurement ff6a0c4c-0b47-4c73-818b-f4dfd07f1a5f: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement ff6a0c4c-0b47-4c73-818b-f4dfd07f1a5f
# Measurement 52f39b5c-3128-4b30-a333-4e0578c395e5: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 52f39b5c-3128-4b30-a333-4e0578c395e5
# Measurement 725e63f3-47e2-4e26-8f69-282b57d4862e: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 725e63f3-47e2-4e26-8f69-282b57d4862e
# Measurement 57b75414-8f34-491b-adcb-67744b7a221b: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 57b75414-8f34-491b-adcb-67744b7a221b
# Measurement 91a10b0a-08c8-4419-9bee-907f65bb3bd8: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 91a10b0a-08c8-4419-9bee-907f65bb3bd8
# Measurement c15340cb-c2a0-44ec-ba2f-e53b60648c50: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement c15340cb-c2a0-44ec-ba2f-e53b60648c50
# Measurement df213038-f6a3-4737-931b-2fcdff75df07: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement df213038-f6a3-4737-931b-2fcdff75df07
# Measurement ded80b09-9900-4e27-a803-f5497a5ba742: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement ded80b09-9900-4e27-a803-f5497a5ba742
# Measurement c69ef0f0-08e9-433f-b745-818f21d3ff2d: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement c69ef0f0-08e9-433f-b745-818f21d3ff2d
# Measurement b261d2d9-0d3b-41a7-a16d-763351dabb98: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement b261d2d9-0d3b-41a7-a16d-763351dabb98
# Measurement 5691b736-713f-4daa-a8a2-4dc306431cab: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 5691b736-713f-4daa-a8a2-4dc306431cab
# Measurement 21dc437d-124d-42fb-8fae-193163823907: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 21dc437d-124d-42fb-8fae-193163823907
# Measurement 349acc22-bed1-45e6-bcf6-c25e673f06b5: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 349acc22-bed1-45e6-bcf6-c25e673f06b5
# Measurement cd0e72f2-78f9-48e2-99f0-5fa959ade177: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement cd0e72f2-78f9-48e2-99f0-5fa959ade177
# Measurement ae5e7ff6-9d53-4c64-8d3e-0b05d84e5441: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement ae5e7ff6-9d53-4c64-8d3e-0b05d84e5441
# Measurement 92dfa023-e33c-4bcf-8305-3b4fe7c2de6c: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 92dfa023-e33c-4bcf-8305-3b4fe7c2de6c
# Measurement fad57ffd-9549-465e-81e2-fb8a7915658b: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement fad57ffd-9549-465e-81e2-fb8a7915658b
# Measurement 7a08ef00-d0a6-418f-b9ac-007cb8ed282d: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 7a08ef00-d0a6-418f-b9ac-007cb8ed282d
# Measurement 6dbf53d3-f509-4349-95b3-7e4bcd6b7538: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 6dbf53d3-f509-4349-95b3-7e4bcd6b7538
# Measurement 96257894-8f3c-4dc8-a000-2b430563df5f: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 96257894-8f3c-4dc8-a000-2b430563df5f
# Measurement f44ddacb-3cb3-48c5-9e4d-04a7d54a512f: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement f44ddacb-3cb3-48c5-9e4d-04a7d54a512f
# Measurement 00d9c3d5-d0a9-453a-ab35-01427e57dc16: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 00d9c3d5-d0a9-453a-ab35-01427e57dc16
# Measurement 5903da59-4132-4c2e-8ced-3b10ab752b3c: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 5903da59-4132-4c2e-8ced-3b10ab752b3c
# Measurement 7c1e9f13-03c7-4e75-bb4e-0787c75931d5: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 7c1e9f13-03c7-4e75-bb4e-0787c75931d5
# Measurement 08fb09d4-ba02-487e-a55a-f6489894e054: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 08fb09d4-ba02-487e-a55a-f6489894e054
# Measurement 291df303-fa79-4ef4-86ca-2d526c8555bb: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 291df303-fa79-4ef4-86ca-2d526c8555bb
# Measurement 2b9710af-231e-434c-a47a-304f8409a8a3: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 2b9710af-231e-434c-a47a-304f8409a8a3
# Measurement a468acdb-b7ac-431a-958a-a5f25ba790e6: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement a468acdb-b7ac-431a-958a-a5f25ba790e6
# Measurement 3686859c-22ea-49dd-ac42-d40dc820dae3: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 3686859c-22ea-49dd-ac42-d40dc820dae3
# Measurement 575383f0-773a-4c73-b59b-3e091072c7a7: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 575383f0-773a-4c73-b59b-3e091072c7a7
# Measurement 3618e66c-d9c3-4f14-8778-4a6ed774f425: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 3618e66c-d9c3-4f14-8778-4a6ed774f425
# Measurement 985e4f24-2a54-4c9a-9cdc-7e9be6255e2b: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 985e4f24-2a54-4c9a-9cdc-7e9be6255e2b
# Measurement f74da47a-8368-4591-bce3-a11ddf468b4a: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement f74da47a-8368-4591-bce3-a11ddf468b4a
# Measurement 1f373ce7-bd78-44e7-b04b-312ecb449380: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 1f373ce7-bd78-44e7-b04b-312ecb449380
# Measurement e7027afb-f2e2-44ce-a1af-a1848db1ded0: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement e7027afb-f2e2-44ce-a1af-a1848db1ded0
# Measurement 46d6bfba-9a3a-45f7-90e4-608ad8662f62: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 46d6bfba-9a3a-45f7-90e4-608ad8662f62
# Measurement eaa77712-676f-4865-987c-74f96bfcd90a: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement eaa77712-676f-4865-987c-74f96bfcd90a
# Measurement c35ad235-ec53-4c43-820a-ae6d16632255: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement c35ad235-ec53-4c43-820a-ae6d16632255
# Measurement 3436b269-83f9-4a34-b9ea-30beb1eb6cb8: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 3436b269-83f9-4a34-b9ea-30beb1eb6cb8
# Measurement f6a44543-1358-4172-b2ea-2ec9a3b2ca77: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement f6a44543-1358-4172-b2ea-2ec9a3b2ca77
# Measurement 395a1940-573f-4c3e-a39a-0c87a837a19a: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 395a1940-573f-4c3e-a39a-0c87a837a19a
# Measurement 43a59aac-d2d8-422e-a5d2-573abb27c76f: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 43a59aac-d2d8-422e-a5d2-573abb27c76f
# Measurement f3be8dda-8df9-4c72-b747-f1e693983a25: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement f3be8dda-8df9-4c72-b747-f1e693983a25
# Measurement 1bae314b-22df-4d32-906e-c6e35998e84c: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 1bae314b-22df-4d32-906e-c6e35998e84c
# Measurement 4e0bec1d-f320-413b-882e-f35e30ba1085: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 4e0bec1d-f320-413b-882e-f35e30ba1085
# Measurement 22dd95ad-e799-4503-a748-fc92a542697a: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 22dd95ad-e799-4503-a748-fc92a542697a
# Measurement 2972579f-7812-4fab-82bb-89399ce57318: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 2972579f-7812-4fab-82bb-89399ce57318
# Measurement 3117c2b9-b289-419d-b98d-3da89b4abf0d: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 3117c2b9-b289-419d-b98d-3da89b4abf0d
# Measurement c541c23e-95e1-4793-b975-585153c85bf3: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement c541c23e-95e1-4793-b975-585153c85bf3
# Measurement eb7f056b-97b4-4442-ba9c-f68ae5514772: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement eb7f056b-97b4-4442-ba9c-f68ae5514772
# Measurement 13700e72-d0e4-47d8-93af-3e5176fad9fe: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 13700e72-d0e4-47d8-93af-3e5176fad9fe
# Measurement 8705ced1-c06c-4cb1-ba28-20927eddf7f9: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 8705ced1-c06c-4cb1-ba28-20927eddf7f9
# Measurement ea236ff5-21fb-4fb8-aa8c-de3f0a28e320: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement ea236ff5-21fb-4fb8-aa8c-de3f0a28e320
# Measurement 51ebe2af-85f0-47c3-b731-88c90797a1a9: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 51ebe2af-85f0-47c3-b731-88c90797a1a9
# Measurement d9f1aa0f-b7a1-419a-ae9d-c2cd103b2548: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement d9f1aa0f-b7a1-419a-ae9d-c2cd103b2548
# Measurement ec0f8b72-d8ff-441b-9a0d-ce61a87af787: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement ec0f8b72-d8ff-441b-9a0d-ce61a87af787
# Measurement 2bbaa36e-d2b8-49e2-baab-54adb1b25af0: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 2bbaa36e-d2b8-49e2-baab-54adb1b25af0
# Measurement 98a96550-6d02-423f-ba5a-136c8340cfcc: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 98a96550-6d02-423f-ba5a-136c8340cfcc
# Measurement 0e78eab1-f8cf-4340-89b2-678eaacaf788: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 0e78eab1-f8cf-4340-89b2-678eaacaf788
# Measurement 1d15173e-c2c1-43d5-b1e1-5a74464392e9: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 1d15173e-c2c1-43d5-b1e1-5a74464392e9
# Measurement 2d91d4b9-2982-4a18-9cdd-4b1bdc67059a: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 2d91d4b9-2982-4a18-9cdd-4b1bdc67059a
# Measurement da317d6e-ad9a-4ece-bd07-dfe662304a38: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement da317d6e-ad9a-4ece-bd07-dfe662304a38
# Measurement 2c1308c1-61ae-4309-a826-92a1db8088ab: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 2c1308c1-61ae-4309-a826-92a1db8088ab
# Measurement b6a90bbe-c3f9-455f-b262-bfbc8820bef3: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement b6a90bbe-c3f9-455f-b262-bfbc8820bef3
# Measurement c4ac4dbf-d819-42ce-b5eb-fdde6645c95f: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement c4ac4dbf-d819-42ce-b5eb-fdde6645c95f
# Measurement fe3f6aec-17b9-4190-a25c-5a987f47f910: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement fe3f6aec-17b9-4190-a25c-5a987f47f910
# Measurement 229db3f7-d8f4-4801-a595-6ec12658b1fb: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 229db3f7-d8f4-4801-a595-6ec12658b1fb
# Measurement 60b36de6-11fb-4147-bda7-88d2a59adfaf: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 60b36de6-11fb-4147-bda7-88d2a59adfaf
# Measurement 2dfa9d93-f593-488f-a417-6d8259227238: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 2dfa9d93-f593-488f-a417-6d8259227238
# Measurement 5170220e-1cf2-4000-87b6-4d8cb04a6b96: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 5170220e-1cf2-4000-87b6-4d8cb04a6b96
# Measurement e5d86cbb-da9e-46df-b42a-9cb2a5c7fcd1: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement e5d86cbb-da9e-46df-b42a-9cb2a5c7fcd1
# Measurement 4f19bd01-8ca0-473b-91a4-722d71df4ac0: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 4f19bd01-8ca0-473b-91a4-722d71df4ac0
# Measurement 2759c2c1-2a3a-461c-ac1b-17dc9b3ebac9: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 2759c2c1-2a3a-461c-ac1b-17dc9b3ebac9
# Measurement c60a69a5-80a0-4431-8a03-14ed5dc6aa98: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement c60a69a5-80a0-4431-8a03-14ed5dc6aa98
# Measurement e9901a9b-690d-41f6-aa39-080f5ab7e927: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement e9901a9b-690d-41f6-aa39-080f5ab7e927
# Measurement 3cb347bd-1043-49e0-8c78-2770b627a4e6: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 3cb347bd-1043-49e0-8c78-2770b627a4e6
# Measurement 51cc0724-da82-44f6-b18c-aec038bb8f20: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 51cc0724-da82-44f6-b18c-aec038bb8f20
# Measurement 826e5bb6-9311-4c21-ae03-92ad874fe47a: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 826e5bb6-9311-4c21-ae03-92ad874fe47a
# Measurement e6a9c54b-21bf-421c-b2be-4058f4e62824: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement e6a9c54b-21bf-421c-b2be-4058f4e62824
# Measurement 8154f83e-ff4a-4d88-9fb1-09e350700c42: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 8154f83e-ff4a-4d88-9fb1-09e350700c42
# Measurement 0af6b11d-4294-495b-bbe2-9f9b4b1f35ae: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 0af6b11d-4294-495b-bbe2-9f9b4b1f35ae
# Measurement fba2563d-9b1f-40a5-883b-6ffcab21c0c1: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement fba2563d-9b1f-40a5-883b-6ffcab21c0c1
# Measurement 81d4f39b-3dae-401f-aa82-68fbe7da1eb4: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 81d4f39b-3dae-401f-aa82-68fbe7da1eb4
# Measurement a6107db3-0320-4bde-aba2-69e567b2e458: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement a6107db3-0320-4bde-aba2-69e567b2e458
# Measurement a5a33e11-1707-49ce-a795-f21395683f1a: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement a5a33e11-1707-49ce-a795-f21395683f1a
# Measurement d503b112-d1d3-41e0-9710-afe47d272546: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement d503b112-d1d3-41e0-9710-afe47d272546
# Measurement 7308b405-fb0c-4cb4-b922-7cfd0c12499b: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 7308b405-fb0c-4cb4-b922-7cfd0c12499b
# Measurement 6b802187-1b84-4ee6-8e3b-dd68a4d0ae16: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 6b802187-1b84-4ee6-8e3b-dd68a4d0ae16
# Measurement deb7716f-44e7-459c-88a1-87618e641a73: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement deb7716f-44e7-459c-88a1-87618e641a73
# Measurement a1df79f9-759c-4a8f-a48a-423cae8ae6be: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement a1df79f9-759c-4a8f-a48a-423cae8ae6be
# Measurement 283512d4-2c1a-4156-9d52-0273fd47b26b: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 283512d4-2c1a-4156-9d52-0273fd47b26b
# Measurement 9bdbff63-f7d4-44ab-8eef-f637cb061097: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 9bdbff63-f7d4-44ab-8eef-f637cb061097
# Measurement 1817405f-02b6-47ab-8d69-57b42a66c133: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 1817405f-02b6-47ab-8d69-57b42a66c133
# Measurement 60736962-9bd8-4cf8-964c-ff2e4767a130: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 60736962-9bd8-4cf8-964c-ff2e4767a130
# Measurement 90b724ce-db19-43f4-b37b-b5c9464ecdeb: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 90b724ce-db19-43f4-b37b-b5c9464ecdeb
# Measurement 28f7e9fe-0630-4095-b364-52afa4e18f9d: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 28f7e9fe-0630-4095-b364-52afa4e18f9d
# Measurement fbb32b13-678a-4e9c-acd3-fc7c7e8463e9: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement fbb32b13-678a-4e9c-acd3-fc7c7e8463e9
# Measurement bffe0f92-182e-4eea-bd20-65383ade2789: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement bffe0f92-182e-4eea-bd20-65383ade2789
# Measurement 97f470f9-c143-4248-9efa-90c324fcf35b: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 97f470f9-c143-4248-9efa-90c324fcf35b
# Measurement 0c92ce17-e9e8-4e83-ac5b-4cbcafc362af: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 0c92ce17-e9e8-4e83-ac5b-4cbcafc362af
# Measurement 9a1142cd-d2f8-4182-82de-05334d46dd3d: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 9a1142cd-d2f8-4182-82de-05334d46dd3d
# Measurement 3fa29e8a-c560-430e-b232-0a1b091ec351: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 3fa29e8a-c560-430e-b232-0a1b091ec351
# Measurement 0d58c461-8bbf-4541-8223-05c952409ff5: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 0d58c461-8bbf-4541-8223-05c952409ff5
# Measurement 52005a22-5f5e-4f3e-9be6-20e893aba5f0: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 52005a22-5f5e-4f3e-9be6-20e893aba5f0
# Measurement ee43e69d-a4d0-4271-9299-5025fd51872f: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement ee43e69d-a4d0-4271-9299-5025fd51872f
# Measurement ba14e6a1-58d7-45d6-9036-91dd73cd5d1f: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement ba14e6a1-58d7-45d6-9036-91dd73cd5d1f
# Measurement 5e302f48-83b2-4feb-bead-be45fe227c93: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 5e302f48-83b2-4feb-bead-be45fe227c93
# Measurement 6ad4728f-bf7b-4af7-9ce7-541f87c6f94c: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 6ad4728f-bf7b-4af7-9ce7-541f87c6f94c
# Measurement 9f027a7c-96e7-4303-b16f-d378977aec4d: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 9f027a7c-96e7-4303-b16f-d378977aec4d
# Measurement 622e1d86-3cd7-4ba6-b613-4a75cdecb3b2: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 622e1d86-3cd7-4ba6-b613-4a75cdecb3b2
# Measurement cd747d34-0c2b-4b3c-920b-81a89e197371: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement cd747d34-0c2b-4b3c-920b-81a89e197371
# Measurement 38c02a2b-903a-4951-8c91-c413a9120d94: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 38c02a2b-903a-4951-8c91-c413a9120d94
# Measurement 917bc09e-417d-4b82-8fdb-8d834460975f: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 917bc09e-417d-4b82-8fdb-8d834460975f
# Measurement bbfa391d-163c-47a6-bb60-a375a34a0625: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement bbfa391d-163c-47a6-bb60-a375a34a0625
# Measurement 7ddc8997-401e-480b-9820-dfa0f2caecee: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 7ddc8997-401e-480b-9820-dfa0f2caecee
# Measurement 0f41b4ec-be88-471a-8fec-0fe427a0e9ed: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 0f41b4ec-be88-471a-8fec-0fe427a0e9ed
# Measurement 6f72926a-40d6-4a28-9fdd-6e92ee0cae55: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 6f72926a-40d6-4a28-9fdd-6e92ee0cae55
# Measurement 68c2d073-3357-4852-82ca-52b89ea1b934: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 68c2d073-3357-4852-82ca-52b89ea1b934
# Measurement a11fee96-9f49-4251-bddf-e66c3a4839c7: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement a11fee96-9f49-4251-bddf-e66c3a4839c7
# Measurement 3e57c99b-3b81-4da6-964b-da7a36283910: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 3e57c99b-3b81-4da6-964b-da7a36283910
# Measurement 3bebc716-2b3b-4ab7-97cc-4cc956f229ce: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 3bebc716-2b3b-4ab7-97cc-4cc956f229ce
# Measurement b8a0a50a-9d51-4cd0-8433-da8bb2403ddf: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement b8a0a50a-9d51-4cd0-8433-da8bb2403ddf
# Measurement f91d71db-79d4-46b7-b8f3-e231398d8368: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement f91d71db-79d4-46b7-b8f3-e231398d8368
# Measurement 6dad5f6c-614d-4488-af35-f8754023f800: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 6dad5f6c-614d-4488-af35-f8754023f800
# Measurement 6f8f205d-e8b4-4649-914a-fdf4b2a58dc9: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 6f8f205d-e8b4-4649-914a-fdf4b2a58dc9
# Measurement 0d703a91-4315-49c1-824d-6e5794173c81: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 0d703a91-4315-49c1-824d-6e5794173c81
# Measurement b40626b4-09de-4f1c-a19d-017c48acce04: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement b40626b4-09de-4f1c-a19d-017c48acce04
# Measurement d1442c92-2604-4123-894a-65ec0b16a830: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement d1442c92-2604-4123-894a-65ec0b16a830
# Measurement 5db3ab0e-efdc-4910-a4e7-590716f163f7: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 5db3ab0e-efdc-4910-a4e7-590716f163f7
# Measurement 102bc4c5-9bcf-4290-bf5d-1a296884c25b: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 102bc4c5-9bcf-4290-bf5d-1a296884c25b
# Measurement 0f4e3dea-bef3-4614-bac9-a4e07ad1699e: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 0f4e3dea-bef3-4614-bac9-a4e07ad1699e
# Measurement 5cfe68e3-c570-4b70-8d04-8137a49882c6: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 5cfe68e3-c570-4b70-8d04-8137a49882c6
# Measurement cf79b229-bc41-4d25-9f83-5ce9f06adbb5: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement cf79b229-bc41-4d25-9f83-5ce9f06adbb5
# Measurement 0afaf787-4b74-4c89-bd3c-d58f09de6cf8: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 0afaf787-4b74-4c89-bd3c-d58f09de6cf8
# Measurement 9fa6efe2-5766-4986-bb1b-bb2978a61e77: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 9fa6efe2-5766-4986-bb1b-bb2978a61e77
# Measurement 762ccb63-ce5b-4881-92bd-993f55904a94: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 762ccb63-ce5b-4881-92bd-993f55904a94
# Measurement ef8f26d5-fd12-406c-884f-0b9a69ef6472: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement ef8f26d5-fd12-406c-884f-0b9a69ef6472
#
# --- Processing Fluid 3 ---
# Added new parameter: parameter_solvent_ratio_urea_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 0ce1393e-8fd8-4315-8997-a05b2c36b2f7: ratio = 0.750000000188 / 0.249999999812 = 3.0
# Added ratio value 3.0 to measurement 0ce1393e-8fd8-4315-8997-a05b2c36b2f7
# Measurement 635cb58b-98a2-44b9-918e-bcd596b4d51e: ratio = 0.750000000188 / 0.249999999812 = 3.0
# Added ratio value 3.0 to measurement 635cb58b-98a2-44b9-918e-bcd596b4d51e
# Measurement e96a3a3a-85e4-483a-98b0-ffb83220702f: ratio = 0.750000000188 / 0.249999999812 = 3.0
# Added ratio value 3.0 to measurement e96a3a3a-85e4-483a-98b0-ffb83220702f
# Measurement db222d84-9c09-44f1-966a-6465625c1966: ratio = 0.750000000188 / 0.249999999812 = 3.0
# Added ratio value 3.0 to measurement db222d84-9c09-44f1-966a-6465625c1966
# Measurement 6fe1941c-048c-4521-8263-9926eaaeabf7: ratio = 0.750000000188 / 0.249999999812 = 3.0
# Added ratio value 3.0 to measurement 6fe1941c-048c-4521-8263-9926eaaeabf7
# Measurement 005c5ce3-25fa-4461-9a65-7f84023477ba: ratio = 0.750000000188 / 0.249999999812 = 3.0
# Added ratio value 3.0 to measurement 005c5ce3-25fa-4461-9a65-7f84023477ba
# Measurement 440636e5-3095-4e49-9907-837507c10eaf: ratio = 0.750000000188 / 0.249999999812 = 3.0
# Added ratio value 3.0 to measurement 440636e5-3095-4e49-9907-837507c10eaf
# Measurement 3df2ab8a-866a-45e7-96bd-855592814654: ratio = 0.750000000188 / 0.249999999812 = 3.0
# Added ratio value 3.0 to measurement 3df2ab8a-866a-45e7-96bd-855592814654
# Measurement d8c19df8-64a0-4f16-a7c2-f23617a57484: ratio = 0.750000000188 / 0.249999999812 = 3.0
# Added ratio value 3.0 to measurement d8c19df8-64a0-4f16-a7c2-f23617a57484
# Measurement 268b4708-1e9c-41d0-9b3a-4fb13a14b8d8: ratio = 0.750000000188 / 0.249999999812 = 3.0
# Added ratio value 3.0 to measurement 268b4708-1e9c-41d0-9b3a-4fb13a14b8d8
# Measurement 64d0fe1e-8466-447a-9285-f532de1bdbe8: ratio = 0.750000000188 / 0.249999999812 = 3.0
# Added ratio value 3.0 to measurement 64d0fe1e-8466-447a-9285-f532de1bdbe8
# Measurement 134e1cf0-9f00-4d9a-a16b-74fb4df9b1fc: ratio = 0.750000000188 / 0.249999999812 = 3.0
# Added ratio value 3.0 to measurement 134e1cf0-9f00-4d9a-a16b-74fb4df9b1fc
# Measurement e94f7283-cff0-4741-8a4b-615768916aca: ratio = 0.750000000188 / 0.249999999812 = 3.0
# ...
# Measurement 98dac6c2-1776-4e85-b87b-9a40e026cb26: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 98dac6c2-1776-4e85-b87b-9a40e026cb26
# Measurement 08c7ad37-8668-426b-82f6-bbf84dc02d7c: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 08c7ad37-8668-426b-82f6-bbf84dc02d7c
# Measurement 8c132a2d-8a78-4185-a3ed-73a7440dc28d: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 8c132a2d-8a78-4185-a3ed-73a7440dc28d
# Measurement 36005d52-68ab-4cd6-b02b-23827503eecd: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 36005d52-68ab-4cd6-b02b-23827503eecd
# Measurement 9702c3dc-93cb-42a6-90cb-1859ca2fbd2c: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 9702c3dc-93cb-42a6-90cb-1859ca2fbd2c
# Measurement 8770582a-0379-4811-b3fd-49f1e86f3a82: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 8770582a-0379-4811-b3fd-49f1e86f3a82
# Measurement 6f10c2f6-7f12-4c7c-8f29-d199d9388b8a: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 6f10c2f6-7f12-4c7c-8f29-d199d9388b8a
# Measurement cb6704aa-eb03-4489-aa7d-2c26bb2c91e3: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement cb6704aa-eb03-4489-aa7d-2c26bb2c91e3
# Measurement ede43d09-8437-4792-b0da-ef5c3a772a0e: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement ede43d09-8437-4792-b0da-ef5c3a772a0e
# Measurement 9c1d6238-e5d8-44a0-9316-ce3b4f4420fa: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 9c1d6238-e5d8-44a0-9316-ce3b4f4420fa
# Measurement c544ace9-b33d-4689-9385-c61bee93aa0a: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement c544ace9-b33d-4689-9385-c61bee93aa0a
# Measurement 91829b93-47f2-46b3-ba12-3c62765973ab: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 91829b93-47f2-46b3-ba12-3c62765973ab
# Measurement a54286ab-40b1-4d99-8c4e-b3c35cf7f807: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement a54286ab-40b1-4d99-8c4e-b3c35cf7f807
# Measurement 0a88422b-a6ef-4646-8c31-9de031980ce6: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 0a88422b-a6ef-4646-8c31-9de031980ce6
# Measurement c475b98b-dc63-4e63-9879-b2c2130a1d8f: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement c475b98b-dc63-4e63-9879-b2c2130a1d8f
# Measurement 4f7c1bba-2ed4-44c2-99ed-dcf5ab5171bf: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 4f7c1bba-2ed4-44c2-99ed-dcf5ab5171bf
# Measurement e42c43a1-a87e-4dd3-9429-b500c769b2d9: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement e42c43a1-a87e-4dd3-9429-b500c769b2d9
# Measurement c7047b5b-b360-47e1-bed5-f1095f034e4c: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement c7047b5b-b360-47e1-bed5-f1095f034e4c
# Measurement 9b6b723e-5562-4e67-ba25-009b918399ee: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 9b6b723e-5562-4e67-ba25-009b918399ee
# Measurement 51f27ccf-1da1-4d21-a9b7-435f614bd1e3: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 51f27ccf-1da1-4d21-a9b7-435f614bd1e3
# Measurement c127ae95-4c4c-4f4b-9537-b31332b6f24d: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement c127ae95-4c4c-4f4b-9537-b31332b6f24d
# Measurement 4e334b9f-3b27-4b72-8caa-1a0ed9d49740: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 4e334b9f-3b27-4b72-8caa-1a0ed9d49740
# Measurement 74a37d7e-f1d9-45e7-b3fc-e9ea31dfa829: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 74a37d7e-f1d9-45e7-b3fc-e9ea31dfa829
# Measurement b61a76c2-e459-4744-ad1f-79c33c6232df: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement b61a76c2-e459-4744-ad1f-79c33c6232df
# Measurement c92ac465-c5e0-4f15-a4a0-582496d767ae: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement c92ac465-c5e0-4f15-a4a0-582496d767ae
# Measurement 0538ae8b-2ce2-4edc-b2ed-d48f4c23daf9: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 0538ae8b-2ce2-4edc-b2ed-d48f4c23daf9
# Measurement 87e4e05a-3971-4c83-a6e5-113cb51b34fb: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 87e4e05a-3971-4c83-a6e5-113cb51b34fb
# Measurement 280716aa-cf68-4f46-8b71-07b250fe27a5: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 280716aa-cf68-4f46-8b71-07b250fe27a5
# Measurement 3fec4752-7498-41ad-8a93-fcb8f661c2ef: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 3fec4752-7498-41ad-8a93-fcb8f661c2ef
# Measurement 1c6f600b-4cf1-4110-b6f0-b1986beea182: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 1c6f600b-4cf1-4110-b6f0-b1986beea182
# Measurement 0b4dbd76-d5e3-4545-8c43-8b1bbe042644: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 0b4dbd76-d5e3-4545-8c43-8b1bbe042644
# Measurement f21e4a6b-2534-4f85-be6b-be9a3aa09bd9: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement f21e4a6b-2534-4f85-be6b-be9a3aa09bd9
# Measurement 72f29e08-8bb7-4739-a7d6-70f8824f1dac: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 72f29e08-8bb7-4739-a7d6-70f8824f1dac
# Measurement 92373101-ecf9-4682-a440-be84d0e2ea26: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 92373101-ecf9-4682-a440-be84d0e2ea26
# Measurement 19fce6bb-1a27-44cb-9e79-3561dfd2f300: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 19fce6bb-1a27-44cb-9e79-3561dfd2f300
#
# --- Processing Fluid 33 ---
# Added new parameter: parameter_solvent_ratio_urea_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 5151391a-f435-4b9c-8db2-bbf4accdd8d9: ratio = 0.562373176 / 0.281186588 = 2.0
# Added ratio value 2.0 to measurement 5151391a-f435-4b9c-8db2-bbf4accdd8d9
# Measurement 3f7a2a1b-5a04-4660-ac8c-099cfcf76291: ratio = 0.562373176 / 0.281186588 = 2.0
# Added ratio value 2.0 to measurement 3f7a2a1b-5a04-4660-ac8c-099cfcf76291
# Measurement e1b88eb0-28c3-44c2-a21c-113d003447f9: ratio = 0.562373176 / 0.281186588 = 2.0
# Added ratio value 2.0 to measurement e1b88eb0-28c3-44c2-a21c-113d003447f9
# Measurement b7f12b7e-8f3b-454c-98ad-8c7b8d73b594: ratio = 0.562373176 / 0.281186588 = 2.0
# Added ratio value 2.0 to measurement b7f12b7e-8f3b-454c-98ad-8c7b8d73b594
# Measurement cdb08f04-9d91-4b86-b4ce-23a3d5b598c0: ratio = 0.562373176 / 0.281186588 = 2.0
# Added ratio value 2.0 to measurement cdb08f04-9d91-4b86-b4ce-23a3d5b598c0
# Measurement f7a134a9-6a64-4ae1-8884-6b03f023089b: ratio = 0.562373176 / 0.281186588 = 2.0
# Added ratio value 2.0 to measurement f7a134a9-6a64-4ae1-8884-6b03f023089b
# Measurement 094f4dc5-5db0-4570-b4ae-ae4f63c776dd: ratio = 0.562373176 / 0.281186588 = 2.0
# Added ratio value 2.0 to measurement 094f4dc5-5db0-4570-b4ae-ae4f63c776dd
# Measurement 7c7ae325-ab07-4f4b-b27b-255908b3ab25: ratio = 0.562373176 / 0.281186588 = 2.0
# Added ratio value 2.0 to measurement 7c7ae325-ab07-4f4b-b27b-255908b3ab25
# Measurement a10a8c9c-a493-45c7-b2fc-ffbda2757908: ratio = 0.562373176 / 0.281186588 = 2.0
# Added ratio value 2.0 to measurement a10a8c9c-a493-45c7-b2fc-ffbda2757908
# Measurement a3c25853-e035-4462-a1c1-50ff7481ad1f: ratio = 0.562373176 / 0.281186588 = 2.0
# Added ratio value 2.0 to measurement a3c25853-e035-4462-a1c1-50ff7481ad1f
#
# --- Processing Fluid 34 ---
# Added new parameter: parameter_solvent_ratio_urea_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 5a148a0c-ea29-489b-9111-f0531b545da3: ratio = 0.222313709333 / 0.111156854667 = 2.0
# Added ratio value 2.0 to measurement 5a148a0c-ea29-489b-9111-f0531b545da3
#
# --- Processing Fluid 35 ---
# Added new parameter: parameter_solvent_ratio_urea_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 9b1a3b3f-9192-4425-aea5-749fc55e407f: ratio = 0.035108250667 / 0.017554125333 = 2.0
# Added ratio value 2.0 to measurement 9b1a3b3f-9192-4425-aea5-749fc55e407f
#
# --- Processing Fluid 36 ---
# Added new parameter: parameter_solvent_ratio_urea_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement a06e6842-deb5-4dfa-86f9-708901288c46: ratio = 0.650095585333 / 0.325047792667 = 2.0
# Added ratio value 2.0 to measurement a06e6842-deb5-4dfa-86f9-708901288c46
#
# --- Processing Fluid 37 ---
# Added new parameter: parameter_solvent_ratio_urea_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 445d92d2-ba4e-4033-8783-87ac736a4379: ratio = 0.63389538 / 0.31694769 = 2.0
# Added ratio value 2.0 to measurement 445d92d2-ba4e-4033-8783-87ac736a4379
#
# --- Processing Fluid 38 ---
# Added new parameter: parameter_solvent_ratio_urea_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement e519360e-2893-47f4-9976-5ec38a59878b: ratio = 0.589895344 / 0.294947672 = 2.0
# Added ratio value 2.0 to measurement e519360e-2893-47f4-9976-5ec38a59878b
#
# --- Processing Fluid 39 ---
# Added new parameter: parameter_solvent_ratio_urea_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 4f51527e-f8b0-45ad-8496-187da0141b62: ratio = 0.526311321333 / 0.263155660667 = 2.0
# Added ratio value 2.0 to measurement 4f51527e-f8b0-45ad-8496-187da0141b62
#
# --- Processing Fluid 40 ---
# Added new parameter: parameter_solvent_ratio_urea_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 4e0f9388-3e49-42c2-80db-6a1dec398a62: ratio = 0.472477279333 / 0.236238639667 = 2.0
# Added ratio value 2.0 to measurement 4e0f9388-3e49-42c2-80db-6a1dec398a62
#
# --- Processing Fluid 41 ---
# Added new parameter: parameter_solvent_ratio_urea_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 6f479e89-0452-4bc6-9f08-0cf0cbc349df: ratio = 0.426765982 / 0.213382991 = 2.0
# Added ratio value 2.0 to measurement 6f479e89-0452-4bc6-9f08-0cf0cbc349df
#
# --- Processing Fluid 42 ---
# Added new parameter: parameter_solvent_ratio_urea_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement d1ef5ed9-40d3-4799-9814-413028d00eb7: ratio = 0.352629193333 / 0.176314596667 = 2.0
# Added ratio value 2.0 to measurement d1ef5ed9-40d3-4799-9814-413028d00eb7
#
# --- Processing Fluid 43 ---
# Added new parameter: parameter_solvent_ratio_urea_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 2fec9fc8-05f3-4db1-ae58-616b17caaeca: ratio = 0.294726726 / 0.147363363 = 2.0
# Added ratio value 2.0 to measurement 2fec9fc8-05f3-4db1-ae58-616b17caaeca
#
# --- Processing Fluid 44 ---
# Added new parameter: parameter_solvent_ratio_urea_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement f08212a7-1979-4419-b561-618ea7a56f19: ratio = 0.593333333333 / 0.296666666667 = 2.0
# Added ratio value 2.0 to measurement f08212a7-1979-4419-b561-618ea7a56f19
#
# --- Processing Fluid 45 ---
# Added new parameter: parameter_solvent_ratio_urea_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement fa8b3b69-48ab-45e8-91e7-a870c2218b82: ratio = 0.533333333333 / 0.266666666667 = 2.0
# Added ratio value 2.0 to measurement fa8b3b69-48ab-45e8-91e7-a870c2218b82
# Measurement 98bc9572-cf74-42ec-82d3-d55cdd0549d2: ratio = 0.533333333333 / 0.266666666667 = 2.0
# Added ratio value 2.0 to measurement 98bc9572-cf74-42ec-82d3-d55cdd0549d2
# Measurement 8737ff77-cc52-4f4b-8637-8f5e68717f9d: ratio = 0.533333333333 / 0.266666666667 = 2.0
# Added ratio value 2.0 to measurement 8737ff77-cc52-4f4b-8637-8f5e68717f9d
# Measurement 1383a78a-1edf-46df-81d6-1ec4f58eeb93: ratio = 0.533333333333 / 0.266666666667 = 2.0
# Added ratio value 2.0 to measurement 1383a78a-1edf-46df-81d6-1ec4f58eeb93
#
# --- Processing Fluid 46 ---
# Added new parameter: parameter_solvent_ratio_urea_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 8bee5f9f-fb8e-4be7-8c12-89c3efc8704a: ratio = 0.48 / 0.24 = 2.0
# Added ratio value 2.0 to measurement 8bee5f9f-fb8e-4be7-8c12-89c3efc8704a
#
# --- Processing Fluid 47 ---
# Added new parameter: parameter_solvent_ratio_urea_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement a75bacd2-7e04-49d0-9068-8aa85b40d3e5: ratio = 0.44 / 0.22 = 2.0
# Added ratio value 2.0 to measurement a75bacd2-7e04-49d0-9068-8aa85b40d3e5
#
# --- Processing Fluid 48 ---
# Added new parameter: parameter_solvent_ratio_urea_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 5e368fe1-dab3-44bc-9ea4-d90d7be322e0: ratio = 0.326666666667 / 0.163333333333 = 2.0
# Added ratio value 2.0 to measurement 5e368fe1-dab3-44bc-9ea4-d90d7be322e0
#
# --- Processing Fluid 49 ---
# Added new parameter: parameter_solvent_ratio_urea_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement af867458-9000-44c3-9237-f2664f3cbb85: ratio = 0.166666666667 / 0.083333333333 = 2.0
# Added ratio value 2.0 to measurement af867458-9000-44c3-9237-f2664f3cbb85
# Measurement 0131c84b-4f75-47da-94f1-f9527d603a20: ratio = 0.166666666667 / 0.083333333333 = 2.0
# Added ratio value 2.0 to measurement 0131c84b-4f75-47da-94f1-f9527d603a20
# Measurement d8443786-aa25-43e2-bdf7-c9c849d7c1e5: ratio = 0.166666666667 / 0.083333333333 = 2.0
# Added ratio value 2.0 to measurement d8443786-aa25-43e2-bdf7-c9c849d7c1e5
#
# --- Processing Fluid 50 ---
# Added new parameter: parameter_solvent_ratio_urea_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 865274ab-568c-463c-9f6c-11f015891a69: ratio = 0.206666666667 / 0.103333333333 = 2.0
# Added ratio value 2.0 to measurement 865274ab-568c-463c-9f6c-11f015891a69
# Measurement 5613e993-637a-4906-b74b-f8b50550235d: ratio = 0.206666666667 / 0.103333333333 = 2.0
# Added ratio value 2.0 to measurement 5613e993-637a-4906-b74b-f8b50550235d
# Measurement af2290e3-9210-4510-9154-459816ccd6ff: ratio = 0.206666666667 / 0.103333333333 = 2.0
# Added ratio value 2.0 to measurement af2290e3-9210-4510-9154-459816ccd6ff
#
# --- Processing Fluid 51 ---
# Added new parameter: parameter_solvent_ratio_urea_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 5410eb84-e9d9-40f6-bb7c-0b80c7def9cd: ratio = 0.38 / 0.19 = 2.0
# Added ratio value 2.0 to measurement 5410eb84-e9d9-40f6-bb7c-0b80c7def9cd
# Measurement 1b2feac6-0cc3-495e-ae0e-a0e3249803e3: ratio = 0.38 / 0.19 = 2.0
# Added ratio value 2.0 to measurement 1b2feac6-0cc3-495e-ae0e-a0e3249803e3
# Measurement 754049d4-509f-41e4-b22c-f52faf069457: ratio = 0.38 / 0.19 = 2.0
# Added ratio value 2.0 to measurement 754049d4-509f-41e4-b22c-f52faf069457
#
# --- Processing Fluid 52 ---
# Added new parameter: parameter_solvent_ratio_urea_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 70e7543f-58be-4bde-8bee-6ae89100a5a1: ratio = 0.613333333333 / 0.306666666667 = 2.0
# Added ratio value 2.0 to measurement 70e7543f-58be-4bde-8bee-6ae89100a5a1
# Measurement 8f2c3533-503d-4c5a-b863-c71508ef06d9: ratio = 0.613333333333 / 0.306666666667 = 2.0
# Added ratio value 2.0 to measurement 8f2c3533-503d-4c5a-b863-c71508ef06d9
# Measurement 6cb59ded-2dbb-42bc-ab86-fe1b8764f5e2: ratio = 0.613333333333 / 0.306666666667 = 2.0
# Added ratio value 2.0 to measurement 6cb59ded-2dbb-42bc-ab86-fe1b8764f5e2
# === Solvent Ratio Calculation Complete ===
#
# 📁 Output saved to: /home/sga/Code/FAIRFluids/Workflows/outputs/Xu_Glycerol_Water.json

# %%
# Import der wiederverwendbaren Plot-Speicherfunktion
from fairfluids.core.plot_utils import save_plot_as_svg

# Die Funktion save_plot_as_svg() kann jetzt in allen Zellen verwendet werden
# Sie speichert automatisch Plots als SVG-Dateien im Verzeichnis 'image_output'
# und verwendet den Plot-Titel als Dateinamen (mit eindeutigem Zähler)

# %%
df_data_glyceline = extract_fairfluids_data(doc)

# Compute mole_fraction_water column for use in filtering
df_data_glyceline = df_data_glyceline.copy()
df_data_glyceline["mole_fraction_water"] = df_data_glyceline["mole_fractions"].apply(
    lambda mf: mf[-1] if isinstance(mf, (list, tuple)) and len(mf) > 0 else float('nan')
)

# Ensure mole_fraction_water is 1.0 when [Water] is the only component
def get_water_mole_fraction(row):
    """Get the mole fraction of water from fluid_compounds and mole_fractions."""
    if not isinstance(row["fluid_compounds"], list) or not isinstance(row["mole_fractions"], (list, tuple)):
        return 0.0
    
    # Find the position of water in fluid_compounds
    water_position = -1
    for i, compound in enumerate(row["fluid_compounds"]):
        if isinstance(compound, str) and compound.lower() in ['water', 'h2o']:
            water_position = i
            break
    
    # If water is found and mole_fractions has enough elements, return the mole fraction
    if water_position >= 0 and len(row["mole_fractions"]) > water_position:
        return row["mole_fractions"][water_position]
    else:
        return 0.0

df_data_glyceline["mole_fraction_water"] = df_data_glyceline.apply(get_water_mole_fraction, axis=1)

# Apply 0 to mole_fraction_water if only cholinechloride and glycerol is present in fluid_compounds
df_data_glyceline.loc[
    (df_data_glyceline["fluid_compounds"].apply(
        lambda comps: isinstance(comps, list)
        and len(comps) == 2
        and set(comps) == set(["Choline Chloride", "Glycerol"])
    )),
    "mole_fraction_water"
] = 0.0

# Additional dataframe for just [Choline Chloride, Glycerol]
df_reline_just_cc_gly = df_data_glyceline[
    df_data_glyceline["fluid_compounds"].apply(
        lambda comps: isinstance(comps, list)
        and len(comps) == 2
        and set(comps) == set(["Choline Chloride", "Glycerol"])
    )
]

# Filter for ratio == 2 OR (molefractions has water == 1)
df_data_glyceline_ratio_or_pure_water = df_data_glyceline[
    (df_data_glyceline["Solvent: Amount ratio of component to other component of binary solvent"] == 2)
    | (df_data_glyceline["mole_fraction_water"] == 1.0)
    | (df_data_glyceline["mole_fraction_water"] == 0.0)  # include the newly set 0.0 rows
]

# Sort by the water mole fraction, descending
df_data_glyceline_ratio_or_pure_water = df_data_glyceline_ratio_or_pure_water.sort_values(
    by="mole_fraction_water", ascending=False
)
df_data_glyceline_ratio_or_pure_water
#df_reline_just_cc_gly
# Save the dataframe as Excel to home directory
import os
excel_output_path = os.path.expanduser("~/df_data_glyceline_ratio_or_pure_water.xlsx")
df_data_glyceline_ratio_or_pure_water.to_excel(excel_output_path, index=False)
print(f"Saved dataframe to {excel_output_path}")
# Out:
# Saved dataframe to /home/sga/df_data_glyceline_ratio_or_pure_water.xlsx

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Make sure required columns exist
required_cols = ["viscosity_value", "temperature", "source_doi", "mole_fraction_water"]
for col in required_cols:
    if col not in df_data_glyceline_ratio_or_pure_water.columns:
        raise ValueError(f"Column '{col}' not found in dataframe.")

# Filter out rows with missing data
plot_df = df_data_glyceline_ratio_or_pure_water[df_data_glyceline_ratio_or_pure_water["viscosity_value"].notnull() & df_data_glyceline_ratio_or_pure_water["temperature"].notnull() & df_data_glyceline_ratio_or_pure_water["source_doi"].notnull()]

# Calculate ln(viscosity) and 1/RT (Kelvin)
# Use R = 8.314 J/(mol*K), but since it's unitless vs. 1/K, you can leave as 1/T or explicitly use 1/(R*T)
R = 8.314 # J/(mol*K)
plot_df = plot_df.copy()
plot_df["inv_RT"] = 1000 / (R * plot_df["temperature"].astype(float))
plot_df["ln_viscosity"] = np.log(plot_df["viscosity_value"].astype(float))

plt.figure(figsize=(11, 7))
sns.scatterplot(
    data=plot_df,
    x="inv_RT",
    y="ln_viscosity",
    hue="source_doi",
    palette='tab20',
    s=80,
    edgecolor='gray'
)
plt.title(r'Plot of ln($\eta$) vs (RT)$^{-1}$, Grouped by DOI')
plt.xlabel(r'(RT)$^{-1}$ / mol kJ$^{-1}$')
plt.ylabel(r'ln($\eta$ / $Pa \cdot s$)')
plt.legend(title="DOI", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
save_plot_as_svg()
plt.show()
# Out:
# ✓ Plot gespeichert: image_output/Plot_of_ln_vs_RT_Grouped_by_DOI_14.svg (120,500 Bytes)

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import cm
from scipy.stats import linregress

# Make sure required columns exist
required_cols = ["viscosity_value", "temperature", "source_doi", "mole_fraction_water"]
for col in required_cols:
    if col not in df_data_glyceline_ratio_or_pure_water.columns:
        raise ValueError(f"Column '{col}' not found in dataframe.")

# Fill missing/None values in mole_fraction_water with 0
df_data_glyceline_ratio_or_pure_water = df_data_glyceline_ratio_or_pure_water.copy()
df_data_glyceline_ratio_or_pure_water["mole_fraction_water"] = (
    df_data_glyceline_ratio_or_pure_water["mole_fraction_water"]
    .fillna(0)
    .apply(lambda x: 0 if x is None else x)
)

# Filter out rows with missing data
plot_df = df_data_glyceline_ratio_or_pure_water[
    df_data_glyceline_ratio_or_pure_water["viscosity_value"].notnull() &
    df_data_glyceline_ratio_or_pure_water["temperature"].notnull() &
    df_data_glyceline_ratio_or_pure_water["source_doi"].notnull()
].copy()

# Calculate ln(viscosity) and 1/(R*T)
R = 8.314  # J/(mol*K)
plot_df["inv_RT"] = 1000 / (R * plot_df["temperature"].astype(float))
plot_df["ln_viscosity"] = np.log(plot_df["viscosity_value"].astype(float))

# Use mole_fraction_water to color the water amount
plot_df["water_mole_fraction"] = plot_df["mole_fraction_water"].astype(float)

# We'll use unique discrete values for water mole fraction as hue
plot_df["water_mole_fraction_rounded"] = plot_df["water_mole_fraction"].round(3)
discrete_mole_fractions = np.sort(plot_df["water_mole_fraction_rounded"].unique())

# Set up colormap: Blues colormap, N bins = number of unique mole fractions
N = len(discrete_mole_fractions)
cmap = cm.get_cmap('Blues', N)
color_dict = {mf: cmap(i) for i, mf in enumerate(discrete_mole_fractions)}

plt.figure(figsize=(11,8))
ax = plt.gca()

# Scatter points for each discrete fraction, so legend can be discrete
for i, mf in enumerate(discrete_mole_fractions):
    subset = plot_df[plot_df["water_mole_fraction_rounded"] == mf]
    ax.scatter(
        subset["inv_RT"], 
        subset["ln_viscosity"], 
        color=color_dict[mf],
        s=30, 
        edgecolor='black',
        linewidth=0.2,
        label=f"{mf:.3f}"
    )

# Linear fit and store slopes per discrete water content
slope_results = []
for mf in discrete_mole_fractions:
    group = plot_df[plot_df["water_mole_fraction_rounded"] == mf]
    if len(group) >= 2:
        x = group["inv_RT"].values
        y = group["ln_viscosity"].values
        slope, intercept, r_value, p_value, std_err = linregress(x, y)
        xfit = np.linspace(x.min(), x.max(), 50)
        yfit = intercept + slope * xfit
        # Optional: plot the fits in same color, commented out for clarity
        # ax.plot(xfit, yfit, linestyle='--', linewidth=2, color=color_dict[mf])
        mf_tuple = tuple(group["mole_fractions"].iloc[0]) if "mole_fractions" in group.columns and isinstance(group["mole_fractions"].iloc[0], (list, tuple)) else group["mole_fractions"].iloc[0] if "mole_fractions" in group.columns else None
        slope_results.append({
            "mole_fractions": mf_tuple,
            "water_mole_fraction": float(mf),
            "slope": slope
        })

# Make discrete legend
handles, labels = ax.get_legend_handles_labels()
by_label = dict(zip(labels, handles))
lgd = ax.legend(by_label.values(), by_label.keys(), title="Water mole fraction", bbox_to_anchor=(1.04, 1), loc='upper left', borderaxespad=0.)

plt.title(r'Plot of ln($\eta$) vs 1/(R*T), Grouped by water mole fraction')
plt.xlabel(r'R$ \cdot$ T$^{-1}$ / mol kJ$^{-1}$')
plt.ylabel(r'ln($\eta$ / $Pa \cdot s$)')
plt.tight_layout()
save_plot_as_svg()
plt.show()

import pandas as pd
activation_energy_df = pd.DataFrame(slope_results)
activation_energy_df = activation_energy_df.rename(columns={'slope': 'activation_energy'})
print("All linear fit activation energies by water mole fraction:")
display(activation_energy_df[["water_mole_fraction", "activation_energy"]])
# Out:
# /tmp/ipykernel_13941/2964956621.py:41: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('Blues', N)
# ✓ Plot gespeichert: image_output/Plot_of_ln_vs_1RT_Grouped_by_water_mole_fraction_15.svg (115,375 Bytes)
# All linear fit activation energies by water mole fraction:
#     water_mole_fraction  activation_energy
# 0                 0.000          44.435182
# 1                 0.100          39.132853
# 2                 0.108          40.366403
# 3                 0.156          38.285661
# 4                 0.238          37.590289
# 5                 0.250          29.986001
# 6                 0.254          41.597359
# 7                 0.342          34.740694
# 8                 0.400          31.063405
# 9                 0.402          33.526415
# 10                0.500          26.200012
# 11                0.598          28.874286
# 12                0.720          24.938581
# 13                0.750          22.789299
# 14                0.800          22.366546
# 15                0.857          18.893528
# 16                0.900          16.528942
# 17                0.901          17.207759
# 18                0.934          16.013872
# 19                0.960          15.546665
# 20                0.982          14.912522
# 21                1.000          13.962867

# %%
import matplotlib.pyplot as plt
import numpy as np

# Remove the gray background globally
plt.style.use('default')

fig, ax = plt.subplots(figsize=(10, 6))

# Calculate inv_RT and ln_viscosity if not already present, use correct dataframe columns
if "inv_RT" not in df_reline_just_cc_gly.columns or "ln_viscosity" not in df_reline_just_cc_gly.columns:
    R = 8.314462618  # J/(mol*K)
    df_reline_just_cc_gly = df_reline_just_cc_gly.copy()
    df_reline_just_cc_gly["inv_RT"] = 1 / (R * df_reline_just_cc_gly["temperature"])
    # Defensive: Make sure viscosity_value column is numeric and positive
    viscosity_numeric = pd.to_numeric(df_reline_just_cc_gly["viscosity_value"], errors='coerce')
    # Replace/mark as NaN any infeasible values (<=0 or failed conversion)
    bad_mask = (viscosity_numeric.isna()) | (viscosity_numeric <= 0)
    if bad_mask.any():
        print(f"Warning: {bad_mask.sum()} rows in viscosity_value are NaN, <=0, or invalid. These will be skipped for ln(viscosity).")
    ln_viscosity = np.full_like(viscosity_numeric, np.nan, dtype=np.float64)
    ln_viscosity[~bad_mask] = np.log(viscosity_numeric[~bad_mask])
    df_reline_just_cc_gly["ln_viscosity"] = ln_viscosity

# Use different marker shapes for different "Solvent: Amount ratio of component to other component of binary solvent"
if "glycerol_cholinechloride" in df_reline_just_cc_gly.columns:
    ratio_col = "glycerol_cholinechloride"
elif "Solvent: Amount ratio of component to other component of binary solvent" in df_reline_just_cc_gly.columns:
    ratio_col = "Solvent: Amount ratio of component to other component of binary solvent"
else:
    ratio_col = None

if ratio_col is not None:
    unique_ratios = df_reline_just_cc_gly[ratio_col].dropna().unique()
    ratios_sorted = np.sort(unique_ratios)
    # Common matplotlib marker styles, enough for up to 8 unique ratios
    markers = ['o', 's', 'D', '^', 'v', '<', '>', 'P', '*', 'X', 'h', 'H']
    marker_styles = {ratio: markers[i % len(markers)] for i, ratio in enumerate(ratios_sorted)}
else:
    marker_styles = None

# Get unique DOIs and assign colors
dois = df_reline_just_cc_gly["source_doi"].unique()
colors = plt.cm.Set2.colors
color_map = {doi: colors[i % len(colors)] for i, doi in enumerate(dois)}

legend_handles = []
for doi in dois:
    doi_subset = df_reline_just_cc_gly[
        (df_reline_just_cc_gly["source_doi"] == doi)
        & (~df_reline_just_cc_gly["inv_RT"].isna())
        & (~df_reline_just_cc_gly["ln_viscosity"].isna())
    ]
    if marker_styles is not None and ratio_col is not None:
        for ratio in sorted(marker_styles.keys()):
            subset = doi_subset[doi_subset[ratio_col] == ratio]
            if subset.empty:
                continue
            handle = ax.scatter(
                subset["inv_RT"],
                subset["ln_viscosity"],
                label=f"{doi}\nratio={ratio}",
                marker=marker_styles[ratio],
                color=color_map[doi],
                s=55,
                edgecolor='black',
                linewidth=0.8,
            )
            # Collect one handle per ratio:doi for custom legend
            legend_handles.append((f"{doi} | ratio={ratio}", handle))
    else:
        subset = doi_subset
        handle = ax.scatter(
            subset["inv_RT"],
            subset["ln_viscosity"],
            label=doi,
            color=color_map[doi],
            s=20,
            edgecolor='black',
            linewidth=0.1
        )
        legend_handles.append((doi, handle))

ax.set_xlabel('1/(R*T) [mol/J]')
ax.set_ylabel('ln(viscosity)')

# Remove default axes and legend background
ax.set_facecolor('white')
fig.patch.set_facecolor('white')

# Custom legend: show one per DOI+ratio combination if marker_styles exist
from matplotlib.patches import Patch
from matplotlib.legend_handler import HandlerTuple

if marker_styles is not None:
    unique_labels = {}
    for lbl, h in legend_handles:
        if lbl not in unique_labels:
            unique_labels[lbl] = h
    leg = ax.legend(unique_labels.values(), unique_labels.keys(), title='DOI | ratio', bbox_to_anchor=(1.04, 1), loc='upper left', frameon=False)
else:
    leg = ax.legend(title='DOI', bbox_to_anchor=(1.04, 1), loc='upper left', frameon=False)

ax.set_title('Plot of ln(viscosity) vs 1/(R*T),\ncolors by DOI, marker by solvent ratio')
plt.tight_layout()
save_plot_as_svg()
plt.show()
# Out:
# Warning: 239 rows in viscosity_value are NaN, <=0, or invalid. These will be skipped for ln(viscosity).
# ✓ Plot gespeichert: image_output/Plot_of_lnviscosity_vs_1RT_colors_by_DOI_marker_by_16.svg (114,258 Bytes)

# %%
# Calculate activation energies for each DOI and each ratio exactly as in cell 72-96 (see file_context_0)
from scipy.stats import linregress

activation_energy_results = []
for mf in [0]:  # This dataset is for pure reline (no water), so mole fraction is always 0
    group = df_reline_just_cc_gly  # All of this DF has water_mole_fraction = 0
    # For each unique source_doi in this water content, do a fit for that subset
    for doi in group["source_doi"].unique():
        doi_group = group[group["source_doi"] == doi]
        # Find proper ratio column
        if "glycerol_cholinechloride" in doi_group.columns:
            ratio_col = "glycerol_cholinechloride"
        elif "Solvent: Amount ratio of component to other component of binary solvent" in doi_group.columns:
            ratio_col = "Solvent: Amount ratio of component to other component of binary solvent"
        else:
            ratio_col = None

        # Work as in (72-96): group by ratio (if exists) or just DOI
        if ratio_col is not None:
            for ratio in sorted(doi_group[ratio_col].dropna().unique()):
                if ratio == 2:
                    continue  # Skip those with molar_ratio == 2
                sub2 = doi_group[
                    (doi_group[ratio_col] == ratio)
                    & (~doi_group["inv_RT"].isna())
                    & (~doi_group["ln_viscosity"].isna())
                ]
                if len(sub2) >= 2:
                    x = sub2["inv_RT"].values
                    y = sub2["ln_viscosity"].values
                    slope, intercept, r_value, p_value, std_err = linregress(x, y)
                    activation_energy_results.append({
                        "water_mole_fraction": float(mf),
                        "activation_energy": abs(slope),
                        "source_doi": doi,
                        "ordinate": intercept,
                        "statistic": r_value,
                        "molar_ratio": ratio,
                    })
        else:
            sub2 = doi_group[
                (~doi_group["inv_RT"].isna())
                & (~doi_group["ln_viscosity"].isna())
            ]
            if len(sub2) >= 2:
                x = sub2["inv_RT"].values
                y = sub2["ln_viscosity"].values
                slope, intercept, r_value, p_value, std_err = linregress(x, y)
                activation_energy_results.append({
                    "water_mole_fraction": float(mf),
                    "activation_energy": abs(slope),
                    "source_doi": doi,
                    "ordinate": intercept,
                    "statistic": r_value,
                    "molar_ratio": None,
                })

activation_energies_pure = pd.DataFrame(activation_energy_results)
display(activation_energies_pure)
# Out:
#    water_mole_fraction  activation_energy          source_doi   ordinate  \
# 0                  0.0       45502.133942  10.1039/c0gc00395f -19.587819
# 1                  0.0       47045.892294  10.1039/c0gc00395f -20.124261
# 2                  0.0       48304.321208  10.1039/c0gc00395f -20.543573
# 3                  0.0       50296.423067  10.1039/c0gc00395f -21.256798
# 4                  0.0       53401.786797  10.1039/c0gc00395f -22.208433
# 5                  0.0       54772.293625  10.1039/c0gc00395f -22.513597
#
#    statistic  molar_ratio
# 0   0.999903          2.3
# 1   0.999625          3.0
# 2   0.997493          4.0
# 3   0.999803          5.7
# 4   0.999157          9.0
# 5   0.999573         19.0

# %%
# Plot ln(viscosity/1000) vs 1/(R*T) but only for "Solvent: Amount ratio of component to other component of binary solvent" == 2
# with no grey background (no 'ggplot' style)

# Remove previous style settings to avoid grey background
plt.style.use('default')

ratio_of_interest = 2

if "glycerol_cholinechloride" in df_reline_just_cc_gly.columns:
    ratio_col_plot2 = "glycerol_cholinechloride"
elif "Solvent: Amount ratio of component to other component of binary solvent" in df_reline_just_cc_gly.columns:
    ratio_col_plot2 = "Solvent: Amount ratio of component to other component of binary solvent"
else:
    ratio_col_plot2 = None

if ratio_col_plot2 is not None:
    filtered_df = df_reline_just_cc_gly[df_reline_just_cc_gly[ratio_col_plot2] == ratio_of_interest].copy()
else:
    filtered_df = df_reline_just_cc_gly.copy()  # fallback: plot all

# Check if 'viscosity' column exists, if not use 'property_value'
if 'viscosity' in filtered_df.columns:
    viscosity_col = 'viscosity'
elif 'property_value' in filtered_df.columns:
    viscosity_col = 'property_value'
else:
    print("Error: Neither 'viscosity' nor 'property_value' column found in the dataframe")
    print("Available columns:", filtered_df.columns.tolist())
    viscosity_col = None

if viscosity_col is not None:
    # Calculate ln(viscosity/1000) for the filtered data
    filtered_df["ln_viscosity_scaled"] = np.log(filtered_df[viscosity_col] / 1000)

    fig2, ax2 = plt.subplots(figsize=(10, 6))

    # Set background to white explicitly
    fig2.patch.set_facecolor('white')
    ax2.set_facecolor('white')

    # Colors by DOI
    dois2 = filtered_df["source_doi"].unique()
    colors2 = plt.cm.Paired.colors
    color_map2 = {doi: colors2[i % len(colors2)] for i, doi in enumerate(dois2)}

    for doi in dois2:
        subset2 = filtered_df[
            (filtered_df["source_doi"] == doi)
            & (~filtered_df["inv_RT"].isna())
            & (~filtered_df["ln_viscosity_scaled"].isna())
        ]
        if subset2.empty:
            continue
        ax2.scatter(
            subset2["inv_RT"],
            subset2["ln_viscosity_scaled"],
            label=doi,
            color=color_map2[doi],
            s=60,
            edgecolor='black',
            linewidth=0.2
        )

    ax2.set_xlabel('$R \cdot T^{-1}$ / mol J$^{-1}$', fontsize=14)
    ax2.set_ylabel('ln(Aₛ) / ln(Pa*s)', fontsize=14)
    ax2.set_title(f"Arrhenius plot of Glyceline (Component ratio 1:{ratio_of_interest})", fontsize=16)

    # Increase tick label font size
    ax2.tick_params(axis='both', which='major', labelsize=12)

    # Create secondary x-axis for temperature
    ax2_temp = ax2.twiny()

    # Get the current x-axis limits
    x_min, x_max = ax2.get_xlim()

    # Convert 1/(R*T) to temperature (K)
    R = 8.314462618  # J/mol/K
    T_min = 1 / (R * x_max)  # Higher 1/(R*T) corresponds to lower temperature
    T_max = 1 / (R * x_min)  # Lower 1/(R*T) corresponds to higher temperature

    # Set temperature axis limits and ticks
    ax2_temp.set_xlim(T_max, T_min)
    temp_ticks = np.linspace(T_max, T_min, 6)
    ax2_temp.set_xticks(temp_ticks)
    ax2_temp.set_xticklabels([f'{T:.0f}' for T in temp_ticks])
    ax2_temp.set_xlabel('Temperature [K]', fontsize=14)
    ax2_temp.tick_params(axis='x', which='major', labelsize=12)

    # Make legend background white and non-fancy with increased font size
    legend = ax2.legend(title='DOI', bbox_to_anchor=(1.04, 1), loc='upper left', frameon=True, fancybox=False, fontsize=12)
    if legend is not None:
        legend.get_frame().set_facecolor('white')
        legend.get_frame().set_edgecolor('black')
        legend.get_title().set_fontsize(14)

    plt.tight_layout()
    save_plot_as_svg()
    plt.show()
# Out:
# <>:64: SyntaxWarning: invalid escape sequence '\c'
# <>:64: SyntaxWarning: invalid escape sequence '\c'
# /tmp/ipykernel_13941/580043810.py:64: SyntaxWarning: invalid escape sequence '\c'
#   ax2.set_xlabel('$R \cdot T^{-1}$ / mol J$^{-1}$', fontsize=14)
# ✓ Plot gespeichert: image_output/Arrhenius_plot_of_Glyceline_Component_ratio_12_17.svg (98,442 Bytes)

# %%
# Plot filtered_df grouped by DOI, splitting temperature points into low and high temperature groups
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Create figure and axis
fig, ax = plt.subplots(figsize=(12, 8))

# Get unique DOIs
dois = filtered_df['source_doi'].unique()

# Color map for DOIs
colors = plt.cm.tab10(np.linspace(0, 1, len(dois)))
color_map = dict(zip(dois, colors))

# List to store all split data
split_data = []

# Get overall x-axis range for extending lines
all_inv_RT = filtered_df[~filtered_df["inv_RT"].isna()]["inv_RT"]
x_range_min = all_inv_RT.min() * 0.95
x_range_max = all_inv_RT.max() * 1.05

# Process each DOI
for i, doi in enumerate(dois):
    subset = filtered_df[
        (filtered_df["source_doi"] == doi)
        & (~filtered_df["inv_RT"].isna())
        & (~filtered_df["ln_viscosity"].isna())
    ]
    
    if len(subset) < 2:
        continue  # Skip if not enough points
    
    # Sort by temperature (inverse of inv_RT for proper ordering)
    subset_sorted = subset.sort_values('inv_RT')
    
    # Split into two halves based on temperature
    n_points = len(subset_sorted)
    mid_point = n_points // 2
    
    # Lower half (higher temperatures - lower inv_RT values)
    low_temp_group = subset_sorted.iloc[:mid_point].copy()
    low_temp_group['temperature_group'] = 'High T'
    
    # Upper half (lower temperatures - higher inv_RT values)  
    high_temp_group = subset_sorted.iloc[mid_point:].copy()
    high_temp_group['temperature_group'] = 'Low T'
    
    # Add to split_data list
    split_data.append(low_temp_group)
    split_data.append(high_temp_group)
    
    # Plot low temperature group (circles)
    if len(low_temp_group) > 0:
        ax.scatter(
            low_temp_group["inv_RT"],
            low_temp_group["ln_viscosity"],
            label=f'{doi} (High T)',
            color=color_map[doi],
            marker='o',
            s=80,
            alpha=0.7,
            edgecolor='black',
            linewidth=0.5
        )
        
        # Fit and plot extended Arrhenius line for high temperature group
        if len(low_temp_group) >= 2:
            x_high = low_temp_group["inv_RT"].values
            y_high = low_temp_group["ln_viscosity"].values
            slope_high, intercept_high = np.polyfit(x_high, y_high, 1)
            
            # Create extended line points for plotting
            x_line_high = np.linspace(x_range_min, x_range_max, 100)
            y_line_high = slope_high * x_line_high + intercept_high
            
            ax.plot(x_line_high, y_line_high, color=color_map[doi], 
                   linestyle='-', alpha=0.8, linewidth=2)
    
    # Plot high temperature group (squares)
    if len(high_temp_group) > 0:
        ax.scatter(
            high_temp_group["inv_RT"],
            high_temp_group["ln_viscosity"],
            label=f'{doi} (Low T)',
            color=color_map[doi],
            marker='s',
            s=80,
            alpha=0.7,
            edgecolor='black',
            linewidth=0.5
        )
        
        # Fit and plot extended Arrhenius line for low temperature group
        if len(high_temp_group) >= 2:
            x_low = high_temp_group["inv_RT"].values
            y_low = high_temp_group["ln_viscosity"].values
            slope_low, intercept_low = np.polyfit(x_low, y_low, 1)
            
            # Create extended line points for plotting
            x_line_low = np.linspace(x_range_min, x_range_max, 100)
            y_line_low = slope_low * x_line_low + intercept_low
            
            ax.plot(x_line_low, y_line_low, color=color_map[doi], 
                   linestyle='--', alpha=0.8, linewidth=2)
    
    # Plot extended full range Arrhenius line
    if len(subset_sorted) >= 2:
        x_full = subset_sorted["inv_RT"].values
        y_full = subset_sorted["ln_viscosity"].values
        slope_full, intercept_full = np.polyfit(x_full, y_full, 1)
        
        # Create extended line points for plotting
        x_line_full = np.linspace(x_range_min, x_range_max, 100)
        y_line_full = slope_full * x_line_full + intercept_full
        
        ax.plot(x_line_full, y_line_full, color=color_map[doi], 
               linestyle=':', alpha=0.6, linewidth=3)

# Set labels and title
ax.set_xlabel('$R \cdot T^{-1}$ / mol J$^{-1}$', fontsize=14)
ax.set_ylabel('ln(Aₛ) / ln(Pa*s)', fontsize=14)
ax.set_title('Arrhenius Plot: Temperature Groups by DOI (Glyceline, ratio 1:2)', fontsize=16)

# Increase tick label font size
ax.tick_params(axis='both', which='major', labelsize=12)

# Create secondary x-axis for temperature
ax_temp = ax.twiny()

# Get the current x-axis limits
x_min, x_max = ax.get_xlim()

# Convert 1/(R*T) to temperature (K)
R = 8.314462618  # J/mol/K
T_min = 1 / (R * x_max)  # Higher 1/(R*T) corresponds to lower temperature
T_max = 1 / (R * x_min)  # Lower 1/(R*T) corresponds to higher temperature

# Set temperature axis limits and ticks
ax_temp.set_xlim(T_max, T_min)
temp_ticks = np.linspace(T_max, T_min, 6)
ax_temp.set_xticks(temp_ticks)
ax_temp.set_xticklabels([f'{T:.0f}' for T in temp_ticks])
ax_temp.set_xlabel('Temperature / K', fontsize=14)
ax_temp.tick_params(axis='x', which='major', labelsize=12)

# Create legend with two columns to accommodate more entries
legend = ax.legend(bbox_to_anchor=(1.04, 1), loc='upper left', frameon=True, 
                  fancybox=False, fontsize=10, ncol=1)
if legend is not None:
    legend.get_frame().set_facecolor('white')
    legend.get_frame().set_edgecolor('black')

# Add legend for line styles
from matplotlib.lines import Line2D
line_legend_elements = [
    Line2D([0], [0], color='black', linestyle='-', label='High T fit'),
    Line2D([0], [0], color='black', linestyle='--', label='Low T fit'),
    Line2D([0], [0], color='black', linestyle=':', label='Full range fit')
]
line_legend = ax.legend(handles=line_legend_elements, loc='lower right', 
                       frameon=True, fancybox=False, fontsize=10)
line_legend.get_frame().set_facecolor('white')
line_legend.get_frame().set_edgecolor('black')

# Add the original legend back
ax.add_artist(legend)

plt.tight_layout()
save_plot_as_svg()
plt.show()

# Combine all split data into a single DataFrame
split_points_df = pd.concat(split_data, ignore_index=True)

print(f"Split points DataFrame shape: {split_points_df.shape}")
print("\nTemperature group distribution:")
print(split_points_df['temperature_group'].value_counts())
display(split_points_df.head(10))
# Out:
# <>:122: SyntaxWarning: invalid escape sequence '\c'
# <>:122: SyntaxWarning: invalid escape sequence '\c'
# /tmp/ipykernel_13941/1315099217.py:122: SyntaxWarning: invalid escape sequence '\c'
#   ax.set_xlabel('$R \cdot T^{-1}$ / mol J$^{-1}$', fontsize=14)
# ✓ Plot gespeichert: image_output/Arrhenius_Plot_Temperature_Groups_by_DOI_Glyceline_18.svg (156,029 Bytes)
# Split points DataFrame shape: (72, 27)
#
# Temperature group distribution:
# temperature_group
# Low T     38
# High T    34
# Name: count, dtype: int64
#                 fluid_compounds property_type  property_value  uncertainty  \
# 0  [Choline Chloride, Glycerol]     viscosity        0.019587     0.000098
# 1  [Choline Chloride, Glycerol]     viscosity        0.026333     0.000132
# 2  [Choline Chloride, Glycerol]     viscosity        0.036741     0.000184
# 3  [Choline Chloride, Glycerol]     viscosity        0.053812     0.000269
# 4  [Choline Chloride, Glycerol]     viscosity        0.081589     0.000408
# 5  [Choline Chloride, Glycerol]     viscosity        0.133375     0.000667
# 6  [Choline Chloride, Glycerol]     viscosity        0.246793     0.001234
# 7  [Choline Chloride, Glycerol]     viscosity        0.472967     0.002365
# 8  [Choline Chloride, Glycerol]     viscosity        1.003943     0.005020
# 9  [Choline Chloride, Glycerol]     viscosity        0.040940     0.000819
#
#    temperature                    mole_fractions  \
# 0       363.15  [0.333333333333, 0.666666666667]
# 1       353.15  [0.333333333333, 0.666666666667]
# 2       343.15  [0.333333333333, 0.666666666667]
# 3       333.15  [0.333333333333, 0.666666666667]
# 4       323.15  [0.333333333333, 0.666666666667]
# 5       313.15  [0.333333333333, 0.666666666667]
# 6       303.15  [0.333333333333, 0.666666666667]
# 7       293.15  [0.333333333333, 0.666666666667]
# 8       283.15  [0.333333333333, 0.666666666667]
# 9       338.15  [0.333333333333, 0.666666666667]
#
#                          measurement_id                   source_doi  \
# 0  3686859c-22ea-49dd-ac42-d40dc820dae3  10.1016/j.fluid.2014.01.028
# 1  a468acdb-b7ac-431a-958a-a5f25ba790e6  10.1016/j.fluid.2014.01.028
# 2  2b9710af-231e-434c-a47a-304f8409a8a3  10.1016/j.fluid.2014.01.028
# 3  291df303-fa79-4ef4-86ca-2d526c8555bb  10.1016/j.fluid.2014.01.028
# 4  08fb09d4-ba02-487e-a55a-f6489894e054  10.1016/j.fluid.2014.01.028
# 5  7c1e9f13-03c7-4e75-bb4e-0787c75931d5  10.1016/j.fluid.2014.01.028
# 6  5903da59-4132-4c2e-8ced-3b10ab752b3c  10.1016/j.fluid.2014.01.028
# 7  00d9c3d5-d0a9-453a-ab35-01427e57dc16  10.1016/j.fluid.2014.01.028
# 8  f44ddacb-3cb3-48c5-9e4d-04a7d54a512f  10.1016/j.fluid.2014.01.028
# 9  51ebe2af-85f0-47c3-b731-88c90797a1a9    10.1016/j.jct.2018.07.031
#
#    Mole fraction  Temperature  ...  density_uncertainty  \
# 0       0.666667       363.15  ...                 None
# 1       0.666667       353.15  ...                 None
# 2       0.666667       343.15  ...                 None
# 3       0.666667       333.15  ...                 None
# 4       0.666667       323.15  ...                 None
# 5       0.666667       313.15  ...                 None
# 6       0.666667       303.15  ...                 None
# 7       0.666667       293.15  ...                 None
# 8       0.666667       283.15  ...                 None
# 9       0.666667       338.15  ...                 None
#
#   thermalConductivity_value thermalConductivity_uncertainty  viscosity_value  \
# 0                      None                            None         0.019587
# 1                      None                            None         0.026333
# 2                      None                            None         0.036741
# 3                      None                            None         0.053812
# 4                      None                            None         0.081589
# 5                      None                            None         0.133375
# 6                      None                            None         0.246793
# 7                      None                            None         0.472967
# 8                      None                            None         1.003943
# 9                      None                            None          0.04094
#
#    viscosity_uncertainty mole_fraction_water    inv_RT ln_viscosity  \
# 0               0.000098                 0.0  0.000331    -3.932910
# 1               0.000132                 0.0  0.000341    -3.636929
# 2               0.000184                 0.0  0.000350    -3.303865
# 3               0.000269                 0.0  0.000361    -2.922264
# 4               0.000408                 0.0  0.000372    -2.506055
# 5               0.000667                 0.0  0.000384    -2.014591
# 6               0.001234                 0.0  0.000397    -1.399206
# 7               0.002365                 0.0  0.000410    -0.748729
# 8                0.00502                 0.0  0.000425     0.003935
# 9               0.000819                 0.0  0.000356    -3.195648
#
#   ln_viscosity_scaled temperature_group
# 0          -10.840665            High T
# 1          -10.544684            High T
# 2          -10.211620            High T
# 3           -9.830020            High T
# 4           -9.413810             Low T
# 5           -8.922347             Low T
# 6           -8.306961             Low T
# 7           -7.656485             Low T
# 8           -6.903820             Low T
# 9          -10.103403            High T
#
# [10 rows x 27 columns]

# %%
# Plot filtered_df grouped by DOI, splitting temperature points into low and high temperature groups
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Get unique DOIs
dois = filtered_df['source_doi'].unique()

# Filter out DOIs with insufficient data first
valid_dois = []
for doi in dois:
    subset = filtered_df[
        (filtered_df["source_doi"] == doi)
        & (~filtered_df["inv_RT"].isna())
        & (~filtered_df["ln_viscosity"].isna())
    ]
    if len(subset) >= 2:
        valid_dois.append(doi)

# Calculate number of subplots needed
n_dois = len(valid_dois)
n_cols = 3  # Number of columns
n_rows = (n_dois + n_cols - 1) // n_cols  # Ceiling division

# Create figure with subplots
fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, 5 * n_rows))

# Flatten axes array for easier indexing
if n_rows == 1:
    axes = [axes] if n_cols == 1 else axes
else:
    axes = axes.flatten()

# Color map for temperature groups
temp_colors = {'High T': '#FF6B6B', 'Low T': '#4ECDC4'}

# List to store all split data
split_data = []

# Process each valid DOI
for i, doi in enumerate(valid_dois):
    ax = axes[i]
    
    subset = filtered_df[
        (filtered_df["source_doi"] == doi)
        & (~filtered_df["inv_RT"].isna())
        & (~filtered_df["ln_viscosity"].isna())
    ]
    
    # Sort by temperature (inverse of inv_RT for proper ordering)
    subset_sorted = subset.sort_values('inv_RT')
    
    # Split into two halves based on temperature
    n_points = len(subset_sorted)
    mid_point = n_points // 2
    
    # Lower half (higher temperatures - lower inv_RT values)
    low_temp_group = subset_sorted.iloc[:mid_point].copy()
    low_temp_group['temperature_group'] = 'High T'
    
    # Upper half (lower temperatures - higher inv_RT values)  
    high_temp_group = subset_sorted.iloc[mid_point:].copy()
    high_temp_group['temperature_group'] = 'Low T'
    
    # Add to split_data list
    split_data.append(low_temp_group)
    split_data.append(high_temp_group)
    
    # Get x-axis range for extending lines (scaled by 1000)
    x_range_min = subset_sorted["inv_RT"].min() * 1000 * 0.95
    x_range_max = subset_sorted["inv_RT"].max() * 1000 * 1.05
    
    # Plot high temperature group (circles) - scale x-axis by 1000
    if len(low_temp_group) > 0:
        ax.scatter(
            low_temp_group["inv_RT"] * 1000,
            low_temp_group["ln_viscosity"],
            label='High T',
            color=temp_colors['High T'],
            marker='o',
            s=80,
            alpha=0.7,
            edgecolor='black',
            linewidth=0.5
        )
        
        # Fit and plot extended Arrhenius line for high temperature group
        if len(low_temp_group) >= 2:
            x_high = low_temp_group["inv_RT"].values
            y_high = low_temp_group["ln_viscosity"].values
            slope_high, intercept_high = np.polyfit(x_high, y_high, 1)
            
            # Create extended line points for plotting (scaled by 1000)
            x_line_high = np.linspace(x_range_min, x_range_max, 100)
            y_line_high = slope_high * (x_line_high / 1000) + intercept_high
            
            ax.plot(x_line_high, y_line_high, color=temp_colors['High T'], 
                   linestyle='-', alpha=0.8, linewidth=2)
    
    # Plot low temperature group (squares) - scale x-axis by 1000
    if len(high_temp_group) > 0:
        ax.scatter(
            high_temp_group["inv_RT"] * 1000,
            high_temp_group["ln_viscosity"],
            label='Low T',
            color=temp_colors['Low T'],
            marker='s',
            s=80,
            alpha=0.7,
            edgecolor='black',
            linewidth=0.5
        )
        
        # Fit and plot extended Arrhenius line for low temperature group
        if len(high_temp_group) >= 2:
            x_low = high_temp_group["inv_RT"].values
            y_low = high_temp_group["ln_viscosity"].values
            slope_low, intercept_low = np.polyfit(x_low, y_low, 1)
            
            # Create extended line points for plotting (scaled by 1000)
            x_line_low = np.linspace(x_range_min, x_range_max, 100)
            y_line_low = slope_low * (x_line_low / 1000) + intercept_low
            
            ax.plot(x_line_low, y_line_low, color=temp_colors['Low T'], 
                   linestyle='--', alpha=0.8, linewidth=2)
    
    # Plot extended full range Arrhenius line
    if len(subset_sorted) >= 2:
        x_full = subset_sorted["inv_RT"].values
        y_full = subset_sorted["ln_viscosity"].values
        slope_full, intercept_full = np.polyfit(x_full, y_full, 1)
        
        # Create extended line points for plotting (scaled by 1000)
        x_line_full = np.linspace(x_range_min, x_range_max, 100)
        y_line_full = slope_full * (x_line_full / 1000) + intercept_full
        
        ax.plot(x_line_full, y_line_full, color='gray', 
               linestyle=':', alpha=0.6, linewidth=3, label='Full range')
    
    # Set labels and title for each subplot
    ax.set_xlabel(r'(RT)$^{-1}$ / mol kJ$^{-1}$', fontsize=10)
    ax.set_ylabel(r'ln($\eta$ / Pa$\cdot$s)', fontsize=10)
    ax.set_title(f'DOI: {doi}', fontsize=10, wrap=True)
    
    # Add legend to each subplot
    ax.legend(fontsize=8, loc='best')
    
    # Increase tick label font size
    ax.tick_params(axis='both', which='major', labelsize=8)
    
    # Create secondary x-axis for temperature
    ax_temp = ax.twiny()
    
    # Get the current x-axis limits (already scaled by 1000)
    x_min, x_max = ax.get_xlim()
    
    # Convert 1/(R*T) to temperature (K) - need to divide by 1000 first
    R = 8.314462618  # J/mol/K
    T_min = 1 / (R * (x_max / 1000))  # Higher 1/(R*T) corresponds to lower temperature
    T_max = 1 / (R * (x_min / 1000))  # Lower 1/(R*T) corresponds to higher temperature
    
    # Set temperature axis limits and ticks
    ax_temp.set_xlim(T_max, T_min)
    temp_ticks = np.linspace(T_max, T_min, 4)  # Fewer ticks for smaller plots
    ax_temp.set_xticks(temp_ticks)
    ax_temp.set_xticklabels([f'{T:.0f}' for T in temp_ticks], fontsize=8)
    ax_temp.set_xlabel('Temperature / K', fontsize=8)
    ax_temp.tick_params(axis='x', which='major', labelsize=8)

# Hide empty subplots
for j in range(i + 1, len(axes)):
    axes[j].set_visible(False)

# Add overall title
fig.suptitle('Arrhenius Plots: Temperature Groups by DOI (Glyceline, ratio 1:2)', 
             fontsize=16, y=0.98)

plt.tight_layout()
save_plot_as_svg()
plt.show()

# Combine all split data into a single DataFrame
split_points_df = pd.concat(split_data, ignore_index=True)

print(f"Split points DataFrame shape: {split_points_df.shape}")
print("\nTemperature group distribution:")
print(split_points_df['temperature_group'].value_counts())
display(split_points_df.head(10))
# Out:
# ✓ Plot gespeichert: image_output/Arrhenius_Plots_Temperature_Groups_by_DOI_Glycelin_19.svg (238,357 Bytes)
# Split points DataFrame shape: (72, 27)
#
# Temperature group distribution:
# temperature_group
# Low T     38
# High T    34
# Name: count, dtype: int64
#                 fluid_compounds property_type  property_value  uncertainty  \
# 0  [Choline Chloride, Glycerol]     viscosity        0.019587     0.000098
# 1  [Choline Chloride, Glycerol]     viscosity        0.026333     0.000132
# 2  [Choline Chloride, Glycerol]     viscosity        0.036741     0.000184
# 3  [Choline Chloride, Glycerol]     viscosity        0.053812     0.000269
# 4  [Choline Chloride, Glycerol]     viscosity        0.081589     0.000408
# 5  [Choline Chloride, Glycerol]     viscosity        0.133375     0.000667
# 6  [Choline Chloride, Glycerol]     viscosity        0.246793     0.001234
# 7  [Choline Chloride, Glycerol]     viscosity        0.472967     0.002365
# 8  [Choline Chloride, Glycerol]     viscosity        1.003943     0.005020
# 9  [Choline Chloride, Glycerol]     viscosity        0.040940     0.000819
#
#    temperature                    mole_fractions  \
# 0       363.15  [0.333333333333, 0.666666666667]
# 1       353.15  [0.333333333333, 0.666666666667]
# 2       343.15  [0.333333333333, 0.666666666667]
# 3       333.15  [0.333333333333, 0.666666666667]
# 4       323.15  [0.333333333333, 0.666666666667]
# 5       313.15  [0.333333333333, 0.666666666667]
# 6       303.15  [0.333333333333, 0.666666666667]
# 7       293.15  [0.333333333333, 0.666666666667]
# 8       283.15  [0.333333333333, 0.666666666667]
# 9       338.15  [0.333333333333, 0.666666666667]
#
#                          measurement_id                   source_doi  \
# 0  3686859c-22ea-49dd-ac42-d40dc820dae3  10.1016/j.fluid.2014.01.028
# 1  a468acdb-b7ac-431a-958a-a5f25ba790e6  10.1016/j.fluid.2014.01.028
# 2  2b9710af-231e-434c-a47a-304f8409a8a3  10.1016/j.fluid.2014.01.028
# 3  291df303-fa79-4ef4-86ca-2d526c8555bb  10.1016/j.fluid.2014.01.028
# 4  08fb09d4-ba02-487e-a55a-f6489894e054  10.1016/j.fluid.2014.01.028
# 5  7c1e9f13-03c7-4e75-bb4e-0787c75931d5  10.1016/j.fluid.2014.01.028
# 6  5903da59-4132-4c2e-8ced-3b10ab752b3c  10.1016/j.fluid.2014.01.028
# 7  00d9c3d5-d0a9-453a-ab35-01427e57dc16  10.1016/j.fluid.2014.01.028
# 8  f44ddacb-3cb3-48c5-9e4d-04a7d54a512f  10.1016/j.fluid.2014.01.028
# 9  51ebe2af-85f0-47c3-b731-88c90797a1a9    10.1016/j.jct.2018.07.031
#
#    Mole fraction  Temperature  ...  density_uncertainty  \
# 0       0.666667       363.15  ...                 None
# 1       0.666667       353.15  ...                 None
# 2       0.666667       343.15  ...                 None
# 3       0.666667       333.15  ...                 None
# 4       0.666667       323.15  ...                 None
# 5       0.666667       313.15  ...                 None
# 6       0.666667       303.15  ...                 None
# 7       0.666667       293.15  ...                 None
# 8       0.666667       283.15  ...                 None
# 9       0.666667       338.15  ...                 None
#
#   thermalConductivity_value thermalConductivity_uncertainty  viscosity_value  \
# 0                      None                            None         0.019587
# 1                      None                            None         0.026333
# 2                      None                            None         0.036741
# 3                      None                            None         0.053812
# 4                      None                            None         0.081589
# 5                      None                            None         0.133375
# 6                      None                            None         0.246793
# 7                      None                            None         0.472967
# 8                      None                            None         1.003943
# 9                      None                            None          0.04094
#
#    viscosity_uncertainty mole_fraction_water    inv_RT ln_viscosity  \
# 0               0.000098                 0.0  0.000331    -3.932910
# 1               0.000132                 0.0  0.000341    -3.636929
# 2               0.000184                 0.0  0.000350    -3.303865
# 3               0.000269                 0.0  0.000361    -2.922264
# 4               0.000408                 0.0  0.000372    -2.506055
# 5               0.000667                 0.0  0.000384    -2.014591
# 6               0.001234                 0.0  0.000397    -1.399206
# 7               0.002365                 0.0  0.000410    -0.748729
# 8                0.00502                 0.0  0.000425     0.003935
# 9               0.000819                 0.0  0.000356    -3.195648
#
#   ln_viscosity_scaled temperature_group
# 0          -10.840665            High T
# 1          -10.544684            High T
# 2          -10.211620            High T
# 3           -9.830020            High T
# 4           -9.413810             Low T
# 5           -8.922347             Low T
# 6           -8.306961             Low T
# 7           -7.656485             Low T
# 8           -6.903820             Low T
# 9          -10.103403            High T
#
# [10 rows x 27 columns]

# %%
# Calculate activation energy (E_a) for each DOI and temperature group combination from the split points
# ln(viscosity) = ln(A) + E_a / R * (1/T)
# So: slope = E_a / R  =>  E_a = slope * R

import numpy as np

R = 8.314462618  # J/mol/K (universal gas constant)

group_activation_energies = []

# Filter for glyceline mixtures only (no water) - mole_fraction_water should be 0.0
glyceline_data = split_points_df[split_points_df['mole_fraction_water'] == 0.0]

# Get unique combinations of DOI and temperature group for glyceline only
doi_temp_combinations = glyceline_data[['source_doi', 'temperature_group']].drop_duplicates()

for _, row in doi_temp_combinations.iterrows():
    doi = row['source_doi']
    temp_group = row['temperature_group']
    
    subset = glyceline_data[
        (glyceline_data['source_doi'] == doi) & 
        (glyceline_data['temperature_group'] == temp_group)
    ]
    
    if len(subset) < 2:
        continue  # Not enough points to fit
    
    # Calculate temperature range for this subset
    temp_min = subset['temperature'].min()
    temp_max = subset['temperature'].max()
    temp_range = f"{temp_min:.0f}-{temp_max:.0f}"
    
    # Fit: ln(viscosity) = slope * inv_RT + intercept
    # NOTE: inv_RT is already 1/(R*T), so slope directly gives E_a in J/mol
    x = subset["inv_RT"].values
    y = subset["ln_viscosity"].values
    
    # Check for outliers or unreasonable data points
    print(f"DOI: {doi}, Group: {temp_group}")
    print(f"  Temperature range: {temp_range} K")
    print(f"  inv_RT range: {x.min():.6f} to {x.max():.6f}")
    print(f"  ln(viscosity) range: {y.min():.3f} to {y.max():.3f}")
    
    # np.polyfit returns [slope, intercept]
    slope, intercept = np.polyfit(x, y, 1)
    # Since inv_RT = 1/(R*T), the slope is already E_a in J/mol (no need to multiply by R)
    E_a = slope  # activation energy in J/mol
    E_a_kJ_per_mol = E_a / 1000  # Convert to kJ/mol for easier interpretation
    
    print(f"  Slope: {slope:.1f}, E_a: {E_a_kJ_per_mol:.1f} kJ/mol")
    
    # Calculate R-squared for goodness of fit
    y_pred = slope * x + intercept
    ss_res = np.sum((y - y_pred) ** 2)
    ss_tot = np.sum((y - np.mean(y)) ** 2)
    r_squared = 1 - (ss_res / ss_tot)
    
    group_activation_energies.append({
        "source_doi": doi,
        "temperature_group": temp_group,
        "temperature_range": temp_range,
        "activation_energy_J_per_mol": E_a,
        "activation_energy_kJ_per_mol": E_a_kJ_per_mol,
        "arrhenius_prefactor_lnA": intercept,
        "r_squared": r_squared,
        "n_points": len(subset)
    })
    print()

# Also calculate activation energy for full temperature range for each DOI (glyceline only)
unique_dois = glyceline_data['source_doi'].unique()

for doi in unique_dois:
    subset = glyceline_data[glyceline_data['source_doi'] == doi]
    
    if len(subset) < 2:
        continue  # Not enough points to fit
    
    # Calculate temperature range for this subset
    temp_min = subset['temperature'].min()
    temp_max = subset['temperature'].max()
    temp_range = f"{temp_min:.0f}-{temp_max:.0f}"
    
    # Fit: ln(viscosity) = slope * inv_RT + intercept
    x = subset["inv_RT"].values
    y = subset["ln_viscosity"].values
    
    print(f"DOI: {doi}, Full Range")
    print(f"  Temperature range: {temp_range} K")
    print(f"  inv_RT range: {x.min():.6f} to {x.max():.6f}")
    print(f"  ln(viscosity) range: {y.min():.3f} to {y.max():.3f}")
    
    # np.polyfit returns [slope, intercept]
    slope, intercept = np.polyfit(x, y, 1)
    # Since inv_RT = 1/(R*T), the slope is already E_a in J/mol (no need to multiply by R)
    E_a = slope  # activation energy in J/mol
    E_a_kJ_per_mol = E_a / 1000  # Convert to kJ/mol for easier interpretation
    
    print(f"  Slope: {slope:.1f}, E_a: {E_a_kJ_per_mol:.1f} kJ/mol")
    
    # Calculate R-squared for goodness of fit
    y_pred = slope * x + intercept
    ss_res = np.sum((y - y_pred) ** 2)
    ss_tot = np.sum((y - np.mean(y)) ** 2)
    r_squared = 1 - (ss_res / ss_tot)
    
    group_activation_energies.append({
        "source_doi": doi,
        "temperature_group": "Full Range",
        "temperature_range": temp_range,
        "activation_energy_J_per_mol": E_a,
        "activation_energy_kJ_per_mol": E_a_kJ_per_mol,
        "arrhenius_prefactor_lnA": intercept,
        "r_squared": r_squared,
        "n_points": len(subset)
    })
    print()

# Convert to DataFrame for summary display
group_activation_energy_df = pd.DataFrame(group_activation_energies)

print("Activation energies (E_a) and Arrhenius prefactor by DOI and temperature group (Glyceline Only - No Water):")
print("Note: Typical activation energies for viscous flow are 10-100 kJ/mol")
display(group_activation_energy_df)
# Out:
# DOI: 10.1016/j.fluid.2014.01.028, Group: High T
#   Temperature range: 333-363 K
#   inv_RT range: 0.000331 to 0.000361
#   ln(viscosity) range: -3.933 to -2.922
#   Slope: 33881.7, E_a: 33.9 kJ/mol
#
# DOI: 10.1016/j.fluid.2014.01.028, Group: Low T
#   Temperature range: 283-323 K
#   inv_RT range: 0.000372 to 0.000425
#   ln(viscosity) range: -2.506 to 0.004
#   Slope: 47918.9, E_a: 47.9 kJ/mol
#
# DOI: 10.1016/j.jct.2018.07.031, Group: High T
#   Temperature range: 311-338 K
#   inv_RT range: 0.000356 to 0.000387
#   ln(viscosity) range: -3.196 to -1.904
#   Slope: 41073.2, E_a: 41.1 kJ/mol
#
# DOI: 10.1016/j.jct.2018.07.031, Group: Low T
#   Temperature range: 278-308 K
#   inv_RT range: 0.000390 to 0.000432
#   ln(viscosity) range: -1.763 to 0.413
#   Slope: 51631.2, E_a: 51.6 kJ/mol
#
# DOI: NO, Group: High T
#   Temperature range: 323-353 K
#   inv_RT range: 0.000341 to 0.000372
#   ln(viscosity) range: -3.862 to -2.714
#   Slope: 36716.1, E_a: 36.7 kJ/mol
#
# DOI: NO, Group: Low T
#   Temperature range: 293-313 K
#   inv_RT range: 0.000384 to 0.000410
#   ln(viscosity) range: -2.211 to -0.969
#   Slope: 47488.5, E_a: 47.5 kJ/mol
#
# DOI: 10.1016/j.molliq.2015.11.032, Group: High T
#   Temperature range: 328-353 K
#   inv_RT range: 0.000341 to 0.000367
#   ln(viscosity) range: -3.472 to -2.624
#   Slope: 29644.6, E_a: 29.6 kJ/mol
#
# DOI: 10.1016/j.molliq.2015.11.032, Group: Low T
#   Temperature range: 298-323 K
#   inv_RT range: 0.000372 to 0.000404
#   ln(viscosity) range: -2.388 to -1.085
#   Slope: 40731.9, E_a: 40.7 kJ/mol
#
# DOI: 10.1039/C1CP22554E, Group: High T
#   Temperature range: 318-328 K
#   inv_RT range: 0.000367 to 0.000378
#   ln(viscosity) range: -2.957 to -2.501
#   Slope: 39515.1, E_a: 39.5 kJ/mol
#
# DOI: 10.1039/C1CP22554E, Group: Low T
#   Temperature range: 298-313 K
#   inv_RT range: 0.000384 to 0.000404
#   ln(viscosity) range: -2.263 to -1.351
#   Slope: 47033.7, E_a: 47.0 kJ/mol
#
# DOI: 10.1039/c0gc00395f, Group: High T
#   Temperature range: 313-328 K
#   inv_RT range: 0.000367 to 0.000384
#   ln(viscosity) range: -2.957 to -2.263
#   Slope: 39778.4, E_a: 39.8 kJ/mol
#
# DOI: 10.1039/c0gc00395f, Group: Low T
#   Temperature range: 293-308 K
#   inv_RT range: 0.000390 to 0.000410
#   ln(viscosity) range: -1.966 to -0.978
#   Slope: 49365.2, E_a: 49.4 kJ/mol
#
# DOI: 10.1016/j.fluid.2014.01.028, Full Range
#   Temperature range: 283-363 K
#   inv_RT range: 0.000331 to 0.000425
#   ln(viscosity) range: -3.933 to 0.004
#   Slope: 41927.9, E_a: 41.9 kJ/mol
#
# DOI: 10.1016/j.jct.2018.07.031, Full Range
#   Temperature range: 278-338 K
#   inv_RT range: 0.000356 to 0.000432
#   ln(viscosity) range: -3.196 to 0.413
#   Slope: 46750.7, E_a: 46.8 kJ/mol
#
# DOI: NO, Full Range
#   Temperature range: 293-353 K
#   inv_RT range: 0.000341 to 0.000410
#   ln(viscosity) range: -3.862 to -0.969
#   Slope: 41608.4, E_a: 41.6 kJ/mol
#
# DOI: 10.1016/j.molliq.2015.11.032, Full Range
#   Temperature range: 298-353 K
#   inv_RT range: 0.000341 to 0.000404
#   ln(viscosity) range: -3.472 to -1.085
#   Slope: 37403.1, E_a: 37.4 kJ/mol
#
# DOI: 10.1039/C1CP22554E, Full Range
#   Temperature range: 298-328 K
#   inv_RT range: 0.000367 to 0.000404
#   ln(viscosity) range: -2.957 to -1.351
#   Slope: 43650.3, E_a: 43.7 kJ/mol
#
# DOI: 10.1039/c0gc00395f, Full Range
#   Temperature range: 293-328 K
#   inv_RT range: 0.000367 to 0.000410
#   ln(viscosity) range: -2.957 to -0.978
#   Slope: 45102.0, E_a: 45.1 kJ/mol
#
# DOI: 10.1039/c9cp00036d, Full Range
#   Temperature range: 320-360 K
#   inv_RT range: 0.000334 to 0.000376
#   ln(viscosity) range: -3.669 to -2.054
#   Slope: 38701.8, E_a: 38.7 kJ/mol
#
# Activation energies (E_a) and Arrhenius prefactor by DOI and temperature group (Glyceline Only - No Water):
# Note: Typical activation energies for viscous flow are 10-100 kJ/mol
#                       source_doi temperature_group temperature_range  \
# 0    10.1016/j.fluid.2014.01.028            High T           333-363
# 1    10.1016/j.fluid.2014.01.028             Low T           283-323
# 2      10.1016/j.jct.2018.07.031            High T           311-338
# 3      10.1016/j.jct.2018.07.031             Low T           278-308
# 4                             NO            High T           323-353
# 5                             NO             Low T           293-313
# 6   10.1016/j.molliq.2015.11.032            High T           328-353
# 7   10.1016/j.molliq.2015.11.032             Low T           298-323
# 8             10.1039/C1CP22554E            High T           318-328
# 9             10.1039/C1CP22554E             Low T           298-313
# 10            10.1039/c0gc00395f            High T           313-328
# 11            10.1039/c0gc00395f             Low T           293-308
# 12   10.1016/j.fluid.2014.01.028        Full Range           283-363
# 13     10.1016/j.jct.2018.07.031        Full Range           278-338
# 14                            NO        Full Range           293-353
# 15  10.1016/j.molliq.2015.11.032        Full Range           298-353
# 16            10.1039/C1CP22554E        Full Range           298-328
# 17            10.1039/c0gc00395f        Full Range           293-328
# 18            10.1039/c9cp00036d        Full Range           320-360
#
#     activation_energy_J_per_mol  activation_energy_kJ_per_mol  \
# 0                  33881.699530                     33.881700
# 1                  47918.947805                     47.918948
# 2                  41073.168777                     41.073169
# 3                  51631.248713                     51.631249
# 4                  36716.090607                     36.716091
# 5                  47488.465346                     47.488465
# 6                  29644.627352                     29.644627
# 7                  40731.929070                     40.731929
# 8                  39515.113405                     39.515113
# 9                  47033.702850                     47.033703
# 10                 39778.392710                     39.778393
# 11                 49365.168668                     49.365169
# 12                 41927.868165                     41.927868
# 13                 46750.709953                     46.750710
# 14                 41608.383489                     41.608383
# 15                 37403.092032                     37.403092
# 16                 43650.263472                     43.650263
# 17                 45102.046533                     45.102047
# 18                 38701.775055                     38.701775
#
#     arrhenius_prefactor_lnA  r_squared  n_points
# 0                -15.165900   0.999022         4
# 1                -20.385919   0.998612         5
# 2                -17.823342   0.999330        12
# 3                -21.951472   0.998993        13
# 4                -16.390721   0.997996         4
# 5                -20.466047   0.999687         5
# 6                -13.525274   0.975107         6
# 7                -17.545085   0.997972         6
# 8                -17.451681   0.998239         3
# 9                -20.335841   0.999912         4
# 10               -17.542429   0.999304         4
# 11               -21.246557   0.998481         4
# 12               -17.979190   0.992622         9
# 13               -19.938777   0.996546        25
# 14               -18.131910   0.996343         9
# 15               -16.260954   0.992438        12
# 16               -18.998364   0.998036         7
# 17               -19.540212   0.997044         8
# 18               -16.593692   1.000000         2

# %%
# Create a bar plot showing activation energy differences by DOI and temperature group
import matplotlib.pyplot as plt
import numpy as np

# Create the bar plot
fig, ax = plt.subplots(figsize=(12, 8))

# Get unique DOIs for grouping
unique_dois = group_activation_energy_df['source_doi'].unique()
n_dois = len(unique_dois)

# Set up bar positions
bar_width = 0.25
x_pos = np.arange(n_dois)

# Separate data by temperature group
high_t_data = []
low_t_data = []
full_range_data = []
doi_labels = []
high_t_ranges = []
low_t_ranges = []
full_ranges = []

for doi in unique_dois:
    doi_data = group_activation_energy_df[group_activation_energy_df['source_doi'] == doi]
    
    high_t = doi_data[doi_data['temperature_group'] == 'High T']
    low_t = doi_data[doi_data['temperature_group'] == 'Low T']
    full_range = doi_data[doi_data['temperature_group'] == 'Full Range']
    
    high_t_val = high_t['activation_energy_J_per_mol'].iloc[0] if len(high_t) > 0 else 0
    low_t_val = low_t['activation_energy_J_per_mol'].iloc[0] if len(low_t) > 0 else 0
    full_range_val = full_range['activation_energy_J_per_mol'].iloc[0] if len(full_range) > 0 else 0
    
    high_t_range = high_t['temperature_range'].iloc[0] if len(high_t) > 0 else ""
    low_t_range = low_t['temperature_range'].iloc[0] if len(low_t) > 0 else ""
    full_range_range = full_range['temperature_range'].iloc[0] if len(full_range) > 0 else ""
    
    high_t_data.append(high_t_val)
    low_t_data.append(low_t_val)
    full_range_data.append(full_range_val)
    high_t_ranges.append(high_t_range)
    low_t_ranges.append(low_t_range)
    full_ranges.append(full_range_range)
    
    # Create shorter labels for better readability
    short_doi = doi.split('/')[-1] if '/' in doi else doi
    doi_labels.append(short_doi)

# Create bars
bars1 = ax.bar(x_pos - bar_width, high_t_data, bar_width, 
               label='High Temperature', alpha=0.8, color='#E74C3C')
bars2 = ax.bar(x_pos, low_t_data, bar_width,
               label='Low Temperature', alpha=0.8, color='#3498DB')
bars3 = ax.bar(x_pos + bar_width, full_range_data, bar_width,
               label='Full Range', alpha=0.8, color='#2ECC71')

# Customize the plot
ax.set_xlabel('DOI', fontsize=12)
ax.set_ylabel('Activation Energy (J/mol)', fontsize=12)
ax.set_title('Activation Energy Comparison by DOI and Temperature Group', fontsize=14, fontweight='bold')
ax.set_xticks(x_pos)
ax.set_xticklabels(doi_labels, rotation=45, ha='right')
ax.legend()

# Add value labels on bars with temperature ranges
def add_value_labels_with_temp(bars, temp_ranges):
    for bar, temp_range in zip(bars, temp_ranges):
        height = bar.get_height()
        if height > 0:  # Only add label if there's a value
            label_text = f'{height:.0f}\n({temp_range}K)' if temp_range else f'{height:.0f}'
            ax.text(bar.get_x() + bar.get_width()/2., height,
                   label_text,
                   ha='center', va='bottom', fontsize=8)

add_value_labels_with_temp(bars1, high_t_ranges)
add_value_labels_with_temp(bars2, low_t_ranges)
add_value_labels_with_temp(bars3, full_ranges)

# Format y-axis to show values in scientific notation
ax.ticklabel_format(style='scientific', axis='y', scilimits=(0,0))

plt.tight_layout()
save_plot_as_svg()
plt.show()

# Calculate and display the differences
print("\nActivation Energy Differences by DOI:")
print("=" * 60)
for i, doi in enumerate(unique_dois):
    short_doi = doi_labels[i]
    print(f"{short_doi}:")
    
    if high_t_data[i] > 0 and low_t_data[i] > 0:
        diff_hl = low_t_data[i] - high_t_data[i]
        percent_diff_hl = (diff_hl / high_t_data[i]) * 100
        print(f"  Low T ({low_t_ranges[i]}K) - High T ({high_t_ranges[i]}K): {diff_hl:,.0f} J/mol ({percent_diff_hl:+.1f}%)")
    
    if full_range_data[i] > 0:
        if high_t_data[i] > 0:
            diff_fh = full_range_data[i] - high_t_data[i]
            percent_diff_fh = (diff_fh / high_t_data[i]) * 100
            print(f"  Full Range ({full_ranges[i]}K) - High T ({high_t_ranges[i]}K): {diff_fh:,.0f} J/mol ({percent_diff_fh:+.1f}%)")
        
        if low_t_data[i] > 0:
            diff_fl = full_range_data[i] - low_t_data[i]
            percent_diff_fl = (diff_fl / low_t_data[i]) * 100
            print(f"  Full Range ({full_ranges[i]}K) - Low T ({low_t_ranges[i]}K): {diff_fl:,.0f} J/mol ({percent_diff_fl:+.1f}%)")
    
    print()
# Out:
# ✓ Plot gespeichert: image_output/Activation_Energy_Comparison_by_DOI_and_Temperatur_20.svg (83,851 Bytes)
# Activation Energy Differences by DOI:
# ============================================================
# j.fluid.2014.01.028:
#   Low T (283-323K) - High T (333-363K): 14,037 J/mol (+41.4%)
#   Full Range (283-363K) - High T (333-363K): 8,046 J/mol (+23.7%)
#   Full Range (283-363K) - Low T (283-323K): -5,991 J/mol (-12.5%)
#
# j.jct.2018.07.031:
#   Low T (278-308K) - High T (311-338K): 10,558 J/mol (+25.7%)
#   Full Range (278-338K) - High T (311-338K): 5,678 J/mol (+13.8%)
#   Full Range (278-338K) - Low T (278-308K): -4,881 J/mol (-9.5%)
#
# NO:
#   Low T (293-313K) - High T (323-353K): 10,772 J/mol (+29.3%)
#   Full Range (293-353K) - High T (323-353K): 4,892 J/mol (+13.3%)
#   Full Range (293-353K) - Low T (293-313K): -5,880 J/mol (-12.4%)
#
# j.molliq.2015.11.032:
#   Low T (298-323K) - High T (328-353K): 11,087 J/mol (+37.4%)
#   Full Range (298-353K) - High T (328-353K): 7,758 J/mol (+26.2%)
#   Full Range (298-353K) - Low T (298-323K): -3,329 J/mol (-8.2%)
#
# C1CP22554E:
#   Low T (298-313K) - High T (318-328K): 7,519 J/mol (+19.0%)
#   Full Range (298-328K) - High T (318-328K): 4,135 J/mol (+10.5%)
#   Full Range (298-328K) - Low T (298-313K): -3,383 J/mol (-7.2%)
#
# c0gc00395f:
#   Low T (293-308K) - High T (313-328K): 9,587 J/mol (+24.1%)
#   Full Range (293-328K) - High T (313-328K): 5,324 J/mol (+13.4%)
#   Full Range (293-328K) - Low T (293-308K): -4,263 J/mol (-8.6%)
#
# c9cp00036d:

# %%
# Calculate activation energy (E_a) for each DOI/series from the Arrhenius fit:
# ln(viscosity) = ln(A) + E_a / R * (1/T)
# So: slope = E_a / R  =>  E_a = slope * R
# We'll do this for each DOI/series in the filtered_df, using linear regression.

import numpy as np

R = 8.314462618  # J/mol/K (universal gas constant)

activation_energies = []

for doi in dois2:
    subset2 = filtered_df[
        (filtered_df["source_doi"] == doi)
        & (~filtered_df["inv_RT"].isna())
        & (~filtered_df["ln_viscosity"].isna())
    ]
    if len(subset2) < 2:
        continue  # Not enough points to fit
    # Fit: ln(viscosity) = slope * inv_RT + intercept
    x = subset2["inv_RT"].values
    y = subset2["ln_viscosity"].values
    # np.polyfit returns [slope, intercept]
    slope, intercept = np.polyfit(x, y, 1)
    E_a = slope * R  # activation energy in J/mol
    # Optional: y-intercept is ln(A), the Arrhenius prefactor
    activation_energies.append({
        "doi": doi,
        "activation_energy_J_per_mol": E_a,
        "arrhenius_prefactor_lnA": intercept
    })

# Convert activation energies to DataFrame for summary display
import pandas as pd
activation_energy_df = pd.DataFrame(activation_energies)

print("Activation energies (E_a) and Arrhenius prefactor by DOI (solvent ratio == 2):")
display(activation_energy_df)
# Out:
# Activation energies (E_a) and Arrhenius prefactor by DOI (solvent ratio == 2):
#                             doi  activation_energy_J_per_mol  \
# 0   10.1016/j.fluid.2014.01.028                348607.692513
# 1     10.1016/j.jct.2018.07.031                388707.030266
# 2                            NO                345951.349117
# 3  10.1016/j.molliq.2015.11.032                310986.610499
# 4            10.1039/C1CP22554E                362928.483901
# 5            10.1039/c0gc00395f                374999.279896
# 6            10.1039/c9cp00036d                321784.461947
#
#    arrhenius_prefactor_lnA
# 0               -17.979190
# 1               -19.938777
# 2               -18.131910
# 3               -16.260954
# 4               -18.998364
# 5               -19.540212
# 6               -16.593692

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import cm
from scipy.stats import linregress

# Make sure required columns exist
required_cols = [
    "viscosity_value", 
    "temperature", 
    "source_doi", 
    "mole_fraction_water",
    "Solvent: Amount ratio of component to other component of binary solvent"
]
for col in required_cols:
    if col not in df_data_glyceline_ratio_or_pure_water.columns:
        raise ValueError(f"Column '{col}' not found in dataframe.")

# Filter on solvent ratio: keep rows where ratio <=2 or ratio is NaN (missing/None)
df_data_glyceline_ratio_or_pure_water_filtered = df_data_glyceline_ratio_or_pure_water[
    (df_data_glyceline_ratio_or_pure_water["Solvent: Amount ratio of component to other component of binary solvent"].isna()) |
    (df_data_glyceline_ratio_or_pure_water["Solvent: Amount ratio of component to other component of binary solvent"] <= 2)
].copy()

# Fill missing/None values in mole_fraction_water with 0
df_data_glyceline_ratio_or_pure_water_filtered["mole_fraction_water"] = (
    df_data_glyceline_ratio_or_pure_water_filtered["mole_fraction_water"]
    .fillna(0)
    .apply(lambda x: 0 if x is None else x)
)

# Clean for missing values in variables used
plot_df = df_data_glyceline_ratio_or_pure_water_filtered[
    df_data_glyceline_ratio_or_pure_water_filtered["viscosity_value"].notnull() &
    df_data_glyceline_ratio_or_pure_water_filtered["temperature"].notnull() &
    df_data_glyceline_ratio_or_pure_water_filtered["source_doi"].notnull()
].copy()

# Calculate ln(viscosity) and 1/(R*T)
R = 8.314  # J/(mol*K)
plot_df["inv_RT"] = 1000 / (R * plot_df["temperature"].astype(float))  # Factor 1000 for kJ instead of J
plot_df["ln_viscosity"] = np.log(plot_df["viscosity_value"].astype(float))

# Use mole_fraction_water to color the water amount
plot_df["water_mole_fraction"] = plot_df["mole_fraction_water"].astype(float)

# We'll use unique discrete values for water mole fraction as hue
plot_df["water_mole_fraction_rounded"] = plot_df["water_mole_fraction"].round(3)
discrete_mole_fractions = np.sort(plot_df["water_mole_fraction_rounded"].unique())

# Set up colormap: Blues colormap, N bins = number of unique mole fractions
N = len(discrete_mole_fractions)
cmap = cm.get_cmap('Blues', N)
color_dict = {mf: cmap(i) for i, mf in enumerate(discrete_mole_fractions)}

plt.figure(figsize=(11,7))
ax = plt.gca()

# Increase font size globally
plt.rcParams.update({'font.size': 14})

# Scatter points for each discrete fraction, so legend can be discrete
for i, mf in enumerate(discrete_mole_fractions):
    subset = plot_df[plot_df["water_mole_fraction_rounded"] == mf]
    ax.scatter(
        subset["inv_RT"], 
        subset["ln_viscosity"], 
        color=color_dict[mf],
        s=55, 
        edgecolor='black',
        linewidth=0.2,
        label=f"{mf:.3f}"
    )

# Linear fit and store slopes per discrete water content, including source_doi
slope_results = []
for mf in discrete_mole_fractions:
    group = plot_df[plot_df["water_mole_fraction_rounded"] == mf]
    # For each unique source_doi in this water content, do a fit for that subset
    for doi in group["source_doi"].unique():
        doi_group = group[group["source_doi"] == doi]
        if len(doi_group) >= 2:
            x = doi_group["inv_RT"].values
            y = doi_group["ln_viscosity"].values
            slope, intercept, r_value, p_value, std_err = linregress(x, y)
            xfit = np.linspace(x.min(), x.max(), 50)
            yfit = intercept + slope * xfit
            # Optionally: plot fits per color, commented
            # ax.plot(xfit, yfit, linestyle='--', linewidth=2, color=color_dict[mf])
            mf_tuple = (tuple(doi_group["mole_fractions"].iloc[0]) if "mole_fractions" in doi_group.columns and isinstance(doi_group["mole_fractions"].iloc[0], (list, tuple)) 
                        else doi_group["mole_fractions"].iloc[0] if "mole_fractions" in doi_group.columns else None)
            slope_results.append({
                "mole_fractions": mf_tuple,
                "water_mole_fraction": float(mf),
                "slope": slope,
                "source_doi": doi,
                "ordinate": intercept,
                "statistic": r_value
            })

# Create secondary x-axis for temperature
ax2 = ax.twiny()

# Get the range of 1/(R*T) values to create corresponding temperature values
inv_RT_min, inv_RT_max = ax.get_xlim()
T_max = 1000 / (R * inv_RT_min)  # Higher temperature corresponds to lower 1/(R*T), factor 1000 for kJ
T_min = 1000 / (R * inv_RT_max)  # Lower temperature corresponds to higher 1/(R*T), factor 1000 for kJ

# Set temperature ticks
temp_ticks = np.linspace(T_min, T_max, 6)  # 6 temperature points
inv_RT_ticks = 1000 / (R * temp_ticks)  # Factor 1000 for kJ

ax2.set_xlim(ax.get_xlim())
ax2.set_xticks(inv_RT_ticks)
ax2.set_xticklabels([f'{T:.0f}' for T in temp_ticks])
ax2.set_xlabel('Temperature / K', fontsize=16)

# Make discrete legend
handles, labels = ax.get_legend_handles_labels()
by_label = dict(zip(labels, handles))
lgd = ax.legend(by_label.values(), by_label.keys(), title="Water mole fraction", bbox_to_anchor=(1.04, 1), loc='upper left', borderaxespad=0., fontsize=12)
lgd.get_title().set_fontsize(14)

plt.title('Arrhenius plot of Glyceline with different water mole fractions', fontsize=15)
ax.set_xlabel(r'(RT)$^{-1}$ / mol $\cdot$ kJ$^{-1}$', fontsize=16)
ax.set_ylabel(r'ln($\eta$ / Pa $\cdot$ s)', fontsize=16)
ax.tick_params(axis='both', which='major', labelsize=12)
ax2.tick_params(axis='x', which='major', labelsize=12)
plt.tight_layout()
save_plot_as_svg()
plt.show()

import pandas as pd
activation_energy_df = pd.DataFrame(slope_results)
# Rename for clarity
activation_energy_df = activation_energy_df.rename(columns={'slope': 'activation_energy'})
# Ensure 'ordinate' and 'statistic' columns are present (they are, see above)
print("All linear fit activation energies by water mole fraction and source DOI, including ordinate and statistic:")
display(activation_energy_df[["water_mole_fraction", "activation_energy", "source_doi", "ordinate", "statistic"]])

activation_energy_df['measurement'] = 'measured'
activation_energy_df.to_csv('activation_energy_results_measured.csv', index=False)


# Add a column called 'measured' and fill it with 'measured'
df_data_glyceline_ratio_or_pure_water_filtered['measured'] = 'measured'

# Save the activation energy data to CSV
df_data_glyceline_ratio_or_pure_water_filtered.to_csv('df_data_glyceline_ratio_or_pure_water.csv', index=False)
print("Saved activation energy data to 'df_data_glyceline_ratio_or_pure_water.csv'")
# Out:
# /tmp/ipykernel_13941/246883716.py:52: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('Blues', N)
# ✓ Plot gespeichert: image_output/Arrhenius_plot_of_Glyceline_with_different_water_m_21.svg (112,516 Bytes)
# All linear fit activation energies by water mole fraction and source DOI, including ordinate and statistic:
#     water_mole_fraction  activation_energy                    source_doi  \
# 0                 0.000          41.606068                            NO
# 1                 0.000          43.647835            10.1039/C1CP22554E
# 2                 0.000          37.401011  10.1016/j.molliq.2015.11.032
# 3                 0.000          46.748109     10.1016/j.jct.2018.07.031
# 4                 0.000          41.925535   10.1016/j.fluid.2014.01.028
# 5                 0.000          45.099537            10.1039/c0gc00395f
# 6                 0.000          38.699622            10.1039/c9cp00036d
# 7                 0.100          39.132853            10.1039/c9cp00036d
# 8                 0.108          40.366403   10.1016/j.fluid.2014.01.028
# 9                 0.156          38.285661                            NO
# 10                0.238          37.590289   10.1016/j.fluid.2014.01.028
# 11                0.250          35.234334            10.1039/c9cp00036d
# 12                0.254          41.597359     10.1016/j.jct.2018.07.031
# 13                0.342          34.740694   10.1016/j.fluid.2014.01.028
# 14                0.400          31.063405                            NO
# 15                0.402          33.526415   10.1016/j.fluid.2014.01.028
# 16                0.500          26.200012            10.1039/c9cp00036d
# 17                0.598          28.874286   10.1016/j.fluid.2014.01.028
# 18                0.720          24.938581   10.1016/j.fluid.2014.01.028
# 19                0.750          22.789299            10.1039/c9cp00036d
# 20                0.800          22.366546   10.1016/j.fluid.2014.01.028
# 21                0.857          18.893528   10.1016/j.fluid.2014.01.028
# 22                0.900          16.528942            10.1039/c9cp00036d
# 23                0.901          17.207759   10.1016/j.fluid.2014.01.028
# 24                0.934          16.013872   10.1016/j.fluid.2014.01.028
# 25                0.960          15.546665   10.1016/j.fluid.2014.01.028
# 26                0.982          14.912522   10.1016/j.fluid.2014.01.028
# 27                1.000          14.303635            10.1039/c9cp00036d
# 28                1.000          13.957940   10.1016/j.fluid.2014.01.028
#
#      ordinate  statistic
# 0  -18.131910   0.998170
# 1  -18.998364   0.999017
# 2  -16.260954   0.996212
# 3  -19.938777   0.998271
# 4  -17.979190   0.996304
# 5  -19.540212   0.998521
# 6  -16.593692   1.000000
# 7  -17.079889   1.000000
# 8  -17.714444   0.996411
# 9  -17.089777   0.969991
# 10 -17.066439   0.995796
# 11 -16.115574   1.000000
# 12 -18.633964   0.998101
# 13 -16.344019   0.996203
# 14 -15.152492   0.994897
# 15 -16.112062   0.996679
# 16 -13.356711   0.955275
# 17 -15.259642   0.998425
# 18 -14.486951   0.997750
# 19 -13.978490   0.998256
# 20 -14.060410   0.996535
# 21 -13.195562   0.997762
# 22 -12.825185   0.998260
# 23 -12.922000   0.997371
# 24 -12.784446   0.995661
# 25 -12.863887   0.998110
# 26 -12.841238   0.997674
# 27 -12.920179   0.998713
# 28 -12.655573   0.996172
# Saved activation energy data to 'df_data_glyceline_ratio_or_pure_water.csv'

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import cm
from scipy.stats import linregress
import seaborn as sns

# Set a beautiful color palette
plt.style.use('default')
sns.set_palette("husl")

# Make sure required columns exist
required_cols = [
    "viscosity_value", 
    "temperature", 
    "source_doi", 
    "mole_fraction_water",
    "Solvent: Amount ratio of component to other component of binary solvent"
]
for col in required_cols:
    if col not in df_data_glyceline_ratio_or_pure_water.columns:
        raise ValueError(f"Column '{col}' not found in dataframe.")

# Filter on solvent ratio: keep rows where ratio <=2 or ratio is NaN (missing/None)
df_data_glyceline_ratio_or_pure_water_filtered = df_data_glyceline_ratio_or_pure_water[
    (df_data_glyceline_ratio_or_pure_water["Solvent: Amount ratio of component to other component of binary solvent"].isna()) |
    (df_data_glyceline_ratio_or_pure_water["Solvent: Amount ratio of component to other component of binary solvent"] <= 2)
].copy()

# Fill missing/None values in mole_fraction_water with 0
df_data_glyceline_ratio_or_pure_water_filtered["mole_fraction_water"] = (
    df_data_glyceline_ratio_or_pure_water_filtered["mole_fraction_water"]
    .fillna(0)
    .apply(lambda x: 0 if x is None else x)
)

# Clean for missing values in variables used
plot_df = df_data_glyceline_ratio_or_pure_water_filtered[
    df_data_glyceline_ratio_or_pure_water_filtered["viscosity_value"].notnull() &
    df_data_glyceline_ratio_or_pure_water_filtered["temperature"].notnull() &
    df_data_glyceline_ratio_or_pure_water_filtered["source_doi"].notnull()
].copy()

# Calculate ln(viscosity) and 1/(R*T)
R = 8.314  # J/(mol*K)
plot_df["inv_RT"] = 1000 / (R * plot_df["temperature"].astype(float))  # Factor 1000 for kJ
plot_df["ln_viscosity"] = np.log(plot_df["viscosity_value"].astype(float))

# Use mole_fraction_water to color the water amount
plot_df["water_mole_fraction"] = plot_df["mole_fraction_water"].astype(float)

# We'll use unique discrete values for source_doi as hue
unique_dois = np.sort(plot_df["source_doi"].unique())

# Set up beautiful colormap: use a curated set of distinct, pleasant colors
N = len(unique_dois)
# Curated beautiful color palette with distinct, pleasant colors
beautiful_colors = [
    '#ffba08',  # Amber Flame
    '#3185fc',  # Azure Blue
    '#8fe388',  # Light Green
    '#d00000',  # Brick Ember
    '#cbff8c',  # Lime Cream
    '#1b998b',  # Verdigris
    '#5d2e8c',  # Rebecca Purple
    '#46237a',  # Indigo Velvet
    '#ff7b9c',  # Petal Rouge
    '#ff9b85',  # Salmon
]

if N <= len(beautiful_colors):
    color_dict = {doi: beautiful_colors[i] for i, doi in enumerate(unique_dois)}
else:
    # Fall back to seaborn color palette for many DOIs
    colors = sns.color_palette("husl", N)
    color_dict = {doi: colors[i] for i, doi in enumerate(unique_dois)}

plt.figure(figsize=(11,7))
ax = plt.gca()

# Increase font size globally
plt.rcParams.update({'font.size': 14})

# Scatter points for each discrete DOI, so legend can be discrete
for i, doi in enumerate(unique_dois):
    subset = plot_df[plot_df["source_doi"] == doi]
    ax.scatter(
        subset["inv_RT"], 
        subset["ln_viscosity"], 
        color=color_dict[doi],
        s=80, 
        edgecolor='white',
        linewidth=1.5,
        alpha=0.8,
        label=f"{doi}"
    )

# Linear fit and store slopes per discrete water content, including source_doi
slope_results = []
# Round water mole fraction for grouping
plot_df["water_mole_fraction_rounded"] = plot_df["water_mole_fraction"].round(3)
discrete_mole_fractions = np.sort(plot_df["water_mole_fraction_rounded"].unique())

for mf in discrete_mole_fractions:
    group = plot_df[plot_df["water_mole_fraction_rounded"] == mf]
    # For each unique source_doi in this water content, do a fit for that subset
    for doi in group["source_doi"].unique():
        doi_group = group[group["source_doi"] == doi]
        if len(doi_group) >= 2:
            x = doi_group["inv_RT"].values
            y = doi_group["ln_viscosity"].values
            slope, intercept, r_value, p_value, std_err = linregress(x, y)
            xfit = np.linspace(x.min(), x.max(), 50)
            yfit = intercept + slope * xfit
            # Optionally: plot fits per color, commented
            # ax.plot(xfit, yfit, linestyle='--', linewidth=2, color=color_dict[doi])
            mf_tuple = (tuple(doi_group["mole_fractions"].iloc[0]) if "mole_fractions" in doi_group.columns and isinstance(doi_group["mole_fractions"].iloc[0], (list, tuple)) 
                        else doi_group["mole_fractions"].iloc[0] if "mole_fractions" in doi_group.columns else None)
            slope_results.append({
                "mole_fractions": mf_tuple,
                "water_mole_fraction": float(mf),
                "slope": slope,
                "source_doi": doi,
                "ordinate": intercept,
                "statistic": r_value,
                "color": color_dict[doi]
            })

# Create secondary x-axis for temperature
ax2 = ax.twiny()

# Get the range of 1/(R*T) values to create corresponding temperature values
inv_RT_min, inv_RT_max = ax.get_xlim()
T_max = 1000 / (R * inv_RT_min)  # Higher temperature corresponds to lower 1/(R*T), factor 1000 for kJ
T_min = 1000 / (R * inv_RT_max)  # Lower temperature corresponds to higher 1/(R*T), factor 1000 for kJ

# Set temperature ticks
temp_ticks = np.linspace(T_min, T_max, 6)  # 6 temperature points
inv_RT_ticks = 1000 / (R * temp_ticks)  # Factor 1000 for kJ

ax2.set_xlim(ax.get_xlim())
ax2.set_xticks(inv_RT_ticks)
ax2.set_xticklabels([f'{T:.0f}' for T in temp_ticks])
ax2.set_xlabel('Temperature / K', fontsize=16, color='#2C3E50')

# Make discrete legend without shadow
handles, labels = ax.get_legend_handles_labels()
by_label = dict(zip(labels, handles))
lgd = ax.legend(by_label.values(), by_label.keys(), title="Source DOI", 
               bbox_to_anchor=(1.04, 1), loc='upper left', borderaxespad=0., 
               fontsize=12, frameon=True, fancybox=True, shadow=False)
lgd.get_title().set_fontsize(14)
lgd.get_frame().set_facecolor('white')
lgd.get_frame().set_alpha(1.0)

plt.title('Arrhenius plot of Glyceline with different water mole fractions', 
          fontsize=16, color='#2C3E50', pad=20)
ax.set_xlabel('(RT)$^{-1}$ / mol kJ$^{-1}$', fontsize=16, color='#2C3E50')
ax.set_ylabel('ln($\eta$ / Pa$\cdot$s)', fontsize=16, color='#2C3E50')
ax.tick_params(axis='both', which='major', labelsize=12, colors='#34495E')
ax2.tick_params(axis='x', which='major', labelsize=12, colors='#34495E')

# Set white background color
ax.set_facecolor('white')
plt.tight_layout()
save_plot_as_svg()
plt.show()


activation_energy_df = pd.DataFrame(slope_results)
# Rename for clarity
activation_energy_df = activation_energy_df.rename(columns={'slope': 'activation_energy'})
# Ensure 'ordinate' and 'statistic' columns are present (they are, see above)
print("All linear fit activation energies by water mole fraction and source DOI, including ordinate and statistic:")
display(activation_energy_df[["water_mole_fraction", "activation_energy", "source_doi", "ordinate", "statistic", "color"]])

activation_energy_df['measurement'] = 'measured'
activation_energy_df.to_csv('activation_energy_results_measured.csv', index=False)

# Add color mapping to the filtered dataframe
df_data_glyceline_ratio_or_pure_water_filtered['color'] = df_data_glyceline_ratio_or_pure_water_filtered['source_doi'].map(color_dict)

# Add a column called 'measured' and fill it with 'measured'
df_data_glyceline_ratio_or_pure_water_filtered['measured'] = 'measured'

# Save the activation energy data to CSV
df_data_glyceline_ratio_or_pure_water_filtered.to_csv('df_data_glyceline_ratio_or_pure_water.csv', index=False)
print("Saved activation energy data to 'df_data_glyceline_ratio_or_pure_water.csv'")
# Out:
# <>:158: SyntaxWarning: invalid escape sequence '\e'
# <>:158: SyntaxWarning: invalid escape sequence '\e'
# /tmp/ipykernel_13941/3599414777.py:158: SyntaxWarning: invalid escape sequence '\e'
#   ax.set_ylabel('ln($\eta$ / Pa$\cdot$s)', fontsize=16, color='#2C3E50')
# ✓ Plot gespeichert: image_output/Arrhenius_plot_of_Glyceline_with_different_water_m_22.svg (114,424 Bytes)
# All linear fit activation energies by water mole fraction and source DOI, including ordinate and statistic:
#     water_mole_fraction  activation_energy                    source_doi  \
# 0                 0.000          41.606068                            NO
# 1                 0.000          43.647835            10.1039/C1CP22554E
# 2                 0.000          37.401011  10.1016/j.molliq.2015.11.032
# 3                 0.000          46.748109     10.1016/j.jct.2018.07.031
# 4                 0.000          41.925535   10.1016/j.fluid.2014.01.028
# 5                 0.000          45.099537            10.1039/c0gc00395f
# 6                 0.000          38.699622            10.1039/c9cp00036d
# 7                 0.100          39.132853            10.1039/c9cp00036d
# 8                 0.108          40.366403   10.1016/j.fluid.2014.01.028
# 9                 0.156          38.285661                            NO
# 10                0.238          37.590289   10.1016/j.fluid.2014.01.028
# 11                0.250          35.234334            10.1039/c9cp00036d
# 12                0.254          41.597359     10.1016/j.jct.2018.07.031
# 13                0.342          34.740694   10.1016/j.fluid.2014.01.028
# 14                0.400          31.063405                            NO
# 15                0.402          33.526415   10.1016/j.fluid.2014.01.028
# 16                0.500          26.200012            10.1039/c9cp00036d
# 17                0.598          28.874286   10.1016/j.fluid.2014.01.028
# 18                0.720          24.938581   10.1016/j.fluid.2014.01.028
# 19                0.750          22.789299            10.1039/c9cp00036d
# 20                0.800          22.366546   10.1016/j.fluid.2014.01.028
# 21                0.857          18.893528   10.1016/j.fluid.2014.01.028
# 22                0.900          16.528942            10.1039/c9cp00036d
# 23                0.901          17.207759   10.1016/j.fluid.2014.01.028
# 24                0.934          16.013872   10.1016/j.fluid.2014.01.028
# 25                0.960          15.546665   10.1016/j.fluid.2014.01.028
# 26                0.982          14.912522   10.1016/j.fluid.2014.01.028
# 27                1.000          14.303635            10.1039/c9cp00036d
# 28                1.000          13.957940   10.1016/j.fluid.2014.01.028
#
#      ordinate  statistic                                              color
# 0  -18.131910   0.998170  (0.9628653850704804, 0.4025928454059796, 0.777...
# 1  -18.998364   0.999017  (0.21420912437215422, 0.6714963557258681, 0.69...
# 2  -16.260954   0.996212  (0.5432776721247529, 0.6540981095185215, 0.193...
# 3  -19.938777   0.998271  (0.710130687316902, 0.6046852192663268, 0.1942...
# 4  -17.979190   0.996304  (0.8836443049112893, 0.5240073524369634, 0.195...
# 5  -19.540212   0.998521  (0.5596943802099308, 0.5764402169887779, 0.958...
# 6  -16.593692   1.000000  (0.8578978803740233, 0.44058452715322166, 0.95...
# 7  -17.079889   1.000000  (0.8578978803740233, 0.44058452715322166, 0.95...
# 8  -17.714444   0.996411  (0.8836443049112893, 0.5240073524369634, 0.195...
# 9  -17.089777   0.969991  (0.9628653850704804, 0.4025928454059796, 0.777...
# 10 -17.066439   0.995796  (0.8836443049112893, 0.5240073524369634, 0.195...
# 11 -16.115574   1.000000  (0.8578978803740233, 0.44058452715322166, 0.95...
# 12 -18.633964   0.998101  (0.710130687316902, 0.6046852192663268, 0.1942...
# 13 -16.344019   0.996203  (0.8836443049112893, 0.5240073524369634, 0.195...
# 14 -15.152492   0.994897  (0.9628653850704804, 0.4025928454059796, 0.777...
# 15 -16.112062   0.996679  (0.8836443049112893, 0.5240073524369634, 0.195...
# 16 -13.356711   0.955275  (0.8578978803740233, 0.44058452715322166, 0.95...
# 17 -15.259642   0.998425  (0.8836443049112893, 0.5240073524369634, 0.195...
# 18 -14.486951   0.997750  (0.8836443049112893, 0.5240073524369634, 0.195...
# 19 -13.978490   0.998256  (0.8578978803740233, 0.44058452715322166, 0.95...
# 20 -14.060410   0.996535  (0.8836443049112893, 0.5240073524369634, 0.195...
# 21 -13.195562   0.997762  (0.8836443049112893, 0.5240073524369634, 0.195...
# 22 -12.825185   0.998260  (0.8578978803740233, 0.44058452715322166, 0.95...
# 23 -12.922000   0.997371  (0.8836443049112893, 0.5240073524369634, 0.195...
# 24 -12.784446   0.995661  (0.8836443049112893, 0.5240073524369634, 0.195...
# 25 -12.863887   0.998110  (0.8836443049112893, 0.5240073524369634, 0.195...
# 26 -12.841238   0.997674  (0.8836443049112893, 0.5240073524369634, 0.195...
# 27 -12.920179   0.998713  (0.8578978803740233, 0.44058452715322166, 0.95...
# 28 -12.655573   0.996172  (0.8836443049112893, 0.5240073524369634, 0.195...
# Saved activation energy data to 'df_data_glyceline_ratio_or_pure_water.csv'

# %%
df_data_glyceline_ratio_or_pure_water_filtered = df_data_glyceline_ratio_or_pure_water_filtered[
    (df_data_glyceline_ratio_or_pure_water_filtered['temperature'] > 293) &
    (df_data_glyceline_ratio_or_pure_water_filtered['temperature'] < 335)
]

# Clean for missing values in variables used
plot_df = df_data_glyceline_ratio_or_pure_water_filtered[
    df_data_glyceline_ratio_or_pure_water_filtered["viscosity_value"].notnull() &
    df_data_glyceline_ratio_or_pure_water_filtered["temperature"].notnull() &
    df_data_glyceline_ratio_or_pure_water_filtered["source_doi"].notnull()
].copy()

# Calculate ln(viscosity) and 1/(R*T)
R = 8.314  # J/(mol*K)
plot_df["inv_RT"] = 1000 / (R * plot_df["temperature"].astype(float))  # Factor 1000 for kJ instead of J
plot_df["ln_viscosity"] = np.log(plot_df["viscosity_value"].astype(float))

# Use mole_fraction_water to color the water amount
plot_df["water_mole_fraction"] = plot_df["mole_fraction_water"].astype(float)

# We'll use unique discrete values for source_doi as hue
unique_dois = np.sort(plot_df["source_doi"].unique())

# Set up beautiful colormap: use a curated set of distinct, pleasant colors
N = len(unique_dois)
# Curated beautiful color palette with distinct, pleasant colors
beautiful_colors = [
    '#ffba08',  # Amber Flame
    '#3185fc',  # Azure Blue
    '#8fe388',  # Light Green
    '#d00000',  # Brick Ember
    '#cbff8c',  # Lime Cream
    '#1b998b',  # Verdigris
    '#5d2e8c',  # Rebecca Purple
    '#46237a',  # Indigo Velvet
    '#ff7b9c',  # Petal Rouge
    '#ff9b85',  # Salmon
]

if N <= len(beautiful_colors):
    color_dict = {doi: beautiful_colors[i] for i, doi in enumerate(unique_dois)}
else:
    # Fall back to seaborn color palette for many DOIs
    colors = sns.color_palette("husl", N)
    # Convert RGB tuples to hex strings
    color_dict = {doi: '#{:02x}{:02x}{:02x}'.format(int(colors[i][0]*255), int(colors[i][1]*255), int(colors[i][2]*255)) for i, doi in enumerate(unique_dois)}

plt.figure(figsize=(11,7))
ax = plt.gca()

# Increase font size globally
plt.rcParams.update({'font.size': 14})

# Scatter points for each discrete DOI, so legend can be discrete
for i, doi in enumerate(unique_dois):
    subset = plot_df[plot_df["source_doi"] == doi]
    ax.scatter(
        subset["inv_RT"], 
        subset["ln_viscosity"], 
        color=color_dict[doi],
        s=80, 
        edgecolor='white',
        linewidth=1.5,
        alpha=0.8,
        label=f"{doi}"
    )

# Linear fit and store slopes per discrete water content, including source_doi
slope_results = []
# Round water mole fraction for grouping
plot_df["water_mole_fraction_rounded"] = plot_df["water_mole_fraction"].round(3)
discrete_mole_fractions = np.sort(plot_df["water_mole_fraction_rounded"].unique())

for mf in discrete_mole_fractions:
    group = plot_df[plot_df["water_mole_fraction_rounded"] == mf]
    # For each unique source_doi in this water content, do a fit for that subset
    for doi in group["source_doi"].unique():
        doi_group = group[group["source_doi"] == doi]
        if len(doi_group) >= 2:
            x = doi_group["inv_RT"].values
            y = doi_group["ln_viscosity"].values
            slope, intercept, r_value, p_value, std_err = linregress(x, y)
            xfit = np.linspace(x.min(), x.max(), 50)
            yfit = intercept + slope * xfit
            # Optionally: plot fits per color, commented
            # ax.plot(xfit, yfit, linestyle='--', linewidth=2, color=color_dict[doi])
            mf_tuple = (tuple(doi_group["mole_fractions"].iloc[0]) if "mole_fractions" in doi_group.columns and isinstance(doi_group["mole_fractions"].iloc[0], (list, tuple)) 
                        else doi_group["mole_fractions"].iloc[0] if "mole_fractions" in doi_group.columns else None)
            slope_results.append({
                "mole_fractions": mf_tuple,
                "water_mole_fraction": float(mf),
                "slope": slope,
                "source_doi": doi,
                "ordinate": intercept,
                "statistic": r_value,
                "color": color_dict[doi]
            })

# Create secondary x-axis for temperature
ax2 = ax.twiny()

# Get the range of 1/(R*T) values to create corresponding temperature values
inv_RT_min, inv_RT_max = ax.get_xlim()
T_max = 1000 / (R * inv_RT_min)  # Higher temperature corresponds to lower 1/(R*T), factor 1000 for kJ
T_min = 1000 / (R * inv_RT_max)  # Lower temperature corresponds to higher 1/(R*T), factor 1000 for kJ

# Set temperature ticks
temp_ticks = np.linspace(T_min, T_max, 6)  # 6 temperature points
inv_RT_ticks = 1000 / (R * temp_ticks)  # Factor 1000 for kJ

ax2.set_xlim(ax.get_xlim())
ax2.set_xticks(inv_RT_ticks)
ax2.set_xticklabels([f'{T:.0f}' for T in temp_ticks])
ax2.set_xlabel('Temperature / K', fontsize=16, color='#2C3E50')

# Make discrete legend without shadow
handles, labels = ax.get_legend_handles_labels()
by_label = dict(zip(labels, handles))
lgd = ax.legend(by_label.values(), by_label.keys(), title="Source DOI", 
               bbox_to_anchor=(1.04, 1), loc='upper left', borderaxespad=0., 
               fontsize=12, frameon=True, fancybox=True, shadow=False)
lgd.get_title().set_fontsize(14)
lgd.get_frame().set_facecolor('white')
lgd.get_frame().set_alpha(1.0)

plt.title('Arrhenius plot of Glyceline with different water mole fractions', 
          fontsize=16, color='#2C3E50', pad=20)
ax.set_xlabel('(RT)$^{-1}$ / mol kJ$^{-1}$', fontsize=16, color='#2C3E50')
ax.set_ylabel('ln($\eta$ / Pa$\cdot$s)', fontsize=16, color='#2C3E50')
ax.tick_params(axis='both', which='major', labelsize=12, colors='#34495E')
ax2.tick_params(axis='x', which='major', labelsize=12, colors='#34495E')

# Set white background color
ax.set_facecolor('white')
plt.tight_layout()
save_plot_as_svg()
plt.show()

import pandas as pd
activation_energy_df = pd.DataFrame(slope_results)
# Rename for clarity
activation_energy_df_og = activation_energy_df.rename(columns={'slope': 'activation_energy'})
# Ensure 'ordinate' and 'statistic' columns are present (they are, see above)
print("All linear fit activation energies by water mole fraction and source DOI, including ordinate and statistic:")
display(activation_energy_df_og[["water_mole_fraction", "activation_energy", "source_doi", "ordinate", "statistic", "color"]])

activation_energy_df_og['measurement'] = 'measured'
activation_energy_df_og.to_csv('activation_energy_results_measured.csv', index=False)


# Add a column called 'measured' and fill it with 'measured'
df_data_glyceline_ratio_or_pure_water_filtered['measured'] = 'measured'

# Save the activation energy data to CSV
df_data_glyceline_ratio_or_pure_water_filtered.to_csv('df_data_glyceline_ratio_or_pure_water.csv', index=False)
print("Saved activation energy data to 'df_data_glyceline_ratio_or_pure_water.csv'")
# Out:
# <>:129: SyntaxWarning: invalid escape sequence '\e'
# <>:129: SyntaxWarning: invalid escape sequence '\e'
# /tmp/ipykernel_13941/85001520.py:129: SyntaxWarning: invalid escape sequence '\e'
#   ax.set_ylabel('ln($\eta$ / Pa$\cdot$s)', fontsize=16, color='#2C3E50')
# ✓ Plot gespeichert: image_output/Arrhenius_plot_of_Glyceline_with_different_water_m_24.svg (100,302 Bytes)
# All linear fit activation energies by water mole fraction and source DOI, including ordinate and statistic:
#     water_mole_fraction  activation_energy                    source_doi  \
# 0                 0.000          43.992360                            NO
# 1                 0.000          43.647835            10.1039/C1CP22554E
# 2                 0.000          41.128327  10.1016/j.molliq.2015.11.032
# 3                 0.000          44.548167     10.1016/j.jct.2018.07.031
# 4                 0.000          44.401167   10.1016/j.fluid.2014.01.028
# 5                 0.000          45.099537            10.1039/c0gc00395f
# 6                 0.108          42.740921   10.1016/j.fluid.2014.01.028
# 7                 0.156          45.115184                            NO
# 8                 0.238          39.488831   10.1016/j.fluid.2014.01.028
# 9                 0.254          39.548897     10.1016/j.jct.2018.07.031
# 10                0.342          36.501575   10.1016/j.fluid.2014.01.028
# 11                0.400          31.573940                            NO
# 12                0.402          34.973907   10.1016/j.fluid.2014.01.028
# 13                0.598          29.268034   10.1016/j.fluid.2014.01.028
# 14                0.720          26.577674   10.1016/j.fluid.2014.01.028
# 15                0.800          23.944943   10.1016/j.fluid.2014.01.028
# 16                0.857          19.622711   10.1016/j.fluid.2014.01.028
# 17                0.901          17.975769   10.1016/j.fluid.2014.01.028
# 18                0.934          16.799950   10.1016/j.fluid.2014.01.028
# 19                0.960          15.868361   10.1016/j.fluid.2014.01.028
# 20                0.982          15.423006   10.1016/j.fluid.2014.01.028
# 21                1.000          14.762093   10.1016/j.fluid.2014.01.028
#
#      ordinate  statistic    color
# 0  -19.071649   0.998664  #f566c6
# 1  -18.998364   0.999017  #36abb2
# 2  -17.701857   0.999505  #8aa631
# 3  -19.123307   0.999280  #b59a31
# 4  -19.007296   0.998474  #e18531
# 5  -19.540212   0.998521  #8e92f4
# 6  -18.699900   0.999226  #e18531
# 7  -19.780154   0.963541  #f566c6
# 8  -17.869946   0.997722  #e18531
# 9  -17.874516   0.999111  #b59a31
# 10 -17.086597   0.998807  #e18531
# 11 -15.401781   0.996301  #f566c6
# 12 -16.728736   0.998840  #e18531
# 13 -15.442099   0.999593  #e18531
# 14 -15.150848   0.999486  #e18531
# 15 -14.704598   0.997546  #e18531
# 16 -13.503074   0.999362  #e18531
# 17 -13.243867   0.999348  #e18531
# 18 -13.111616   0.999229  #e18531
# 19 -13.007854   0.999068  #e18531
# 20 -13.059134   0.999355  #e18531
# 21 -12.993980   0.998826  #e18531
# Saved activation energy data to 'df_data_glyceline_ratio_or_pure_water.csv'

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

# Use the color column directly
colors = activation_energy_df_og['color']

# Convert activation energy from J/mol to kJ/mol
activation_energy_kJ = activation_energy_df_og['activation_energy'] / 1000

scatter = plt.scatter(
    activation_energy_df_og['water_mole_fraction'],
    activation_energy_kJ,
    c=colors,
    s=30,
    edgecolor='w'
)

# Calculate mean activation energy for 0 and 1 water fraction (in kJ/mol)
mean_0_water = activation_energy_df_og[activation_energy_df_og['water_mole_fraction'] == 0.0]['activation_energy'].mean() / 1000
mean_1_water = activation_energy_df_og[activation_energy_df_og['water_mole_fraction'] == 1.0]['activation_energy'].mean() / 1000

# Add red line between the means
plt.plot([0.0, 1.0], [mean_0_water, mean_1_water], 'r--', linewidth=1, label='Mean trend')

# Make a discrete legend per source_doi using the color column
unique_dois = activation_energy_df_og['source_doi'].unique()
from matplotlib.patches import Patch
legend_handles = []
for doi in unique_dois:
    # Get the color for this DOI from the first occurrence
    color = activation_energy_df_og[activation_energy_df_og['source_doi'] == doi]['color'].iloc[0]
    legend_handles.append(Patch(facecolor=color, edgecolor='k', label=f"{doi}"))

plt.legend(handles=legend_handles, title="Source DOI", bbox_to_anchor=(1.04, 1), loc='upper left', fontsize=10)

plt.xlabel(r'$\chi_W$')
plt.ylabel(r'Activation Energy $E_a$ / $kJ \cdot mol^{-1}$')
plt.tight_layout()
save_plot_as_svg()
plt.show()
# Out:
# ✓ Plot gespeichert: image_output/plot_25.svg (49,620 Bytes)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

# Use the color column directly
colors = activation_energy_df['color']

# Convert activation energy from J/mol to kJ/mol
activation_energy_kJ = activation_energy_df['activation_energy'] / 1000

scatter = plt.scatter(
    activation_energy_df['water_mole_fraction'],
    activation_energy_kJ,
    c=colors,
    s=80,
    edgecolor='w'
)

# Calculate mean activation energy for 0 and 1 water fraction (in kJ/mol)
mean_0_water = activation_energy_df[activation_energy_df['water_mole_fraction'] == 0.0]['activation_energy'].mean() / 1000
mean_1_water = activation_energy_df[activation_energy_df['water_mole_fraction'] == 1.0]['activation_energy'].mean() / 1000

# Add red line between the means
plt.plot([0.0, 1.0], [mean_0_water, mean_1_water], 'r--', linewidth=1, label='Mean trend')

# Make a discrete legend per source_doi using the color column
unique_dois = activation_energy_df['source_doi'].unique()
from matplotlib.patches import Patch
legend_handles = []
for doi in unique_dois:
    # Get the color for this DOI from the first occurrence
    color = activation_energy_df[activation_energy_df['source_doi'] == doi]['color'].iloc[0]
    legend_handles.append(Patch(facecolor=color, edgecolor='k', label=f"{doi}"))

plt.legend(handles=legend_handles, title="Source DOI", bbox_to_anchor=(1.04, 1), loc='upper left', fontsize=10)

plt.xlabel('$\chi_W$')
plt.ylabel('Activation Energy $E_a$ / $kJ \cdot mol^{-1}$')
plt.tight_layout()
save_plot_as_svg()
plt.show()
# Out:
# <>:37: SyntaxWarning: invalid escape sequence '\c'
# <>:38: SyntaxWarning: invalid escape sequence '\c'
# <>:37: SyntaxWarning: invalid escape sequence '\c'
# <>:38: SyntaxWarning: invalid escape sequence '\c'
# /tmp/ipykernel_13941/1355864785.py:37: SyntaxWarning: invalid escape sequence '\c'
#   plt.xlabel('$\chi_W$')
# /tmp/ipykernel_13941/1355864785.py:38: SyntaxWarning: invalid escape sequence '\c'
#   plt.ylabel('Activation Energy $E_a$ / $kJ \cdot mol^{-1}$')
# /tmp/ipykernel_13941/1355864785.py:37: SyntaxWarning: invalid escape sequence '\c'
#   plt.xlabel('$\chi_W$')
# /tmp/ipykernel_13941/1355864785.py:38: SyntaxWarning: invalid escape sequence '\c'
#   plt.ylabel('Activation Energy $E_a$ / $kJ \cdot mol^{-1}$')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Applications/miniconda3/envs/xyz/lib/python3.13/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'activation_energy'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[48], line 9
#       6 colors = activation_energy_df['color']
#       8 # Convert activation energy from J/mol to kJ/mol
# ----> 9 activation_energy_kJ = activation_energy_df['activation_energy'] / 1000
#      11 scatter = plt.scatter(
#      12     activation_energy_df['water_mole_fraction'],
#      13     activation_energy_kJ,
#    (...)     16     edgecolor='w'
#      17 )
#      19 # Calculate mean activation energy for 0 and 1 water fraction (in kJ/mol)
#
# File ~/Applications/miniconda3/envs/xyz/lib/python3.13/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/Applications/miniconda3/envs/xyz/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'activation_energy'

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(10, 6))

# Separate data for water_mole_fraction == 0 and others
zero_water_data = activation_energy_df[activation_energy_df['water_mole_fraction'] == 0.0]
other_data = activation_energy_df[activation_energy_df['water_mole_fraction'] != 0.0]

# Calculate mean activation energy for zero water content (in kJ/mol)
mean_0_water = zero_water_data['activation_energy'].mean() / 1000
mean_1_water = activation_energy_df[activation_energy_df['water_mole_fraction'] == 1.0]['activation_energy'].mean() / 1000

# Calculate the linear trend line values for each data point
water_fractions = activation_energy_df['water_mole_fraction']
trend_line_values = mean_0_water + (mean_1_water - mean_0_water) * water_fractions

# Calculate residues for all data points
activation_energy_kJ = activation_energy_df['activation_energy'] / 1000
residues = activation_energy_kJ - trend_line_values

# Plot zero water content points individually
zero_water_residues = residues[activation_energy_df['water_mole_fraction'] == 0.0]
plt.scatter(
    zero_water_data['water_mole_fraction'],
    zero_water_residues,
    c=zero_water_data['color'],
    s=80,
    edgecolor='w'
)

# For zero water content, also calculate residue for the mean point
zero_water_residue = mean_0_water - mean_0_water  # This will be 0

# Plot the mean point for zero water content
plt.scatter(
    0.0,
    zero_water_residue,
    c='black',
    s=120,
    edgecolor='w',
    marker='D',
    label='Mean (0% water)'
)

# Plot other data points colored by DOI
scatter = plt.scatter(
    other_data['water_mole_fraction'],
    residues[activation_energy_df['water_mole_fraction'] != 0.0],
    c=other_data['color'],
    s=80,
    edgecolor='w'
)

# Add dotted red line connecting mean at mole fraction 0 to mole fraction 1
one_water_residue = mean_1_water - (mean_0_water + (mean_1_water - mean_0_water) * 1.0)
plt.plot([0.0, 1.0], [zero_water_residue, one_water_residue], 'r:', linewidth=2, label='Mean trend')

# Make a discrete legend per source_doi using the color column
unique_dois = activation_energy_df['source_doi'].unique()
from matplotlib.patches import Patch
legend_handles = []
for doi in unique_dois:
    # Get the color for this DOI from the first occurrence
    color = activation_energy_df[activation_energy_df['source_doi'] == doi]['color'].iloc[0]
    legend_handles.append(Patch(facecolor=color, edgecolor='k', label=f"{doi}"))

legend_handles.append(Patch(facecolor='black', edgecolor='k', label='Mean of Activation Energy at $\chi_W = 0$'))

plt.legend(handles=legend_handles, title="Source DOI", bbox_to_anchor=(1.04, 1), loc='upper left', fontsize=10)

plt.xlabel('$\chi_W$')
plt.ylabel('$\Delta E_a^{excess}$ / $kJ \cdot mol^{-1}$')
plt.tight_layout()
save_plot_as_svg()
plt.show()
# Out:
# <>:68: SyntaxWarning: invalid escape sequence '\c'
# <>:72: SyntaxWarning: invalid escape sequence '\c'
# <>:73: SyntaxWarning: invalid escape sequence '\D'
# <>:68: SyntaxWarning: invalid escape sequence '\c'
# <>:72: SyntaxWarning: invalid escape sequence '\c'
# <>:73: SyntaxWarning: invalid escape sequence '\D'
# /tmp/ipykernel_17091/2251435907.py:68: SyntaxWarning: invalid escape sequence '\c'
#   legend_handles.append(Patch(facecolor='black', edgecolor='k', label='Mean of Activation Energy at $\chi_W = 0$'))
# /tmp/ipykernel_17091/2251435907.py:72: SyntaxWarning: invalid escape sequence '\c'
#   plt.xlabel('$\chi_W$')
# /tmp/ipykernel_17091/2251435907.py:73: SyntaxWarning: invalid escape sequence '\D'
#   plt.ylabel('$\Delta E_a^{excess}$ / $kJ \cdot mol^{-1}$')
# ✓ Plot gespeichert: image_output/plot_11.svg (54,384 Bytes)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

# Use the color column directly
colors = activation_energy_df['color']

# Convert activation energy from J/mol to kJ/mol
activation_energy_kJ = activation_energy_df['activation_energy'] / 1000

scatter = plt.scatter(
    activation_energy_df['ordinate'],
    activation_energy_kJ,
    c=colors,
    s=60
)

# Make a discrete legend per source_doi using the color column
unique_dois = activation_energy_df['source_doi'].unique()
from matplotlib.patches import Patch
legend_handles = []
for doi in unique_dois:
    # Get the color for this DOI from the first occurrence
    color = activation_energy_df[activation_energy_df['source_doi'] == doi]['color'].iloc[0]
    legend_handles.append(Patch(facecolor=color, label=f"{doi}"))

plt.legend(handles=legend_handles, title="Source DOI", bbox_to_anchor=(1.04, 1), loc='upper left')

plt.xlabel('ln(As / Pa·s)')
plt.ylabel('Activation Energy $E_a$ / $kJ \cdot mol^{-1}$')

plt.tight_layout()
save_plot_as_svg()
plt.show()
# Out:
# <>:30: SyntaxWarning: invalid escape sequence '\c'
# <>:30: SyntaxWarning: invalid escape sequence '\c'
# /tmp/ipykernel_17091/3236673562.py:30: SyntaxWarning: invalid escape sequence '\c'
#   plt.ylabel('Activation Energy $E_a$ / $kJ \cdot mol^{-1}$')
# ✓ Plot gespeichert: image_output/plot_12.svg (48,582 Bytes)

# %%
activation_energy_df_combined = pd.concat([activation_energy_df, activation_energies_pure], ignore_index=True)
if 'mole_fractions' in activation_energy_df_combined.columns:
    activation_energy_df_combined = activation_energy_df_combined.drop(columns=['mole_fractions'])
activation_energy_df_combined['molar_ratio'] = activation_energy_df_combined['molar_ratio'].fillna(2)
activation_energy_df_combined
# Out:
#     water_mole_fraction  activation_energy                    source_doi  \
# 0                 0.000          46.748109     10.1016/j.jct.2018.07.031
# 1                 0.000          37.401011  10.1016/j.molliq.2015.11.032
# 2                 0.000          43.647835            10.1039/c1cp22554e
# 3                 0.000          45.099537            10.1039/c0gc00395f
# 4                 0.000          41.925535   10.1016/j.fluid.2014.01.028
# 5                 0.108          40.366403   10.1016/j.fluid.2014.01.028
# 6                 0.238          37.590289   10.1016/j.fluid.2014.01.028
# 7                 0.254          41.597359     10.1016/j.jct.2018.07.031
# 8                 0.342          34.740694   10.1016/j.fluid.2014.01.028
# 9                 0.402          33.526415   10.1016/j.fluid.2014.01.028
# 10                0.598          28.874286   10.1016/j.fluid.2014.01.028
# 11                0.720          24.938581   10.1016/j.fluid.2014.01.028
# 12                0.800          22.366546   10.1016/j.fluid.2014.01.028
# 13                0.857          18.893528   10.1016/j.fluid.2014.01.028
# 14                0.901          17.207759   10.1016/j.fluid.2014.01.028
# 15                0.934          16.013872   10.1016/j.fluid.2014.01.028
# 16                0.960          15.546665   10.1016/j.fluid.2014.01.028
# 17                0.982          14.912522   10.1016/j.fluid.2014.01.028
# 18                1.000          13.957940   10.1016/j.fluid.2014.01.028
# 19                0.000       45502.133942            10.1039/c0gc00395f
# 20                0.000       47045.892294            10.1039/c0gc00395f
# 21                0.000       48304.321208            10.1039/c0gc00395f
# 22                0.000       50296.423067            10.1039/c0gc00395f
# 23                0.000       53401.786797            10.1039/c0gc00395f
# 24                0.000       54772.293625            10.1039/c0gc00395f
#
#      ordinate  statistic    color measurement  molar_ratio
# 0  -19.938777   0.998271  #8fe388    measured          2.0
# 1  -16.260954   0.996212  #d00000    measured          2.0
# 2  -18.998364   0.999017  #5d2e8c    measured          2.0
# 3  -19.540212   0.998521  #1b998b    measured          2.0
# 4  -17.979190   0.996304  #3185fc    measured          2.0
# 5  -17.714444   0.996411  #3185fc    measured          2.0
# 6  -17.066439   0.995796  #3185fc    measured          2.0
# 7  -18.633964   0.998101  #8fe388    measured          2.0
# 8  -16.344019   0.996203  #3185fc    measured          2.0
# 9  -16.112062   0.996679  #3185fc    measured          2.0
# 10 -15.259642   0.998425  #3185fc    measured          2.0
# 11 -14.486951   0.997750  #3185fc    measured          2.0
# 12 -14.060410   0.996535  #3185fc    measured          2.0
# 13 -13.195562   0.997762  #3185fc    measured          2.0
# 14 -12.922000   0.997371  #3185fc    measured          2.0
# 15 -12.784446   0.995661  #3185fc    measured          2.0
# 16 -12.863887   0.998110  #3185fc    measured          2.0
# 17 -12.841238   0.997674  #3185fc    measured          2.0
# 18 -12.655573   0.996172  #3185fc    measured          2.0
# 19 -19.587819   0.999903      NaN         NaN          2.3
# 20 -20.124261   0.999625      NaN         NaN          3.0
# 21 -20.543573   0.997493      NaN         NaN          4.0
# 22 -21.256798   0.999803      NaN         NaN          5.7
# 23 -22.208433   0.999157      NaN         NaN          9.0
# 24 -22.513597   0.999573      NaN         NaN         19.0

# %%
# Apply the activation energy calculation logic from Cell 11 (lines 1-97) 
# to the data from Cell 15/16 (lines 1-186)
# This splits the data by temperature groups and calculates activation energies

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Use the plot_df from Cell 15/16 (or recreate it if needed)
# Make sure we have the filtered data with inv_RT and ln_viscosity calculated
if 'plot_df' not in locals() and 'plot_df' not in globals():
    # Recreate plot_df from df_data_glyceline_ratio_or_pure_water_filtered if it exists
    if 'df_data_glyceline_ratio_or_pure_water_filtered' in locals() or 'df_data_glyceline_ratio_or_pure_water_filtered' in globals():
        plot_df = df_data_glyceline_ratio_or_pure_water_filtered[
            df_data_glyceline_ratio_or_pure_water_filtered["viscosity_value"].notnull() &
            df_data_glyceline_ratio_or_pure_water_filtered["temperature"].notnull() &
            df_data_glyceline_ratio_or_pure_water_filtered["source_doi"].notnull()
        ].copy()
        
        R = 8.314  # J/(mol*K)
        plot_df["inv_RT"] = 1 / (R * plot_df["temperature"].astype(float))
        plot_df["ln_viscosity"] = np.log(plot_df["viscosity_value"].astype(float)/1000)
    else:
        raise ValueError("plot_df or df_data_glyceline_ratio_or_pure_water_filtered not found. Please run Cell 15/16 first.")

# Create a composition identifier from mole_fractions for grouping
# Convert mole_fractions to tuple for grouping (if it's a list/tuple)
def get_composition_key(mf):
    """Convert mole_fractions to a hashable tuple for grouping."""
    if isinstance(mf, (list, tuple)):
        # Round to 3 decimal places for grouping similar compositions
        return tuple(round(x, 3) for x in mf)
    elif pd.isna(mf):
        return None
    else:
        return (round(float(mf), 3),)

plot_df = plot_df.copy()
plot_df['composition_key'] = plot_df['mole_fractions'].apply(get_composition_key)

# Get unique combinations of DOI and composition
doi_composition_combinations = plot_df[
    plot_df['composition_key'].notna() &
    plot_df['source_doi'].notna() &
    (~plot_df["inv_RT"].isna()) &
    (~plot_df["ln_viscosity"].isna())
][['source_doi', 'composition_key']].drop_duplicates()

# List to store all split data
split_data = []

# Process each valid DOI-composition combination - split into temperature groups (High T and Low T)
for _, row in doi_composition_combinations.iterrows():
    doi = row['source_doi']
    comp_key = row['composition_key']
    
    subset = plot_df[
        (plot_df["source_doi"] == doi) &
        (plot_df["composition_key"] == comp_key) &
        (~plot_df["inv_RT"].isna()) &
        (~plot_df["ln_viscosity"].isna())
    ]
    
    if len(subset) < 2:
        continue  # Not enough points to split
    
    # Sort by temperature (inverse of inv_RT for proper ordering)
    subset_sorted = subset.sort_values('inv_RT')
    
    # Split into two halves based on temperature
    n_points = len(subset_sorted)
    mid_point = n_points // 2
    
    # Lower half (higher temperatures - lower inv_RT values)
    low_temp_group = subset_sorted.iloc[:mid_point].copy()
    low_temp_group['temperature_group'] = 'High T'
    
    # Upper half (lower temperatures - higher inv_RT values)  
    high_temp_group = subset_sorted.iloc[mid_point:].copy()
    high_temp_group['temperature_group'] = 'Low T'
    
    # Add to split_data list
    split_data.append(low_temp_group)
    split_data.append(high_temp_group)

# Combine all split data into a single DataFrame
split_points_df = pd.concat(split_data, ignore_index=True)

print(f"Split points DataFrame shape: {split_points_df.shape}")
print("\nTemperature group distribution:")
print(split_points_df['temperature_group'].value_counts())
display(split_points_df.head(10))

# Now apply the activation energy calculation logic from Cell 11
R = 8.314462618  # J/mol/K (universal gas constant)

group_activation_energies = []

# Get unique combinations of DOI, composition, and temperature group
doi_comp_temp_combinations = split_points_df[['source_doi', 'composition_key', 'temperature_group']].drop_duplicates()

for _, row in doi_comp_temp_combinations.iterrows():
    doi = row['source_doi']
    comp_key = row['composition_key']
    temp_group = row['temperature_group']
    
    subset = split_points_df[
        (split_points_df['source_doi'] == doi) & 
        (split_points_df['composition_key'] == comp_key) &
        (split_points_df['temperature_group'] == temp_group)
    ]
    
    if len(subset) < 2:
        continue  # Not enough points to fit
    
    # Calculate temperature range for this subset
    temp_min = subset['temperature'].min()
    temp_max = subset['temperature'].max()
    temp_range = f"{temp_min:.0f}-{temp_max:.0f}"
    
    # Fit: ln(viscosity) = slope * inv_RT + intercept
    x = subset["inv_RT"].values
    y = subset["ln_viscosity"].values
    
    # np.polyfit returns [slope, intercept]
    slope, intercept = np.polyfit(x, y, 1)
    E_a = slope * R  # activation energy in J/mol
    
    # Calculate R-squared for goodness of fit
    y_pred = slope * x + intercept
    ss_res = np.sum((y - y_pred) ** 2)
    ss_tot = np.sum((y - np.mean(y)) ** 2)
    r_squared = 1 - (ss_res / ss_tot)
    
    group_activation_energies.append({
        "source_doi": doi,
        "composition_key": comp_key,
        "temperature_group": temp_group,
        "temperature_range": temp_range,
        "activation_energy_J_per_mol": E_a,
        "arrhenius_prefactor_lnA": intercept,
        "r_squared": r_squared,
        "n_points": len(subset)
    })

# Also calculate activation energy for full temperature range for each DOI-composition combination
doi_comp_combinations = split_points_df[['source_doi', 'composition_key']].drop_duplicates()

for _, row in doi_comp_combinations.iterrows():
    doi = row['source_doi']
    comp_key = row['composition_key']
    subset = split_points_df[
        (split_points_df['source_doi'] == doi) &
        (split_points_df['composition_key'] == comp_key)
    ]
    
    if len(subset) < 2:
        continue  # Not enough points to fit
    
    # Calculate temperature range for this subset
    temp_min = subset['temperature'].min()
    temp_max = subset['temperature'].max()
    temp_range = f"{temp_min:.0f}-{temp_max:.0f}"
    
    # Fit: ln(viscosity) = slope * inv_RT + intercept
    x = subset["inv_RT"].values
    y = subset["ln_viscosity"].values
    
    # np.polyfit returns [slope, intercept]
    slope, intercept = np.polyfit(x, y, 1)
    E_a = slope * R  # activation energy in J/mol
    
    # Calculate R-squared for goodness of fit
    y_pred = slope * x + intercept
    ss_res = np.sum((y - y_pred) ** 2)
    ss_tot = np.sum((y - np.mean(y)) ** 2)
    r_squared = 1 - (ss_res / ss_tot)
    
    group_activation_energies.append({
        "source_doi": doi,
        "composition_key": comp_key,
        "temperature_group": "Full Range",
        "temperature_range": temp_range,
        "activation_energy_J_per_mol": E_a,
        "arrhenius_prefactor_lnA": intercept,
        "r_squared": r_squared,
        "n_points": len(subset)
    })

# Convert to DataFrame for summary display
group_activation_energy_df = pd.DataFrame(group_activation_energies)

print("\nActivation energies (E_a) and Arrhenius prefactor by DOI and temperature group:")
display(group_activation_energy_df)
# Out:
# Split points DataFrame shape: (203, 26)
#
# Temperature group distribution:
# temperature_group
# Low T     110
# High T     93
# Name: count, dtype: int64
#                        fluid_compounds property_type  property_value  \
# 0                              [Water]     viscosity        0.000331
# 1                              [Water]     viscosity        0.000386
# 2                              [Water]     viscosity        0.000435
# 3                              [Water]     viscosity        0.000477
# 4                              [Water]     viscosity        0.000549
# 5                              [Water]     viscosity        0.000649
# 6                              [Water]     viscosity        0.000791
# 7                              [Water]     viscosity        0.000984
# 8                              [Water]     viscosity        0.001274
# 9  [Choline Chloride, Glycerol, Water]     viscosity        0.000386
#
#    uncertainty  temperature                            mole_fractions  \
# 0     0.000002       363.15                                     [1.0]
# 1     0.000002       353.15                                     [1.0]
# 2     0.000002       343.15                                     [1.0]
# 3     0.000002       333.15                                     [1.0]
# 4     0.000003       323.15                                     [1.0]
# 5     0.000003       313.15                                     [1.0]
# 6     0.000004       303.15                                     [1.0]
# 7     0.000005       293.15                                     [1.0]
# 8     0.000006       283.15                                     [1.0]
# 9     0.000002       363.15  [0.006033333333, 0.012066666667, 0.9819]
#
#                          measurement_id                   source_doi  \
# 0  57752fcf-7087-418f-8443-180470bce062  10.1016/j.fluid.2014.01.028
# 1  a391af92-cf16-4076-bd90-c835c63511b9  10.1016/j.fluid.2014.01.028
# 2  dc548f08-57ea-4102-b45c-647ea283ef16  10.1016/j.fluid.2014.01.028
# 3  2dba9cd5-5ff5-4384-a5a7-eeea3df8b136  10.1016/j.fluid.2014.01.028
# 4  a320de01-0c91-4124-ba7d-5480fb9964fa  10.1016/j.fluid.2014.01.028
# 5  3ee182dd-7f4d-4242-b066-602461767760  10.1016/j.fluid.2014.01.028
# 6  a73fc0a6-3c04-4d27-b837-fda3899ab3f9  10.1016/j.fluid.2014.01.028
# 7  7bdb635e-bc87-4a76-aff9-ed2266d7ecd3  10.1016/j.fluid.2014.01.028
# 8  47179c39-a8ad-446e-a401-6bd775b8f5ca  10.1016/j.fluid.2014.01.028
# 9  c7a0830a-12f8-42b6-8e40-e19325f0a9c9  10.1016/j.fluid.2014.01.028
#
#    Mole fraction  Temperature  ...  \
# 0         1.0000       363.15  ...
# 1         1.0000       353.15  ...
# 2         1.0000       343.15  ...
# 3         1.0000       333.15  ...
# 4         1.0000       323.15  ...
# 5         1.0000       313.15  ...
# 6         1.0000       303.15  ...
# 7         1.0000       293.15  ...
# 8         1.0000       283.15  ...
# 9         0.9819       363.15  ...
#
#                                  composition_temp_id viscosity_value  \
# 0  ((Water,), 363.15, 57752fcf-7087-418f-8443-180...        0.000331
# 1  ((Water,), 353.15, a391af92-cf16-4076-bd90-c83...        0.000386
# 2  ((Water,), 343.15, dc548f08-57ea-4102-b45c-647...        0.000435
# 3  ((Water,), 333.15, 2dba9cd5-5ff5-4384-a5a7-eee...        0.000477
# 4  ((Water,), 323.15, a320de01-0c91-4124-ba7d-548...        0.000549
# 5  ((Water,), 313.15, 3ee182dd-7f4d-4242-b066-602...        0.000649
# 6  ((Water,), 303.15, a73fc0a6-3c04-4d27-b837-fda...        0.000791
# 7  ((Water,), 293.15, 7bdb635e-bc87-4a76-aff9-ed2...        0.000984
# 8  ((Water,), 283.15, 47179c39-a8ad-446e-a401-6bd...        0.001274
# 9  ((Choline Chloride, Glycerol, Water), 363.15, ...        0.000386
#
#   viscosity_uncertainty  mole_fraction_water    inv_RT  ln_viscosity  \
# 0              0.000002               1.0000  0.331210     -8.014601
# 1              0.000002               1.0000  0.340589     -7.859673
# 2              0.000002               1.0000  0.350514     -7.739245
# 3              0.000002               1.0000  0.361036     -7.647994
# 4              0.000003               1.0000  0.372208     -7.507959
# 5              0.000003               1.0000  0.384094     -7.339770
# 6              0.000004               1.0000  0.396764     -7.141707
# 7              0.000005               1.0000  0.410299     -6.924291
# 8              0.000006               1.0000  0.424789     -6.665672
# 9              0.000002               0.9819  0.331210     -7.859155
#
#   water_mole_fraction water_mole_fraction_rounded        composition_key  \
# 0              1.0000                       1.000                 (1.0,)
# 1              1.0000                       1.000                 (1.0,)
# 2              1.0000                       1.000                 (1.0,)
# 3              1.0000                       1.000                 (1.0,)
# 4              1.0000                       1.000                 (1.0,)
# 5              1.0000                       1.000                 (1.0,)
# 6              1.0000                       1.000                 (1.0,)
# 7              1.0000                       1.000                 (1.0,)
# 8              1.0000                       1.000                 (1.0,)
# 9              0.9819                       0.982  (0.006, 0.012, 0.982)
#
#    temperature_group
# 0             High T
# 1             High T
# 2             High T
# 3             High T
# 4              Low T
# 5              Low T
# 6              Low T
# 7              Low T
# 8              Low T
# 9             High T
#
# [10 rows x 26 columns]
# Activation energies (E_a) and Arrhenius prefactor by DOI and temperature group:
#                       source_doi        composition_key temperature_group  \
# 0    10.1016/j.fluid.2014.01.028                 (1.0,)            High T
# 1    10.1016/j.fluid.2014.01.028                 (1.0,)             Low T
# 2    10.1016/j.fluid.2014.01.028  (0.006, 0.012, 0.982)            High T
# 3    10.1016/j.fluid.2014.01.028  (0.006, 0.012, 0.982)             Low T
# 4    10.1016/j.fluid.2014.01.028   (0.013, 0.027, 0.96)            High T
# 5    10.1016/j.fluid.2014.01.028   (0.013, 0.027, 0.96)             Low T
# 6    10.1016/j.fluid.2014.01.028  (0.022, 0.044, 0.933)            High T
# 7    10.1016/j.fluid.2014.01.028  (0.022, 0.044, 0.933)             Low T
# 8    10.1016/j.fluid.2014.01.028  (0.033, 0.066, 0.901)            High T
# 9    10.1016/j.fluid.2014.01.028  (0.033, 0.066, 0.901)             Low T
# 10   10.1016/j.fluid.2014.01.028  (0.048, 0.095, 0.857)            High T
# 11   10.1016/j.fluid.2014.01.028  (0.048, 0.095, 0.857)             Low T
# 12   10.1016/j.fluid.2014.01.028    (0.067, 0.134, 0.8)            High T
# 13   10.1016/j.fluid.2014.01.028    (0.067, 0.134, 0.8)             Low T
# 14   10.1016/j.fluid.2014.01.028   (0.093, 0.187, 0.72)            High T
# 15   10.1016/j.fluid.2014.01.028   (0.093, 0.187, 0.72)             Low T
# 16   10.1016/j.fluid.2014.01.028  (0.134, 0.268, 0.598)            High T
# 17   10.1016/j.fluid.2014.01.028  (0.134, 0.268, 0.598)             Low T
# 18   10.1016/j.fluid.2014.01.028  (0.199, 0.399, 0.402)            High T
# 19   10.1016/j.fluid.2014.01.028  (0.199, 0.399, 0.402)             Low T
# 20   10.1016/j.fluid.2014.01.028  (0.219, 0.438, 0.343)            High T
# 21   10.1016/j.fluid.2014.01.028  (0.219, 0.438, 0.343)             Low T
# 22     10.1016/j.jct.2018.07.031  (0.249, 0.496, 0.254)            High T
# 23     10.1016/j.jct.2018.07.031  (0.249, 0.496, 0.254)             Low T
# 24   10.1016/j.fluid.2014.01.028  (0.254, 0.508, 0.238)            High T
# 25   10.1016/j.fluid.2014.01.028  (0.254, 0.508, 0.238)             Low T
# 26   10.1016/j.fluid.2014.01.028  (0.297, 0.595, 0.108)            High T
# 27   10.1016/j.fluid.2014.01.028  (0.297, 0.595, 0.108)             Low T
# 28     10.1016/j.jct.2018.07.031         (0.333, 0.667)            High T
# 29     10.1016/j.jct.2018.07.031         (0.333, 0.667)             Low T
# 30  10.1016/j.molliq.2015.11.032         (0.333, 0.667)            High T
# 31  10.1016/j.molliq.2015.11.032         (0.333, 0.667)             Low T
# 32            10.1039/c1cp22554e         (0.333, 0.667)            High T
# 33            10.1039/c1cp22554e         (0.333, 0.667)             Low T
# 34            10.1039/c0gc00395f         (0.333, 0.667)            High T
# 35            10.1039/c0gc00395f         (0.333, 0.667)             Low T
# 36   10.1016/j.fluid.2014.01.028         (0.333, 0.667)            High T
# 37   10.1016/j.fluid.2014.01.028         (0.333, 0.667)             Low T
# 38   10.1016/j.fluid.2014.01.028                 (1.0,)        Full Range
# 39   10.1016/j.fluid.2014.01.028  (0.006, 0.012, 0.982)        Full Range
# 40   10.1016/j.fluid.2014.01.028   (0.013, 0.027, 0.96)        Full Range
# 41   10.1016/j.fluid.2014.01.028  (0.022, 0.044, 0.933)        Full Range
# 42   10.1016/j.fluid.2014.01.028  (0.033, 0.066, 0.901)        Full Range
# 43   10.1016/j.fluid.2014.01.028  (0.048, 0.095, 0.857)        Full Range
# 44   10.1016/j.fluid.2014.01.028    (0.067, 0.134, 0.8)        Full Range
# 45   10.1016/j.fluid.2014.01.028   (0.093, 0.187, 0.72)        Full Range
# 46   10.1016/j.fluid.2014.01.028  (0.134, 0.268, 0.598)        Full Range
# 47   10.1016/j.fluid.2014.01.028  (0.199, 0.399, 0.402)        Full Range
# 48   10.1016/j.fluid.2014.01.028  (0.219, 0.438, 0.343)        Full Range
# 49     10.1016/j.jct.2018.07.031  (0.249, 0.496, 0.254)        Full Range
# 50   10.1016/j.fluid.2014.01.028  (0.254, 0.508, 0.238)        Full Range
# 51   10.1016/j.fluid.2014.01.028  (0.297, 0.595, 0.108)        Full Range
# 52     10.1016/j.jct.2018.07.031         (0.333, 0.667)        Full Range
# 53  10.1016/j.molliq.2015.11.032         (0.333, 0.667)        Full Range
# 54            10.1039/c1cp22554e         (0.333, 0.667)        Full Range
# 55            10.1039/c0gc00395f         (0.333, 0.667)        Full Range
# 56   10.1016/j.fluid.2014.01.028         (0.333, 0.667)        Full Range
#
#    temperature_range  activation_energy_J_per_mol  arrhenius_prefactor_lnA  \
# 0            333-363                   101.695137               -12.045355
# 1            283-323                   133.132418               -13.482804
# 2            333-363                   105.119756               -12.048167
# 3            283-323                   137.545277               -13.496073
# 4            333-363                   114.367397               -12.235612
# 5            283-323                   142.224808               -13.490797
# 6            333-363                    99.792999               -11.389993
# 7            283-323                   149.777368               -13.585480
# 8            333-363                   118.438775               -11.887904
# 9            283-323                   159.518940               -13.716042
# 10           333-363                   132.925026               -12.180537
# 11           283-323                   173.877422               -14.006353
# 12           333-363                   151.250892               -12.601180
# 13           283-323                   211.117253               -15.275471
# 14           333-363                   170.335978               -12.936015
# 15           283-323                   229.212013               -15.541486
# 16           333-363                   208.204554               -13.924765
# 17           283-323                   258.428842               -16.144852
# 18           333-363                   230.877699               -14.096928
# 19           283-323                   316.097429               -17.916951
# 20           333-363                   232.105481               -13.959303
# 21           283-323                   329.435944               -18.304541
# 22           311-338                   301.300469               -16.637368
# 23           278-308                   383.539127               -20.502746
# 24           333-363                   252.286238               -14.530880
# 25           283-323                   358.875722               -19.305609
# 26           333-363                   264.528539               -14.733084
# 27           283-323                   380.006817               -19.856264
# 28           311-338                   341.482325               -17.823342
# 29           278-308                   429.262202               -21.951472
# 30           328-353                   246.465432               -13.525274
# 31           298-323                   338.645258               -17.545085
# 32           318-328                   328.528653               -17.451681
# 33           298-313                   391.038205               -20.335841
# 34           313-328                   330.717557               -17.542429
# 35           293-308                   410.422012               -21.246557
# 36           333-363                   281.692450               -15.165900
# 37           283-323                   398.398132               -20.385919
# 38           283-363                   116.052769               -12.655573
# 39           283-363                   123.989603               -12.841238
# 40           283-363                   129.262167               -12.863887
# 41           283-363                   133.146744               -12.784446
# 42           283-363                   143.073273               -12.922000
# 43           283-363                   157.089532               -13.195562
# 44           283-363                   185.965814               -14.060410
# 45           283-363                   207.350901               -14.486951
# 46           283-363                   240.074173               -15.259642
# 47           283-363                   278.754122               -16.112062
# 48           283-363                   288.850201               -16.344019
# 49           278-338                   345.859687               -18.633964
# 50           283-363                   312.543056               -17.066439
# 51           283-363                   335.624950               -17.714444
# 52           278-338                   388.685403               -19.938777
# 53           298-353                   310.969307               -16.260954
# 54           298-328                   362.908291               -18.998364
# 55           293-328                   374.978415               -19.540212
# 56           283-363                   348.588296               -17.979190
#
#     r_squared  n_points
# 0    0.979997         4
# 1    0.998242         5
# 2    0.998417         4
# 3    0.998425         5
# 4    0.998282         4
# 5    0.998025         5
# 6    0.970668         4
# 7    0.998321         5
# 8    0.998875         4
# 9    0.998529         5
# 10   0.999440         4
# 11   0.998520         5
# 12   0.999648         4
# 13   0.997896         5
# 14   0.999579         4
# 15   0.999828         5
# 16   0.996061         4
# 17   0.997602         5
# 18   0.999521         4
# 19   0.997636         5
# 20   0.999297         4
# 21   0.997555         5
# 22   0.999275        12
# 23   0.998958        13
# 24   0.999396         4
# 25   0.996352         5
# 26   0.998983         4
# 27   0.998302         5
# 28   0.999330        12
# 29   0.998993        13
# 30   0.975107         6
# 31   0.997972         6
# 32   0.998239         3
# 33   0.999912         4
# 34   0.999304         4
# 35   0.998481         4
# 36   0.999022         4
# 37   0.998612         5
# 38   0.992359         9
# 39   0.995354         9
# 40   0.996224         9
# 41   0.991342         9
# 42   0.994749         9
# 43   0.995529         9
# 44   0.993082         9
# 45   0.995505         9
# 46   0.996852         9
# 47   0.993368         9
# 48   0.992421         9
# 49   0.996206        25
# 50   0.991610         9
# 51   0.992835         9
# 52   0.996546        25
# 53   0.992438        12
# 54   0.998036         7
# 55   0.997044         8
# 56   0.992622         9

# %%
# Plot activation_energy_J_per_mol vs arrhenius_prefactor_lnA from group_activation_energy_df
# Color by temperature group with regression lines
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress

# Check if group_activation_energy_df exists
if 'group_activation_energy_df' not in locals() and 'group_activation_energy_df' not in globals():
    raise ValueError("group_activation_energy_df not found. Please run the previous cell first.")

# Create the plot
fig, ax = plt.subplots(figsize=(10, 7))

# Get unique temperature groups for coloring
temp_groups = group_activation_energy_df['temperature_group'].unique()
colors_map = {'High T': '#E74C3C', 'Low T': '#3498DB', 'Full Range': '#2ECC71'}
markers_map = {'High T': 'o', 'Low T': 's', 'Full Range': '^'}

# Plot each temperature group with different colors and markers
for temp_group in temp_groups:
    subset = group_activation_energy_df[group_activation_energy_df['temperature_group'] == temp_group]
    if len(subset) > 0:
        ax.scatter(
            subset['arrhenius_prefactor_lnA'],
            subset['activation_energy_J_per_mol'],
            c=colors_map.get(temp_group, '#95A5A6'),
            marker=markers_map.get(temp_group, 'o'),
            s=100,
            alpha=0.7,
            edgecolor='black',
            linewidth=1,
            label=temp_group
        )

# Add regression lines for each temperature group
for temp_group in temp_groups:
    subset = group_activation_energy_df[group_activation_energy_df['temperature_group'] == temp_group]
    
    if len(subset) >= 2:
        x = subset['arrhenius_prefactor_lnA'].values
        y = subset['activation_energy_J_per_mol'].values
        
        # Perform linear regression
        slope, intercept, r_value, p_value, std_err = linregress(x, y)
        
        # Create x values for the regression line
        x_line = np.linspace(x.min(), x.max(), 100)
        y_line = slope * x_line + intercept
        
        # Plot regression line with same color as the scatter points
        ax.plot(x_line, y_line, 
               linestyle='-',
               linewidth=2.5,
               color=colors_map.get(temp_group, '#95A5A6'),
               alpha=0.8,
               label=f'{temp_group} fit (R²={r_value**2:.3f})')

# Customize the plot
ax.set_xlabel('Arrhenius Prefactor ln(As / Pa·s)', fontsize=14)
ax.set_ylabel('Activation Energy $E_a$ / kJ/mol', fontsize=14)

ax.legend(title='Temperature Group', fontsize=12, frameon=True, fancybox=True, shadow=True)
ax.grid(True, alpha=0.3, linestyle='--')

# Format y-axis to show values in scientific notation if needed
ax.ticklabel_format(style='scientific', axis='y', scilimits=(0,0))

# Increase tick label font size
ax.tick_params(axis='both', which='major', labelsize=12)

plt.tight_layout()
save_plot_as_svg()
plt.show()

# Display summary statistics and regression statistics
print("\nSummary Statistics by Temperature Group:")
print("=" * 70)
for temp_group in temp_groups:
    subset = group_activation_energy_df[group_activation_energy_df['temperature_group'] == temp_group]
    if len(subset) > 0:
        print(f"\n{temp_group}:")
        print(f"  Number of data points: {len(subset)}")
        print(f"  Activation Energy - Mean: {subset['activation_energy_J_per_mol'].mean():.2e} J/mol")
        print(f"  Activation Energy - Std: {subset['activation_energy_J_per_mol'].std():.2e} J/mol")
        print(f"  Arrhenius Prefactor - Mean: {subset['arrhenius_prefactor_lnA'].mean():.2f}")
        print(f"  Arrhenius Prefactor - Std: {subset['arrhenius_prefactor_lnA'].std():.2f}")
        
        # Regression statistics
        if len(subset) >= 2:
            x = subset['arrhenius_prefactor_lnA'].values
            y = subset['activation_energy_J_per_mol'].values
            slope, intercept, r_value, p_value, std_err = linregress(x, y)
            print(f"  Regression - Slope: {slope:.2e}")
            print(f"  Regression - Intercept: {intercept:.2f}")
            print(f"  Regression - R²: {r_value**2:.4f}")
            print(f"  Regression - P-value: {p_value:.4e}")
            print(f"  Regression - Std error: {std_err:.2e}")
# Out:
# ✓ Plot gespeichert: image_output/plot_14.svg (65,899 Bytes)
# Summary Statistics by Temperature Group:
# ======================================================================
#
# High T:
#   Number of data points: 19
#   Activation Energy - Mean: 2.11e+02 J/mol
#   Activation Energy - Std: 8.49e+01 J/mol
#   Arrhenius Prefactor - Mean: -14.04
#   Arrhenius Prefactor - Std: 2.07
#   Regression - Slope: -3.96e+01
#   Regression - Intercept: -344.19
#   Regression - R²: 0.9270
#   Regression - P-value: 4.3067e-11
#   Regression - Std error: 2.69e+00
#
# Low T:
#   Number of data points: 19
#   Activation Energy - Mean: 2.81e+02 J/mol
#   Activation Energy - Std: 1.08e+02 J/mol
#   Arrhenius Prefactor - Mean: -17.16
#   Arrhenius Prefactor - Std: 3.05
#   Regression - Slope: -3.52e+01
#   Regression - Intercept: -323.30
#   Regression - R²: 0.9817
#   Regression - P-value: 3.3054e-16
#   Regression - Std error: 1.17e+00
#
# Full Range:
#   Number of data points: 19
#   Activation Energy - Mean: 2.52e+02 J/mol
#   Activation Energy - Std: 9.77e+01 J/mol
#   Arrhenius Prefactor - Mean: -15.77
#   Arrhenius Prefactor - Std: 2.54
#   Regression - Slope: -3.79e+01
#   Regression - Intercept: -346.13
#   Regression - R²: 0.9737
#   Regression - P-value: 7.1408e-15
#   Regression - Std error: 1.51e+00

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import cm
from scipy.stats import linregress
import seaborn as sns
import pandas as pd

# Set a beautiful color palette
plt.style.use('default')
sns.set_palette("husl")

# Make sure required columns exist
required_cols = [
    "viscosity_value", 
    "temperature", 
    "source_doi", 
    "mole_fraction_water",
    "Solvent: Amount ratio of component to other component of binary solvent"
]
for col in required_cols:
    if col not in df_data_glyceline_ratio_or_pure_water.columns:
        raise ValueError(f"Column '{col}' not found in dataframe.")

# Filter on solvent ratio: keep rows where ratio <=2 or ratio is NaN (missing/None)
df_data_glyceline_ratio_or_pure_water_filtered = df_data_glyceline_ratio_or_pure_water[
    (df_data_glyceline_ratio_or_pure_water["Solvent: Amount ratio of component to other component of binary solvent"].isna()) |
    (df_data_glyceline_ratio_or_pure_water["Solvent: Amount ratio of component to other component of binary solvent"] <= 2)
].copy()

# Fill missing/None values in mole_fraction_water with 0
df_data_glyceline_ratio_or_pure_water_filtered["mole_fraction_water"] = (
    df_data_glyceline_ratio_or_pure_water_filtered["mole_fraction_water"]
    .fillna(0)
    .apply(lambda x: 0 if x is None else x)
)

# Clean for missing values in variables used
plot_df = df_data_glyceline_ratio_or_pure_water_filtered[
    df_data_glyceline_ratio_or_pure_water_filtered["viscosity_value"].notnull() &
    df_data_glyceline_ratio_or_pure_water_filtered["temperature"].notnull() &
    df_data_glyceline_ratio_or_pure_water_filtered["source_doi"].notnull()
].copy()

# Create a plot of viscosity vs temperature with Arrhenius fits
fig, ax = plt.subplots(figsize=(12, 8))
# Get unique DOIs and assign colors
unique_dois = plot_df["source_doi"].unique()
colors = sns.color_palette("husl", n_colors=len(unique_dois))
doi_color_map = dict(zip(unique_dois, colors))

# Store fit results
fit_results = []

# Plot viscosity vs temperature, colored by DOI, with Arrhenius fits
for doi in unique_dois:
    doi_data = plot_df[plot_df["source_doi"] == doi].copy()
    
    # Get unique compositions within this DOI
    unique_compositions_in_doi = doi_data["mole_fraction_water"].unique()
    
    for composition in unique_compositions_in_doi:
        composition_data = doi_data[doi_data["mole_fraction_water"] == composition].copy()
        
        # Plot scatter points
        ax.scatter(composition_data["temperature"], composition_data["viscosity_value"], 
                   alpha=0.6, s=50, color=doi_color_map[doi], 
                   label=f'{doi}, χ_W = {composition:.3f}')
        
        # Fit Arrhenius equation directly: η = A * exp(Ea/(R*T))
        if len(composition_data) >= 3:  # Need at least 3 points for a meaningful fit
            T = composition_data["temperature"].values
            eta = composition_data["viscosity_value"].values
            
            # Remove any zero or negative viscosity values
            valid_mask = eta > 0
            T_valid = T[valid_mask]
            eta_valid = eta[valid_mask]
            
            if len(T_valid) >= 3:
                # Convert to numpy arrays to ensure proper type
                T_valid = np.asarray(T_valid, dtype=float)
                eta_valid = np.asarray(eta_valid, dtype=float)
                
                # Define Arrhenius function
                R = 8.314  # J/(mol·K)
                def arrhenius(T, A, Ea):
                    return A * np.exp(Ea / (R * T))
                
                # Initial guess for parameters
                # Use linearization for initial guess
                x_init = 1 / T_valid
                y_init = np.log(eta_valid)
                slope_init, intercept_init = np.polyfit(x_init, y_init, 1)
                A_init = np.exp(intercept_init)
                Ea_init = slope_init * R
                
                try:
                    # Fit the Arrhenius equation directly
                    from scipy.optimize import curve_fit
                    popt, pcov = curve_fit(arrhenius, T_valid, eta_valid, 
                                          p0=[A_init, Ea_init], maxfev=10000)
                    A_fit, Ea_fit = popt
                    
                    # Calculate R-squared
                    eta_pred = arrhenius(T_valid, A_fit, Ea_fit)
                    ss_res = np.sum((eta_valid - eta_pred) ** 2)
                    ss_tot = np.sum((eta_valid - np.mean(eta_valid)) ** 2)
                    r_squared = 1 - (ss_res / ss_tot)
                    
                    # Convert activation energy to kJ/mol
                    activation_energy_kJ_per_mol = Ea_fit / 1000
                    
                    # Get molar ratio (if available)
                    molar_ratio = composition_data["Solvent: Amount ratio of component to other component of binary solvent"].iloc[0]
                    if pd.isna(molar_ratio):
                        molar_ratio = 2.0  # Default value
                    
                    # Store results
                    fit_results.append({
                        'water_mole_fraction': composition,
                        'activation_energy': activation_energy_kJ_per_mol,
                        'source_doi': doi,
                        'statistic': r_squared,
                        'color': doi_color_map[doi],
                        'measurement': 'measured',
                        'molar_ratio': molar_ratio
                    })
                    
                    # Generate fit line
                    T_fit = np.linspace(T_valid.min(), T_valid.max(), 100)
                    eta_fit = arrhenius(T_fit, A_fit, Ea_fit)
                    
                    # Plot fit line
                    ax.plot(T_fit, eta_fit, '--', color=doi_color_map[doi], 
                           alpha=0.8, linewidth=2)
                
                except Exception as e:
                    print(f"Fit failed for DOI {doi}, composition {composition}: {e}")

ax.set_xlabel('Temperature (K)', fontsize=14)
ax.set_ylabel('Viscosity (Pa·s)', fontsize=14)
ax.set_title('Viscosity vs Temperature with Arrhenius Fits', fontsize=16, fontweight='bold')
ax.grid(True, alpha=0.3)
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=10)

plt.tight_layout()
plt.show()

# Create DataFrame with fit results
fit_results_df = pd.DataFrame(fit_results)
# Convert color to hex string
fit_results_df['color'] = fit_results_df['color'].apply(lambda c: '#{:02x}{:02x}{:02x}'.format(int(c[0]*255), int(c[1]*255), int(c[2]*255)))
print(fit_results_df)
# Out:
#     water_mole_fraction  activation_energy                    source_doi  \
# 0              1.000000          14.861340   10.1016/j.fluid.2014.01.028
# 1              0.981900          15.761664   10.1016/j.fluid.2014.01.028
# 2              0.960200          16.400662   10.1016/j.fluid.2014.01.028
# 3              0.933500          17.195939   10.1016/j.fluid.2014.01.028
# 4              0.900700          18.404349   10.1016/j.fluid.2014.01.028
# 5              0.857400          20.246933   10.1016/j.fluid.2014.01.028
# 6              0.799700          24.370507   10.1016/j.fluid.2014.01.028
# 7              0.719900          26.845289   10.1016/j.fluid.2014.01.028
# 8              0.597800          31.641366   10.1016/j.fluid.2014.01.028
# 9              0.402200          39.083800   10.1016/j.fluid.2014.01.028
# 10             0.342500          40.926547   10.1016/j.fluid.2014.01.028
# 11             0.238100          45.056889   10.1016/j.fluid.2014.01.028
# 12             0.108000          47.608510   10.1016/j.fluid.2014.01.028
# 13             0.000000          49.591206   10.1016/j.fluid.2014.01.028
# 14             0.254364          46.408010     10.1016/j.jct.2018.07.031
# 15             0.000000          52.531391     10.1016/j.jct.2018.07.031
# 16             0.000000          40.158961  10.1016/j.molliq.2015.11.032
# 17             0.000000          45.327603            10.1039/c1cp22554e
# 18             0.000000          48.062411            10.1039/c0gc00395f
#
#     statistic    color measurement  molar_ratio
# 0    0.993191  #f67088    measured          2.0
# 1    0.996007  #f67088    measured          2.0
# 2    0.996394  #f67088    measured          2.0
# 3    0.995033  #f67088    measured          2.0
# 4    0.996126  #f67088    measured          2.0
# 5    0.996722  #f67088    measured          2.0
# 6    0.996818  #f67088    measured          2.0
# 7    0.998595  #f67088    measured          2.0
# 8    0.997944  #f67088    measured          2.0
# 9    0.997577  #f67088    measured          2.0
# 10   0.997780  #f67088    measured          2.0
# 11   0.998193  #f67088    measured          2.0
# 12   0.998833  #f67088    measured          2.0
# 13   0.999082  #f67088    measured          2.0
# 14   0.998456  #96a331    measured          2.0
# 15   0.998809  #96a331    measured          2.0
# 16   0.997873  #35aca4    measured          2.0
# 17   0.998873  #38a7d0    measured          2.0
# 18   0.997806  #a38cf4    measured          2.0

# %%
# Get unique DOIs and their colors
unique_dois = activation_energy_df_og['source_doi'].unique()
doi_colors = {}
for doi in unique_dois:
    color = activation_energy_df_og[activation_energy_df_og['source_doi'] == doi]['color'].iloc[0]
    doi_colors[doi] = color

print("Unique DOIs and their colors:")
for doi, color in doi_colors.items():
    print(f"{doi}: {color}")
# Out:
# Unique DOIs and their colors:
# 10.1016/j.jct.2018.07.031: #8fe388
# 10.1016/j.molliq.2015.11.032: #d00000
# 10.1039/c1cp22554e: #5d2e8c
# 10.1039/c0gc00395f: #1b998b
# 10.1016/j.fluid.2014.01.028: #3185fc

# %%
activation_energy_df_og['measurement'] = 'linearized'
activation_energy_df_og
# Out:
#                                        mole_fractions  water_mole_fraction  \
# 0                    (0.333333333333, 0.666666666667)                0.000
# 1                    (0.333333333333, 0.666666666667)                0.000
# 2                    (0.333333333333, 0.666666666667)                0.000
# 3                    (0.333333333333, 0.666666666667)                0.000
# 4                    (0.333333333333, 0.666666666667)                0.000
# 5             (0.297333333333, 0.594666666667, 0.108)                0.108
# 6            (0.253966666667, 0.507933333333, 0.2381)                0.238
# 7          (0.24937655859, 0.49625935141, 0.25436409)                0.254
# 8            (0.219166666667, 0.438333333333, 0.3425)                0.342
# 9            (0.199266666667, 0.398533333333, 0.4022)                0.402
# 10           (0.134066666667, 0.268133333333, 0.5978)                0.598
# 11           (0.093366666667, 0.186733333333, 0.7199)                0.720
# 12           (0.066766666667, 0.133533333333, 0.7997)                0.800
# 13           (0.047533333333, 0.095066666667, 0.8574)                0.857
# 14  (0.033100000000000004, 0.06620000000000001, 0....                0.901
# 15           (0.022166666667, 0.044333333333, 0.9335)                0.934
# 16           (0.013266666667, 0.026533333333, 0.9602)                0.960
# 17           (0.006033333333, 0.012066666667, 0.9819)                0.982
# 18                                             (1.0,)                1.000
#
#     activation_energy                    source_doi   ordinate  statistic  \
# 0           44.548167     10.1016/j.jct.2018.07.031 -19.123307   0.999280
# 1           41.128327  10.1016/j.molliq.2015.11.032 -17.701857   0.999505
# 2           43.647835            10.1039/c1cp22554e -18.998364   0.999017
# 3           45.099537            10.1039/c0gc00395f -19.540212   0.998521
# 4           44.401167   10.1016/j.fluid.2014.01.028 -19.007296   0.998474
# 5           42.740921   10.1016/j.fluid.2014.01.028 -18.699900   0.999226
# 6           39.488831   10.1016/j.fluid.2014.01.028 -17.869946   0.997722
# 7           39.548897     10.1016/j.jct.2018.07.031 -17.874516   0.999111
# 8           36.501575   10.1016/j.fluid.2014.01.028 -17.086597   0.998807
# 9           34.973907   10.1016/j.fluid.2014.01.028 -16.728736   0.998840
# 10          29.268034   10.1016/j.fluid.2014.01.028 -15.442099   0.999593
# 11          26.577674   10.1016/j.fluid.2014.01.028 -15.150848   0.999486
# 12          23.944943   10.1016/j.fluid.2014.01.028 -14.704598   0.997546
# 13          19.622711   10.1016/j.fluid.2014.01.028 -13.503074   0.999362
# 14          17.975769   10.1016/j.fluid.2014.01.028 -13.243867   0.999348
# 15          16.799950   10.1016/j.fluid.2014.01.028 -13.111616   0.999229
# 16          15.868361   10.1016/j.fluid.2014.01.028 -13.007854   0.999068
# 17          15.423006   10.1016/j.fluid.2014.01.028 -13.059134   0.999355
# 18          14.762093   10.1016/j.fluid.2014.01.028 -12.993980   0.998826
#
#       color measurement
# 0   #8fe388  linearized
# 1   #d00000  linearized
# 2   #5d2e8c  linearized
# 3   #1b998b  linearized
# 4   #3185fc  linearized
# 5   #3185fc  linearized
# 6   #3185fc  linearized
# 7   #8fe388  linearized
# 8   #3185fc  linearized
# 9   #3185fc  linearized
# 10  #3185fc  linearized
# 11  #3185fc  linearized
# 12  #3185fc  linearized
# 13  #3185fc  linearized
# 14  #3185fc  linearized
# 15  #3185fc  linearized
# 16  #3185fc  linearized
# 17  #3185fc  linearized
# 18  #3185fc  linearized

# %%
# Update colors in fit_results_df to match doi_colors
fit_results_df['color'] = fit_results_df['source_doi'].map(doi_colors)
fit_results_df['measurement'] = 'least squares'
combined_df = pd.concat([activation_energy_df_og, fit_results_df], ignore_index=True)
combined_df
# Out:
#                                        mole_fractions  water_mole_fraction  \
# 0                    (0.333333333333, 0.666666666667)             0.000000
# 1                    (0.333333333333, 0.666666666667)             0.000000
# 2                    (0.333333333333, 0.666666666667)             0.000000
# 3                    (0.333333333333, 0.666666666667)             0.000000
# 4                    (0.333333333333, 0.666666666667)             0.000000
# 5             (0.297333333333, 0.594666666667, 0.108)             0.108000
# 6            (0.253966666667, 0.507933333333, 0.2381)             0.238000
# 7          (0.24937655859, 0.49625935141, 0.25436409)             0.254000
# 8            (0.219166666667, 0.438333333333, 0.3425)             0.342000
# 9            (0.199266666667, 0.398533333333, 0.4022)             0.402000
# 10           (0.134066666667, 0.268133333333, 0.5978)             0.598000
# 11           (0.093366666667, 0.186733333333, 0.7199)             0.720000
# 12           (0.066766666667, 0.133533333333, 0.7997)             0.800000
# 13           (0.047533333333, 0.095066666667, 0.8574)             0.857000
# 14  (0.033100000000000004, 0.06620000000000001, 0....             0.901000
# 15           (0.022166666667, 0.044333333333, 0.9335)             0.934000
# 16           (0.013266666667, 0.026533333333, 0.9602)             0.960000
# 17           (0.006033333333, 0.012066666667, 0.9819)             0.982000
# 18                                             (1.0,)             1.000000
# 19                                                NaN             1.000000
# 20                                                NaN             0.981900
# 21                                                NaN             0.960200
# 22                                                NaN             0.933500
# 23                                                NaN             0.900700
# 24                                                NaN             0.857400
# 25                                                NaN             0.799700
# 26                                                NaN             0.719900
# 27                                                NaN             0.597800
# 28                                                NaN             0.402200
# 29                                                NaN             0.342500
# 30                                                NaN             0.238100
# 31                                                NaN             0.108000
# 32                                                NaN             0.000000
# 33                                                NaN             0.254364
# 34                                                NaN             0.000000
# 35                                                NaN             0.000000
# 36                                                NaN             0.000000
# 37                                                NaN             0.000000
#
#     activation_energy                    source_doi   ordinate  statistic  \
# 0           44.548167     10.1016/j.jct.2018.07.031 -19.123307   0.999280
# 1           41.128327  10.1016/j.molliq.2015.11.032 -17.701857   0.999505
# 2           43.647835            10.1039/c1cp22554e -18.998364   0.999017
# 3           45.099537            10.1039/c0gc00395f -19.540212   0.998521
# 4           44.401167   10.1016/j.fluid.2014.01.028 -19.007296   0.998474
# 5           42.740921   10.1016/j.fluid.2014.01.028 -18.699900   0.999226
# 6           39.488831   10.1016/j.fluid.2014.01.028 -17.869946   0.997722
# 7           39.548897     10.1016/j.jct.2018.07.031 -17.874516   0.999111
# 8           36.501575   10.1016/j.fluid.2014.01.028 -17.086597   0.998807
# 9           34.973907   10.1016/j.fluid.2014.01.028 -16.728736   0.998840
# 10          29.268034   10.1016/j.fluid.2014.01.028 -15.442099   0.999593
# 11          26.577674   10.1016/j.fluid.2014.01.028 -15.150848   0.999486
# 12          23.944943   10.1016/j.fluid.2014.01.028 -14.704598   0.997546
# 13          19.622711   10.1016/j.fluid.2014.01.028 -13.503074   0.999362
# 14          17.975769   10.1016/j.fluid.2014.01.028 -13.243867   0.999348
# 15          16.799950   10.1016/j.fluid.2014.01.028 -13.111616   0.999229
# 16          15.868361   10.1016/j.fluid.2014.01.028 -13.007854   0.999068
# 17          15.423006   10.1016/j.fluid.2014.01.028 -13.059134   0.999355
# 18          14.762093   10.1016/j.fluid.2014.01.028 -12.993980   0.998826
# 19          14.861340   10.1016/j.fluid.2014.01.028        NaN   0.993191
# 20          15.761664   10.1016/j.fluid.2014.01.028        NaN   0.996007
# 21          16.400662   10.1016/j.fluid.2014.01.028        NaN   0.996394
# 22          17.195939   10.1016/j.fluid.2014.01.028        NaN   0.995033
# 23          18.404349   10.1016/j.fluid.2014.01.028        NaN   0.996126
# 24          20.246933   10.1016/j.fluid.2014.01.028        NaN   0.996722
# 25          24.370507   10.1016/j.fluid.2014.01.028        NaN   0.996818
# 26          26.845289   10.1016/j.fluid.2014.01.028        NaN   0.998595
# 27          31.641366   10.1016/j.fluid.2014.01.028        NaN   0.997944
# 28          39.083800   10.1016/j.fluid.2014.01.028        NaN   0.997577
# 29          40.926547   10.1016/j.fluid.2014.01.028        NaN   0.997780
# 30          45.056889   10.1016/j.fluid.2014.01.028        NaN   0.998193
# 31          47.608510   10.1016/j.fluid.2014.01.028        NaN   0.998833
# 32          49.591206   10.1016/j.fluid.2014.01.028        NaN   0.999082
# 33          46.408010     10.1016/j.jct.2018.07.031        NaN   0.998456
# 34          52.531391     10.1016/j.jct.2018.07.031        NaN   0.998809
# 35          40.158961  10.1016/j.molliq.2015.11.032        NaN   0.997873
# 36          45.327603            10.1039/c1cp22554e        NaN   0.998873
# 37          48.062411            10.1039/c0gc00395f        NaN   0.997806
#
#       color    measurement  molar_ratio
# 0   #8fe388     linearized          NaN
# 1   #d00000     linearized          NaN
# 2   #5d2e8c     linearized          NaN
# 3   #1b998b     linearized          NaN
# 4   #3185fc     linearized          NaN
# 5   #3185fc     linearized          NaN
# 6   #3185fc     linearized          NaN
# 7   #8fe388     linearized          NaN
# 8   #3185fc     linearized          NaN
# 9   #3185fc     linearized          NaN
# 10  #3185fc     linearized          NaN
# 11  #3185fc     linearized          NaN
# 12  #3185fc     linearized          NaN
# 13  #3185fc     linearized          NaN
# 14  #3185fc     linearized          NaN
# 15  #3185fc     linearized          NaN
# 16  #3185fc     linearized          NaN
# 17  #3185fc     linearized          NaN
# 18  #3185fc     linearized          NaN
# 19  #3185fc  least squares          2.0
# 20  #3185fc  least squares          2.0
# 21  #3185fc  least squares          2.0
# 22  #3185fc  least squares          2.0
# 23  #3185fc  least squares          2.0
# 24  #3185fc  least squares          2.0
# 25  #3185fc  least squares          2.0
# 26  #3185fc  least squares          2.0
# 27  #3185fc  least squares          2.0
# 28  #3185fc  least squares          2.0
# 29  #3185fc  least squares          2.0
# 30  #3185fc  least squares          2.0
# 31  #3185fc  least squares          2.0
# 32  #3185fc  least squares          2.0
# 33  #8fe388  least squares          2.0
# 34  #8fe388  least squares          2.0
# 35  #d00000  least squares          2.0
# 36  #5d2e8c  least squares          2.0
# 37  #1b998b  least squares          2.0
