# %% [markdown]
# # CML to FAIRFluids Conversion - Composition-Based Approach
#
# This notebook demonstrates how to convert CML (Chemical Markup Language) files to FAIRFluids format using the `FAIRFluidsCMLParser` class with the new **composition-based approach**.
#
# ## Key Features
#
# - **Composition-based fluid creation**: $E_a$ch unique composition gets its own fluid block
# - **Automatic compound ID generation** with consistent naming
# - **Support for multiple property types** (viscosity, conductivity, density)
# - **Intelligent composition grouping** based on mole fraction combinations
# - **No filtering needed**: Only compounds present in each composition are included
#
# ## Overview
#
# The parser automatically:
# 1. Extracts compounds from CML data or uses provided compound definitions
# 2. Generates consistent compound IDs using cleaned common names
# 3. **Groups measurements by unique compositions** (mole fraction combinations)
# 4. **Creates separate fluid blocks for each unique composition**
# 5. **Only includes compounds with non-zero mole fractions in each fluid**
# 6. Creates parameter definitions specific to each composition
# 7. Assigns measurements to the appropriate fluid based on composition
#
# ## Important Notes
#
# - **Composition-Based Approach**: $E_a$ch unique composition becomes a separate fluid block
# - **No Zero Mole Fractions**: Compounds with zero mole fractions are automatically excluded from each fluid
# - **Consistent IDs**: Compound and parameter IDs use cleaned names for consistency
# - **Clean Data Structure**: No post-processing filtering needed - data is structured correctly from the start

# %%
# Import the FAIRFluids models
import sys
sys.path.append('/home/sga/Code/FAIRFluids')
from fairfluids import FAIRFluidsCMLParser
from fairfluids.core.lib import FAIRFluidsDocument, Version, Citation
from fairfluids.core.functionalities import FAIRFluidsCMLParser
from fairfluids import FAIRFluidsDocument, FluidIO, calculate_ratio_of_solvent
from fairfluids.core.visualization import extract_fairfluids_data, plot_dataframe

# Test the extended class
doc = FAIRFluidsDocument(
    version=Version(
        versionMajor=1,
        versionMinor=0
    )
)

# Add same data as example
doc.citation = Citation(Type="journal")
doc.citation.add_to_author(given_name="Gudrun", family_name="Gygli")

# Define the compounds as variables (dictionaries) for use in a compounds list
# Note: compoundID will be automatically generated using the new consistent naming convention
compound_water = {
    "pubChemID": 962,
    "commonName": "Water",
    "name_IUPAC": "oxidane",
    "standard_InChI": "InChI=1S/H2O/h1H2",
    "standard_InChI_key": "XLYOFNOQVPJJNP-UHFFFAOYSA-N"
}

compound_cholinechloride = {
    "pubChemID": 6209,
    "commonName": "Choline chloride",  # Updated to use proper spacing
    "name_IUPAC": "Choline chloride",
    "standard_InChI": "InChI=1S/C5H11ClNO2/c1"
}

compound_glycerol = {
    "pubChemID": 753,
    "commonName": "Glycerol",
    "name_IUPAC": "glycerol",
    "standard_InChI": "InChI=1S/C3H8O3/c1-2-3-4/h2-3H,1H3",
    "standard_InChI_key": "XLYOFNOQVPJJNP-UHFFFAOYSA-N"
}

compound_urea = {
    "pubChemID": 1176,
    "commonName": "Urea",
    "name_IUPAC": "urea",
    "standard_InChI": "InChI=1S/C2H4N2O/c1-2-4-3/h1H3,(H,2,4)"
}

compounds = [
        compound_cholinechloride,
        compound_glycerol,
        compound_water
    ]
    


# Path to the test CML file
cml_path = "/home/sga/Code/FAIRFluids/fairfluids/data/cml_xml/gygli/ChCl_glycerol.xml"
#cml_path = "/home/sga/Code/FAIRFluids/fairfluids/data/cml_xml/xu/CML_exp_sim.xml"




# Parse the CML file
parser = FAIRFluidsCMLParser(cml_path, compounds=compounds)
doc = parser.parse()

doc   = calculate_ratio_of_solvent(
    doc=doc,
    parameter_id_1="parameter_mole_fraction_glycerol",
    parameter_id_2="parameter_mole_fraction_cholinechloride",
    name="urea_cholinechloride",
    compound_id_1="compound_glycerol",
    compound_id_2="compound_cholinechloride",
    precision=1  # Round to 2 decimal places - ensures 2.0 instead of 2.0075...
)

# Save the model to a JSON file
with open('/home/sga/Code/FAIRFluids/Workflows/paper_outputs/Xu_Glycerol_Water.json', 'w') as f:
    f.write(doc.model_dump_json(indent=4))
    
print(f"\n📁 Output saved to: /home/sga/Code/FAIRFluids/Workflows/outputs/Xu_Glycerol_Water.json")
# Out:
# Fetching compound data from PubChem for CID 6209...
# Successfully fetched and merged data for CID 6209
# Fetching compound data from PubChem for CID 753...
# Successfully fetched and merged data for CID 753
# Fetching compound data from PubChem for CID 962...
# Successfully fetched and merged data for CID 962
# Found 30 unique compositions
# Composition (0.25, 0.5, 0.25): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.0, 0.0, 1.0): compounds ['compound_water']
# Composition (0.006, 0.012, 0.982): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.013, 0.027, 0.96): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.022, 0.044, 0.933): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.033, 0.066, 0.901): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.048, 0.095, 0.857): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.067, 0.134, 0.8): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.093, 0.187, 0.72): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.134, 0.268, 0.598): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.199, 0.399, 0.402): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.219, 0.438, 0.343): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.254, 0.508, 0.238): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.297, 0.595, 0.108): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.333, 0.667, 0.0): compounds ['compound_cholinechloride', 'compound_glycerol']
# Composition (0.249, 0.496, 0.254): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.05, 0.95, 0.0): compounds ['compound_cholinechloride', 'compound_glycerol']
# Composition (0.1, 0.9, 0.0): compounds ['compound_cholinechloride', 'compound_glycerol']
# Composition (0.15, 0.85, 0.0): compounds ['compound_cholinechloride', 'compound_glycerol']
# Composition (0.2, 0.8, 0.0): compounds ['compound_cholinechloride', 'compound_glycerol']
# Composition (0.25, 0.75, 0.0): compounds ['compound_cholinechloride', 'compound_glycerol']
# Composition (0.3, 0.7, 0.0): compounds ['compound_cholinechloride', 'compound_glycerol']
# Composition (0.147, 0.295, 0.558): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.176, 0.353, 0.471): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.213, 0.427, 0.36): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.236, 0.472, 0.291): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.263, 0.526, 0.211): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.295, 0.59, 0.115): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.317, 0.634, 0.049): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.325, 0.65, 0.025): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# === Calculating Solvent Ratio: urea_cholinechloride ===
# Component 1: parameter_mole_fraction_glycerol
# Component 2: parameter_mole_fraction_cholinechloride
# Processing 30 fluids
#
# --- Processing Fluid 1 ---
# Added new parameter: parameter_solvent_ratio_urea_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement aaa0bd8a-db96-4e7c-ac83-e52d1a71200c: ratio = 0.500156324667 / 0.250078162333 = 2.0
# Added ratio value 2.0 to measurement aaa0bd8a-db96-4e7c-ac83-e52d1a71200c
#
# --- Processing Fluid 2 ---
# Skipping fluid 2: compound_glycerol not in compounds list
# Skipping fluid 2: compound_cholinechloride not in compounds list
#
# --- Processing Fluid 3 ---
# Added new parameter: parameter_solvent_ratio_urea_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 1f02802c-486d-4711-9ee1-9ea25d54ad36: ratio = 0.012066666667 / 0.006033333333 = 2.0
# Added ratio value 2.0 to measurement 1f02802c-486d-4711-9ee1-9ea25d54ad36
# Measurement 2471cda9-2aa4-48a1-9a60-f14dc0ccbd6a: ratio = 0.012066666667 / 0.006033333333 = 2.0
# Added ratio value 2.0 to measurement 2471cda9-2aa4-48a1-9a60-f14dc0ccbd6a
# Measurement 5a26493f-4602-4f1b-b4ed-239a0845ba68: ratio = 0.012066666667 / 0.006033333333 = 2.0
# Added ratio value 2.0 to measurement 5a26493f-4602-4f1b-b4ed-239a0845ba68
# Measurement dd207558-fcb4-4a24-ab44-25f4d497e7b7: ratio = 0.012066666667 / 0.006033333333 = 2.0
# Added ratio value 2.0 to measurement dd207558-fcb4-4a24-ab44-25f4d497e7b7
# Measurement 24c72388-9e10-4968-9651-c5741ec39a16: ratio = 0.012066666667 / 0.006033333333 = 2.0
# Added ratio value 2.0 to measurement 24c72388-9e10-4968-9651-c5741ec39a16
# Measurement 721fadd3-c095-41ce-9714-068cfe5a358d: ratio = 0.012066666667 / 0.006033333333 = 2.0
# Added ratio value 2.0 to measurement 721fadd3-c095-41ce-9714-068cfe5a358d
# Measurement e304cb61-09e1-49df-96a4-fcbfc65667b7: ratio = 0.012066666667 / 0.006033333333 = 2.0
# Added ratio value 2.0 to measurement e304cb61-09e1-49df-96a4-fcbfc65667b7
# Measurement 5274f6e6-eb92-46cc-b265-58149555a481: ratio = 0.012066666667 / 0.006033333333 = 2.0
# Added ratio value 2.0 to measurement 5274f6e6-eb92-46cc-b265-58149555a481
# Measurement 7a0bdad8-c31f-425e-9062-dcd8aeaba518: ratio = 0.012066666667 / 0.006033333333 = 2.0
# Added ratio value 2.0 to measurement 7a0bdad8-c31f-425e-9062-dcd8aeaba518
#
# --- Processing Fluid 4 ---
# Added new parameter: parameter_solvent_ratio_urea_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 35f8cafb-9da6-4843-b52b-b92443161f41: ratio = 0.026533333333 / 0.013266666667 = 2.0
# Added ratio value 2.0 to measurement 35f8cafb-9da6-4843-b52b-b92443161f41
# Measurement 6de35aeb-d408-4c75-ba0f-c5e8dff687f9: ratio = 0.026533333333 / 0.013266666667 = 2.0
# Added ratio value 2.0 to measurement 6de35aeb-d408-4c75-ba0f-c5e8dff687f9
# Measurement 298b53b0-217b-484e-aaf4-d27b5b5f2a7d: ratio = 0.026533333333 / 0.013266666667 = 2.0
# Added ratio value 2.0 to measurement 298b53b0-217b-484e-aaf4-d27b5b5f2a7d
# Measurement 1c9eccac-6ecd-4b19-8ba2-9c38e8ee263d: ratio = 0.026533333333 / 0.013266666667 = 2.0
# Added ratio value 2.0 to measurement 1c9eccac-6ecd-4b19-8ba2-9c38e8ee263d
# Measurement f13b2b2d-2834-48e6-be4c-efaabdec25ea: ratio = 0.026533333333 / 0.013266666667 = 2.0
# Added ratio value 2.0 to measurement f13b2b2d-2834-48e6-be4c-efaabdec25ea
# Measurement c16f97ac-74e6-4a4a-b362-185a0313595e: ratio = 0.026533333333 / 0.013266666667 = 2.0
# Added ratio value 2.0 to measurement c16f97ac-74e6-4a4a-b362-185a0313595e
# Measurement b1f170ff-f172-46cb-80ec-1dbd7eaf5a5f: ratio = 0.026533333333 / 0.013266666667 = 2.0
# Added ratio value 2.0 to measurement b1f170ff-f172-46cb-80ec-1dbd7eaf5a5f
# Measurement 164a3a0c-1658-461a-adfd-0458e58da6e0: ratio = 0.026533333333 / 0.013266666667 = 2.0
# Added ratio value 2.0 to measurement 164a3a0c-1658-461a-adfd-0458e58da6e0
# Measurement ff69bcc8-785c-4c05-ade4-917c9e5714a4: ratio = 0.026533333333 / 0.013266666667 = 2.0
# Added ratio value 2.0 to measurement ff69bcc8-785c-4c05-ade4-917c9e5714a4
#
# --- Processing Fluid 5 ---
# Added new parameter: parameter_solvent_ratio_urea_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 4fa7b90d-79de-4f22-979c-71f21a84b57f: ratio = 0.044333333333 / 0.022166666667 = 2.0
# Added ratio value 2.0 to measurement 4fa7b90d-79de-4f22-979c-71f21a84b57f
# Measurement 6c557b88-f3d7-4cd0-8f04-370a364c3acf: ratio = 0.044333333333 / 0.022166666667 = 2.0
# Added ratio value 2.0 to measurement 6c557b88-f3d7-4cd0-8f04-370a364c3acf
# Measurement 048f2768-bf16-4368-87bd-b1e5d0077372: ratio = 0.044333333333 / 0.022166666667 = 2.0
# Added ratio value 2.0 to measurement 048f2768-bf16-4368-87bd-b1e5d0077372
# Measurement 7bce0187-ff52-4473-97f9-950b3996eb66: ratio = 0.044333333333 / 0.022166666667 = 2.0
# Added ratio value 2.0 to measurement 7bce0187-ff52-4473-97f9-950b3996eb66
# Measurement 567ce7ad-0817-41c6-807d-96145dcf978c: ratio = 0.044333333333 / 0.022166666667 = 2.0
# Added ratio value 2.0 to measurement 567ce7ad-0817-41c6-807d-96145dcf978c
# Measurement f40bbe1c-2e0d-4eae-8ff8-d1a71cb732e8: ratio = 0.044333333333 / 0.022166666667 = 2.0
# Added ratio value 2.0 to measurement f40bbe1c-2e0d-4eae-8ff8-d1a71cb732e8
# Measurement 1f8c18f2-daaf-427d-bc37-ec28814f0871: ratio = 0.044333333333 / 0.022166666667 = 2.0
# Added ratio value 2.0 to measurement 1f8c18f2-daaf-427d-bc37-ec28814f0871
# Measurement 848f37bd-29b6-4562-867a-771ef88636f2: ratio = 0.044333333333 / 0.022166666667 = 2.0
# Added ratio value 2.0 to measurement 848f37bd-29b6-4562-867a-771ef88636f2
# Measurement 293e1a82-c6d6-40b1-948b-855c988987dc: ratio = 0.044333333333 / 0.022166666667 = 2.0
# Added ratio value 2.0 to measurement 293e1a82-c6d6-40b1-948b-855c988987dc
#
# --- Processing Fluid 6 ---
# Added new parameter: parameter_solvent_ratio_urea_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 3d7d89dc-e052-4409-90c7-0d7754960945: ratio = 0.0662 / 0.0331 = 2.0
# Added ratio value 2.0 to measurement 3d7d89dc-e052-4409-90c7-0d7754960945
# Measurement 5a9b4375-8658-4ce0-89bd-3771eb8c9bdf: ratio = 0.0662 / 0.0331 = 2.0
# Added ratio value 2.0 to measurement 5a9b4375-8658-4ce0-89bd-3771eb8c9bdf
# Measurement 94d6a8c8-5504-4c1d-b3dc-6efb241dce33: ratio = 0.0662 / 0.0331 = 2.0
# Added ratio value 2.0 to measurement 94d6a8c8-5504-4c1d-b3dc-6efb241dce33
# Measurement 3fd590a6-f642-498c-b753-e9d810075f64: ratio = 0.0662 / 0.0331 = 2.0
# Added ratio value 2.0 to measurement 3fd590a6-f642-498c-b753-e9d810075f64
# Measurement 8f28a579-0958-448a-97e4-e7e2aed786f3: ratio = 0.0662 / 0.0331 = 2.0
# Added ratio value 2.0 to measurement 8f28a579-0958-448a-97e4-e7e2aed786f3
# Measurement e92b63e6-7aff-4bc2-8d17-db224c0d35bc: ratio = 0.0662 / 0.0331 = 2.0
# Added ratio value 2.0 to measurement e92b63e6-7aff-4bc2-8d17-db224c0d35bc
# Measurement a15fd524-72d3-4795-b4be-6449116ec928: ratio = 0.0662 / 0.0331 = 2.0
# Added ratio value 2.0 to measurement a15fd524-72d3-4795-b4be-6449116ec928
# Measurement dd8139f2-1d1d-46ca-aee4-5999668f3586: ratio = 0.0662 / 0.0331 = 2.0
# Added ratio value 2.0 to measurement dd8139f2-1d1d-46ca-aee4-5999668f3586
# Measurement 0daa23a7-c0ed-40bd-a959-feb60962913b: ratio = 0.0662 / 0.0331 = 2.0
# Added ratio value 2.0 to measurement 0daa23a7-c0ed-40bd-a959-feb60962913b
#
# --- Processing Fluid 7 ---
# Added new parameter: parameter_solvent_ratio_urea_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 085d64c7-0c20-4535-b8e2-49e29212884f: ratio = 0.095066666667 / 0.047533333333 = 2.0
# Added ratio value 2.0 to measurement 085d64c7-0c20-4535-b8e2-49e29212884f
# Measurement c9cad851-f7be-4806-8617-1cc858a007ed: ratio = 0.095066666667 / 0.047533333333 = 2.0
# Added ratio value 2.0 to measurement c9cad851-f7be-4806-8617-1cc858a007ed
# Measurement 31326c96-5fda-40ed-9c61-1d52b6647e29: ratio = 0.095066666667 / 0.047533333333 = 2.0
# Added ratio value 2.0 to measurement 31326c96-5fda-40ed-9c61-1d52b6647e29
# Measurement 54cc68d5-9a57-48af-9e13-b25213a98323: ratio = 0.095066666667 / 0.047533333333 = 2.0
# Added ratio value 2.0 to measurement 54cc68d5-9a57-48af-9e13-b25213a98323
# Measurement 02bc464f-b26b-4bde-8b52-4fd7a59a9e11: ratio = 0.095066666667 / 0.047533333333 = 2.0
# Added ratio value 2.0 to measurement 02bc464f-b26b-4bde-8b52-4fd7a59a9e11
# Measurement eec5ea89-e9e4-4261-8ab5-b8110797380e: ratio = 0.095066666667 / 0.047533333333 = 2.0
# Added ratio value 2.0 to measurement eec5ea89-e9e4-4261-8ab5-b8110797380e
# Measurement 9e666600-6754-4462-b46d-9c31671011de: ratio = 0.095066666667 / 0.047533333333 = 2.0
# Added ratio value 2.0 to measurement 9e666600-6754-4462-b46d-9c31671011de
# Measurement 911dd0c1-4ce8-49a4-b602-cb930531496d: ratio = 0.095066666667 / 0.047533333333 = 2.0
# Added ratio value 2.0 to measurement 911dd0c1-4ce8-49a4-b602-cb930531496d
# Measurement 10ab8beb-8852-49a9-a57c-1d2a47d15a35: ratio = 0.095066666667 / 0.047533333333 = 2.0
# Added ratio value 2.0 to measurement 10ab8beb-8852-49a9-a57c-1d2a47d15a35
#
# --- Processing Fluid 8 ---
# Added new parameter: parameter_solvent_ratio_urea_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 5941f246-9b9b-4ce8-98ec-949472c29e31: ratio = 0.133533333333 / 0.066766666667 = 2.0
# Added ratio value 2.0 to measurement 5941f246-9b9b-4ce8-98ec-949472c29e31
# Measurement 4d57a880-d609-4859-aa3c-db13ec460fe6: ratio = 0.133533333333 / 0.066766666667 = 2.0
# Added ratio value 2.0 to measurement 4d57a880-d609-4859-aa3c-db13ec460fe6
# Measurement 1b783a03-2448-4991-81c7-e0fc66a14042: ratio = 0.133533333333 / 0.066766666667 = 2.0
# Added ratio value 2.0 to measurement 1b783a03-2448-4991-81c7-e0fc66a14042
# Measurement 196dc157-475f-44b1-96e8-1f606b53766c: ratio = 0.133533333333 / 0.066766666667 = 2.0
# Added ratio value 2.0 to measurement 196dc157-475f-44b1-96e8-1f606b53766c
# Measurement 1150c0f5-4204-4f7c-a73e-a98510ccc133: ratio = 0.133533333333 / 0.066766666667 = 2.0
# Added ratio value 2.0 to measurement 1150c0f5-4204-4f7c-a73e-a98510ccc133
# Measurement fc083bc7-85e0-4c60-b5f1-f957bc4ecddd: ratio = 0.133533333333 / 0.066766666667 = 2.0
# Added ratio value 2.0 to measurement fc083bc7-85e0-4c60-b5f1-f957bc4ecddd
# Measurement 5ddea9e5-814a-42cf-97d0-bf5a30343344: ratio = 0.133533333333 / 0.066766666667 = 2.0
# Added ratio value 2.0 to measurement 5ddea9e5-814a-42cf-97d0-bf5a30343344
# Measurement 25afe226-ab95-43bf-be84-6f155ca09fab: ratio = 0.133533333333 / 0.066766666667 = 2.0
# Added ratio value 2.0 to measurement 25afe226-ab95-43bf-be84-6f155ca09fab
# Measurement 1b82c237-cb4d-4ab1-a51f-a1e3e85b172f: ratio = 0.133533333333 / 0.066766666667 = 2.0
# Added ratio value 2.0 to measurement 1b82c237-cb4d-4ab1-a51f-a1e3e85b172f
#
# --- Processing Fluid 9 ---
# Added new parameter: parameter_solvent_ratio_urea_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement d282f24d-9745-4c32-bb32-def22b072236: ratio = 0.186733333333 / 0.093366666667 = 2.0
# Added ratio value 2.0 to measurement d282f24d-9745-4c32-bb32-def22b072236
# Measurement eec400d9-2bf5-481a-bcae-0e9a404ac32e: ratio = 0.186733333333 / 0.093366666667 = 2.0
# Added ratio value 2.0 to measurement eec400d9-2bf5-481a-bcae-0e9a404ac32e
# Measurement 4ef86b2c-7474-4aa1-9e82-9e44fd685846: ratio = 0.186733333333 / 0.093366666667 = 2.0
# Added ratio value 2.0 to measurement 4ef86b2c-7474-4aa1-9e82-9e44fd685846
# Measurement 3e4cd62a-a968-4086-8e4d-2fcd44730546: ratio = 0.186733333333 / 0.093366666667 = 2.0
# Added ratio value 2.0 to measurement 3e4cd62a-a968-4086-8e4d-2fcd44730546
# Measurement a208dcfa-1720-4f10-8a87-e4bb1ccd0b95: ratio = 0.186733333333 / 0.093366666667 = 2.0
# Added ratio value 2.0 to measurement a208dcfa-1720-4f10-8a87-e4bb1ccd0b95
# Measurement 859f9af8-00a5-4d12-91ca-058e7234cc6a: ratio = 0.186733333333 / 0.093366666667 = 2.0
# Added ratio value 2.0 to measurement 859f9af8-00a5-4d12-91ca-058e7234cc6a
# Measurement f0eeb1a9-e54f-423c-bb34-0bbe4c8881f1: ratio = 0.186733333333 / 0.093366666667 = 2.0
# Added ratio value 2.0 to measurement f0eeb1a9-e54f-423c-bb34-0bbe4c8881f1
# Measurement 1f433863-33e5-4ab0-8517-9c2186411f9c: ratio = 0.186733333333 / 0.093366666667 = 2.0
# Added ratio value 2.0 to measurement 1f433863-33e5-4ab0-8517-9c2186411f9c
# Measurement 68609df1-be53-4c0a-bdc3-8016ea58fb0d: ratio = 0.186733333333 / 0.093366666667 = 2.0
# Added ratio value 2.0 to measurement 68609df1-be53-4c0a-bdc3-8016ea58fb0d
#
# --- Processing Fluid 10 ---
# Added new parameter: parameter_solvent_ratio_urea_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 4f5f966e-a109-43bc-a930-96b85369092a: ratio = 0.268133333333 / 0.134066666667 = 2.0
# Added ratio value 2.0 to measurement 4f5f966e-a109-43bc-a930-96b85369092a
# Measurement ee40f6b1-1543-4a2f-9c1b-7a6c82eb281a: ratio = 0.268133333333 / 0.134066666667 = 2.0
# Added ratio value 2.0 to measurement ee40f6b1-1543-4a2f-9c1b-7a6c82eb281a
# Measurement 5971d146-4d5a-4a0f-876f-8b718e673df7: ratio = 0.268133333333 / 0.134066666667 = 2.0
# Added ratio value 2.0 to measurement 5971d146-4d5a-4a0f-876f-8b718e673df7
# Measurement 75ba7d08-77eb-4356-8b32-cef08b81a968: ratio = 0.268133333333 / 0.134066666667 = 2.0
# Added ratio value 2.0 to measurement 75ba7d08-77eb-4356-8b32-cef08b81a968
# Measurement 6fc8f3ad-3a6d-4586-9dc5-c088dbac5bf4: ratio = 0.268133333333 / 0.134066666667 = 2.0
# Added ratio value 2.0 to measurement 6fc8f3ad-3a6d-4586-9dc5-c088dbac5bf4
# Measurement 781a5a53-f553-4f45-9ac8-e8ec3503ef3d: ratio = 0.268133333333 / 0.134066666667 = 2.0
# Added ratio value 2.0 to measurement 781a5a53-f553-4f45-9ac8-e8ec3503ef3d
# Measurement b67b65a5-0016-414b-9146-bb8209a72f38: ratio = 0.268133333333 / 0.134066666667 = 2.0
# Added ratio value 2.0 to measurement b67b65a5-0016-414b-9146-bb8209a72f38
# Measurement 188e8abe-d93e-4270-a4bf-4d337956c873: ratio = 0.268133333333 / 0.134066666667 = 2.0
# Added ratio value 2.0 to measurement 188e8abe-d93e-4270-a4bf-4d337956c873
# Measurement 07070bc8-35e9-415d-b4a0-29faeffbad2e: ratio = 0.268133333333 / 0.134066666667 = 2.0
# Added ratio value 2.0 to measurement 07070bc8-35e9-415d-b4a0-29faeffbad2e
#
# --- Processing Fluid 11 ---
# Added new parameter: parameter_solvent_ratio_urea_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 01ecd11d-f94e-4dd0-8d29-76e0d796c5f7: ratio = 0.398533333333 / 0.199266666667 = 2.0
# Added ratio value 2.0 to measurement 01ecd11d-f94e-4dd0-8d29-76e0d796c5f7
# Measurement 8f347b49-ed08-4f96-b0b0-d4615cbc81da: ratio = 0.398533333333 / 0.199266666667 = 2.0
# Added ratio value 2.0 to measurement 8f347b49-ed08-4f96-b0b0-d4615cbc81da
# Measurement ecc67e63-3a0e-4430-aa5b-e5a9a7d6b19a: ratio = 0.398533333333 / 0.199266666667 = 2.0
# Added ratio value 2.0 to measurement ecc67e63-3a0e-4430-aa5b-e5a9a7d6b19a
# Measurement a42f802f-d8bf-4418-971d-0bd761cbb333: ratio = 0.398533333333 / 0.199266666667 = 2.0
# Added ratio value 2.0 to measurement a42f802f-d8bf-4418-971d-0bd761cbb333
# Measurement af70af9b-2f09-4375-854b-afc497adbc4f: ratio = 0.398533333333 / 0.199266666667 = 2.0
# Added ratio value 2.0 to measurement af70af9b-2f09-4375-854b-afc497adbc4f
# Measurement 50a9e373-8a1e-4485-906a-13baa62bee6e: ratio = 0.398533333333 / 0.199266666667 = 2.0
# Added ratio value 2.0 to measurement 50a9e373-8a1e-4485-906a-13baa62bee6e
# Measurement e06f5658-d576-4e13-9355-54e5b868a99d: ratio = 0.398533333333 / 0.199266666667 = 2.0
# Added ratio value 2.0 to measurement e06f5658-d576-4e13-9355-54e5b868a99d
# Measurement 49595f9f-4646-4c60-93e3-928b97b4199e: ratio = 0.398533333333 / 0.199266666667 = 2.0
# Added ratio value 2.0 to measurement 49595f9f-4646-4c60-93e3-928b97b4199e
# Measurement 2abe5974-b2b6-428a-879f-8454483a671d: ratio = 0.398533333333 / 0.199266666667 = 2.0
# Added ratio value 2.0 to measurement 2abe5974-b2b6-428a-879f-8454483a671d
#
# --- Processing Fluid 12 ---
# Added new parameter: parameter_solvent_ratio_urea_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 363f2740-589a-463c-9ae0-685b5d73059a: ratio = 0.438333333333 / 0.219166666667 = 2.0
# Added ratio value 2.0 to measurement 363f2740-589a-463c-9ae0-685b5d73059a
# Measurement 6ea844c2-84dc-4657-8274-1a3550d08a8f: ratio = 0.438333333333 / 0.219166666667 = 2.0
# Added ratio value 2.0 to measurement 6ea844c2-84dc-4657-8274-1a3550d08a8f
# Measurement d97b4849-64d6-40b7-a76c-eb69f3d4107b: ratio = 0.438333333333 / 0.219166666667 = 2.0
# Added ratio value 2.0 to measurement d97b4849-64d6-40b7-a76c-eb69f3d4107b
# Measurement 5b27818f-b47d-4fff-808d-34d75b729fce: ratio = 0.438333333333 / 0.219166666667 = 2.0
# Added ratio value 2.0 to measurement 5b27818f-b47d-4fff-808d-34d75b729fce
# Measurement 1482d3d7-d7d2-4cd9-9602-24ac675a0591: ratio = 0.438333333333 / 0.219166666667 = 2.0
# Added ratio value 2.0 to measurement 1482d3d7-d7d2-4cd9-9602-24ac675a0591
# Measurement 85d8bc8e-ffdc-4e17-8852-df778721f806: ratio = 0.438333333333 / 0.219166666667 = 2.0
# Added ratio value 2.0 to measurement 85d8bc8e-ffdc-4e17-8852-df778721f806
# Measurement 1c326840-aca2-46b0-ace4-933738d37e65: ratio = 0.438333333333 / 0.219166666667 = 2.0
# Added ratio value 2.0 to measurement 1c326840-aca2-46b0-ace4-933738d37e65
# Measurement 4bdf4de2-41af-4087-afba-c11edcba5eee: ratio = 0.438333333333 / 0.219166666667 = 2.0
# Added ratio value 2.0 to measurement 4bdf4de2-41af-4087-afba-c11edcba5eee
# Measurement 42f823f1-78bb-48f1-9769-838b43fd3f08: ratio = 0.438333333333 / 0.219166666667 = 2.0
# Added ratio value 2.0 to measurement 42f823f1-78bb-48f1-9769-838b43fd3f08
#
# --- Processing Fluid 13 ---
# Added new parameter: parameter_solvent_ratio_urea_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 75549e3e-7d40-44da-9b16-33152dc089bb: ratio = 0.507933333333 / 0.253966666667 = 2.0
# Added ratio value 2.0 to measurement 75549e3e-7d40-44da-9b16-33152dc089bb
# Measurement 6be86dd3-cbe5-4759-8fc8-6d8952d1aa86: ratio = 0.507933333333 / 0.253966666667 = 2.0
# Added ratio value 2.0 to measurement 6be86dd3-cbe5-4759-8fc8-6d8952d1aa86
# Measurement 2ef0b502-5822-4b80-a6b6-2d92635c1a5b: ratio = 0.507933333333 / 0.253966666667 = 2.0
# Added ratio value 2.0 to measurement 2ef0b502-5822-4b80-a6b6-2d92635c1a5b
# Measurement 4e2343a0-689f-494a-b52d-94b21874acdd: ratio = 0.507933333333 / 0.253966666667 = 2.0
# Added ratio value 2.0 to measurement 4e2343a0-689f-494a-b52d-94b21874acdd
# Measurement ca350b92-6aff-434c-ab97-894c7102b77a: ratio = 0.507933333333 / 0.253966666667 = 2.0
# Added ratio value 2.0 to measurement ca350b92-6aff-434c-ab97-894c7102b77a
# Measurement 87f8ba3a-60ee-4c2d-9c8d-fa3a21da9f66: ratio = 0.507933333333 / 0.253966666667 = 2.0
# Added ratio value 2.0 to measurement 87f8ba3a-60ee-4c2d-9c8d-fa3a21da9f66
# Measurement d5d0f425-1869-48a7-a8bc-2d265617c4b6: ratio = 0.507933333333 / 0.253966666667 = 2.0
# Added ratio value 2.0 to measurement d5d0f425-1869-48a7-a8bc-2d265617c4b6
# Measurement 6b8d611f-1188-4406-b1f5-e26e5cc00154: ratio = 0.507933333333 / 0.253966666667 = 2.0
# Added ratio value 2.0 to measurement 6b8d611f-1188-4406-b1f5-e26e5cc00154
# Measurement 1a95f18b-a5aa-4503-b87e-1d1ec086c0c4: ratio = 0.507933333333 / 0.253966666667 = 2.0
# Added ratio value 2.0 to measurement 1a95f18b-a5aa-4503-b87e-1d1ec086c0c4
#
# --- Processing Fluid 14 ---
# Added new parameter: parameter_solvent_ratio_urea_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement b737bc37-b992-47b8-9350-878dd6a77574: ratio = 0.594666666667 / 0.297333333333 = 2.0
# Added ratio value 2.0 to measurement b737bc37-b992-47b8-9350-878dd6a77574
# Measurement 0b9f761f-0de4-44f8-b861-588092aca810: ratio = 0.594666666667 / 0.297333333333 = 2.0
# Added ratio value 2.0 to measurement 0b9f761f-0de4-44f8-b861-588092aca810
# Measurement cecfcdec-fd4c-4ca6-9297-b804ec37b2ce: ratio = 0.594666666667 / 0.297333333333 = 2.0
# Added ratio value 2.0 to measurement cecfcdec-fd4c-4ca6-9297-b804ec37b2ce
# Measurement 2c80223b-b48f-4420-b825-e13ded842e43: ratio = 0.594666666667 / 0.297333333333 = 2.0
# Added ratio value 2.0 to measurement 2c80223b-b48f-4420-b825-e13ded842e43
# Measurement 6102d8d1-4353-4f8b-b6ea-0b192e824473: ratio = 0.594666666667 / 0.297333333333 = 2.0
# Added ratio value 2.0 to measurement 6102d8d1-4353-4f8b-b6ea-0b192e824473
# Measurement 9f6f56ec-3a9c-4630-b6a6-e6b1a8c5375c: ratio = 0.594666666667 / 0.297333333333 = 2.0
# Added ratio value 2.0 to measurement 9f6f56ec-3a9c-4630-b6a6-e6b1a8c5375c
# Measurement c8272768-c200-4dcc-9a80-7f5a0a3a6675: ratio = 0.594666666667 / 0.297333333333 = 2.0
# Added ratio value 2.0 to measurement c8272768-c200-4dcc-9a80-7f5a0a3a6675
# Measurement f4869594-d8ba-4a50-bee3-487ec9885671: ratio = 0.594666666667 / 0.297333333333 = 2.0
# Added ratio value 2.0 to measurement f4869594-d8ba-4a50-bee3-487ec9885671
# Measurement da1cef68-5e14-4f8a-a1ed-384f4b692814: ratio = 0.594666666667 / 0.297333333333 = 2.0
# Added ratio value 2.0 to measurement da1cef68-5e14-4f8a-a1ed-384f4b692814
#
# --- Processing Fluid 15 ---
# Added new parameter: parameter_solvent_ratio_urea_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 3eac0cdc-3373-4dc8-863b-a1eaba599564: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 3eac0cdc-3373-4dc8-863b-a1eaba599564
# Measurement 44d5be16-a6c3-4ceb-ba36-4c471992bfda: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 44d5be16-a6c3-4ceb-ba36-4c471992bfda
# Measurement 2f79b54a-3d84-4c21-9912-9cfb74fd33fa: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 2f79b54a-3d84-4c21-9912-9cfb74fd33fa
# Measurement c027839b-bc3e-423f-87da-b7be6ce64fd2: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement c027839b-bc3e-423f-87da-b7be6ce64fd2
# Measurement d45fd7f2-5961-4bcd-b448-e94920f9803d: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement d45fd7f2-5961-4bcd-b448-e94920f9803d
# Measurement ead4eb49-3061-49df-85d8-59b905b12010: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement ead4eb49-3061-49df-85d8-59b905b12010
# Measurement 5069ac42-54c8-4909-a7fd-a06e46193af0: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 5069ac42-54c8-4909-a7fd-a06e46193af0
# Measurement fc6383f3-0c43-47cb-bf48-7d860e7fc6d3: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement fc6383f3-0c43-47cb-bf48-7d860e7fc6d3
# Measurement f1588f66-baec-43a2-abf4-09d6777d4d07: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement f1588f66-baec-43a2-abf4-09d6777d4d07
# Measurement 377d4da7-ae57-4e9e-914b-5fd7aff7e6bf: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 377d4da7-ae57-4e9e-914b-5fd7aff7e6bf
# Measurement c869c19b-b731-46b8-8a57-4c4238ee800b: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement c869c19b-b731-46b8-8a57-4c4238ee800b
# Measurement 3d7f95e1-7a36-407e-bd52-e0debccca6e2: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 3d7f95e1-7a36-407e-bd52-e0debccca6e2
# Measurement d863b908-3466-4e5a-976c-5ac33fc0e744: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement d863b908-3466-4e5a-976c-5ac33fc0e744
# Measurement c5eb8569-96ee-43f0-acc6-50cc55bb89b0: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement c5eb8569-96ee-43f0-acc6-50cc55bb89b0
# Measurement f37a3bbe-946d-475a-9f47-ef79e2e031c2: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement f37a3bbe-946d-475a-9f47-ef79e2e031c2
# Measurement 69e02b49-7071-454b-9192-3da190eb081a: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 69e02b49-7071-454b-9192-3da190eb081a
# Measurement 9f107542-3124-4dde-8ea4-e11de9295a07: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 9f107542-3124-4dde-8ea4-e11de9295a07
# Measurement 17ef9c6e-eed6-4e5f-9b03-cfeca1e58f0a: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 17ef9c6e-eed6-4e5f-9b03-cfeca1e58f0a
# Measurement 2c431f0e-a371-4bdc-afbb-6a5ba025334b: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 2c431f0e-a371-4bdc-afbb-6a5ba025334b
# Measurement e07606f3-a147-4d5d-a8f6-ae4959e8ece2: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement e07606f3-a147-4d5d-a8f6-ae4959e8ece2
# Measurement bd068f78-a9b0-4de9-900a-ea2f58c54dd1: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement bd068f78-a9b0-4de9-900a-ea2f58c54dd1
# Measurement ec1f889d-c6cf-4541-9b5a-069bc5138bf1: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement ec1f889d-c6cf-4541-9b5a-069bc5138bf1
# Measurement 73802280-4dbf-44be-9225-c510745dbe98: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 73802280-4dbf-44be-9225-c510745dbe98
# Measurement 43bfd4b7-22c3-4f0f-9d37-6dacd55d8482: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 43bfd4b7-22c3-4f0f-9d37-6dacd55d8482
# Measurement 0211680d-87a7-44a4-a5a4-e3970990bee4: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 0211680d-87a7-44a4-a5a4-e3970990bee4
# Measurement d30cbcce-e74b-4eb0-973e-9fd7aec3b712: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement d30cbcce-e74b-4eb0-973e-9fd7aec3b712
# Measurement 5467e7b9-c042-471b-ad21-9f40e4159d75: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 5467e7b9-c042-471b-ad21-9f40e4159d75
# Measurement 1dccada7-2f23-4c8f-8cc4-2b52334e855f: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 1dccada7-2f23-4c8f-8cc4-2b52334e855f
# Measurement aa9d3ba7-3c6a-48c3-817a-b866cfa0753c: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement aa9d3ba7-3c6a-48c3-817a-b866cfa0753c
# Measurement 12bf784b-1496-4798-9f50-2a1091130712: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 12bf784b-1496-4798-9f50-2a1091130712
# Measurement 1f71b285-9cc2-4d35-877b-530c6a1794fb: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 1f71b285-9cc2-4d35-877b-530c6a1794fb
# Measurement 2fd83554-a868-4c0d-b1a3-42c297bf9e22: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 2fd83554-a868-4c0d-b1a3-42c297bf9e22
# Measurement d66c103f-3bd6-457c-8308-7ba54b39962d: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement d66c103f-3bd6-457c-8308-7ba54b39962d
# Measurement e2f84b2e-9823-474e-a97d-0c4ee5e55b63: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement e2f84b2e-9823-474e-a97d-0c4ee5e55b63
# Measurement 6e52d6b6-887e-4df1-9195-b439ec6901ce: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 6e52d6b6-887e-4df1-9195-b439ec6901ce
# Measurement 2cc323da-388d-4f33-bf03-50bf08cbeca0: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 2cc323da-388d-4f33-bf03-50bf08cbeca0
# Measurement ead14259-77a2-4752-b1c6-c0024ed21804: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement ead14259-77a2-4752-b1c6-c0024ed21804
# Measurement b75f84c4-ce2f-4493-86aa-4f1c6d8965c4: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement b75f84c4-ce2f-4493-86aa-4f1c6d8965c4
# Measurement d30605e0-8742-4888-bf1e-a9b30210adba: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement d30605e0-8742-4888-bf1e-a9b30210adba
# Measurement 6b6ff11d-a426-4afc-9b9e-2ebe7f107dda: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 6b6ff11d-a426-4afc-9b9e-2ebe7f107dda
# Measurement 1341a5f9-9c59-4680-9a52-7fc54e56e231: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 1341a5f9-9c59-4680-9a52-7fc54e56e231
# Measurement b71dcbbb-56d0-41a8-86cc-048b2d1c0471: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement b71dcbbb-56d0-41a8-86cc-048b2d1c0471
# Measurement 8a52c9d0-4795-4c8a-9928-d61e0edf4560: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 8a52c9d0-4795-4c8a-9928-d61e0edf4560
# Measurement cb102170-7ae1-4bfe-8d6a-23e52ff2686e: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement cb102170-7ae1-4bfe-8d6a-23e52ff2686e
# Measurement b3d4a203-e393-4059-a3cb-b1f35d2ba0e4: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement b3d4a203-e393-4059-a3cb-b1f35d2ba0e4
# Measurement 8482ffa1-ff1c-44c5-9817-8215f2688fcb: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 8482ffa1-ff1c-44c5-9817-8215f2688fcb
# Measurement 1fbd2648-9fff-42da-b2fd-c57c8f3c31be: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 1fbd2648-9fff-42da-b2fd-c57c8f3c31be
# Measurement e0543e23-6027-4052-988b-8bdc940900a2: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement e0543e23-6027-4052-988b-8bdc940900a2
# Measurement 6c089945-0d5d-43ce-84b5-9cd22cf50f02: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 6c089945-0d5d-43ce-84b5-9cd22cf50f02
# Measurement a4d4695b-ba93-420a-a341-1a97e19833a2: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement a4d4695b-ba93-420a-a341-1a97e19833a2
# Measurement 2fa71ed7-2574-473e-8391-fe773a75b575: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 2fa71ed7-2574-473e-8391-fe773a75b575
# Measurement 1b964451-0713-45ef-9708-d3459c5ea87e: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 1b964451-0713-45ef-9708-d3459c5ea87e
# Measurement 5b909627-bc62-4372-9ebd-8fa45f11af0f: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 5b909627-bc62-4372-9ebd-8fa45f11af0f
# Measurement 1903429f-f1ad-45b5-a281-d7638e4706b4: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 1903429f-f1ad-45b5-a281-d7638e4706b4
# Measurement 8c246a5e-c666-4a18-8f81-2c91bf6226e9: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 8c246a5e-c666-4a18-8f81-2c91bf6226e9
# Measurement 98f3377a-fd4a-4f61-88f8-50e478432582: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 98f3377a-fd4a-4f61-88f8-50e478432582
# Measurement b22196d4-1adf-466c-801f-2b208de0a36b: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement b22196d4-1adf-466c-801f-2b208de0a36b
# Measurement 6d866037-8b5e-44fe-bc44-be246107dc2e: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 6d866037-8b5e-44fe-bc44-be246107dc2e
# Measurement a6a30f4f-0afa-4a06-b27f-50bc0863668d: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement a6a30f4f-0afa-4a06-b27f-50bc0863668d
# Measurement 86a6270e-5248-48e7-931e-0e1112f1e41f: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 86a6270e-5248-48e7-931e-0e1112f1e41f
# Measurement b840fac0-1ccb-4f53-b55c-90e798d60352: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement b840fac0-1ccb-4f53-b55c-90e798d60352
# Measurement 549f5651-614b-48b2-96af-5d8f1559e078: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 549f5651-614b-48b2-96af-5d8f1559e078
#
# --- Processing Fluid 16 ---
# Added new parameter: parameter_solvent_ratio_urea_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement c74f6eea-eb8e-4238-a772-8dce9a33ecae: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement c74f6eea-eb8e-4238-a772-8dce9a33ecae
# Measurement 6936ec02-0797-489d-9d8d-16d536b82c1c: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 6936ec02-0797-489d-9d8d-16d536b82c1c
# Measurement 96cd6b73-4dd0-4481-97b1-9b59e6bfd2f9: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 96cd6b73-4dd0-4481-97b1-9b59e6bfd2f9
# Measurement 855a1026-1778-4369-b565-d5f444316be5: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 855a1026-1778-4369-b565-d5f444316be5
# Measurement 60e6d9fc-0208-478f-82d0-8d2afff7d15e: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 60e6d9fc-0208-478f-82d0-8d2afff7d15e
# Measurement 7f6359a9-2bb8-429f-be90-98b46f32edd6: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 7f6359a9-2bb8-429f-be90-98b46f32edd6
# Measurement d64e50ac-9b9e-4a3e-a376-34c6bbec2360: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement d64e50ac-9b9e-4a3e-a376-34c6bbec2360
# Measurement 83ba0527-3bf6-4209-9561-c3370b1162ca: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 83ba0527-3bf6-4209-9561-c3370b1162ca
# Measurement 20d0c30a-8e76-4b0e-b2c2-b2b0c944856c: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 20d0c30a-8e76-4b0e-b2c2-b2b0c944856c
# Measurement 9f83f5c2-cf05-44a1-bfdf-b545a9b9577d: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 9f83f5c2-cf05-44a1-bfdf-b545a9b9577d
# Measurement 1bd45b37-55ae-4377-8bf2-4b6e9596ea32: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 1bd45b37-55ae-4377-8bf2-4b6e9596ea32
# Measurement 6b923e09-56dd-4c55-b235-d97295a1ce04: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 6b923e09-56dd-4c55-b235-d97295a1ce04
# Measurement ded8ff38-d2cd-4878-8f1c-a54d02dc3d01: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement ded8ff38-d2cd-4878-8f1c-a54d02dc3d01
# Measurement 610d99ec-dad1-47f0-8da1-8fc7cc718304: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 610d99ec-dad1-47f0-8da1-8fc7cc718304
# Measurement de2a36b9-51cc-4c4f-823d-6ba459ffcdb4: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement de2a36b9-51cc-4c4f-823d-6ba459ffcdb4
# Measurement 7d5ccde9-50ad-49c4-b93a-aab8efff7db7: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 7d5ccde9-50ad-49c4-b93a-aab8efff7db7
# Measurement f1dce6b8-8fa4-482a-b268-a0e6acc4c9a4: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement f1dce6b8-8fa4-482a-b268-a0e6acc4c9a4
# Measurement 9aa5dd08-1ea4-42c2-aae1-4ce239ea1161: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 9aa5dd08-1ea4-42c2-aae1-4ce239ea1161
# Measurement 16590efc-4c9e-4df2-9e9a-f039bf84c325: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 16590efc-4c9e-4df2-9e9a-f039bf84c325
# Measurement 893d2c76-e0c5-40bf-96e0-b8230fd9dfb6: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 893d2c76-e0c5-40bf-96e0-b8230fd9dfb6
# Measurement 330215d2-8a25-4a1a-8cad-d0a93fb4b616: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 330215d2-8a25-4a1a-8cad-d0a93fb4b616
# Measurement c71af9ec-7f8e-4761-99e3-25a4a30f885a: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement c71af9ec-7f8e-4761-99e3-25a4a30f885a
# Measurement 65a25768-bcae-4772-9410-6ee0f99017ae: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 65a25768-bcae-4772-9410-6ee0f99017ae
# Measurement 28578056-aa47-4350-b456-943f6e7312c8: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 28578056-aa47-4350-b456-943f6e7312c8
# Measurement e87ad383-b3f7-44b7-8dcd-1c858ff673e4: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement e87ad383-b3f7-44b7-8dcd-1c858ff673e4
#
# --- Processing Fluid 17 ---
# Added new parameter: parameter_solvent_ratio_urea_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement e26ffd10-fcff-464b-a3e1-e63088606374: ratio = 0.949999999952 / 0.050000000047 = 19.0
# Added ratio value 19.0 to measurement e26ffd10-fcff-464b-a3e1-e63088606374
# Measurement 2d725643-d219-4215-86f2-4c9b873b0909: ratio = 0.949999999952 / 0.050000000047 = 19.0
# Added ratio value 19.0 to measurement 2d725643-d219-4215-86f2-4c9b873b0909
# Measurement 3440b236-cf72-4e84-9248-58d7169f0b05: ratio = 0.949999999952 / 0.050000000047 = 19.0
# Added ratio value 19.0 to measurement 3440b236-cf72-4e84-9248-58d7169f0b05
# Measurement f0e75825-d797-4309-8211-30c32a0d9252: ratio = 0.949999999952 / 0.050000000047 = 19.0
# Added ratio value 19.0 to measurement f0e75825-d797-4309-8211-30c32a0d9252
# Measurement 8cfcf206-4b58-4fff-9b42-dea5ead394b8: ratio = 0.949999999952 / 0.050000000047 = 19.0
# Added ratio value 19.0 to measurement 8cfcf206-4b58-4fff-9b42-dea5ead394b8
# Measurement e9c39a3f-37cf-4f61-9a23-34448108e208: ratio = 0.949999999952 / 0.050000000047 = 19.0
# Added ratio value 19.0 to measurement e9c39a3f-37cf-4f61-9a23-34448108e208
# Measurement d2205288-2303-4aa8-806c-4f0a99d626fd: ratio = 0.949999999952 / 0.050000000047 = 19.0
# Added ratio value 19.0 to measurement d2205288-2303-4aa8-806c-4f0a99d626fd
# Measurement 56d65c18-4964-4edc-8882-c98a575a7b2b: ratio = 0.949999999952 / 0.050000000047 = 19.0
# Added ratio value 19.0 to measurement 56d65c18-4964-4edc-8882-c98a575a7b2b
# Measurement c56afcb4-4722-4c48-be53-b5311160b20e: ratio = 0.949999999952 / 0.050000000047 = 19.0
# Added ratio value 19.0 to measurement c56afcb4-4722-4c48-be53-b5311160b20e
#
# --- Processing Fluid 18 ---
# Added new parameter: parameter_solvent_ratio_urea_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 4383e80b-f9e2-47d1-b515-afb16faef93f: ratio = 0.90000000009 / 0.09999999991 = 9.0
# Added ratio value 9.0 to measurement 4383e80b-f9e2-47d1-b515-afb16faef93f
# Measurement 1ec36418-2170-4631-8e9a-2700d3eac7b7: ratio = 0.90000000009 / 0.09999999991 = 9.0
# Added ratio value 9.0 to measurement 1ec36418-2170-4631-8e9a-2700d3eac7b7
# Measurement cd260688-61e3-4719-a429-44b92a0d9a44: ratio = 0.90000000009 / 0.09999999991 = 9.0
# Added ratio value 9.0 to measurement cd260688-61e3-4719-a429-44b92a0d9a44
# Measurement b338ac59-6cb4-4ff6-bff4-615c1335ff84: ratio = 0.90000000009 / 0.09999999991 = 9.0
# Added ratio value 9.0 to measurement b338ac59-6cb4-4ff6-bff4-615c1335ff84
# Measurement fe08ec77-acce-412a-a702-e7acc6bd4ea0: ratio = 0.90000000009 / 0.09999999991 = 9.0
# Added ratio value 9.0 to measurement fe08ec77-acce-412a-a702-e7acc6bd4ea0
# Measurement 99d0df24-4e31-4816-904e-1abea5d155f4: ratio = 0.90000000009 / 0.09999999991 = 9.0
# Added ratio value 9.0 to measurement 99d0df24-4e31-4816-904e-1abea5d155f4
# Measurement 20e8fe36-5cc7-4029-b36c-fdb8e9f0dfa6: ratio = 0.90000000009 / 0.09999999991 = 9.0
# Added ratio value 9.0 to measurement 20e8fe36-5cc7-4029-b36c-fdb8e9f0dfa6
# Measurement 77c49ebb-c4d1-4710-9dda-ba4f95bdf83b: ratio = 0.90000000009 / 0.09999999991 = 9.0
# Added ratio value 9.0 to measurement 77c49ebb-c4d1-4710-9dda-ba4f95bdf83b
# Measurement 1ff08d1e-8c0b-438e-a940-136945162a93: ratio = 0.90000000009 / 0.09999999991 = 9.0
# Added ratio value 9.0 to measurement 1ff08d1e-8c0b-438e-a940-136945162a93
#
# --- Processing Fluid 19 ---
# Added new parameter: parameter_solvent_ratio_urea_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 72189975-3d32-4f18-9602-0ef5ddb1bd34: ratio = 0.85000000017 / 0.14999999983 = 5.7
# Added ratio value 5.7 to measurement 72189975-3d32-4f18-9602-0ef5ddb1bd34
# Measurement 6484124e-c57b-4f61-9770-693025fb04b6: ratio = 0.85000000017 / 0.14999999983 = 5.7
# Added ratio value 5.7 to measurement 6484124e-c57b-4f61-9770-693025fb04b6
# Measurement 6e9c1b71-00d2-42bb-8ea6-0a9a8e5392f6: ratio = 0.85000000017 / 0.14999999983 = 5.7
# Added ratio value 5.7 to measurement 6e9c1b71-00d2-42bb-8ea6-0a9a8e5392f6
# Measurement 0c3c0267-5cc0-4ea0-99f9-05965ac4ca6e: ratio = 0.85000000017 / 0.14999999983 = 5.7
# Added ratio value 5.7 to measurement 0c3c0267-5cc0-4ea0-99f9-05965ac4ca6e
# Measurement 05ee2899-a277-44f2-8544-537f17343077: ratio = 0.85000000017 / 0.14999999983 = 5.7
# Added ratio value 5.7 to measurement 05ee2899-a277-44f2-8544-537f17343077
# Measurement d5d06212-fc8a-41db-8967-e9058572134d: ratio = 0.85000000017 / 0.14999999983 = 5.7
# Added ratio value 5.7 to measurement d5d06212-fc8a-41db-8967-e9058572134d
# Measurement 4fa3bb86-249a-432a-9bbd-3cc9f0370df9: ratio = 0.85000000017 / 0.14999999983 = 5.7
# Added ratio value 5.7 to measurement 4fa3bb86-249a-432a-9bbd-3cc9f0370df9
# Measurement a1115ef2-9db3-4c64-aa1d-f0162c08b16c: ratio = 0.85000000017 / 0.14999999983 = 5.7
# Added ratio value 5.7 to measurement a1115ef2-9db3-4c64-aa1d-f0162c08b16c
# Measurement 394509bc-97f9-4557-9852-676b2be17646: ratio = 0.85000000017 / 0.14999999983 = 5.7
# Added ratio value 5.7 to measurement 394509bc-97f9-4557-9852-676b2be17646
#
# --- Processing Fluid 20 ---
# Added new parameter: parameter_solvent_ratio_urea_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 79258a96-90fc-4fc4-9e48-e05a6a4ebb07: ratio = 0.8 / 0.2 = 4.0
# Added ratio value 4.0 to measurement 79258a96-90fc-4fc4-9e48-e05a6a4ebb07
# Measurement ed7adcff-bd04-46f6-9455-c4000347cd53: ratio = 0.8 / 0.2 = 4.0
# Added ratio value 4.0 to measurement ed7adcff-bd04-46f6-9455-c4000347cd53
# Measurement ede1c5a2-68fd-4d42-ad4d-b87ad167930e: ratio = 0.8 / 0.2 = 4.0
# Added ratio value 4.0 to measurement ede1c5a2-68fd-4d42-ad4d-b87ad167930e
# Measurement 51a439f1-e7bf-418b-adb8-051651a93cc6: ratio = 0.8 / 0.2 = 4.0
# Added ratio value 4.0 to measurement 51a439f1-e7bf-418b-adb8-051651a93cc6
# Measurement 2039f946-14e7-4f99-b899-96f24b5865c5: ratio = 0.8 / 0.2 = 4.0
# Added ratio value 4.0 to measurement 2039f946-14e7-4f99-b899-96f24b5865c5
# Measurement 1478251d-3b89-45d6-a819-6a1c71095e23: ratio = 0.8 / 0.2 = 4.0
# Added ratio value 4.0 to measurement 1478251d-3b89-45d6-a819-6a1c71095e23
# Measurement 3741d0f7-d8d3-4423-b099-decb7745bd7b: ratio = 0.8 / 0.2 = 4.0
# Added ratio value 4.0 to measurement 3741d0f7-d8d3-4423-b099-decb7745bd7b
# Measurement 82c4cc4b-44f9-43b5-831d-5873cbb25cef: ratio = 0.8 / 0.2 = 4.0
# Added ratio value 4.0 to measurement 82c4cc4b-44f9-43b5-831d-5873cbb25cef
# Measurement 8ff69329-0521-49a5-90d7-cfa7b0c8c629: ratio = 0.8 / 0.2 = 4.0
# Added ratio value 4.0 to measurement 8ff69329-0521-49a5-90d7-cfa7b0c8c629
#
# --- Processing Fluid 21 ---
# Added new parameter: parameter_solvent_ratio_urea_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement a58c655b-17ea-40cc-9222-9a5a25c5e771: ratio = 0.750000000188 / 0.249999999812 = 3.0
# Added ratio value 3.0 to measurement a58c655b-17ea-40cc-9222-9a5a25c5e771
# Measurement 7d997d9b-a574-493d-b26a-3cd962faf915: ratio = 0.750000000188 / 0.249999999812 = 3.0
# Added ratio value 3.0 to measurement 7d997d9b-a574-493d-b26a-3cd962faf915
# Measurement 40e3d618-ed6a-4323-8dc9-07b6057ccc51: ratio = 0.750000000188 / 0.249999999812 = 3.0
# Added ratio value 3.0 to measurement 40e3d618-ed6a-4323-8dc9-07b6057ccc51
# Measurement e7356da3-6d51-4bc6-9a1f-eba1b042c2ad: ratio = 0.750000000188 / 0.249999999812 = 3.0
# Added ratio value 3.0 to measurement e7356da3-6d51-4bc6-9a1f-eba1b042c2ad
# Measurement 1fbd27f4-000c-48a6-bfda-2e5063c23e62: ratio = 0.750000000188 / 0.249999999812 = 3.0
# Added ratio value 3.0 to measurement 1fbd27f4-000c-48a6-bfda-2e5063c23e62
# Measurement 81030596-2c79-49ec-aeb9-4d821fd551b5: ratio = 0.750000000188 / 0.249999999812 = 3.0
# Added ratio value 3.0 to measurement 81030596-2c79-49ec-aeb9-4d821fd551b5
# Measurement c31f83fc-3e08-49b5-b5d8-9b0cbbf75b77: ratio = 0.750000000188 / 0.249999999812 = 3.0
# Added ratio value 3.0 to measurement c31f83fc-3e08-49b5-b5d8-9b0cbbf75b77
# Measurement 2d0e0de2-1cae-476e-85ca-1f627bab38ec: ratio = 0.750000000188 / 0.249999999812 = 3.0
# Added ratio value 3.0 to measurement 2d0e0de2-1cae-476e-85ca-1f627bab38ec
# Measurement 576f3857-2f49-43e7-87a9-0e5dd9786730: ratio = 0.750000000188 / 0.249999999812 = 3.0
# Added ratio value 3.0 to measurement 576f3857-2f49-43e7-87a9-0e5dd9786730
#
# --- Processing Fluid 22 ---
# Added new parameter: parameter_solvent_ratio_urea_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 4f0c787a-f13e-4ba0-94b8-eac72409308f: ratio = 0.69999999979 / 0.30000000021 = 2.3
# Added ratio value 2.3 to measurement 4f0c787a-f13e-4ba0-94b8-eac72409308f
# Measurement 461a9d75-152a-47f2-9c6f-1585b45b0d6c: ratio = 0.69999999979 / 0.30000000021 = 2.3
# Added ratio value 2.3 to measurement 461a9d75-152a-47f2-9c6f-1585b45b0d6c
# Measurement 82e32308-299e-45b1-b80d-3c259d4d1fc3: ratio = 0.69999999979 / 0.30000000021 = 2.3
# Added ratio value 2.3 to measurement 82e32308-299e-45b1-b80d-3c259d4d1fc3
# Measurement 6b87ff25-849d-442d-963d-4a8aea68bbfa: ratio = 0.69999999979 / 0.30000000021 = 2.3
# Added ratio value 2.3 to measurement 6b87ff25-849d-442d-963d-4a8aea68bbfa
# Measurement 36644ebe-08c8-464e-b897-c0fe92510eb7: ratio = 0.69999999979 / 0.30000000021 = 2.3
# Added ratio value 2.3 to measurement 36644ebe-08c8-464e-b897-c0fe92510eb7
# Measurement b344991b-aa9e-46f0-b513-4d28401529f0: ratio = 0.69999999979 / 0.30000000021 = 2.3
# Added ratio value 2.3 to measurement b344991b-aa9e-46f0-b513-4d28401529f0
# Measurement 6fff6f8a-aa1f-411e-93d0-40c994f34e3b: ratio = 0.69999999979 / 0.30000000021 = 2.3
# Added ratio value 2.3 to measurement 6fff6f8a-aa1f-411e-93d0-40c994f34e3b
# Measurement 41e801a4-e554-4bb1-a1a5-2278370c9d81: ratio = 0.69999999979 / 0.30000000021 = 2.3
# Added ratio value 2.3 to measurement 41e801a4-e554-4bb1-a1a5-2278370c9d81
# Measurement 4f80b54e-ff16-4f20-8c6e-1dc5ddb6ef44: ratio = 0.69999999979 / 0.30000000021 = 2.3
# Added ratio value 2.3 to measurement 4f80b54e-ff16-4f20-8c6e-1dc5ddb6ef44
#
# --- Processing Fluid 23 ---
# Added new parameter: parameter_solvent_ratio_urea_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 98fd7474-39dc-4ffd-b41c-752c62c7788e: ratio = 0.294726726 / 0.147363363 = 2.0
# Added ratio value 2.0 to measurement 98fd7474-39dc-4ffd-b41c-752c62c7788e
#
# --- Processing Fluid 24 ---
# Added new parameter: parameter_solvent_ratio_urea_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 5d73398b-6743-4124-b147-a9cf7ef7e8ca: ratio = 0.352629193333 / 0.176314596667 = 2.0
# Added ratio value 2.0 to measurement 5d73398b-6743-4124-b147-a9cf7ef7e8ca
#
# --- Processing Fluid 25 ---
# Added new parameter: parameter_solvent_ratio_urea_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement ec4e81de-98a5-41d7-b0b1-ae62dfe31395: ratio = 0.426765982 / 0.213382991 = 2.0
# Added ratio value 2.0 to measurement ec4e81de-98a5-41d7-b0b1-ae62dfe31395
#
# --- Processing Fluid 26 ---
# Added new parameter: parameter_solvent_ratio_urea_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement b0a4470e-2fca-43ae-b8aa-d6d3acebce19: ratio = 0.472477279333 / 0.236238639667 = 2.0
# Added ratio value 2.0 to measurement b0a4470e-2fca-43ae-b8aa-d6d3acebce19
#
# --- Processing Fluid 27 ---
# Added new parameter: parameter_solvent_ratio_urea_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 7c56f5c4-7dd9-4241-94f9-c565b411c052: ratio = 0.526311321333 / 0.263155660667 = 2.0
# Added ratio value 2.0 to measurement 7c56f5c4-7dd9-4241-94f9-c565b411c052
#
# --- Processing Fluid 28 ---
# Added new parameter: parameter_solvent_ratio_urea_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement dab1e3ff-a2f0-457c-b6d5-b76b812e05a3: ratio = 0.589895344 / 0.294947672 = 2.0
# Added ratio value 2.0 to measurement dab1e3ff-a2f0-457c-b6d5-b76b812e05a3
#
# --- Processing Fluid 29 ---
# Added new parameter: parameter_solvent_ratio_urea_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 9aaf1a15-4209-4133-a0d2-1e9ab8b691bf: ratio = 0.63389538 / 0.31694769 = 2.0
# Added ratio value 2.0 to measurement 9aaf1a15-4209-4133-a0d2-1e9ab8b691bf
#
# --- Processing Fluid 30 ---
# Added new parameter: parameter_solvent_ratio_urea_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement fb319c2e-ee9c-4676-bed4-41866e9a12e4: ratio = 0.650095585333 / 0.325047792667 = 2.0
# Added ratio value 2.0 to measurement fb319c2e-ee9c-4676-bed4-41866e9a12e4
# === Solvent Ratio Calculation Complete ===
#
# 📁 Output saved to: /home/sga/Code/FAIRFluids/Workflows/outputs/Xu_Glycerol_Water.json

# %%
df_data_glyceline = extract_fairfluids_data(doc)

# Compute mole_fraction_water column for use in filtering
df_data_glyceline = df_data_glyceline.copy()
df_data_glyceline["mole_fraction_water"] = df_data_glyceline["mole_fractions"].apply(
    lambda mf: mf[-1] if isinstance(mf, (list, tuple)) and len(mf) > 0 else float('nan')
)

# Ensure mole_fraction_water is 1.0 when [Water] is the only component
def get_water_mole_fraction(row):
    """Get the mole fraction of water from fluid_compounds and mole_fractions."""
    if not isinstance(row["fluid_compounds"], list) or not isinstance(row["mole_fractions"], (list, tuple)):
        return 0.0
    
    # Find the position of water in fluid_compounds
    water_position = -1
    for i, compound in enumerate(row["fluid_compounds"]):
        if isinstance(compound, str) and compound.lower() in ['water', 'h2o']:
            water_position = i
            break
    
    # If water is found and mole_fractions has enough elements, return the mole fraction
    if water_position >= 0 and len(row["mole_fractions"]) > water_position:
        return row["mole_fractions"][water_position]
    else:
        return 0.0

df_data_glyceline["mole_fraction_water"] = df_data_glyceline.apply(get_water_mole_fraction, axis=1)

# Apply 0 to mole_fraction_water if only cholinechloride and glycerol is present in fluid_compounds
df_data_glyceline.loc[
    (df_data_glyceline["fluid_compounds"].apply(
        lambda comps: isinstance(comps, list)
        and len(comps) == 2
        and set(comps) == set(["Choline Chloride", "Glycerol"])
    )),
    "mole_fraction_water"
] = 0.0

# Additional dataframe for just [Choline Chloride, Glycerol]
df_reline_just_cc_gly = df_data_glyceline[
    df_data_glyceline["fluid_compounds"].apply(
        lambda comps: isinstance(comps, list)
        and len(comps) == 2
        and set(comps) == set(["Choline Chloride", "Glycerol"])
    )
]

# Filter for ratio == 2 OR (molefractions has water == 1)
df_data_glyceline_ratio_or_pure_water = df_data_glyceline[
    (df_data_glyceline["Solvent: Amount ratio of component to other component of binary solvent"] == 2)
    | (df_data_glyceline["mole_fraction_water"] == 1.0)
    | (df_data_glyceline["mole_fraction_water"] == 0.0)  # include the newly set 0.0 rows
]

# Sort by the water mole fraction, descending
df_data_glyceline_ratio_or_pure_water = df_data_glyceline_ratio_or_pure_water.sort_values(
    by="mole_fraction_water", ascending=False
)
df_data_glyceline_ratio_or_pure_water
#df_reline_just_cc_gly
# Out:
#                   fluid_compounds property_type  property_value  uncertainty  \
# 2                         [Water]     viscosity        0.000984     0.000005
# 1                         [Water]     viscosity        0.001274     0.000006
# 4                         [Water]     viscosity        0.000649     0.000003
# 3                         [Water]     viscosity        0.000791     0.000004
# 6                         [Water]     viscosity        0.000477     0.000002
# ..                            ...           ...             ...          ...
# 223  [Choline Chloride, Glycerol]     viscosity        0.548000          NaN
# 222  [Choline Chloride, Glycerol]     viscosity        0.074000     0.002220
# 229  [Choline Chloride, Glycerol]     viscosity        0.107000     0.003210
# 227  [Choline Chloride, Glycerol]     viscosity        0.194000     0.005820
# 228  [Choline Chloride, Glycerol]     viscosity        0.140000     0.004200
#
#      temperature                  mole_fractions  \
# 2         293.15                           [1.0]
# 1         283.15                           [1.0]
# 4         313.15                           [1.0]
# 3         303.15                           [1.0]
# 6         333.15                           [1.0]
# ..           ...                             ...
# 223       293.15  [0.14999999983, 0.85000000017]
# 222       328.15  [0.09999999991, 0.90000000009]
# 229       318.15  [0.14999999983, 0.85000000017]
# 227       308.15  [0.14999999983, 0.85000000017]
# 228       313.15  [0.14999999983, 0.85000000017]
#
#                            measurement_id                   source_doi  \
# 2    15066af3-838d-4b8e-b80c-bc9ab630296a  10.1016/j.fluid.2014.01.028
# 1    5546497f-309a-44a8-8fe3-f367ffbeff24  10.1016/j.fluid.2014.01.028
# 4    f0162dfb-0d87-4c95-8321-988db358ce05  10.1016/j.fluid.2014.01.028
# 3    875bd6be-feb0-4169-987f-74fcaa03800b  10.1016/j.fluid.2014.01.028
# 6    0b84e36d-ec7c-4fb1-8495-be4fa84ad99e  10.1016/j.fluid.2014.01.028
# ..                                    ...                          ...
# 223  72189975-3d32-4f18-9602-0ef5ddb1bd34            10.1021/jp0671998
# 222  1ff08d1e-8c0b-438e-a940-136945162a93           10.1039/c0gc00395f
# 229  4fa3bb86-249a-432a-9bbd-3cc9f0370df9           10.1039/c0gc00395f
# 227  05ee2899-a277-44f2-8544-537f17343077           10.1039/c0gc00395f
# 228  d5d06212-fc8a-41db-8967-e9058572134d           10.1039/c0gc00395f
#
#      Mole fraction  Temperature  \
# 2             1.00       293.15
# 1             1.00       283.15
# 4             1.00       313.15
# 3             1.00       303.15
# 6             1.00       333.15
# ..             ...          ...
# 223           0.85       293.15
# 222           0.90       328.15
# 229           0.85       318.15
# 227           0.85       308.15
# 228           0.85       313.15
#
#      Solvent: Amount ratio of component to other component of binary solvent  \
# 2                                                  NaN
# 1                                                  NaN
# 4                                                  NaN
# 3                                                  NaN
# 6                                                  NaN
# ..                                                 ...
# 223                                                5.7
# 222                                                9.0
# 229                                                5.7
# 227                                                5.7
# 228                                                5.7
#
#       doc_label mole_fractions_rounded  mole_fraction_Choline Chloride  \
# 2    Document_1                 (1.0,)                            1.00
# 1    Document_1                 (1.0,)                            1.00
# 4    Document_1                 (1.0,)                            1.00
# 3    Document_1                 (1.0,)                            1.00
# 6    Document_1                 (1.0,)                            1.00
# ..          ...                    ...                             ...
# 223  Document_1           (0.15, 0.85)                            0.15
# 222  Document_1             (0.1, 0.9)                            0.10
# 229  Document_1           (0.15, 0.85)                            0.15
# 227  Document_1           (0.15, 0.85)                            0.15
# 228  Document_1           (0.15, 0.85)                            0.15
#
#      mole_fraction_Glycerol  mole_fraction_Water  \
# 2                       NaN                  NaN
# 1                       NaN                  NaN
# 4                       NaN                  NaN
# 3                       NaN                  NaN
# 6                       NaN                  NaN
# ..                      ...                  ...
# 223                    0.85                  NaN
# 222                    0.90                  NaN
# 229                    0.85                  NaN
# 227                    0.85                  NaN
# 228                    0.85                  NaN
#
#                                    composition_temp_id viscosity_value  \
# 2    ((Water,), 293.15, 15066af3-838d-4b8e-b80c-bc9...        0.000984
# 1    ((Water,), 283.15, 5546497f-309a-44a8-8fe3-f36...        0.001274
# 4    ((Water,), 313.15, f0162dfb-0d87-4c95-8321-988...        0.000649
# 3    ((Water,), 303.15, 875bd6be-feb0-4169-987f-74f...        0.000791
# 6    ((Water,), 333.15, 0b84e36d-ec7c-4fb1-8495-be4...        0.000477
# ..                                                 ...             ...
# 223  ((Choline Chloride, Glycerol), 293.15, 7218997...           0.548
# 222  ((Choline Chloride, Glycerol), 328.15, 1ff08d1...           0.074
# 229  ((Choline Chloride, Glycerol), 318.15, 4fa3bb8...           0.107
# 227  ((Choline Chloride, Glycerol), 308.15, 05ee289...           0.194
# 228  ((Choline Chloride, Glycerol), 313.15, d5d0621...            0.14
#
#     viscosity_uncertainty  mole_fraction_water
# 2                0.000005                  1.0
# 1                0.000006                  1.0
# 4                0.000003                  1.0
# 3                0.000004                  1.0
# 6                0.000002                  1.0
# ..                    ...                  ...
# 223                   NaN                  0.0
# 222               0.00222                  0.0
# 229               0.00321                  0.0
# 227               0.00582                  0.0
# 228                0.0042                  0.0
#
# [267 rows x 20 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Make sure required columns exist
required_cols = ["viscosity_value", "temperature", "source_doi", "mole_fraction_water"]
for col in required_cols:
    if col not in df_data_glyceline_ratio_or_pure_water.columns:
        raise ValueError(f"Column '{col}' not found in dataframe.")

# Filter out rows with missing data
plot_df = df_data_glyceline_ratio_or_pure_water[df_data_glyceline_ratio_or_pure_water["viscosity_value"].notnull() & df_data_glyceline_ratio_or_pure_water["temperature"].notnull() & df_data_glyceline_ratio_or_pure_water["source_doi"].notnull()]

# Calculate ln(viscosity) and 1/RT (Kelvin)
# Use R = 8.314 J/(mol*K), but since it's unitless vs. 1/K, you can leave as 1/T or explicitly use 1/(R*T)
R = 8.314 # J/(mol*K)
plot_df = plot_df.copy()
plot_df["inv_RT"] = 1 / (R * plot_df["temperature"].astype(float))
plot_df["ln_viscosity"] = np.log(plot_df["viscosity_value"].astype(float))

plt.figure(figsize=(11, 7))
sns.scatterplot(
    data=plot_df,
    x="inv_RT",
    y="ln_viscosity",
    hue="source_doi",
    palette='tab20',
    s=80,
    edgecolor='gray'
)
plt.title('Plot of ln(Aₛ) vs 1/(R*T), Grouped by DOI')
plt.xlabel('1 (R*T)$^{-1}$ / mol J$^{-1}$')
plt.ylabel('ln(Aₛ) / ln(Pa*s)')
plt.legend(title="DOI", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import cm
from scipy.stats import linregress

# Make sure required columns exist
required_cols = ["viscosity_value", "temperature", "source_doi", "mole_fraction_water"]
for col in required_cols:
    if col not in df_data_glyceline_ratio_or_pure_water.columns:
        raise ValueError(f"Column '{col}' not found in dataframe.")

# Fill missing/None values in mole_fraction_water with 0
df_data_glyceline_ratio_or_pure_water = df_data_glyceline_ratio_or_pure_water.copy()
df_data_glyceline_ratio_or_pure_water["mole_fraction_water"] = (
    df_data_glyceline_ratio_or_pure_water["mole_fraction_water"]
    .fillna(0)
    .apply(lambda x: 0 if x is None else x)
)

# Filter out rows with missing data
plot_df = df_data_glyceline_ratio_or_pure_water[
    df_data_glyceline_ratio_or_pure_water["viscosity_value"].notnull() &
    df_data_glyceline_ratio_or_pure_water["temperature"].notnull() &
    df_data_glyceline_ratio_or_pure_water["source_doi"].notnull()
].copy()

# Calculate ln(viscosity) and 1/(R*T)
R = 8.314  # J/(mol*K)
plot_df["inv_RT"] = 1 / (R * plot_df["temperature"].astype(float))
plot_df["ln_viscosity"] = np.log(plot_df["viscosity_value"].astype(float))

# Use mole_fraction_water to color the water amount
plot_df["water_mole_fraction"] = plot_df["mole_fraction_water"].astype(float)

# We'll use unique discrete values for water mole fraction as hue
plot_df["water_mole_fraction_rounded"] = plot_df["water_mole_fraction"].round(3)
discrete_mole_fractions = np.sort(plot_df["water_mole_fraction_rounded"].unique())

# Set up colormap: Blues colormap, N bins = number of unique mole fractions
N = len(discrete_mole_fractions)
cmap = cm.get_cmap('Blues', N)
color_dict = {mf: cmap(i) for i, mf in enumerate(discrete_mole_fractions)}

plt.figure(figsize=(11,8))
ax = plt.gca()

# Scatter points for each discrete fraction, so legend can be discrete
for i, mf in enumerate(discrete_mole_fractions):
    subset = plot_df[plot_df["water_mole_fraction_rounded"] == mf]
    ax.scatter(
        subset["inv_RT"], 
        subset["ln_viscosity"], 
        color=color_dict[mf],
        s=30, 
        edgecolor='black',
        linewidth=0.2,
        label=f"{mf:.3f}"
    )

# Linear fit and store slopes per discrete water content
slope_results = []
for mf in discrete_mole_fractions:
    group = plot_df[plot_df["water_mole_fraction_rounded"] == mf]
    if len(group) >= 2:
        x = group["inv_RT"].values
        y = group["ln_viscosity"].values
        slope, intercept, r_value, p_value, std_err = linregress(x, y)
        xfit = np.linspace(x.min(), x.max(), 50)
        yfit = intercept + slope * xfit
        # Optional: plot the fits in same color, commented out for clarity
        # ax.plot(xfit, yfit, linestyle='--', linewidth=2, color=color_dict[mf])
        mf_tuple = tuple(group["mole_fractions"].iloc[0]) if "mole_fractions" in group.columns and isinstance(group["mole_fractions"].iloc[0], (list, tuple)) else group["mole_fractions"].iloc[0] if "mole_fractions" in group.columns else None
        slope_results.append({
            "mole_fractions": mf_tuple,
            "water_mole_fraction": float(mf),
            "slope": slope
        })

# Make discrete legend
handles, labels = ax.get_legend_handles_labels()
by_label = dict(zip(labels, handles))
lgd = ax.legend(by_label.values(), by_label.keys(), title="Water mole fraction", bbox_to_anchor=(1.04, 1), loc='upper left', borderaxespad=0.)

plt.title('Plot of ln(Aₛ) vs 1/(R*T), Grouped by water mole fraction')
plt.xlabel('1 (R*T)$^{-1}$ / mol J$^{-1}$')
plt.ylabel('ln(Aₛ) / ln(Pa*s)')
plt.tight_layout()
plt.show()

import pandas as pd
activation_energy_df = pd.DataFrame(slope_results)
activation_energy_df = activation_energy_df.rename(columns={'slope': 'activation_energy'})
print("All linear fit activation energies by water mole fraction:")
display(activation_energy_df[["water_mole_fraction", "activation_energy"]])
# Out:
# /tmp/ipykernel_7996/2456799823.py:41: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('Blues', N)
# All linear fit activation energies by water mole fraction:
#     water_mole_fraction  activation_energy
# 0                 0.000       44964.716603
# 1                 0.108       40366.403098
# 2                 0.238       37590.289435
# 3                 0.254       41597.359069
# 4                 0.342       34740.693961
# 5                 0.402       33526.414685
# 6                 0.598       28874.286184
# 7                 0.720       24938.581185
# 8                 0.800       22366.546410
# 9                 0.857       18893.527986
# 10                0.901       17207.759499
# 11                0.934       16013.872479
# 12                0.960       15546.665223
# 13                0.982       14912.521507
# 14                1.000       13957.939791

# %%
import matplotlib.pyplot as plt
import numpy as np

# Remove the gray background globally
plt.style.use('default')

fig, ax = plt.subplots(figsize=(10, 6))

# Calculate inv_RT and ln_viscosity if not already present, use correct dataframe columns
if "inv_RT" not in df_reline_just_cc_gly.columns or "ln_viscosity" not in df_reline_just_cc_gly.columns:
    R = 8.314462618  # J/(mol*K)
    df_reline_just_cc_gly = df_reline_just_cc_gly.copy()
    df_reline_just_cc_gly["inv_RT"] = 1 / (R * df_reline_just_cc_gly["temperature"])
    # Defensive: Make sure viscosity_value column is numeric and positive
    viscosity_numeric = pd.to_numeric(df_reline_just_cc_gly["viscosity_value"], errors='coerce')
    # Replace/mark as NaN any infeasible values (<=0 or failed conversion)
    bad_mask = (viscosity_numeric.isna()) | (viscosity_numeric <= 0)
    if bad_mask.any():
        print(f"Warning: {bad_mask.sum()} rows in viscosity_value are NaN, <=0, or invalid. These will be skipped for ln(viscosity).")
    ln_viscosity = np.full_like(viscosity_numeric, np.nan, dtype=np.float64)
    ln_viscosity[~bad_mask] = np.log(viscosity_numeric[~bad_mask])
    df_reline_just_cc_gly["ln_viscosity"] = ln_viscosity

# Use different marker shapes for different "Solvent: Amount ratio of component to other component of binary solvent"
if "glycerol_cholinechloride" in df_reline_just_cc_gly.columns:
    ratio_col = "glycerol_cholinechloride"
elif "Solvent: Amount ratio of component to other component of binary solvent" in df_reline_just_cc_gly.columns:
    ratio_col = "Solvent: Amount ratio of component to other component of binary solvent"
else:
    ratio_col = None

if ratio_col is not None:
    unique_ratios = df_reline_just_cc_gly[ratio_col].dropna().unique()
    ratios_sorted = np.sort(unique_ratios)
    # Common matplotlib marker styles, enough for up to 8 unique ratios
    markers = ['o', 's', 'D', '^', 'v', '<', '>', 'P', '*', 'X', 'h', 'H']
    marker_styles = {ratio: markers[i % len(markers)] for i, ratio in enumerate(ratios_sorted)}
else:
    marker_styles = None

# Get unique DOIs and assign colors
dois = df_reline_just_cc_gly["source_doi"].unique()
colors = plt.cm.Set2.colors
color_map = {doi: colors[i % len(colors)] for i, doi in enumerate(dois)}

legend_handles = []
for doi in dois:
    doi_subset = df_reline_just_cc_gly[
        (df_reline_just_cc_gly["source_doi"] == doi)
        & (~df_reline_just_cc_gly["inv_RT"].isna())
        & (~df_reline_just_cc_gly["ln_viscosity"].isna())
    ]
    if marker_styles is not None and ratio_col is not None:
        for ratio in sorted(marker_styles.keys()):
            subset = doi_subset[doi_subset[ratio_col] == ratio]
            if subset.empty:
                continue
            handle = ax.scatter(
                subset["inv_RT"],
                subset["ln_viscosity"],
                label=f"{doi}\nratio={ratio}",
                marker=marker_styles[ratio],
                color=color_map[doi],
                s=55,
                edgecolor='black',
                linewidth=0.8,
            )
            # Collect one handle per ratio:doi for custom legend
            legend_handles.append((f"{doi} | ratio={ratio}", handle))
    else:
        subset = doi_subset
        handle = ax.scatter(
            subset["inv_RT"],
            subset["ln_viscosity"],
            label=doi,
            color=color_map[doi],
            s=20,
            edgecolor='black',
            linewidth=0.1
        )
        legend_handles.append((doi, handle))

ax.set_xlabel('1/(R*T) [mol/J]')
ax.set_ylabel('ln(viscosity)')

# Remove default axes and legend background
ax.set_facecolor('white')
fig.patch.set_facecolor('white')

# Custom legend: show one per DOI+ratio combination if marker_styles exist
from matplotlib.patches import Patch
from matplotlib.legend_handler import HandlerTuple

if marker_styles is not None:
    unique_labels = {}
    for lbl, h in legend_handles:
        if lbl not in unique_labels:
            unique_labels[lbl] = h
    leg = ax.legend(unique_labels.values(), unique_labels.keys(), title='DOI | ratio', bbox_to_anchor=(1.04, 1), loc='upper left', frameon=False)
else:
    leg = ax.legend(title='DOI', bbox_to_anchor=(1.04, 1), loc='upper left', frameon=False)

ax.set_title('Plot of ln(viscosity) vs 1/(R*T),\ncolors by DOI, marker by solvent ratio')
plt.tight_layout()
plt.show()

# %%
# Calculate activation energies for each DOI and each ratio exactly as in cell 72-96 (see file_context_0)
from scipy.stats import linregress

activation_energy_results = []
for mf in [0]:  # This dataset is for pure reline (no water), so mole fraction is always 0
    group = df_reline_just_cc_gly  # All of this DF has water_mole_fraction = 0
    # For each unique source_doi in this water content, do a fit for that subset
    for doi in group["source_doi"].unique():
        doi_group = group[group["source_doi"] == doi]
        # Find proper ratio column
        if "glycerol_cholinechloride" in doi_group.columns:
            ratio_col = "glycerol_cholinechloride"
        elif "Solvent: Amount ratio of component to other component of binary solvent" in doi_group.columns:
            ratio_col = "Solvent: Amount ratio of component to other component of binary solvent"
        else:
            ratio_col = None

        # Work as in (72-96): group by ratio (if exists) or just DOI
        if ratio_col is not None:
            for ratio in sorted(doi_group[ratio_col].dropna().unique()):
                if ratio == 2:
                    continue  # Skip those with molar_ratio == 2
                sub2 = doi_group[
                    (doi_group[ratio_col] == ratio)
                    & (~doi_group["inv_RT"].isna())
                    & (~doi_group["ln_viscosity"].isna())
                ]
                if len(sub2) >= 2:
                    x = sub2["inv_RT"].values
                    y = sub2["ln_viscosity"].values
                    slope, intercept, r_value, p_value, std_err = linregress(x, y)
                    activation_energy_results.append({
                        "water_mole_fraction": float(mf),
                        "activation_energy": abs(slope),
                        "source_doi": doi,
                        "ordinate": intercept,
                        "statistic": r_value,
                        "molar_ratio": ratio,
                    })
        else:
            sub2 = doi_group[
                (~doi_group["inv_RT"].isna())
                & (~doi_group["ln_viscosity"].isna())
            ]
            if len(sub2) >= 2:
                x = sub2["inv_RT"].values
                y = sub2["ln_viscosity"].values
                slope, intercept, r_value, p_value, std_err = linregress(x, y)
                activation_energy_results.append({
                    "water_mole_fraction": float(mf),
                    "activation_energy": abs(slope),
                    "source_doi": doi,
                    "ordinate": intercept,
                    "statistic": r_value,
                    "molar_ratio": None,
                })

activation_energies_pure = pd.DataFrame(activation_energy_results)
display(activation_energies_pure)
# Out:
#    water_mole_fraction  activation_energy          source_doi   ordinate  \
# 0                  0.0       45502.133942  10.1039/c0gc00395f -19.587819
# 1                  0.0       47045.892294  10.1039/c0gc00395f -20.124261
# 2                  0.0       48304.321208  10.1039/c0gc00395f -20.543573
# 3                  0.0       50296.423067  10.1039/c0gc00395f -21.256798
# 4                  0.0       53401.786797  10.1039/c0gc00395f -22.208433
# 5                  0.0       54772.293625  10.1039/c0gc00395f -22.513597
#
#    statistic  molar_ratio
# 0   0.999903          2.3
# 1   0.999625          3.0
# 2   0.997493          4.0
# 3   0.999803          5.7
# 4   0.999157          9.0
# 5   0.999573         19.0

# %%
# Plot ln(viscosity/1000) vs 1/(R*T) but only for "Solvent: Amount ratio of component to other component of binary solvent" == 2
# with no grey background (no 'ggplot' style)

# Remove previous style settings to avoid grey background
plt.style.use('default')

ratio_of_interest = 2

if "glycerol_cholinechloride" in df_reline_just_cc_gly.columns:
    ratio_col_plot2 = "glycerol_cholinechloride"
elif "Solvent: Amount ratio of component to other component of binary solvent" in df_reline_just_cc_gly.columns:
    ratio_col_plot2 = "Solvent: Amount ratio of component to other component of binary solvent"
else:
    ratio_col_plot2 = None

if ratio_col_plot2 is not None:
    filtered_df = df_reline_just_cc_gly[df_reline_just_cc_gly[ratio_col_plot2] == ratio_of_interest].copy()
else:
    filtered_df = df_reline_just_cc_gly.copy()  # fallback: plot all

# Check if 'viscosity' column exists, if not use 'property_value'
if 'viscosity' in filtered_df.columns:
    viscosity_col = 'viscosity'
elif 'property_value' in filtered_df.columns:
    viscosity_col = 'property_value'
else:
    print("Error: Neither 'viscosity' nor 'property_value' column found in the dataframe")
    print("Available columns:", filtered_df.columns.tolist())
    viscosity_col = None

if viscosity_col is not None:
    # Calculate ln(viscosity/1000) for the filtered data
    filtered_df["ln_viscosity_scaled"] = np.log(filtered_df[viscosity_col] / 1000)

    fig2, ax2 = plt.subplots(figsize=(10, 6))

    # Set background to white explicitly
    fig2.patch.set_facecolor('white')
    ax2.set_facecolor('white')

    # Colors by DOI
    dois2 = filtered_df["source_doi"].unique()
    colors2 = plt.cm.Paired.colors
    color_map2 = {doi: colors2[i % len(colors2)] for i, doi in enumerate(dois2)}

    for doi in dois2:
        subset2 = filtered_df[
            (filtered_df["source_doi"] == doi)
            & (~filtered_df["inv_RT"].isna())
            & (~filtered_df["ln_viscosity_scaled"].isna())
        ]
        if subset2.empty:
            continue
        ax2.scatter(
            subset2["inv_RT"],
            subset2["ln_viscosity_scaled"],
            label=doi,
            color=color_map2[doi],
            s=60,
            edgecolor='black',
            linewidth=0.2
        )

    ax2.set_xlabel('1 (R*T)$^{-1}$ / mol J$^{-1}$', fontsize=14)
    ax2.set_ylabel('ln(Aₛ) / ln(Pa*s)', fontsize=14)
    ax2.set_title(f"Arrhenius plot of Glyceline (Component ratio 1:{ratio_of_interest})", fontsize=16)

    # Increase tick label font size
    ax2.tick_params(axis='both', which='major', labelsize=12)

    # Create secondary x-axis for temperature
    ax2_temp = ax2.twiny()

    # Get the current x-axis limits
    x_min, x_max = ax2.get_xlim()

    # Convert 1/(R*T) to temperature (K)
    R = 8.314462618  # J/mol/K
    T_min = 1 / (R * x_max)  # Higher 1/(R*T) corresponds to lower temperature
    T_max = 1 / (R * x_min)  # Lower 1/(R*T) corresponds to higher temperature

    # Set temperature axis limits and ticks
    ax2_temp.set_xlim(T_max, T_min)
    temp_ticks = np.linspace(T_max, T_min, 6)
    ax2_temp.set_xticks(temp_ticks)
    ax2_temp.set_xticklabels([f'{T:.0f}' for T in temp_ticks])
    ax2_temp.set_xlabel('Temperature [K]', fontsize=14)
    ax2_temp.tick_params(axis='x', which='major', labelsize=12)

    # Make legend background white and non-fancy with increased font size
    legend = ax2.legend(title='DOI', bbox_to_anchor=(1.04, 1), loc='upper left', frameon=True, fancybox=False, fontsize=12)
    if legend is not None:
        legend.get_frame().set_facecolor('white')
        legend.get_frame().set_edgecolor('black')
        legend.get_title().set_fontsize(14)

    plt.tight_layout()
    plt.show()

# %%
# Plot filtered_df grouped by DOI, splitting temperature points into low and high temperature groups
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Create figure and axis
fig, ax = plt.subplots(figsize=(12, 8))

# Get unique DOIs
dois = filtered_df['source_doi'].unique()

# Color map for DOIs
colors = plt.cm.tab10(np.linspace(0, 1, len(dois)))
color_map = dict(zip(dois, colors))

# List to store all split data
split_data = []

# Get overall x-axis range for extending lines
all_inv_RT = filtered_df[~filtered_df["inv_RT"].isna()]["inv_RT"]
x_range_min = all_inv_RT.min() * 0.95
x_range_max = all_inv_RT.max() * 1.05

# Process each DOI
for i, doi in enumerate(dois):
    subset = filtered_df[
        (filtered_df["source_doi"] == doi)
        & (~filtered_df["inv_RT"].isna())
        & (~filtered_df["ln_viscosity"].isna())
    ]
    
    if len(subset) < 2:
        continue  # Skip if not enough points
    
    # Sort by temperature (inverse of inv_RT for proper ordering)
    subset_sorted = subset.sort_values('inv_RT')
    
    # Split into two halves based on temperature
    n_points = len(subset_sorted)
    mid_point = n_points // 2
    
    # Lower half (higher temperatures - lower inv_RT values)
    low_temp_group = subset_sorted.iloc[:mid_point].copy()
    low_temp_group['temperature_group'] = 'High T'
    
    # Upper half (lower temperatures - higher inv_RT values)  
    high_temp_group = subset_sorted.iloc[mid_point:].copy()
    high_temp_group['temperature_group'] = 'Low T'
    
    # Add to split_data list
    split_data.append(low_temp_group)
    split_data.append(high_temp_group)
    
    # Plot low temperature group (circles)
    if len(low_temp_group) > 0:
        ax.scatter(
            low_temp_group["inv_RT"],
            low_temp_group["ln_viscosity"],
            label=f'{doi} (High T)',
            color=color_map[doi],
            marker='o',
            s=80,
            alpha=0.7,
            edgecolor='black',
            linewidth=0.5
        )
        
        # Fit and plot extended Arrhenius line for high temperature group
        if len(low_temp_group) >= 2:
            x_high = low_temp_group["inv_RT"].values
            y_high = low_temp_group["ln_viscosity"].values
            slope_high, intercept_high = np.polyfit(x_high, y_high, 1)
            
            # Create extended line points for plotting
            x_line_high = np.linspace(x_range_min, x_range_max, 100)
            y_line_high = slope_high * x_line_high + intercept_high
            
            ax.plot(x_line_high, y_line_high, color=color_map[doi], 
                   linestyle='-', alpha=0.8, linewidth=2)
    
    # Plot high temperature group (squares)
    if len(high_temp_group) > 0:
        ax.scatter(
            high_temp_group["inv_RT"],
            high_temp_group["ln_viscosity"],
            label=f'{doi} (Low T)',
            color=color_map[doi],
            marker='s',
            s=80,
            alpha=0.7,
            edgecolor='black',
            linewidth=0.5
        )
        
        # Fit and plot extended Arrhenius line for low temperature group
        if len(high_temp_group) >= 2:
            x_low = high_temp_group["inv_RT"].values
            y_low = high_temp_group["ln_viscosity"].values
            slope_low, intercept_low = np.polyfit(x_low, y_low, 1)
            
            # Create extended line points for plotting
            x_line_low = np.linspace(x_range_min, x_range_max, 100)
            y_line_low = slope_low * x_line_low + intercept_low
            
            ax.plot(x_line_low, y_line_low, color=color_map[doi], 
                   linestyle='--', alpha=0.8, linewidth=2)
    
    # Plot extended full range Arrhenius line
    if len(subset_sorted) >= 2:
        x_full = subset_sorted["inv_RT"].values
        y_full = subset_sorted["ln_viscosity"].values
        slope_full, intercept_full = np.polyfit(x_full, y_full, 1)
        
        # Create extended line points for plotting
        x_line_full = np.linspace(x_range_min, x_range_max, 100)
        y_line_full = slope_full * x_line_full + intercept_full
        
        ax.plot(x_line_full, y_line_full, color=color_map[doi], 
               linestyle=':', alpha=0.6, linewidth=3)

# Set labels and title
ax.set_xlabel('1 (R*T)$^{-1}$ / mol J$^{-1}$', fontsize=14)
ax.set_ylabel('ln(Aₛ) / ln(Pa*s)', fontsize=14)
ax.set_title('Arrhenius Plot: Temperature Groups by DOI (Glyceline, ratio 1:2)', fontsize=16)

# Increase tick label font size
ax.tick_params(axis='both', which='major', labelsize=12)

# Create secondary x-axis for temperature
ax_temp = ax.twiny()

# Get the current x-axis limits
x_min, x_max = ax.get_xlim()

# Convert 1/(R*T) to temperature (K)
R = 8.314462618  # J/mol/K
T_min = 1 / (R * x_max)  # Higher 1/(R*T) corresponds to lower temperature
T_max = 1 / (R * x_min)  # Lower 1/(R*T) corresponds to higher temperature

# Set temperature axis limits and ticks
ax_temp.set_xlim(T_max, T_min)
temp_ticks = np.linspace(T_max, T_min, 6)
ax_temp.set_xticks(temp_ticks)
ax_temp.set_xticklabels([f'{T:.0f}' for T in temp_ticks])
ax_temp.set_xlabel('Temperature / K', fontsize=14)
ax_temp.tick_params(axis='x', which='major', labelsize=12)

# Create legend with two columns to accommodate more entries
legend = ax.legend(bbox_to_anchor=(1.04, 1), loc='upper left', frameon=True, 
                  fancybox=False, fontsize=10, ncol=1)
if legend is not None:
    legend.get_frame().set_facecolor('white')
    legend.get_frame().set_edgecolor('black')

# Add legend for line styles
from matplotlib.lines import Line2D
line_legend_elements = [
    Line2D([0], [0], color='black', linestyle='-', label='High T fit'),
    Line2D([0], [0], color='black', linestyle='--', label='Low T fit'),
    Line2D([0], [0], color='black', linestyle=':', label='Full range fit')
]
line_legend = ax.legend(handles=line_legend_elements, loc='lower right', 
                       frameon=True, fancybox=False, fontsize=10)
line_legend.get_frame().set_facecolor('white')
line_legend.get_frame().set_edgecolor('black')

# Add the original legend back
ax.add_artist(legend)

plt.tight_layout()
plt.show()

# Combine all split data into a single DataFrame
split_points_df = pd.concat(split_data, ignore_index=True)

print(f"Split points DataFrame shape: {split_points_df.shape}")
print("\nTemperature group distribution:")
print(split_points_df['temperature_group'].value_counts())
display(split_points_df.head(10))
# Out:
# Split points DataFrame shape: (61, 24)
#
# Temperature group distribution:
# temperature_group
# Low T     32
# High T    29
# Name: count, dtype: int64
#                 fluid_compounds property_type  property_value  uncertainty  \
# 0  [Choline Chloride, Glycerol]     viscosity        0.019587     0.000098
# 1  [Choline Chloride, Glycerol]     viscosity        0.026333     0.000132
# 2  [Choline Chloride, Glycerol]     viscosity        0.036741     0.000184
# 3  [Choline Chloride, Glycerol]     viscosity        0.053812     0.000269
# 4  [Choline Chloride, Glycerol]     viscosity        0.081589     0.000408
# 5  [Choline Chloride, Glycerol]     viscosity        0.133375     0.000667
# 6  [Choline Chloride, Glycerol]     viscosity        0.246793     0.001234
# 7  [Choline Chloride, Glycerol]     viscosity        0.472967     0.002365
# 8  [Choline Chloride, Glycerol]     viscosity        1.003943     0.005020
# 9  [Choline Chloride, Glycerol]     viscosity        0.040940     0.000819
#
#    temperature                    mole_fractions  \
# 0       363.15  [0.333333333333, 0.666666666667]
# 1       353.15  [0.333333333333, 0.666666666667]
# 2       343.15  [0.333333333333, 0.666666666667]
# 3       333.15  [0.333333333333, 0.666666666667]
# 4       323.15  [0.333333333333, 0.666666666667]
# 5       313.15  [0.333333333333, 0.666666666667]
# 6       303.15  [0.333333333333, 0.666666666667]
# 7       293.15  [0.333333333333, 0.666666666667]
# 8       283.15  [0.333333333333, 0.666666666667]
# 9       338.15  [0.333333333333, 0.666666666667]
#
#                          measurement_id                   source_doi  \
# 0  f1588f66-baec-43a2-abf4-09d6777d4d07  10.1016/j.fluid.2014.01.028
# 1  fc6383f3-0c43-47cb-bf48-7d860e7fc6d3  10.1016/j.fluid.2014.01.028
# 2  5069ac42-54c8-4909-a7fd-a06e46193af0  10.1016/j.fluid.2014.01.028
# 3  ead4eb49-3061-49df-85d8-59b905b12010  10.1016/j.fluid.2014.01.028
# 4  d45fd7f2-5961-4bcd-b448-e94920f9803d  10.1016/j.fluid.2014.01.028
# 5  c027839b-bc3e-423f-87da-b7be6ce64fd2  10.1016/j.fluid.2014.01.028
# 6  2f79b54a-3d84-4c21-9912-9cfb74fd33fa  10.1016/j.fluid.2014.01.028
# 7  44d5be16-a6c3-4ceb-ba36-4c471992bfda  10.1016/j.fluid.2014.01.028
# 8  3eac0cdc-3373-4dc8-863b-a1eaba599564  10.1016/j.fluid.2014.01.028
# 9  e2f84b2e-9823-474e-a97d-0c4ee5e55b63    10.1016/j.jct.2018.07.031
#
#    Mole fraction  Temperature  ...  mole_fraction_Glycerol  \
# 0       0.666667       363.15  ...                   0.667
# 1       0.666667       353.15  ...                   0.667
# 2       0.666667       343.15  ...                   0.667
# 3       0.666667       333.15  ...                   0.667
# 4       0.666667       323.15  ...                   0.667
# 5       0.666667       313.15  ...                   0.667
# 6       0.666667       303.15  ...                   0.667
# 7       0.666667       293.15  ...                   0.667
# 8       0.666667       283.15  ...                   0.667
# 9       0.666667       338.15  ...                   0.667
#
#   mole_fraction_Water                                composition_temp_id  \
# 0                 NaN  ((Choline Chloride, Glycerol), 363.15, f1588f6...
# 1                 NaN  ((Choline Chloride, Glycerol), 353.15, fc6383f...
# 2                 NaN  ((Choline Chloride, Glycerol), 343.15, 5069ac4...
# 3                 NaN  ((Choline Chloride, Glycerol), 333.15, ead4eb4...
# 4                 NaN  ((Choline Chloride, Glycerol), 323.15, d45fd7f...
# 5                 NaN  ((Choline Chloride, Glycerol), 313.15, c027839...
# 6                 NaN  ((Choline Chloride, Glycerol), 303.15, 2f79b54...
# 7                 NaN  ((Choline Chloride, Glycerol), 293.15, 44d5be1...
# 8                 NaN  ((Choline Chloride, Glycerol), 283.15, 3eac0cd...
# 9                 NaN  ((Choline Chloride, Glycerol), 338.15, e2f84b2...
#
#    viscosity_value  viscosity_uncertainty  mole_fraction_water    inv_RT  \
# 0         0.019587               0.000098                  0.0  0.000331
# 1         0.026333               0.000132                  0.0  0.000341
# 2         0.036741               0.000184                  0.0  0.000350
# 3         0.053812               0.000269                  0.0  0.000361
# 4         0.081589               0.000408                  0.0  0.000372
# 5         0.133375               0.000667                  0.0  0.000384
# 6         0.246793               0.001234                  0.0  0.000397
# 7         0.472967               0.002365                  0.0  0.000410
# 8         1.003943                0.00502                  0.0  0.000425
# 9          0.04094               0.000819                  0.0  0.000356
#
#   ln_viscosity ln_viscosity_scaled  temperature_group
# 0    -3.932910          -10.840665             High T
# 1    -3.636929          -10.544684             High T
# 2    -3.303865          -10.211620             High T
# 3    -2.922264           -9.830020             High T
# 4    -2.506055           -9.413810              Low T
# 5    -2.014591           -8.922347              Low T
# 6    -1.399206           -8.306961              Low T
# 7    -0.748729           -7.656485              Low T
# 8     0.003935           -6.903820              Low T
# 9    -3.195648          -10.103403             High T
#
# [10 rows x 24 columns]

# %%
# Plot filtered_df grouped by DOI, splitting temperature points into low and high temperature groups
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Get unique DOIs
dois = filtered_df['source_doi'].unique()

# Filter out DOIs with insufficient data first
valid_dois = []
for doi in dois:
    subset = filtered_df[
        (filtered_df["source_doi"] == doi)
        & (~filtered_df["inv_RT"].isna())
        & (~filtered_df["ln_viscosity"].isna())
    ]
    if len(subset) >= 2:
        valid_dois.append(doi)

# Calculate number of subplots needed
n_dois = len(valid_dois)
n_cols = 3  # Number of columns
n_rows = (n_dois + n_cols - 1) // n_cols  # Ceiling division

# Create figure with subplots
fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, 5 * n_rows))

# Flatten axes array for easier indexing
if n_rows == 1:
    axes = [axes] if n_cols == 1 else axes
else:
    axes = axes.flatten()

# Color map for temperature groups
temp_colors = {'High T': '#FF6B6B', 'Low T': '#4ECDC4'}

# List to store all split data
split_data = []

# Process each valid DOI
for i, doi in enumerate(valid_dois):
    ax = axes[i]
    
    subset = filtered_df[
        (filtered_df["source_doi"] == doi)
        & (~filtered_df["inv_RT"].isna())
        & (~filtered_df["ln_viscosity"].isna())
    ]
    
    # Sort by temperature (inverse of inv_RT for proper ordering)
    subset_sorted = subset.sort_values('inv_RT')
    
    # Split into two halves based on temperature
    n_points = len(subset_sorted)
    mid_point = n_points // 2
    
    # Lower half (higher temperatures - lower inv_RT values)
    low_temp_group = subset_sorted.iloc[:mid_point].copy()
    low_temp_group['temperature_group'] = 'High T'
    
    # Upper half (lower temperatures - higher inv_RT values)  
    high_temp_group = subset_sorted.iloc[mid_point:].copy()
    high_temp_group['temperature_group'] = 'Low T'
    
    # Add to split_data list
    split_data.append(low_temp_group)
    split_data.append(high_temp_group)
    
    # Get x-axis range for extending lines
    x_range_min = subset_sorted["inv_RT"].min() * 0.95
    x_range_max = subset_sorted["inv_RT"].max() * 1.05
    
    # Plot high temperature group (circles)
    if len(low_temp_group) > 0:
        ax.scatter(
            low_temp_group["inv_RT"],
            low_temp_group["ln_viscosity"],
            label='High T',
            color=temp_colors['High T'],
            marker='o',
            s=80,
            alpha=0.7,
            edgecolor='black',
            linewidth=0.5
        )
        
        # Fit and plot extended Arrhenius line for high temperature group
        if len(low_temp_group) >= 2:
            x_high = low_temp_group["inv_RT"].values
            y_high = low_temp_group["ln_viscosity"].values
            slope_high, intercept_high = np.polyfit(x_high, y_high, 1)
            
            # Create extended line points for plotting
            x_line_high = np.linspace(x_range_min, x_range_max, 100)
            y_line_high = slope_high * x_line_high + intercept_high
            
            ax.plot(x_line_high, y_line_high, color=temp_colors['High T'], 
                   linestyle='-', alpha=0.8, linewidth=2)
    
    # Plot low temperature group (squares)
    if len(high_temp_group) > 0:
        ax.scatter(
            high_temp_group["inv_RT"],
            high_temp_group["ln_viscosity"],
            label='Low T',
            color=temp_colors['Low T'],
            marker='s',
            s=80,
            alpha=0.7,
            edgecolor='black',
            linewidth=0.5
        )
        
        # Fit and plot extended Arrhenius line for low temperature group
        if len(high_temp_group) >= 2:
            x_low = high_temp_group["inv_RT"].values
            y_low = high_temp_group["ln_viscosity"].values
            slope_low, intercept_low = np.polyfit(x_low, y_low, 1)
            
            # Create extended line points for plotting
            x_line_low = np.linspace(x_range_min, x_range_max, 100)
            y_line_low = slope_low * x_line_low + intercept_low
            
            ax.plot(x_line_low, y_line_low, color=temp_colors['Low T'], 
                   linestyle='--', alpha=0.8, linewidth=2)
    
    # Plot extended full range Arrhenius line
    if len(subset_sorted) >= 2:
        x_full = subset_sorted["inv_RT"].values
        y_full = subset_sorted["ln_viscosity"].values
        slope_full, intercept_full = np.polyfit(x_full, y_full, 1)
        
        # Create extended line points for plotting
        x_line_full = np.linspace(x_range_min, x_range_max, 100)
        y_line_full = slope_full * x_line_full + intercept_full
        
        ax.plot(x_line_full, y_line_full, color='gray', 
               linestyle=':', alpha=0.6, linewidth=3, label='Full range')
    
    # Set labels and title for each subplot
    ax.set_xlabel('1 (R*T)$^{-1}$ / mol J$^{-1}$', fontsize=10)
    ax.set_ylabel('ln(Aₛ) / ln(Pa*s)', fontsize=10)
    ax.set_title(f'DOI: {doi}', fontsize=10, wrap=True)
    
    # Add legend to each subplot
    ax.legend(fontsize=8, loc='best')
    
    # Increase tick label font size
    ax.tick_params(axis='both', which='major', labelsize=8)
    
    # Create secondary x-axis for temperature
    ax_temp = ax.twiny()
    
    # Get the current x-axis limits
    x_min, x_max = ax.get_xlim()
    
    # Convert 1/(R*T) to temperature (K)
    R = 8.314462618  # J/mol/K
    T_min = 1 / (R * x_max)  # Higher 1/(R*T) corresponds to lower temperature
    T_max = 1 / (R * x_min)  # Lower 1/(R*T) corresponds to higher temperature
    
    # Set temperature axis limits and ticks
    ax_temp.set_xlim(T_max, T_min)
    temp_ticks = np.linspace(T_max, T_min, 4)  # Fewer ticks for smaller plots
    ax_temp.set_xticks(temp_ticks)
    ax_temp.set_xticklabels([f'{T:.0f}' for T in temp_ticks], fontsize=8)
    ax_temp.set_xlabel('Temperature / K', fontsize=8)
    ax_temp.tick_params(axis='x', which='major', labelsize=8)

# Hide empty subplots
for j in range(i + 1, len(axes)):
    axes[j].set_visible(False)

# Add overall title
fig.suptitle('Arrhenius Plots: Temperature Groups by DOI (Glyceline, ratio 1:2)', 
             fontsize=16, y=0.98)

plt.tight_layout()
plt.show()

# Combine all split data into a single DataFrame
split_points_df = pd.concat(split_data, ignore_index=True)

print(f"Split points DataFrame shape: {split_points_df.shape}")
print("\nTemperature group distribution:")
print(split_points_df['temperature_group'].value_counts())
display(split_points_df.head(10))
# Out:
# Split points DataFrame shape: (61, 24)
#
# Temperature group distribution:
# temperature_group
# Low T     32
# High T    29
# Name: count, dtype: int64
#                 fluid_compounds property_type  property_value  uncertainty  \
# 0  [Choline Chloride, Glycerol]     viscosity        0.019587     0.000098
# 1  [Choline Chloride, Glycerol]     viscosity        0.026333     0.000132
# 2  [Choline Chloride, Glycerol]     viscosity        0.036741     0.000184
# 3  [Choline Chloride, Glycerol]     viscosity        0.053812     0.000269
# 4  [Choline Chloride, Glycerol]     viscosity        0.081589     0.000408
# 5  [Choline Chloride, Glycerol]     viscosity        0.133375     0.000667
# 6  [Choline Chloride, Glycerol]     viscosity        0.246793     0.001234
# 7  [Choline Chloride, Glycerol]     viscosity        0.472967     0.002365
# 8  [Choline Chloride, Glycerol]     viscosity        1.003943     0.005020
# 9  [Choline Chloride, Glycerol]     viscosity        0.040940     0.000819
#
#    temperature                    mole_fractions  \
# 0       363.15  [0.333333333333, 0.666666666667]
# 1       353.15  [0.333333333333, 0.666666666667]
# 2       343.15  [0.333333333333, 0.666666666667]
# 3       333.15  [0.333333333333, 0.666666666667]
# 4       323.15  [0.333333333333, 0.666666666667]
# 5       313.15  [0.333333333333, 0.666666666667]
# 6       303.15  [0.333333333333, 0.666666666667]
# 7       293.15  [0.333333333333, 0.666666666667]
# 8       283.15  [0.333333333333, 0.666666666667]
# 9       338.15  [0.333333333333, 0.666666666667]
#
#                          measurement_id                   source_doi  \
# 0  f1588f66-baec-43a2-abf4-09d6777d4d07  10.1016/j.fluid.2014.01.028
# 1  fc6383f3-0c43-47cb-bf48-7d860e7fc6d3  10.1016/j.fluid.2014.01.028
# 2  5069ac42-54c8-4909-a7fd-a06e46193af0  10.1016/j.fluid.2014.01.028
# 3  ead4eb49-3061-49df-85d8-59b905b12010  10.1016/j.fluid.2014.01.028
# 4  d45fd7f2-5961-4bcd-b448-e94920f9803d  10.1016/j.fluid.2014.01.028
# 5  c027839b-bc3e-423f-87da-b7be6ce64fd2  10.1016/j.fluid.2014.01.028
# 6  2f79b54a-3d84-4c21-9912-9cfb74fd33fa  10.1016/j.fluid.2014.01.028
# 7  44d5be16-a6c3-4ceb-ba36-4c471992bfda  10.1016/j.fluid.2014.01.028
# 8  3eac0cdc-3373-4dc8-863b-a1eaba599564  10.1016/j.fluid.2014.01.028
# 9  e2f84b2e-9823-474e-a97d-0c4ee5e55b63    10.1016/j.jct.2018.07.031
#
#    Mole fraction  Temperature  ...  mole_fraction_Glycerol  \
# 0       0.666667       363.15  ...                   0.667
# 1       0.666667       353.15  ...                   0.667
# 2       0.666667       343.15  ...                   0.667
# 3       0.666667       333.15  ...                   0.667
# 4       0.666667       323.15  ...                   0.667
# 5       0.666667       313.15  ...                   0.667
# 6       0.666667       303.15  ...                   0.667
# 7       0.666667       293.15  ...                   0.667
# 8       0.666667       283.15  ...                   0.667
# 9       0.666667       338.15  ...                   0.667
#
#   mole_fraction_Water                                composition_temp_id  \
# 0                 NaN  ((Choline Chloride, Glycerol), 363.15, f1588f6...
# 1                 NaN  ((Choline Chloride, Glycerol), 353.15, fc6383f...
# 2                 NaN  ((Choline Chloride, Glycerol), 343.15, 5069ac4...
# 3                 NaN  ((Choline Chloride, Glycerol), 333.15, ead4eb4...
# 4                 NaN  ((Choline Chloride, Glycerol), 323.15, d45fd7f...
# 5                 NaN  ((Choline Chloride, Glycerol), 313.15, c027839...
# 6                 NaN  ((Choline Chloride, Glycerol), 303.15, 2f79b54...
# 7                 NaN  ((Choline Chloride, Glycerol), 293.15, 44d5be1...
# 8                 NaN  ((Choline Chloride, Glycerol), 283.15, 3eac0cd...
# 9                 NaN  ((Choline Chloride, Glycerol), 338.15, e2f84b2...
#
#    viscosity_value  viscosity_uncertainty  mole_fraction_water    inv_RT  \
# 0         0.019587               0.000098                  0.0  0.000331
# 1         0.026333               0.000132                  0.0  0.000341
# 2         0.036741               0.000184                  0.0  0.000350
# 3         0.053812               0.000269                  0.0  0.000361
# 4         0.081589               0.000408                  0.0  0.000372
# 5         0.133375               0.000667                  0.0  0.000384
# 6         0.246793               0.001234                  0.0  0.000397
# 7         0.472967               0.002365                  0.0  0.000410
# 8         1.003943                0.00502                  0.0  0.000425
# 9          0.04094               0.000819                  0.0  0.000356
#
#   ln_viscosity ln_viscosity_scaled  temperature_group
# 0    -3.932910          -10.840665             High T
# 1    -3.636929          -10.544684             High T
# 2    -3.303865          -10.211620             High T
# 3    -2.922264           -9.830020             High T
# 4    -2.506055           -9.413810              Low T
# 5    -2.014591           -8.922347              Low T
# 6    -1.399206           -8.306961              Low T
# 7    -0.748729           -7.656485              Low T
# 8     0.003935           -6.903820              Low T
# 9    -3.195648          -10.103403             High T
#
# [10 rows x 24 columns]

# %%
# Calculate activation energy (E_a) for each DOI and temperature group combination from the split points
# ln(viscosity) = ln(A) + E_a / R * (1/T)
# So: slope = E_a / R  =>  E_a = slope * R

import numpy as np

R = 8.314462618  # J/mol/K (universal gas constant)

group_activation_energies = []

# Filter for glyceline mixtures only (no water) - mole_fraction_water should be 0.0
glyceline_data = split_points_df[split_points_df['mole_fraction_water'] == 0.0]

# Get unique combinations of DOI and temperature group for glyceline only
doi_temp_combinations = glyceline_data[['source_doi', 'temperature_group']].drop_duplicates()

for _, row in doi_temp_combinations.iterrows():
    doi = row['source_doi']
    temp_group = row['temperature_group']
    
    subset = glyceline_data[
        (glyceline_data['source_doi'] == doi) & 
        (glyceline_data['temperature_group'] == temp_group)
    ]
    
    if len(subset) < 2:
        continue  # Not enough points to fit
    
    # Calculate temperature range for this subset
    temp_min = subset['temperature'].min()
    temp_max = subset['temperature'].max()
    temp_range = f"{temp_min:.0f}-{temp_max:.0f}"
    
    # Fit: ln(viscosity) = slope * inv_RT + intercept
    # NOTE: inv_RT is already 1/(R*T), so slope directly gives E_a in J/mol
    x = subset["inv_RT"].values
    y = subset["ln_viscosity"].values
    
    # Check for outliers or unreasonable data points
    print(f"DOI: {doi}, Group: {temp_group}")
    print(f"  Temperature range: {temp_range} K")
    print(f"  inv_RT range: {x.min():.6f} to {x.max():.6f}")
    print(f"  ln(viscosity) range: {y.min():.3f} to {y.max():.3f}")
    
    # np.polyfit returns [slope, intercept]
    slope, intercept = np.polyfit(x, y, 1)
    # Since inv_RT = 1/(R*T), the slope is already E_a in J/mol (no need to multiply by R)
    E_a = slope  # activation energy in J/mol
    E_a_kJ_per_mol = E_a / 1000  # Convert to kJ/mol for easier interpretation
    
    print(f"  Slope: {slope:.1f}, E_a: {E_a_kJ_per_mol:.1f} kJ/mol")
    
    # Calculate R-squared for goodness of fit
    y_pred = slope * x + intercept
    ss_res = np.sum((y - y_pred) ** 2)
    ss_tot = np.sum((y - np.mean(y)) ** 2)
    r_squared = 1 - (ss_res / ss_tot)
    
    group_activation_energies.append({
        "source_doi": doi,
        "temperature_group": temp_group,
        "temperature_range": temp_range,
        "activation_energy_J_per_mol": E_a,
        "activation_energy_kJ_per_mol": E_a_kJ_per_mol,
        "arrhenius_prefactor_lnA": intercept,
        "r_squared": r_squared,
        "n_points": len(subset)
    })
    print()

# Also calculate activation energy for full temperature range for each DOI (glyceline only)
unique_dois = glyceline_data['source_doi'].unique()

for doi in unique_dois:
    subset = glyceline_data[glyceline_data['source_doi'] == doi]
    
    if len(subset) < 2:
        continue  # Not enough points to fit
    
    # Calculate temperature range for this subset
    temp_min = subset['temperature'].min()
    temp_max = subset['temperature'].max()
    temp_range = f"{temp_min:.0f}-{temp_max:.0f}"
    
    # Fit: ln(viscosity) = slope * inv_RT + intercept
    x = subset["inv_RT"].values
    y = subset["ln_viscosity"].values
    
    print(f"DOI: {doi}, Full Range")
    print(f"  Temperature range: {temp_range} K")
    print(f"  inv_RT range: {x.min():.6f} to {x.max():.6f}")
    print(f"  ln(viscosity) range: {y.min():.3f} to {y.max():.3f}")
    
    # np.polyfit returns [slope, intercept]
    slope, intercept = np.polyfit(x, y, 1)
    # Since inv_RT = 1/(R*T), the slope is already E_a in J/mol (no need to multiply by R)
    E_a = slope  # activation energy in J/mol
    E_a_kJ_per_mol = E_a / 1000  # Convert to kJ/mol for easier interpretation
    
    print(f"  Slope: {slope:.1f}, E_a: {E_a_kJ_per_mol:.1f} kJ/mol")
    
    # Calculate R-squared for goodness of fit
    y_pred = slope * x + intercept
    ss_res = np.sum((y - y_pred) ** 2)
    ss_tot = np.sum((y - np.mean(y)) ** 2)
    r_squared = 1 - (ss_res / ss_tot)
    
    group_activation_energies.append({
        "source_doi": doi,
        "temperature_group": "Full Range",
        "temperature_range": temp_range,
        "activation_energy_J_per_mol": E_a,
        "activation_energy_kJ_per_mol": E_a_kJ_per_mol,
        "arrhenius_prefactor_lnA": intercept,
        "r_squared": r_squared,
        "n_points": len(subset)
    })
    print()

# Convert to DataFrame for summary display
group_activation_energy_df = pd.DataFrame(group_activation_energies)

print("Activation energies (E_a) and Arrhenius prefactor by DOI and temperature group (Glyceline Only - No Water):")
print("Note: Typical activation energies for viscous flow are 10-100 kJ/mol")
display(group_activation_energy_df)
# Out:
# DOI: 10.1016/j.fluid.2014.01.028, Group: High T
#   Temperature range: 333-363 K
#   inv_RT range: 0.000331 to 0.000361
#   ln(viscosity) range: -3.933 to -2.922
#   Slope: 33881.7, E_a: 33.9 kJ/mol
#
# DOI: 10.1016/j.fluid.2014.01.028, Group: Low T
#   Temperature range: 283-323 K
#   inv_RT range: 0.000372 to 0.000425
#   ln(viscosity) range: -2.506 to 0.004
#   Slope: 47918.9, E_a: 47.9 kJ/mol
#
# DOI: 10.1016/j.jct.2018.07.031, Group: High T
#   Temperature range: 311-338 K
#   inv_RT range: 0.000356 to 0.000387
#   ln(viscosity) range: -3.196 to -1.904
#   Slope: 41073.2, E_a: 41.1 kJ/mol
#
# DOI: 10.1016/j.jct.2018.07.031, Group: Low T
#   Temperature range: 278-308 K
#   inv_RT range: 0.000390 to 0.000432
#   ln(viscosity) range: -1.763 to 0.413
#   Slope: 51631.2, E_a: 51.6 kJ/mol
#
# DOI: 10.1016/j.molliq.2015.11.032, Group: High T
#   Temperature range: 328-353 K
#   inv_RT range: 0.000341 to 0.000367
#   ln(viscosity) range: -3.472 to -2.624
#   Slope: 29644.6, E_a: 29.6 kJ/mol
#
# DOI: 10.1016/j.molliq.2015.11.032, Group: Low T
#   Temperature range: 298-323 K
#   inv_RT range: 0.000372 to 0.000404
#   ln(viscosity) range: -2.388 to -1.085
#   Slope: 40731.9, E_a: 40.7 kJ/mol
#
# DOI: 10.1039/c0gc00395f, Group: High T
#   Temperature range: 313-328 K
#   inv_RT range: 0.000367 to 0.000384
#   ln(viscosity) range: -2.957 to -2.263
#   Slope: 39778.4, E_a: 39.8 kJ/mol
#
# DOI: 10.1039/c0gc00395f, Group: Low T
#   Temperature range: 293-308 K
#   inv_RT range: 0.000390 to 0.000410
#   ln(viscosity) range: -1.966 to -0.978
#   Slope: 49365.2, E_a: 49.4 kJ/mol
#
# DOI: 10.1039/c1cp22554e, Group: High T
#   Temperature range: 318-328 K
#   inv_RT range: 0.000367 to 0.000378
#   ln(viscosity) range: -2.957 to -2.501
#   Slope: 39515.1, E_a: 39.5 kJ/mol
#
# DOI: 10.1039/c1cp22554e, Group: Low T
#   Temperature range: 298-313 K
#   inv_RT range: 0.000384 to 0.000404
#   ln(viscosity) range: -2.263 to -1.351
#   Slope: 47033.7, E_a: 47.0 kJ/mol
#
# DOI: 10.1016/j.fluid.2014.01.028, Full Range
#   Temperature range: 283-363 K
#   inv_RT range: 0.000331 to 0.000425
#   ln(viscosity) range: -3.933 to 0.004
#   Slope: 41927.9, E_a: 41.9 kJ/mol
#
# DOI: 10.1016/j.jct.2018.07.031, Full Range
#   Temperature range: 278-338 K
#   inv_RT range: 0.000356 to 0.000432
#   ln(viscosity) range: -3.196 to 0.413
#   Slope: 46750.7, E_a: 46.8 kJ/mol
#
# DOI: 10.1016/j.molliq.2015.11.032, Full Range
#   Temperature range: 298-353 K
#   inv_RT range: 0.000341 to 0.000404
#   ln(viscosity) range: -3.472 to -1.085
#   Slope: 37403.1, E_a: 37.4 kJ/mol
#
# DOI: 10.1039/c0gc00395f, Full Range
#   Temperature range: 293-328 K
#   inv_RT range: 0.000367 to 0.000410
#   ln(viscosity) range: -2.957 to -0.978
#   Slope: 45102.0, E_a: 45.1 kJ/mol
#
# DOI: 10.1039/c1cp22554e, Full Range
#   Temperature range: 298-328 K
#   inv_RT range: 0.000367 to 0.000404
#   ln(viscosity) range: -2.957 to -1.351
#   Slope: 43650.3, E_a: 43.7 kJ/mol
#
# Activation energies (E_a) and Arrhenius prefactor by DOI and temperature group (Glyceline Only - No Water):
# Note: Typical activation energies for viscous flow are 10-100 kJ/mol
#                       source_doi temperature_group temperature_range  \
# 0    10.1016/j.fluid.2014.01.028            High T           333-363
# 1    10.1016/j.fluid.2014.01.028             Low T           283-323
# 2      10.1016/j.jct.2018.07.031            High T           311-338
# 3      10.1016/j.jct.2018.07.031             Low T           278-308
# 4   10.1016/j.molliq.2015.11.032            High T           328-353
# 5   10.1016/j.molliq.2015.11.032             Low T           298-323
# 6             10.1039/c0gc00395f            High T           313-328
# 7             10.1039/c0gc00395f             Low T           293-308
# 8             10.1039/c1cp22554e            High T           318-328
# 9             10.1039/c1cp22554e             Low T           298-313
# 10   10.1016/j.fluid.2014.01.028        Full Range           283-363
# 11     10.1016/j.jct.2018.07.031        Full Range           278-338
# 12  10.1016/j.molliq.2015.11.032        Full Range           298-353
# 13            10.1039/c0gc00395f        Full Range           293-328
# 14            10.1039/c1cp22554e        Full Range           298-328
#
#     activation_energy_J_per_mol  activation_energy_kJ_per_mol  \
# 0                  33881.699530                     33.881700
# 1                  47918.947805                     47.918948
# 2                  41073.168777                     41.073169
# 3                  51631.248713                     51.631249
# 4                  29644.627352                     29.644627
# 5                  40731.929070                     40.731929
# 6                  39778.392710                     39.778393
# 7                  49365.168668                     49.365169
# 8                  39515.113405                     39.515113
# 9                  47033.702850                     47.033703
# 10                 41927.868165                     41.927868
# 11                 46750.709953                     46.750710
# 12                 37403.092032                     37.403092
# 13                 45102.046533                     45.102047
# 14                 43650.263472                     43.650263
#
#     arrhenius_prefactor_lnA  r_squared  n_points
# 0                -15.165900   0.999022         4
# 1                -20.385919   0.998612         5
# 2                -17.823342   0.999330        12
# 3                -21.951472   0.998993        13
# 4                -13.525274   0.975107         6
# 5                -17.545085   0.997972         6
# 6                -17.542429   0.999304         4
# 7                -21.246557   0.998481         4
# 8                -17.451681   0.998239         3
# 9                -20.335841   0.999912         4
# 10               -17.979190   0.992622         9
# 11               -19.938777   0.996546        25
# 12               -16.260954   0.992438        12
# 13               -19.540212   0.997044         8
# 14               -18.998364   0.998036         7

# %%
# Create a bar plot showing activation energy differences by DOI and temperature group
import matplotlib.pyplot as plt
import numpy as np

# Create the bar plot
fig, ax = plt.subplots(figsize=(12, 8))

# Get unique DOIs for grouping
unique_dois = group_activation_energy_df['source_doi'].unique()
n_dois = len(unique_dois)

# Set up bar positions
bar_width = 0.25
x_pos = np.arange(n_dois)

# Separate data by temperature group
high_t_data = []
low_t_data = []
full_range_data = []
doi_labels = []
high_t_ranges = []
low_t_ranges = []
full_ranges = []

for doi in unique_dois:
    doi_data = group_activation_energy_df[group_activation_energy_df['source_doi'] == doi]
    
    high_t = doi_data[doi_data['temperature_group'] == 'High T']
    low_t = doi_data[doi_data['temperature_group'] == 'Low T']
    full_range = doi_data[doi_data['temperature_group'] == 'Full Range']
    
    high_t_val = high_t['activation_energy_J_per_mol'].iloc[0] if len(high_t) > 0 else 0
    low_t_val = low_t['activation_energy_J_per_mol'].iloc[0] if len(low_t) > 0 else 0
    full_range_val = full_range['activation_energy_J_per_mol'].iloc[0] if len(full_range) > 0 else 0
    
    high_t_range = high_t['temperature_range'].iloc[0] if len(high_t) > 0 else ""
    low_t_range = low_t['temperature_range'].iloc[0] if len(low_t) > 0 else ""
    full_range_range = full_range['temperature_range'].iloc[0] if len(full_range) > 0 else ""
    
    high_t_data.append(high_t_val)
    low_t_data.append(low_t_val)
    full_range_data.append(full_range_val)
    high_t_ranges.append(high_t_range)
    low_t_ranges.append(low_t_range)
    full_ranges.append(full_range_range)
    
    # Create shorter labels for better readability
    short_doi = doi.split('/')[-1] if '/' in doi else doi
    doi_labels.append(short_doi)

# Create bars
bars1 = ax.bar(x_pos - bar_width, high_t_data, bar_width, 
               label='High Temperature', alpha=0.8, color='#E74C3C')
bars2 = ax.bar(x_pos, low_t_data, bar_width,
               label='Low Temperature', alpha=0.8, color='#3498DB')
bars3 = ax.bar(x_pos + bar_width, full_range_data, bar_width,
               label='Full Range', alpha=0.8, color='#2ECC71')

# Customize the plot
ax.set_xlabel('DOI', fontsize=12)
ax.set_ylabel('Activation Energy (J/mol)', fontsize=12)
ax.set_title('Activation Energy Comparison by DOI and Temperature Group', fontsize=14, fontweight='bold')
ax.set_xticks(x_pos)
ax.set_xticklabels(doi_labels, rotation=45, ha='right')
ax.legend()

# Add value labels on bars with temperature ranges
def add_value_labels_with_temp(bars, temp_ranges):
    for bar, temp_range in zip(bars, temp_ranges):
        height = bar.get_height()
        if height > 0:  # Only add label if there's a value
            label_text = f'{height:.0f}\n({temp_range}K)' if temp_range else f'{height:.0f}'
            ax.text(bar.get_x() + bar.get_width()/2., height,
                   label_text,
                   ha='center', va='bottom', fontsize=8)

add_value_labels_with_temp(bars1, high_t_ranges)
add_value_labels_with_temp(bars2, low_t_ranges)
add_value_labels_with_temp(bars3, full_ranges)

# Format y-axis to show values in scientific notation
ax.ticklabel_format(style='scientific', axis='y', scilimits=(0,0))

plt.tight_layout()
plt.show()

# Calculate and display the differences
print("\nActivation Energy Differences by DOI:")
print("=" * 60)
for i, doi in enumerate(unique_dois):
    short_doi = doi_labels[i]
    print(f"{short_doi}:")
    
    if high_t_data[i] > 0 and low_t_data[i] > 0:
        diff_hl = low_t_data[i] - high_t_data[i]
        percent_diff_hl = (diff_hl / high_t_data[i]) * 100
        print(f"  Low T ({low_t_ranges[i]}K) - High T ({high_t_ranges[i]}K): {diff_hl:,.0f} J/mol ({percent_diff_hl:+.1f}%)")
    
    if full_range_data[i] > 0:
        if high_t_data[i] > 0:
            diff_fh = full_range_data[i] - high_t_data[i]
            percent_diff_fh = (diff_fh / high_t_data[i]) * 100
            print(f"  Full Range ({full_ranges[i]}K) - High T ({high_t_ranges[i]}K): {diff_fh:,.0f} J/mol ({percent_diff_fh:+.1f}%)")
        
        if low_t_data[i] > 0:
            diff_fl = full_range_data[i] - low_t_data[i]
            percent_diff_fl = (diff_fl / low_t_data[i]) * 100
            print(f"  Full Range ({full_ranges[i]}K) - Low T ({low_t_ranges[i]}K): {diff_fl:,.0f} J/mol ({percent_diff_fl:+.1f}%)")
    
    print()
# Out:
# Activation Energy Differences by DOI:
# ============================================================
# j.fluid.2014.01.028:
#   Low T (283-323K) - High T (333-363K): 14,037 J/mol (+41.4%)
#   Full Range (283-363K) - High T (333-363K): 8,046 J/mol (+23.7%)
#   Full Range (283-363K) - Low T (283-323K): -5,991 J/mol (-12.5%)
#
# j.jct.2018.07.031:
#   Low T (278-308K) - High T (311-338K): 10,558 J/mol (+25.7%)
#   Full Range (278-338K) - High T (311-338K): 5,678 J/mol (+13.8%)
#   Full Range (278-338K) - Low T (278-308K): -4,881 J/mol (-9.5%)
#
# j.molliq.2015.11.032:
#   Low T (298-323K) - High T (328-353K): 11,087 J/mol (+37.4%)
#   Full Range (298-353K) - High T (328-353K): 7,758 J/mol (+26.2%)
#   Full Range (298-353K) - Low T (298-323K): -3,329 J/mol (-8.2%)
#
# c0gc00395f:
#   Low T (293-308K) - High T (313-328K): 9,587 J/mol (+24.1%)
#   Full Range (293-328K) - High T (313-328K): 5,324 J/mol (+13.4%)
#   Full Range (293-328K) - Low T (293-308K): -4,263 J/mol (-8.6%)
#
# c1cp22554e:
#   Low T (298-313K) - High T (318-328K): 7,519 J/mol (+19.0%)
#   Full Range (298-328K) - High T (318-328K): 4,135 J/mol (+10.5%)
#   Full Range (298-328K) - Low T (298-313K): -3,383 J/mol (-7.2%)

# %%
# Calculate activation energy (E_a) for each DOI/series from the Arrhenius fit:
# ln(viscosity) = ln(A) + E_a / R * (1/T)
# So: slope = E_a / R  =>  E_a = slope * R
# We'll do this for each DOI/series in the filtered_df, using linear regression.

import numpy as np

R = 8.314462618  # J/mol/K (universal gas constant)

activation_energies = []

for doi in dois2:
    subset2 = filtered_df[
        (filtered_df["source_doi"] == doi)
        & (~filtered_df["inv_RT"].isna())
        & (~filtered_df["ln_viscosity"].isna())
    ]
    if len(subset2) < 2:
        continue  # Not enough points to fit
    # Fit: ln(viscosity) = slope * inv_RT + intercept
    x = subset2["inv_RT"].values
    y = subset2["ln_viscosity"].values
    # np.polyfit returns [slope, intercept]
    slope, intercept = np.polyfit(x, y, 1)
    E_a = slope * R  # activation energy in J/mol
    # Optional: y-intercept is ln(A), the Arrhenius prefactor
    activation_energies.append({
        "doi": doi,
        "activation_energy_J_per_mol": E_a,
        "arrhenius_prefactor_lnA": intercept
    })

# Convert activation energies to DataFrame for summary display
import pandas as pd
activation_energy_df = pd.DataFrame(activation_energies)

print("Activation energies (E_a) and Arrhenius prefactor by DOI (solvent ratio == 2):")
display(activation_energy_df)
# Out:
# Activation energies (E_a) and Arrhenius prefactor by DOI (solvent ratio == 2):
#                             doi  activation_energy_J_per_mol  \
# 0   10.1016/j.fluid.2014.01.028                348607.692513
# 1     10.1016/j.jct.2018.07.031                388707.030266
# 2  10.1016/j.molliq.2015.11.032                310986.610499
# 3            10.1039/c0gc00395f                374999.279896
# 4            10.1039/c1cp22554e                362928.483901
#
#    arrhenius_prefactor_lnA
# 0               -17.979190
# 1               -19.938777
# 2               -16.260954
# 3               -19.540212
# 4               -18.998364

# %%
# Import the FAIRFluids models
import sys
sys.path.append('/home/sga/Code/FAIRFluids')
from fairfluids import FAIRFluidsCMLParser
from fairfluids.core.lib import FAIRFluidsDocument, Version, Citation
from fairfluids.core.functionalities import FAIRFluidsCMLParser
from fairfluids import FAIRFluidsDocument, FluidIO, calculate_ratio_of_solvent
from fairfluids.core.visualization import extract_fairfluids_data, plot_dataframe

# Test the extended class
glyceline_doc = FAIRFluidsDocument(
    version=Version(
        versionMajor=1,
        versionMinor=0
    )
)

# Add same data as example
glyceline_doc.citation = Citation(Type="journal")
glyceline_doc.citation.add_to_author(given_name="Gudrun", family_name="Gygli")



compounds = [
        compound_cholinechloride,
        compound_glycerol,
        compound_water
    ]
    
# Path to the test CML file
cml_path = "/home/sga/Code/FAIRFluids/fairfluids/data/cml_xml/gygli/ChCl_glycerol.xml"



# Parse the CML file
parser = FAIRFluidsCMLParser(cml_path, compounds=compounds)
glyceline_doc = parser.parse()

glyceline_doc   = calculate_ratio_of_solvent(
    doc=glyceline_doc,
    parameter_id_1="parameter_mole_fraction_glycerol",
    parameter_id_2="parameter_mole_fraction_cholinechloride",
    name="glycerol_cholinechloride",
    compound_id_1="compound_glycerol",
    compound_id_2="compound_cholinechloride",
    precision=1  # Round to 2 decimal places - ensures 2.0 instead of 2.0075...
)

save_path = '/home/sga/Code/FAIRFluids/Workflows/outputs/Glyceline_Water.json'


# Save the model to a JSON file
with open(save_path, 'w') as f:
    f.write(glyceline_doc.model_dump_json(indent=4))
    
print(f"\n📁 Output saved to: {save_path}")
# Out:
# Fetching compound data from PubChem for CID 6209...
# Successfully fetched and merged data for CID 6209
# Fetching compound data from PubChem for CID 753...
# Successfully fetched and merged data for CID 753
# Fetching compound data from PubChem for CID 962...
# Successfully fetched and merged data for CID 962
# Found 30 unique compositions
# Composition (0.25, 0.5, 0.25): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.0, 0.0, 1.0): compounds ['compound_water']
# Composition (0.006, 0.012, 0.982): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.013, 0.027, 0.96): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.022, 0.044, 0.933): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.033, 0.066, 0.901): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.048, 0.095, 0.857): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.067, 0.134, 0.8): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.093, 0.187, 0.72): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.134, 0.268, 0.598): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.199, 0.399, 0.402): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.219, 0.438, 0.343): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.254, 0.508, 0.238): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.297, 0.595, 0.108): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.333, 0.667, 0.0): compounds ['compound_cholinechloride', 'compound_glycerol']
# Composition (0.249, 0.496, 0.254): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.05, 0.95, 0.0): compounds ['compound_cholinechloride', 'compound_glycerol']
# Composition (0.1, 0.9, 0.0): compounds ['compound_cholinechloride', 'compound_glycerol']
# Composition (0.15, 0.85, 0.0): compounds ['compound_cholinechloride', 'compound_glycerol']
# Composition (0.2, 0.8, 0.0): compounds ['compound_cholinechloride', 'compound_glycerol']
# Composition (0.25, 0.75, 0.0): compounds ['compound_cholinechloride', 'compound_glycerol']
# Composition (0.3, 0.7, 0.0): compounds ['compound_cholinechloride', 'compound_glycerol']
# Composition (0.147, 0.295, 0.558): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.176, 0.353, 0.471): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.213, 0.427, 0.36): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.236, 0.472, 0.291): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.263, 0.526, 0.211): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.295, 0.59, 0.115): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.317, 0.634, 0.049): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# Composition (0.325, 0.65, 0.025): compounds ['compound_cholinechloride', 'compound_glycerol', 'compound_water']
# === Calculating Solvent Ratio: glycerol_cholinechloride ===
# Component 1: parameter_mole_fraction_glycerol
# Component 2: parameter_mole_fraction_cholinechloride
# Processing 30 fluids
#
# --- Processing Fluid 1 ---
# Added new parameter: parameter_solvent_ratio_glycerol_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 11f0176d-7651-4893-8817-897e7be7c1aa: ratio = 0.500156324667 / 0.250078162333 = 2.0
# Added ratio value 2.0 to measurement 11f0176d-7651-4893-8817-897e7be7c1aa
#
# --- Processing Fluid 2 ---
# Skipping fluid 2: compound_glycerol not in compounds list
# Skipping fluid 2: compound_cholinechloride not in compounds list
#
# --- Processing Fluid 3 ---
# Added new parameter: parameter_solvent_ratio_glycerol_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement c08b165a-3dd3-4ce0-a6b6-c9451f497ed1: ratio = 0.012066666667 / 0.006033333333 = 2.0
# Added ratio value 2.0 to measurement c08b165a-3dd3-4ce0-a6b6-c9451f497ed1
# Measurement 30c5141f-25d1-42b8-830d-4a14f2f76210: ratio = 0.012066666667 / 0.006033333333 = 2.0
# Added ratio value 2.0 to measurement 30c5141f-25d1-42b8-830d-4a14f2f76210
# Measurement 24f102ae-8f8b-4a4e-89a3-0deac67c6f82: ratio = 0.012066666667 / 0.006033333333 = 2.0
# Added ratio value 2.0 to measurement 24f102ae-8f8b-4a4e-89a3-0deac67c6f82
# Measurement 7018c6f4-bda4-42a2-8703-de8c9c13a124: ratio = 0.012066666667 / 0.006033333333 = 2.0
# Added ratio value 2.0 to measurement 7018c6f4-bda4-42a2-8703-de8c9c13a124
# Measurement 076dc08d-3ff5-46c4-9c5a-c6c0c0d087c8: ratio = 0.012066666667 / 0.006033333333 = 2.0
# Added ratio value 2.0 to measurement 076dc08d-3ff5-46c4-9c5a-c6c0c0d087c8
# Measurement cddffe67-8306-4722-833e-c0473e53c0a1: ratio = 0.012066666667 / 0.006033333333 = 2.0
# Added ratio value 2.0 to measurement cddffe67-8306-4722-833e-c0473e53c0a1
# Measurement fb46e20e-db97-4489-be1b-b059dc1b03b4: ratio = 0.012066666667 / 0.006033333333 = 2.0
# Added ratio value 2.0 to measurement fb46e20e-db97-4489-be1b-b059dc1b03b4
# Measurement 4f166228-f705-4028-b2bf-29c0a47bc3d3: ratio = 0.012066666667 / 0.006033333333 = 2.0
# Added ratio value 2.0 to measurement 4f166228-f705-4028-b2bf-29c0a47bc3d3
# Measurement fa952d36-2dc0-4a7a-9dea-a4522e77faea: ratio = 0.012066666667 / 0.006033333333 = 2.0
# Added ratio value 2.0 to measurement fa952d36-2dc0-4a7a-9dea-a4522e77faea
#
# --- Processing Fluid 4 ---
# Added new parameter: parameter_solvent_ratio_glycerol_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 50abce44-c3d5-4596-ae68-481322284843: ratio = 0.026533333333 / 0.013266666667 = 2.0
# Added ratio value 2.0 to measurement 50abce44-c3d5-4596-ae68-481322284843
# Measurement bb2fb5f8-5447-4916-b1c2-d62a21a13883: ratio = 0.026533333333 / 0.013266666667 = 2.0
# Added ratio value 2.0 to measurement bb2fb5f8-5447-4916-b1c2-d62a21a13883
# Measurement 85bdd09d-c9fa-463f-9b23-0f944975311b: ratio = 0.026533333333 / 0.013266666667 = 2.0
# Added ratio value 2.0 to measurement 85bdd09d-c9fa-463f-9b23-0f944975311b
# Measurement ff5f97e7-9bdb-405d-98a1-a89969cde83f: ratio = 0.026533333333 / 0.013266666667 = 2.0
# Added ratio value 2.0 to measurement ff5f97e7-9bdb-405d-98a1-a89969cde83f
# Measurement 784e61ae-266f-4242-9541-4a1f3d04a7e5: ratio = 0.026533333333 / 0.013266666667 = 2.0
# Added ratio value 2.0 to measurement 784e61ae-266f-4242-9541-4a1f3d04a7e5
# Measurement 8bdfcf21-bf83-4c2c-9141-80c1fdd312bd: ratio = 0.026533333333 / 0.013266666667 = 2.0
# Added ratio value 2.0 to measurement 8bdfcf21-bf83-4c2c-9141-80c1fdd312bd
# Measurement 419866fa-2100-4cf9-bb5f-8f9ff4878c04: ratio = 0.026533333333 / 0.013266666667 = 2.0
# Added ratio value 2.0 to measurement 419866fa-2100-4cf9-bb5f-8f9ff4878c04
# Measurement 2f0011bc-f882-4dce-889b-9ec5e4b1e0de: ratio = 0.026533333333 / 0.013266666667 = 2.0
# Added ratio value 2.0 to measurement 2f0011bc-f882-4dce-889b-9ec5e4b1e0de
# Measurement bd160b4c-a9db-4e58-80ca-c61bee1ab460: ratio = 0.026533333333 / 0.013266666667 = 2.0
# Added ratio value 2.0 to measurement bd160b4c-a9db-4e58-80ca-c61bee1ab460
#
# --- Processing Fluid 5 ---
# Added new parameter: parameter_solvent_ratio_glycerol_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 85bda5b0-653d-41b6-b777-7078bca257c5: ratio = 0.044333333333 / 0.022166666667 = 2.0
# Added ratio value 2.0 to measurement 85bda5b0-653d-41b6-b777-7078bca257c5
# Measurement 65ff1775-816f-4ed0-88fe-5c8d978a2918: ratio = 0.044333333333 / 0.022166666667 = 2.0
# Added ratio value 2.0 to measurement 65ff1775-816f-4ed0-88fe-5c8d978a2918
# Measurement 37200657-01bb-4aac-8a2b-909a0c42947d: ratio = 0.044333333333 / 0.022166666667 = 2.0
# Added ratio value 2.0 to measurement 37200657-01bb-4aac-8a2b-909a0c42947d
# Measurement 2a6ca23d-24cc-4ef0-9095-637dd6dafae7: ratio = 0.044333333333 / 0.022166666667 = 2.0
# Added ratio value 2.0 to measurement 2a6ca23d-24cc-4ef0-9095-637dd6dafae7
# Measurement 39e91e61-f320-45c8-bdeb-448c30c8bb00: ratio = 0.044333333333 / 0.022166666667 = 2.0
# Added ratio value 2.0 to measurement 39e91e61-f320-45c8-bdeb-448c30c8bb00
# Measurement ebb3ac10-3b13-4999-bf30-ad5557aab63f: ratio = 0.044333333333 / 0.022166666667 = 2.0
# Added ratio value 2.0 to measurement ebb3ac10-3b13-4999-bf30-ad5557aab63f
# Measurement ebcbe43b-da99-4d4b-8c19-352b65bf3ae8: ratio = 0.044333333333 / 0.022166666667 = 2.0
# Added ratio value 2.0 to measurement ebcbe43b-da99-4d4b-8c19-352b65bf3ae8
# Measurement ddf8bdb4-173f-40d5-ab95-5fb043c1b4de: ratio = 0.044333333333 / 0.022166666667 = 2.0
# Added ratio value 2.0 to measurement ddf8bdb4-173f-40d5-ab95-5fb043c1b4de
# Measurement b2ecde6f-6734-4d4e-8f47-12192729731e: ratio = 0.044333333333 / 0.022166666667 = 2.0
# Added ratio value 2.0 to measurement b2ecde6f-6734-4d4e-8f47-12192729731e
#
# --- Processing Fluid 6 ---
# Added new parameter: parameter_solvent_ratio_glycerol_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 9f217ff4-e302-4864-8a50-afa4626c016d: ratio = 0.0662 / 0.0331 = 2.0
# Added ratio value 2.0 to measurement 9f217ff4-e302-4864-8a50-afa4626c016d
# Measurement 30b591b2-d208-4182-9750-4fe95be1f0df: ratio = 0.0662 / 0.0331 = 2.0
# Added ratio value 2.0 to measurement 30b591b2-d208-4182-9750-4fe95be1f0df
# Measurement 02fb7f15-c89b-4d9e-bc30-448c1a5718f0: ratio = 0.0662 / 0.0331 = 2.0
# Added ratio value 2.0 to measurement 02fb7f15-c89b-4d9e-bc30-448c1a5718f0
# Measurement ea39bad0-1744-475d-b443-1fa4a85781c5: ratio = 0.0662 / 0.0331 = 2.0
# Added ratio value 2.0 to measurement ea39bad0-1744-475d-b443-1fa4a85781c5
# Measurement b2a0efd7-1408-483c-810c-3385cdff618c: ratio = 0.0662 / 0.0331 = 2.0
# Added ratio value 2.0 to measurement b2a0efd7-1408-483c-810c-3385cdff618c
# Measurement c7dcac50-b7c2-444d-a24c-17c5c640067b: ratio = 0.0662 / 0.0331 = 2.0
# Added ratio value 2.0 to measurement c7dcac50-b7c2-444d-a24c-17c5c640067b
# Measurement 989fe058-1b4e-4076-8f93-1f0f9de6ff68: ratio = 0.0662 / 0.0331 = 2.0
# Added ratio value 2.0 to measurement 989fe058-1b4e-4076-8f93-1f0f9de6ff68
# Measurement 2744d280-cdd2-49d1-9491-04433089165c: ratio = 0.0662 / 0.0331 = 2.0
# Added ratio value 2.0 to measurement 2744d280-cdd2-49d1-9491-04433089165c
# Measurement 982175f0-bbd1-4b8b-bf97-0ce14fc45e91: ratio = 0.0662 / 0.0331 = 2.0
# Added ratio value 2.0 to measurement 982175f0-bbd1-4b8b-bf97-0ce14fc45e91
#
# --- Processing Fluid 7 ---
# Added new parameter: parameter_solvent_ratio_glycerol_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 00fb9a30-57af-4d0c-b82e-f98a70d17749: ratio = 0.095066666667 / 0.047533333333 = 2.0
# Added ratio value 2.0 to measurement 00fb9a30-57af-4d0c-b82e-f98a70d17749
# Measurement d8fd8947-e8b0-4199-959e-c8cba4fa65f8: ratio = 0.095066666667 / 0.047533333333 = 2.0
# Added ratio value 2.0 to measurement d8fd8947-e8b0-4199-959e-c8cba4fa65f8
# Measurement 1cc0b75e-3de4-4d0e-af68-9315404329b8: ratio = 0.095066666667 / 0.047533333333 = 2.0
# Added ratio value 2.0 to measurement 1cc0b75e-3de4-4d0e-af68-9315404329b8
# Measurement e13321ba-7ab6-4f63-be28-a26a67e58411: ratio = 0.095066666667 / 0.047533333333 = 2.0
# Added ratio value 2.0 to measurement e13321ba-7ab6-4f63-be28-a26a67e58411
# Measurement ccb31311-49f0-474f-bf24-f2b44cee487f: ratio = 0.095066666667 / 0.047533333333 = 2.0
# Added ratio value 2.0 to measurement ccb31311-49f0-474f-bf24-f2b44cee487f
# Measurement 9dcbdccf-3cff-4ede-8d0a-a06723f2f7ee: ratio = 0.095066666667 / 0.047533333333 = 2.0
# Added ratio value 2.0 to measurement 9dcbdccf-3cff-4ede-8d0a-a06723f2f7ee
# Measurement 59e8b6e6-36f8-406a-95de-254ccd50f842: ratio = 0.095066666667 / 0.047533333333 = 2.0
# Added ratio value 2.0 to measurement 59e8b6e6-36f8-406a-95de-254ccd50f842
# Measurement 6c2f96c2-4270-4962-867a-2223d1f145d6: ratio = 0.095066666667 / 0.047533333333 = 2.0
# Added ratio value 2.0 to measurement 6c2f96c2-4270-4962-867a-2223d1f145d6
# Measurement f29c5584-2f84-4946-8d8b-106ff2569d2c: ratio = 0.095066666667 / 0.047533333333 = 2.0
# Added ratio value 2.0 to measurement f29c5584-2f84-4946-8d8b-106ff2569d2c
#
# --- Processing Fluid 8 ---
# Added new parameter: parameter_solvent_ratio_glycerol_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 255b9f50-6d61-4e53-b328-ecc2b6b5b404: ratio = 0.133533333333 / 0.066766666667 = 2.0
# Added ratio value 2.0 to measurement 255b9f50-6d61-4e53-b328-ecc2b6b5b404
# Measurement 9ab02514-0b31-4aa6-9063-a957ad463d34: ratio = 0.133533333333 / 0.066766666667 = 2.0
# Added ratio value 2.0 to measurement 9ab02514-0b31-4aa6-9063-a957ad463d34
# Measurement a54f9d4c-7e73-4437-9cce-e317e6320b35: ratio = 0.133533333333 / 0.066766666667 = 2.0
# Added ratio value 2.0 to measurement a54f9d4c-7e73-4437-9cce-e317e6320b35
# Measurement b4c77efd-ff93-4a1c-a104-70f474f7c9a4: ratio = 0.133533333333 / 0.066766666667 = 2.0
# Added ratio value 2.0 to measurement b4c77efd-ff93-4a1c-a104-70f474f7c9a4
# Measurement 8108a534-4cb9-4f0a-bff6-83b3e5903348: ratio = 0.133533333333 / 0.066766666667 = 2.0
# Added ratio value 2.0 to measurement 8108a534-4cb9-4f0a-bff6-83b3e5903348
# Measurement 4913b80d-7215-40ad-8f9d-1d3ef1788421: ratio = 0.133533333333 / 0.066766666667 = 2.0
# Added ratio value 2.0 to measurement 4913b80d-7215-40ad-8f9d-1d3ef1788421
# Measurement 0bbcab8f-785b-45da-ad80-3bd21b778fc2: ratio = 0.133533333333 / 0.066766666667 = 2.0
# Added ratio value 2.0 to measurement 0bbcab8f-785b-45da-ad80-3bd21b778fc2
# Measurement f5be1c9c-c75c-46fb-90cf-a2d29629952b: ratio = 0.133533333333 / 0.066766666667 = 2.0
# Added ratio value 2.0 to measurement f5be1c9c-c75c-46fb-90cf-a2d29629952b
# Measurement 1a2a743c-7ce6-493d-8b4b-2549ce9c2e36: ratio = 0.133533333333 / 0.066766666667 = 2.0
# Added ratio value 2.0 to measurement 1a2a743c-7ce6-493d-8b4b-2549ce9c2e36
#
# --- Processing Fluid 9 ---
# Added new parameter: parameter_solvent_ratio_glycerol_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 23197ede-b881-4ddb-b772-b01736205441: ratio = 0.186733333333 / 0.093366666667 = 2.0
# Added ratio value 2.0 to measurement 23197ede-b881-4ddb-b772-b01736205441
# Measurement fcf83fab-1f45-4387-8b5f-ca89e483acbe: ratio = 0.186733333333 / 0.093366666667 = 2.0
# Added ratio value 2.0 to measurement fcf83fab-1f45-4387-8b5f-ca89e483acbe
# Measurement 69fee213-4073-4639-8c8b-75a50c4e9377: ratio = 0.186733333333 / 0.093366666667 = 2.0
# Added ratio value 2.0 to measurement 69fee213-4073-4639-8c8b-75a50c4e9377
# Measurement baf55238-2f27-4e9c-ba25-8d8bef28a54b: ratio = 0.186733333333 / 0.093366666667 = 2.0
# Added ratio value 2.0 to measurement baf55238-2f27-4e9c-ba25-8d8bef28a54b
# Measurement 2735e793-3876-42d3-acf4-ac7619c05216: ratio = 0.186733333333 / 0.093366666667 = 2.0
# Added ratio value 2.0 to measurement 2735e793-3876-42d3-acf4-ac7619c05216
# Measurement 199df837-34df-4322-bfff-15341f792153: ratio = 0.186733333333 / 0.093366666667 = 2.0
# Added ratio value 2.0 to measurement 199df837-34df-4322-bfff-15341f792153
# Measurement 33e40fb1-e13e-4f13-af6f-34077fd70b0b: ratio = 0.186733333333 / 0.093366666667 = 2.0
# Added ratio value 2.0 to measurement 33e40fb1-e13e-4f13-af6f-34077fd70b0b
# Measurement a5421c77-f4cf-4c94-bf4c-4d9931c27f5f: ratio = 0.186733333333 / 0.093366666667 = 2.0
# Added ratio value 2.0 to measurement a5421c77-f4cf-4c94-bf4c-4d9931c27f5f
# Measurement 690ca00f-03f2-471c-9343-e9beb2cd097c: ratio = 0.186733333333 / 0.093366666667 = 2.0
# Added ratio value 2.0 to measurement 690ca00f-03f2-471c-9343-e9beb2cd097c
#
# --- Processing Fluid 10 ---
# Added new parameter: parameter_solvent_ratio_glycerol_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement e1b7b0b6-995d-485a-97a3-6074f05d8b1d: ratio = 0.268133333333 / 0.134066666667 = 2.0
# Added ratio value 2.0 to measurement e1b7b0b6-995d-485a-97a3-6074f05d8b1d
# Measurement 42382802-8bab-40e1-9d08-764c8fbffff5: ratio = 0.268133333333 / 0.134066666667 = 2.0
# Added ratio value 2.0 to measurement 42382802-8bab-40e1-9d08-764c8fbffff5
# Measurement 695791e2-5c35-4ec9-a260-0e2488ba1887: ratio = 0.268133333333 / 0.134066666667 = 2.0
# Added ratio value 2.0 to measurement 695791e2-5c35-4ec9-a260-0e2488ba1887
# Measurement f94cbc62-bfe6-48f5-a80e-d0d5a0197076: ratio = 0.268133333333 / 0.134066666667 = 2.0
# Added ratio value 2.0 to measurement f94cbc62-bfe6-48f5-a80e-d0d5a0197076
# Measurement 72d96a2e-7d0c-4234-80b7-f1cd71604bf9: ratio = 0.268133333333 / 0.134066666667 = 2.0
# Added ratio value 2.0 to measurement 72d96a2e-7d0c-4234-80b7-f1cd71604bf9
# Measurement 6d13f60b-f05a-4637-b698-70adc135abb1: ratio = 0.268133333333 / 0.134066666667 = 2.0
# Added ratio value 2.0 to measurement 6d13f60b-f05a-4637-b698-70adc135abb1
# Measurement 831d3e59-4cd7-41ca-919f-92980638e2e9: ratio = 0.268133333333 / 0.134066666667 = 2.0
# Added ratio value 2.0 to measurement 831d3e59-4cd7-41ca-919f-92980638e2e9
# Measurement 931c1e23-d45f-4b57-8168-527431314558: ratio = 0.268133333333 / 0.134066666667 = 2.0
# Added ratio value 2.0 to measurement 931c1e23-d45f-4b57-8168-527431314558
# Measurement 153eef35-c036-4a9b-9483-887642345bf4: ratio = 0.268133333333 / 0.134066666667 = 2.0
# Added ratio value 2.0 to measurement 153eef35-c036-4a9b-9483-887642345bf4
#
# --- Processing Fluid 11 ---
# Added new parameter: parameter_solvent_ratio_glycerol_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement d1c7f536-5553-4da8-aebc-d6de58cdafd2: ratio = 0.398533333333 / 0.199266666667 = 2.0
# Added ratio value 2.0 to measurement d1c7f536-5553-4da8-aebc-d6de58cdafd2
# Measurement 0a3971a9-57b7-45a9-8e47-02d7b8502cbd: ratio = 0.398533333333 / 0.199266666667 = 2.0
# Added ratio value 2.0 to measurement 0a3971a9-57b7-45a9-8e47-02d7b8502cbd
# Measurement b21adfed-bf27-4761-840e-60420819e462: ratio = 0.398533333333 / 0.199266666667 = 2.0
# Added ratio value 2.0 to measurement b21adfed-bf27-4761-840e-60420819e462
# Measurement e3bdde95-f253-4a9c-9c6b-b01a9f37ec98: ratio = 0.398533333333 / 0.199266666667 = 2.0
# Added ratio value 2.0 to measurement e3bdde95-f253-4a9c-9c6b-b01a9f37ec98
# Measurement 17e61f09-b7e7-44dd-bb80-4b87039a4e2c: ratio = 0.398533333333 / 0.199266666667 = 2.0
# Added ratio value 2.0 to measurement 17e61f09-b7e7-44dd-bb80-4b87039a4e2c
# Measurement d46e66f2-5cc1-4561-a0ee-05b1b58141e2: ratio = 0.398533333333 / 0.199266666667 = 2.0
# Added ratio value 2.0 to measurement d46e66f2-5cc1-4561-a0ee-05b1b58141e2
# Measurement c5c48b59-e94d-4a6e-9741-ccf2d1a92ef7: ratio = 0.398533333333 / 0.199266666667 = 2.0
# Added ratio value 2.0 to measurement c5c48b59-e94d-4a6e-9741-ccf2d1a92ef7
# Measurement e7f71874-e49a-4c89-a16e-2af7b4e61982: ratio = 0.398533333333 / 0.199266666667 = 2.0
# Added ratio value 2.0 to measurement e7f71874-e49a-4c89-a16e-2af7b4e61982
# Measurement 99122d4a-239d-49a4-8441-4e7256bad9c2: ratio = 0.398533333333 / 0.199266666667 = 2.0
# Added ratio value 2.0 to measurement 99122d4a-239d-49a4-8441-4e7256bad9c2
#
# --- Processing Fluid 12 ---
# Added new parameter: parameter_solvent_ratio_glycerol_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement a715e0f0-bdd4-4e40-9623-d9e7b5b902d6: ratio = 0.438333333333 / 0.219166666667 = 2.0
# Added ratio value 2.0 to measurement a715e0f0-bdd4-4e40-9623-d9e7b5b902d6
# Measurement b2920f6e-cfc3-4492-8613-9166593a3970: ratio = 0.438333333333 / 0.219166666667 = 2.0
# Added ratio value 2.0 to measurement b2920f6e-cfc3-4492-8613-9166593a3970
# Measurement 9511a8c8-976e-4cd1-acc6-623c5c39d38a: ratio = 0.438333333333 / 0.219166666667 = 2.0
# Added ratio value 2.0 to measurement 9511a8c8-976e-4cd1-acc6-623c5c39d38a
# Measurement 0f81a528-017c-4420-bbe5-ab27fe822305: ratio = 0.438333333333 / 0.219166666667 = 2.0
# Added ratio value 2.0 to measurement 0f81a528-017c-4420-bbe5-ab27fe822305
# Measurement ff3f6d0b-32fc-4f25-bb81-b690089787ee: ratio = 0.438333333333 / 0.219166666667 = 2.0
# Added ratio value 2.0 to measurement ff3f6d0b-32fc-4f25-bb81-b690089787ee
# Measurement c180d5a7-75e9-4273-bd22-2b69a74e6ca5: ratio = 0.438333333333 / 0.219166666667 = 2.0
# Added ratio value 2.0 to measurement c180d5a7-75e9-4273-bd22-2b69a74e6ca5
# Measurement c49a73df-bf45-4a01-a3b1-dd4ef04816de: ratio = 0.438333333333 / 0.219166666667 = 2.0
# Added ratio value 2.0 to measurement c49a73df-bf45-4a01-a3b1-dd4ef04816de
# Measurement 69688726-8fd4-494b-a7f0-6e32763cee78: ratio = 0.438333333333 / 0.219166666667 = 2.0
# Added ratio value 2.0 to measurement 69688726-8fd4-494b-a7f0-6e32763cee78
# Measurement 90509dac-2fd5-4231-b98e-178019af9dad: ratio = 0.438333333333 / 0.219166666667 = 2.0
# Added ratio value 2.0 to measurement 90509dac-2fd5-4231-b98e-178019af9dad
#
# --- Processing Fluid 13 ---
# Added new parameter: parameter_solvent_ratio_glycerol_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement ca5c9af3-09ce-47df-9b22-89aa982a1024: ratio = 0.507933333333 / 0.253966666667 = 2.0
# Added ratio value 2.0 to measurement ca5c9af3-09ce-47df-9b22-89aa982a1024
# Measurement bfc85cf7-fdf7-4945-a284-d54835e65aad: ratio = 0.507933333333 / 0.253966666667 = 2.0
# Added ratio value 2.0 to measurement bfc85cf7-fdf7-4945-a284-d54835e65aad
# Measurement 7159ef3e-e045-4110-a888-f513ab62ba26: ratio = 0.507933333333 / 0.253966666667 = 2.0
# Added ratio value 2.0 to measurement 7159ef3e-e045-4110-a888-f513ab62ba26
# Measurement abbebaf8-6d7b-4537-b4ba-4d8681c455ed: ratio = 0.507933333333 / 0.253966666667 = 2.0
# Added ratio value 2.0 to measurement abbebaf8-6d7b-4537-b4ba-4d8681c455ed
# Measurement a3665026-1195-4b2f-be98-891734cb1cfb: ratio = 0.507933333333 / 0.253966666667 = 2.0
# Added ratio value 2.0 to measurement a3665026-1195-4b2f-be98-891734cb1cfb
# Measurement 98fbc15b-af6f-474e-9912-cc4a3be183e8: ratio = 0.507933333333 / 0.253966666667 = 2.0
# Added ratio value 2.0 to measurement 98fbc15b-af6f-474e-9912-cc4a3be183e8
# Measurement 3c8f041b-68b7-4610-a97c-e8fb377ac960: ratio = 0.507933333333 / 0.253966666667 = 2.0
# Added ratio value 2.0 to measurement 3c8f041b-68b7-4610-a97c-e8fb377ac960
# Measurement cbd7fe25-3f9f-452d-9e7e-2f701ecc6604: ratio = 0.507933333333 / 0.253966666667 = 2.0
# Added ratio value 2.0 to measurement cbd7fe25-3f9f-452d-9e7e-2f701ecc6604
# Measurement 6369738f-4fe3-4718-b240-7899e6762bd5: ratio = 0.507933333333 / 0.253966666667 = 2.0
# Added ratio value 2.0 to measurement 6369738f-4fe3-4718-b240-7899e6762bd5
#
# --- Processing Fluid 14 ---
# Added new parameter: parameter_solvent_ratio_glycerol_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement bc25dd03-8048-4103-9817-9d57df2feb4a: ratio = 0.594666666667 / 0.297333333333 = 2.0
# Added ratio value 2.0 to measurement bc25dd03-8048-4103-9817-9d57df2feb4a
# Measurement 2d94d992-7ae1-490f-a64b-564b12525f17: ratio = 0.594666666667 / 0.297333333333 = 2.0
# Added ratio value 2.0 to measurement 2d94d992-7ae1-490f-a64b-564b12525f17
# Measurement 33445d1c-4b5e-45ca-ac07-9ba2ed9dc20e: ratio = 0.594666666667 / 0.297333333333 = 2.0
# Added ratio value 2.0 to measurement 33445d1c-4b5e-45ca-ac07-9ba2ed9dc20e
# Measurement 5b893842-8224-4787-b786-3882282bded7: ratio = 0.594666666667 / 0.297333333333 = 2.0
# Added ratio value 2.0 to measurement 5b893842-8224-4787-b786-3882282bded7
# Measurement ee80c5b3-d799-4d34-800c-84733257d8db: ratio = 0.594666666667 / 0.297333333333 = 2.0
# Added ratio value 2.0 to measurement ee80c5b3-d799-4d34-800c-84733257d8db
# Measurement bdebc056-37d4-4700-968b-d943ca66f94a: ratio = 0.594666666667 / 0.297333333333 = 2.0
# Added ratio value 2.0 to measurement bdebc056-37d4-4700-968b-d943ca66f94a
# Measurement fe66069e-0346-470a-a612-5c0e38f59a65: ratio = 0.594666666667 / 0.297333333333 = 2.0
# Added ratio value 2.0 to measurement fe66069e-0346-470a-a612-5c0e38f59a65
# Measurement 652b26af-32eb-4b03-9cd8-e946f940e8fa: ratio = 0.594666666667 / 0.297333333333 = 2.0
# Added ratio value 2.0 to measurement 652b26af-32eb-4b03-9cd8-e946f940e8fa
# Measurement 0bf58bb9-dfc3-48bf-bde6-e83db0b06894: ratio = 0.594666666667 / 0.297333333333 = 2.0
# Added ratio value 2.0 to measurement 0bf58bb9-dfc3-48bf-bde6-e83db0b06894
#
# --- Processing Fluid 15 ---
# Added new parameter: parameter_solvent_ratio_glycerol_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement a0dc3252-4505-4d2b-9f77-a052ea004516: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement a0dc3252-4505-4d2b-9f77-a052ea004516
# Measurement 4b4e37fd-38bc-4c2f-8f9a-4c8460e6627a: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 4b4e37fd-38bc-4c2f-8f9a-4c8460e6627a
# Measurement 4bcad8aa-94bb-497f-b994-c83f887766b6: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 4bcad8aa-94bb-497f-b994-c83f887766b6
# Measurement ee48c197-d0b0-4c2f-a7f6-50d17fa2935e: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement ee48c197-d0b0-4c2f-a7f6-50d17fa2935e
# Measurement 2c6d4dc5-03d9-4842-8ac0-84178acc6ed1: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 2c6d4dc5-03d9-4842-8ac0-84178acc6ed1
# Measurement 713ce507-f740-4289-9b6e-5ef8a3a92068: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 713ce507-f740-4289-9b6e-5ef8a3a92068
# Measurement 2ee5654b-1e6c-4041-94b2-d36b30cba97d: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 2ee5654b-1e6c-4041-94b2-d36b30cba97d
# Measurement 0b0e8d04-98ce-49c5-9974-999292bbce87: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 0b0e8d04-98ce-49c5-9974-999292bbce87
# Measurement c348871d-7be9-496b-a89c-9e62a53d659c: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement c348871d-7be9-496b-a89c-9e62a53d659c
# Measurement a5cd613c-3620-4680-821f-b8f4ef83c9de: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement a5cd613c-3620-4680-821f-b8f4ef83c9de
# Measurement cdd77da4-2456-4921-aa5a-1c643f3a0126: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement cdd77da4-2456-4921-aa5a-1c643f3a0126
# Measurement 9d1fc293-9be6-4394-9480-65a5286a7920: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 9d1fc293-9be6-4394-9480-65a5286a7920
# Measurement 547f28d5-0561-4ff7-8b1e-f9fc6ed60554: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 547f28d5-0561-4ff7-8b1e-f9fc6ed60554
# Measurement 86e773d7-06a7-438b-9efd-f06aae7cbbcb: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 86e773d7-06a7-438b-9efd-f06aae7cbbcb
# Measurement 5b5cea89-98b6-498c-a170-2d19f6fd67c7: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 5b5cea89-98b6-498c-a170-2d19f6fd67c7
# Measurement 2ddb91f2-9276-4830-89e9-0bf42e0d34d1: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 2ddb91f2-9276-4830-89e9-0bf42e0d34d1
# Measurement 2cc21243-b54c-4197-8c9a-1c0b31072240: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 2cc21243-b54c-4197-8c9a-1c0b31072240
# Measurement 4a154984-ba9e-426a-912d-6323d0cdee15: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 4a154984-ba9e-426a-912d-6323d0cdee15
# Measurement dc9157ef-1b66-4db4-bac9-c34bfebfb0e4: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement dc9157ef-1b66-4db4-bac9-c34bfebfb0e4
# Measurement 20120ac0-2d56-4bf0-af0f-bcb4e3f2ef2d: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 20120ac0-2d56-4bf0-af0f-bcb4e3f2ef2d
# Measurement 294c58ea-a16e-43c9-b011-329176b08a69: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 294c58ea-a16e-43c9-b011-329176b08a69
# Measurement ece6a2cb-b91a-457f-a69d-39ec13051570: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement ece6a2cb-b91a-457f-a69d-39ec13051570
# Measurement 564c2ef7-0edf-4513-a0ba-812f587eca1f: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 564c2ef7-0edf-4513-a0ba-812f587eca1f
# Measurement 63d3cb7c-69f0-4747-aa7c-2f30c7d70429: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 63d3cb7c-69f0-4747-aa7c-2f30c7d70429
# Measurement 505e4388-1167-4d4f-95a8-f566c3988c49: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 505e4388-1167-4d4f-95a8-f566c3988c49
# Measurement 27700a02-d161-4dd8-90db-315f733b52fb: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 27700a02-d161-4dd8-90db-315f733b52fb
# Measurement c44479f4-9f6a-4f79-ba1d-f4bb00b89506: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement c44479f4-9f6a-4f79-ba1d-f4bb00b89506
# Measurement 85746fb6-b299-4918-bd26-18db15cde0ce: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 85746fb6-b299-4918-bd26-18db15cde0ce
# Measurement 29c5b5ce-c8cf-4f26-9f68-deaaa444c4fa: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 29c5b5ce-c8cf-4f26-9f68-deaaa444c4fa
# Measurement ebabbdc8-f429-4a50-a58d-6c5f52f6780e: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement ebabbdc8-f429-4a50-a58d-6c5f52f6780e
# Measurement edaf55d9-5fbb-43c3-b228-8b4f1f26e95b: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement edaf55d9-5fbb-43c3-b228-8b4f1f26e95b
# Measurement 45c57df8-062b-4eeb-9a62-30c193c4d3a9: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 45c57df8-062b-4eeb-9a62-30c193c4d3a9
# Measurement 6f2c4cfe-ace8-46af-8853-fab901319c59: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 6f2c4cfe-ace8-46af-8853-fab901319c59
# Measurement 4e26164a-17f4-448a-9ccc-179691af04e0: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 4e26164a-17f4-448a-9ccc-179691af04e0
# Measurement 0504a801-bd13-4976-9ee6-fc00d302927d: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 0504a801-bd13-4976-9ee6-fc00d302927d
# Measurement 69c9e11f-c8bf-4981-860f-5ff729e5bd5b: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 69c9e11f-c8bf-4981-860f-5ff729e5bd5b
# Measurement edeaac2f-2d12-4ac0-a787-06df0108d484: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement edeaac2f-2d12-4ac0-a787-06df0108d484
# Measurement 876b1ea3-e04f-4a58-8958-c8a53806a255: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 876b1ea3-e04f-4a58-8958-c8a53806a255
# Measurement 8bb5d186-6c72-4903-b3a5-e96a6d09f581: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 8bb5d186-6c72-4903-b3a5-e96a6d09f581
# Measurement f4b7fac8-252e-4d4b-b8f5-cf1f7b7ffd2c: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement f4b7fac8-252e-4d4b-b8f5-cf1f7b7ffd2c
# Measurement ca259ce5-e117-45a4-aa7a-16d281b52925: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement ca259ce5-e117-45a4-aa7a-16d281b52925
# Measurement 57493b7d-22ea-4e8f-b7b1-2687b30fcf96: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 57493b7d-22ea-4e8f-b7b1-2687b30fcf96
# Measurement 144c9f2c-412a-430c-8fd4-f76ec2093aa9: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 144c9f2c-412a-430c-8fd4-f76ec2093aa9
# Measurement 9dd1747b-f81f-457f-a935-b98a3584c4ad: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 9dd1747b-f81f-457f-a935-b98a3584c4ad
# Measurement 5d9c9e65-e69f-48b3-b424-548d315c06e1: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 5d9c9e65-e69f-48b3-b424-548d315c06e1
# Measurement 7bf635e2-3020-42cb-8c5d-820b2fdf385d: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 7bf635e2-3020-42cb-8c5d-820b2fdf385d
# Measurement 44dd31e2-64b5-48a5-b798-8b58f9fb9115: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 44dd31e2-64b5-48a5-b798-8b58f9fb9115
# Measurement 3e830a4e-e94c-4078-8412-88aa9abb5332: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 3e830a4e-e94c-4078-8412-88aa9abb5332
# Measurement 26effde4-32c8-43d4-aa1c-bae0f0e0b1cc: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 26effde4-32c8-43d4-aa1c-bae0f0e0b1cc
# Measurement cab17bcc-f720-43f1-a561-5a2e95f7a40f: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement cab17bcc-f720-43f1-a561-5a2e95f7a40f
# Measurement 7ad89b93-2006-4476-9676-c29e0a433946: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 7ad89b93-2006-4476-9676-c29e0a433946
# Measurement 0c2d96ee-4e93-4524-96e3-73df1a71e5b6: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 0c2d96ee-4e93-4524-96e3-73df1a71e5b6
# Measurement 0d6d6cbc-ed3b-46e6-977a-e7f7456a4ddf: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 0d6d6cbc-ed3b-46e6-977a-e7f7456a4ddf
# Measurement 472374f4-2a0b-49a7-a11b-c0f0d59990fa: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 472374f4-2a0b-49a7-a11b-c0f0d59990fa
# Measurement 14c3c249-33d2-4eb6-9993-972a42af0e41: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 14c3c249-33d2-4eb6-9993-972a42af0e41
# Measurement 603ba8de-6d3a-4371-ac1e-6c9a6f6f4bc5: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 603ba8de-6d3a-4371-ac1e-6c9a6f6f4bc5
# Measurement 7c11e9ac-6c5d-4126-812c-cde1691c460d: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 7c11e9ac-6c5d-4126-812c-cde1691c460d
# Measurement 111f534d-ee2d-4dd3-b9d7-1e6aa3e2d076: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 111f534d-ee2d-4dd3-b9d7-1e6aa3e2d076
# Measurement 9c6c5b7a-c371-4f54-a06b-34eb804c29a4: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 9c6c5b7a-c371-4f54-a06b-34eb804c29a4
# Measurement 4f3fb063-e1de-4dc4-ad99-e2a0ba3eb552: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 4f3fb063-e1de-4dc4-ad99-e2a0ba3eb552
# Measurement f7cbc21b-43b8-4667-a190-c488643b983e: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement f7cbc21b-43b8-4667-a190-c488643b983e
# Measurement 3db934d1-f626-46b4-a1df-23d96b1527fd: ratio = 0.666666666667 / 0.333333333333 = 2.0
# Added ratio value 2.0 to measurement 3db934d1-f626-46b4-a1df-23d96b1527fd
#
# --- Processing Fluid 16 ---
# Added new parameter: parameter_solvent_ratio_glycerol_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 3c4f8c71-845b-48ef-ae32-90ab5b51fc50: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 3c4f8c71-845b-48ef-ae32-90ab5b51fc50
# Measurement 17c56a00-7894-4640-91e6-8f5a58a2ed20: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 17c56a00-7894-4640-91e6-8f5a58a2ed20
# Measurement 1d363e8f-3dc2-4182-8a75-98c3a95d6970: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 1d363e8f-3dc2-4182-8a75-98c3a95d6970
# Measurement 9cf0c23b-e6c5-46f5-b45c-fa74835d09cd: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 9cf0c23b-e6c5-46f5-b45c-fa74835d09cd
# Measurement e913427c-ba1c-4f85-9256-2cfa5c1e605f: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement e913427c-ba1c-4f85-9256-2cfa5c1e605f
# Measurement 58e618d6-49f7-4076-87f3-bb1d95c1d298: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 58e618d6-49f7-4076-87f3-bb1d95c1d298
# Measurement 61e0f4f7-eb29-444e-ad96-d389cde6ad6b: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 61e0f4f7-eb29-444e-ad96-d389cde6ad6b
# Measurement 76b870ce-3f3e-44b0-8ef4-0b1f7470fdd8: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 76b870ce-3f3e-44b0-8ef4-0b1f7470fdd8
# Measurement 63ab68e0-2d08-446d-b3d5-8e31591754be: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 63ab68e0-2d08-446d-b3d5-8e31591754be
# Measurement 8f2549cf-5609-40de-85ff-fdfa9a204819: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 8f2549cf-5609-40de-85ff-fdfa9a204819
# Measurement f0ec4dc1-81f0-4404-8fdb-9039514faeee: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement f0ec4dc1-81f0-4404-8fdb-9039514faeee
# Measurement 7fd3c35a-731a-45f7-bbd0-94e8971ec417: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 7fd3c35a-731a-45f7-bbd0-94e8971ec417
# Measurement e186af0e-17f3-4c8c-9205-c9c1c7039a80: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement e186af0e-17f3-4c8c-9205-c9c1c7039a80
# Measurement 2ed6670e-cad4-446e-90de-adc733f866e5: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 2ed6670e-cad4-446e-90de-adc733f866e5
# Measurement d79d6bd8-e0be-4f36-a193-10fd87b0ab70: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement d79d6bd8-e0be-4f36-a193-10fd87b0ab70
# Measurement 0411f81b-83cc-4c2c-a793-c4a608c60fe1: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 0411f81b-83cc-4c2c-a793-c4a608c60fe1
# Measurement f1f28834-1c79-4715-821f-eae0c8a89b63: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement f1f28834-1c79-4715-821f-eae0c8a89b63
# Measurement d555f717-fa1a-4286-be23-d74f40a9a7d1: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement d555f717-fa1a-4286-be23-d74f40a9a7d1
# Measurement dd7dfdd5-a58c-4432-894c-f795bade7b90: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement dd7dfdd5-a58c-4432-894c-f795bade7b90
# Measurement 9527eb82-dd91-493e-945c-fdf850b539a9: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 9527eb82-dd91-493e-945c-fdf850b539a9
# Measurement 2f1eb2c3-a182-45aa-9213-8edd4ded49ba: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 2f1eb2c3-a182-45aa-9213-8edd4ded49ba
# Measurement be298554-ebf2-46b7-add4-19807e06b301: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement be298554-ebf2-46b7-add4-19807e06b301
# Measurement a0e636ca-c15f-4dc0-8916-4328ec4de0ec: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement a0e636ca-c15f-4dc0-8916-4328ec4de0ec
# Measurement 3b796272-9c0f-4de9-b9ec-c393f9a9a892: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 3b796272-9c0f-4de9-b9ec-c393f9a9a892
# Measurement 7f43ddb6-10f0-4c75-8d5e-8e6648b43615: ratio = 0.49625935141 / 0.24937655859 = 2.0
# Added ratio value 2.0 to measurement 7f43ddb6-10f0-4c75-8d5e-8e6648b43615
#
# --- Processing Fluid 17 ---
# Added new parameter: parameter_solvent_ratio_glycerol_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 34907324-3044-4f36-990c-1aed7a65f703: ratio = 0.949999999952 / 0.050000000047 = 19.0
# Added ratio value 19.0 to measurement 34907324-3044-4f36-990c-1aed7a65f703
# Measurement 52c2fe63-d8e5-4faa-881a-10be6f4cff0f: ratio = 0.949999999952 / 0.050000000047 = 19.0
# Added ratio value 19.0 to measurement 52c2fe63-d8e5-4faa-881a-10be6f4cff0f
# Measurement 86957d09-725d-45fd-a4c8-305cdef0efc4: ratio = 0.949999999952 / 0.050000000047 = 19.0
# Added ratio value 19.0 to measurement 86957d09-725d-45fd-a4c8-305cdef0efc4
# Measurement 5937ef8d-0e34-444f-a5c9-550ac0fb0f4f: ratio = 0.949999999952 / 0.050000000047 = 19.0
# Added ratio value 19.0 to measurement 5937ef8d-0e34-444f-a5c9-550ac0fb0f4f
# Measurement 7206b3cd-44bd-4ed3-98d5-c34bea2399b7: ratio = 0.949999999952 / 0.050000000047 = 19.0
# Added ratio value 19.0 to measurement 7206b3cd-44bd-4ed3-98d5-c34bea2399b7
# Measurement b1aa3a32-fe25-474b-a70f-efa7c0285ee5: ratio = 0.949999999952 / 0.050000000047 = 19.0
# Added ratio value 19.0 to measurement b1aa3a32-fe25-474b-a70f-efa7c0285ee5
# Measurement cd7c32e7-ee53-4b47-9df8-fe7f61594a9b: ratio = 0.949999999952 / 0.050000000047 = 19.0
# Added ratio value 19.0 to measurement cd7c32e7-ee53-4b47-9df8-fe7f61594a9b
# Measurement cb27881f-2b78-43b4-8f4d-9794ac46a6df: ratio = 0.949999999952 / 0.050000000047 = 19.0
# Added ratio value 19.0 to measurement cb27881f-2b78-43b4-8f4d-9794ac46a6df
# Measurement 43e8c183-a33f-4904-b916-ed9cddfff25d: ratio = 0.949999999952 / 0.050000000047 = 19.0
# Added ratio value 19.0 to measurement 43e8c183-a33f-4904-b916-ed9cddfff25d
#
# --- Processing Fluid 18 ---
# Added new parameter: parameter_solvent_ratio_glycerol_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 2e7a1cd5-1ebe-4ffd-b9d1-fe801132546b: ratio = 0.90000000009 / 0.09999999991 = 9.0
# Added ratio value 9.0 to measurement 2e7a1cd5-1ebe-4ffd-b9d1-fe801132546b
# Measurement 48d33e20-5687-4ca7-900e-47fc0e1fee93: ratio = 0.90000000009 / 0.09999999991 = 9.0
# Added ratio value 9.0 to measurement 48d33e20-5687-4ca7-900e-47fc0e1fee93
# Measurement 9734b10c-116e-4270-8df4-0bf0feabbe88: ratio = 0.90000000009 / 0.09999999991 = 9.0
# Added ratio value 9.0 to measurement 9734b10c-116e-4270-8df4-0bf0feabbe88
# Measurement 627d5074-73e6-4a56-93f9-e8d3e44f977f: ratio = 0.90000000009 / 0.09999999991 = 9.0
# Added ratio value 9.0 to measurement 627d5074-73e6-4a56-93f9-e8d3e44f977f
# Measurement f2d230c1-0755-49ea-98e1-ea11a8fb589f: ratio = 0.90000000009 / 0.09999999991 = 9.0
# Added ratio value 9.0 to measurement f2d230c1-0755-49ea-98e1-ea11a8fb589f
# Measurement 41753ff2-e9f0-4649-a0a0-1a9159391250: ratio = 0.90000000009 / 0.09999999991 = 9.0
# Added ratio value 9.0 to measurement 41753ff2-e9f0-4649-a0a0-1a9159391250
# Measurement 0b576262-18ea-4c1a-ab62-77383fe58c84: ratio = 0.90000000009 / 0.09999999991 = 9.0
# Added ratio value 9.0 to measurement 0b576262-18ea-4c1a-ab62-77383fe58c84
# Measurement 090d373b-ca1d-49c0-8924-e7f985a38ae8: ratio = 0.90000000009 / 0.09999999991 = 9.0
# Added ratio value 9.0 to measurement 090d373b-ca1d-49c0-8924-e7f985a38ae8
# Measurement a5d35f5d-4683-43e5-b498-2ef572906407: ratio = 0.90000000009 / 0.09999999991 = 9.0
# Added ratio value 9.0 to measurement a5d35f5d-4683-43e5-b498-2ef572906407
#
# --- Processing Fluid 19 ---
# Added new parameter: parameter_solvent_ratio_glycerol_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 46a140ea-f06e-45b3-92c5-b195a07bbc4c: ratio = 0.85000000017 / 0.14999999983 = 5.7
# Added ratio value 5.7 to measurement 46a140ea-f06e-45b3-92c5-b195a07bbc4c
# Measurement 629c8e92-813f-4bf4-8fcb-17b17c986db2: ratio = 0.85000000017 / 0.14999999983 = 5.7
# Added ratio value 5.7 to measurement 629c8e92-813f-4bf4-8fcb-17b17c986db2
# Measurement 344b6cab-c572-44e2-938d-72ead95910b7: ratio = 0.85000000017 / 0.14999999983 = 5.7
# Added ratio value 5.7 to measurement 344b6cab-c572-44e2-938d-72ead95910b7
# Measurement ada7b800-16bb-4f48-8bc6-5251f5ac8931: ratio = 0.85000000017 / 0.14999999983 = 5.7
# Added ratio value 5.7 to measurement ada7b800-16bb-4f48-8bc6-5251f5ac8931
# Measurement db860c5e-e0de-4183-9d07-de95245e54cd: ratio = 0.85000000017 / 0.14999999983 = 5.7
# Added ratio value 5.7 to measurement db860c5e-e0de-4183-9d07-de95245e54cd
# Measurement 5d42a805-f9b1-4a6f-b6a2-d6a19f15b918: ratio = 0.85000000017 / 0.14999999983 = 5.7
# Added ratio value 5.7 to measurement 5d42a805-f9b1-4a6f-b6a2-d6a19f15b918
# Measurement cd0ee39a-ea86-46bc-b4c3-c8e7e6e92287: ratio = 0.85000000017 / 0.14999999983 = 5.7
# Added ratio value 5.7 to measurement cd0ee39a-ea86-46bc-b4c3-c8e7e6e92287
# Measurement 1794466f-9d86-499e-ae5a-c799503e3bd9: ratio = 0.85000000017 / 0.14999999983 = 5.7
# Added ratio value 5.7 to measurement 1794466f-9d86-499e-ae5a-c799503e3bd9
# Measurement 9b85e353-41f7-44e4-b9a4-4d1f47d8a675: ratio = 0.85000000017 / 0.14999999983 = 5.7
# Added ratio value 5.7 to measurement 9b85e353-41f7-44e4-b9a4-4d1f47d8a675
#
# --- Processing Fluid 20 ---
# Added new parameter: parameter_solvent_ratio_glycerol_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 4aad25ca-8a3f-4af7-999f-d2f347db64f9: ratio = 0.8 / 0.2 = 4.0
# Added ratio value 4.0 to measurement 4aad25ca-8a3f-4af7-999f-d2f347db64f9
# Measurement ab174c14-edb0-4b5c-a784-bb6ff7ae1184: ratio = 0.8 / 0.2 = 4.0
# Added ratio value 4.0 to measurement ab174c14-edb0-4b5c-a784-bb6ff7ae1184
# Measurement c6b3835f-a8c1-4df5-b66d-cbc5757f3ce9: ratio = 0.8 / 0.2 = 4.0
# Added ratio value 4.0 to measurement c6b3835f-a8c1-4df5-b66d-cbc5757f3ce9
# Measurement 99be8982-f1a6-4b81-a5ab-cc7afe90fb6f: ratio = 0.8 / 0.2 = 4.0
# Added ratio value 4.0 to measurement 99be8982-f1a6-4b81-a5ab-cc7afe90fb6f
# Measurement c60a4556-de39-43e2-93fb-e6f60894265e: ratio = 0.8 / 0.2 = 4.0
# Added ratio value 4.0 to measurement c60a4556-de39-43e2-93fb-e6f60894265e
# Measurement 10c9d1f6-7842-4e30-8305-becaeb4335a0: ratio = 0.8 / 0.2 = 4.0
# Added ratio value 4.0 to measurement 10c9d1f6-7842-4e30-8305-becaeb4335a0
# Measurement e39fa751-24e4-48d8-8f99-ff3f6f16473e: ratio = 0.8 / 0.2 = 4.0
# Added ratio value 4.0 to measurement e39fa751-24e4-48d8-8f99-ff3f6f16473e
# Measurement e1e23d97-f741-4b4f-879c-c353c9cb3de9: ratio = 0.8 / 0.2 = 4.0
# Added ratio value 4.0 to measurement e1e23d97-f741-4b4f-879c-c353c9cb3de9
# Measurement 6e279902-8832-44b4-84d3-1aa4ecb0455b: ratio = 0.8 / 0.2 = 4.0
# Added ratio value 4.0 to measurement 6e279902-8832-44b4-84d3-1aa4ecb0455b
#
# --- Processing Fluid 21 ---
# Added new parameter: parameter_solvent_ratio_glycerol_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 96be0e98-a7b7-4fbc-b536-abd473c53e7e: ratio = 0.750000000188 / 0.249999999812 = 3.0
# Added ratio value 3.0 to measurement 96be0e98-a7b7-4fbc-b536-abd473c53e7e
# Measurement 35a29f8f-2161-4857-9940-ae078e12e56d: ratio = 0.750000000188 / 0.249999999812 = 3.0
# Added ratio value 3.0 to measurement 35a29f8f-2161-4857-9940-ae078e12e56d
# Measurement f5f1dd1f-1edd-437e-b0ba-06624e8cbc17: ratio = 0.750000000188 / 0.249999999812 = 3.0
# Added ratio value 3.0 to measurement f5f1dd1f-1edd-437e-b0ba-06624e8cbc17
# Measurement f2fe873b-de59-441d-9e9f-d66b63a0137a: ratio = 0.750000000188 / 0.249999999812 = 3.0
# Added ratio value 3.0 to measurement f2fe873b-de59-441d-9e9f-d66b63a0137a
# Measurement 099a57d8-d204-4796-82c4-2462493569b1: ratio = 0.750000000188 / 0.249999999812 = 3.0
# Added ratio value 3.0 to measurement 099a57d8-d204-4796-82c4-2462493569b1
# Measurement bf709ba4-ac9f-4ffe-bca5-eeeab1a5d49d: ratio = 0.750000000188 / 0.249999999812 = 3.0
# Added ratio value 3.0 to measurement bf709ba4-ac9f-4ffe-bca5-eeeab1a5d49d
# Measurement 55a22a07-f1ca-4c1e-9034-f48e7d464957: ratio = 0.750000000188 / 0.249999999812 = 3.0
# Added ratio value 3.0 to measurement 55a22a07-f1ca-4c1e-9034-f48e7d464957
# Measurement 44d7f9cd-5743-432c-be98-9d4af14c3a14: ratio = 0.750000000188 / 0.249999999812 = 3.0
# Added ratio value 3.0 to measurement 44d7f9cd-5743-432c-be98-9d4af14c3a14
# Measurement ae3c1a50-b914-485d-9f25-d4dfcc8501fb: ratio = 0.750000000188 / 0.249999999812 = 3.0
# Added ratio value 3.0 to measurement ae3c1a50-b914-485d-9f25-d4dfcc8501fb
#
# --- Processing Fluid 22 ---
# Added new parameter: parameter_solvent_ratio_glycerol_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 94e5748b-7d23-46a4-b9cb-bf6dfe215255: ratio = 0.69999999979 / 0.30000000021 = 2.3
# Added ratio value 2.3 to measurement 94e5748b-7d23-46a4-b9cb-bf6dfe215255
# Measurement cc3d897f-7f4c-44af-acc5-6342acb1fab3: ratio = 0.69999999979 / 0.30000000021 = 2.3
# Added ratio value 2.3 to measurement cc3d897f-7f4c-44af-acc5-6342acb1fab3
# Measurement 3b409783-a074-4767-9f52-ce57e9be5a7f: ratio = 0.69999999979 / 0.30000000021 = 2.3
# Added ratio value 2.3 to measurement 3b409783-a074-4767-9f52-ce57e9be5a7f
# Measurement a5204159-a3b8-44fc-90a1-ad6ec0fdbcd8: ratio = 0.69999999979 / 0.30000000021 = 2.3
# Added ratio value 2.3 to measurement a5204159-a3b8-44fc-90a1-ad6ec0fdbcd8
# Measurement 4d5f46a9-c552-443f-9b58-a9eec9f5bcc7: ratio = 0.69999999979 / 0.30000000021 = 2.3
# Added ratio value 2.3 to measurement 4d5f46a9-c552-443f-9b58-a9eec9f5bcc7
# Measurement 6d8b4fee-2dee-47bb-8f7a-a52a49755e4f: ratio = 0.69999999979 / 0.30000000021 = 2.3
# Added ratio value 2.3 to measurement 6d8b4fee-2dee-47bb-8f7a-a52a49755e4f
# Measurement 82283cb7-9a08-453b-b608-d0eb1f7d4467: ratio = 0.69999999979 / 0.30000000021 = 2.3
# Added ratio value 2.3 to measurement 82283cb7-9a08-453b-b608-d0eb1f7d4467
# Measurement 3059b195-2032-4e27-be3a-36f52600190b: ratio = 0.69999999979 / 0.30000000021 = 2.3
# Added ratio value 2.3 to measurement 3059b195-2032-4e27-be3a-36f52600190b
# Measurement 83ee8b77-d4fb-4999-b22c-7cf90fbbd00b: ratio = 0.69999999979 / 0.30000000021 = 2.3
# Added ratio value 2.3 to measurement 83ee8b77-d4fb-4999-b22c-7cf90fbbd00b
#
# --- Processing Fluid 23 ---
# Added new parameter: parameter_solvent_ratio_glycerol_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 231cbb26-0036-4a69-9cff-82375e873d49: ratio = 0.294726726 / 0.147363363 = 2.0
# Added ratio value 2.0 to measurement 231cbb26-0036-4a69-9cff-82375e873d49
#
# --- Processing Fluid 24 ---
# Added new parameter: parameter_solvent_ratio_glycerol_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 57ed81b6-de1c-45e1-a17b-64f3860b90a2: ratio = 0.352629193333 / 0.176314596667 = 2.0
# Added ratio value 2.0 to measurement 57ed81b6-de1c-45e1-a17b-64f3860b90a2
#
# --- Processing Fluid 25 ---
# Added new parameter: parameter_solvent_ratio_glycerol_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 8e448202-fcf0-443d-a390-853bb3ba1d43: ratio = 0.426765982 / 0.213382991 = 2.0
# Added ratio value 2.0 to measurement 8e448202-fcf0-443d-a390-853bb3ba1d43
#
# --- Processing Fluid 26 ---
# Added new parameter: parameter_solvent_ratio_glycerol_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 6d65917c-656b-4a59-8d2e-0a8825bc06fb: ratio = 0.472477279333 / 0.236238639667 = 2.0
# Added ratio value 2.0 to measurement 6d65917c-656b-4a59-8d2e-0a8825bc06fb
#
# --- Processing Fluid 27 ---
# Added new parameter: parameter_solvent_ratio_glycerol_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement dd37d382-bb6f-41f9-8af5-8c44eee84651: ratio = 0.526311321333 / 0.263155660667 = 2.0
# Added ratio value 2.0 to measurement dd37d382-bb6f-41f9-8af5-8c44eee84651
#
# --- Processing Fluid 28 ---
# Added new parameter: parameter_solvent_ratio_glycerol_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 1a09fcea-0aa5-402c-b2c4-376f9b149efc: ratio = 0.589895344 / 0.294947672 = 2.0
# Added ratio value 2.0 to measurement 1a09fcea-0aa5-402c-b2c4-376f9b149efc
#
# --- Processing Fluid 29 ---
# Added new parameter: parameter_solvent_ratio_glycerol_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement b98b4699-7711-4f9c-8b49-61da54c8f578: ratio = 0.63389538 / 0.31694769 = 2.0
# Added ratio value 2.0 to measurement b98b4699-7711-4f9c-8b49-61da54c8f578
#
# --- Processing Fluid 30 ---
# Added new parameter: parameter_solvent_ratio_glycerol_cholinechloride
# Associated compounds: ['compound_glycerol', 'compound_cholinechloride']
# Measurement 728b3fd5-7840-4231-8618-3026395b785e: ratio = 0.650095585333 / 0.325047792667 = 2.0
# Added ratio value 2.0 to measurement 728b3fd5-7840-4231-8618-3026395b785e
# === Solvent Ratio Calculation Complete ===
#
# 📁 Output saved to: /home/sga/Code/FAIRFluids/Workflows/outputs/Glyceline_Water.json

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import cm
from scipy.stats import linregress

# Make sure required columns exist
required_cols = [
    "viscosity_value", 
    "temperature", 
    "source_doi", 
    "mole_fraction_water",
    "Solvent: Amount ratio of component to other component of binary solvent"
]
for col in required_cols:
    if col not in df_data_glyceline_ratio_or_pure_water.columns:
        raise ValueError(f"Column '{col}' not found in dataframe.")

# Filter on solvent ratio: keep rows where ratio <=2 or ratio is NaN (missing/None)
df_data_glyceline_ratio_or_pure_water_filtered = df_data_glyceline_ratio_or_pure_water[
    (df_data_glyceline_ratio_or_pure_water["Solvent: Amount ratio of component to other component of binary solvent"].isna()) |
    (df_data_glyceline_ratio_or_pure_water["Solvent: Amount ratio of component to other component of binary solvent"] <= 2)
].copy()

# Fill missing/None values in mole_fraction_water with 0
df_data_glyceline_ratio_or_pure_water_filtered["mole_fraction_water"] = (
    df_data_glyceline_ratio_or_pure_water_filtered["mole_fraction_water"]
    .fillna(0)
    .apply(lambda x: 0 if x is None else x)
)

# Clean for missing values in variables used
plot_df = df_data_glyceline_ratio_or_pure_water_filtered[
    df_data_glyceline_ratio_or_pure_water_filtered["viscosity_value"].notnull() &
    df_data_glyceline_ratio_or_pure_water_filtered["temperature"].notnull() &
    df_data_glyceline_ratio_or_pure_water_filtered["source_doi"].notnull()
].copy()

# Calculate ln(viscosity) and 1/(R*T)
R = 8.314  # J/(mol*K)
plot_df["inv_RT"] = 1 / (R * plot_df["temperature"].astype(float))
plot_df["ln_viscosity"] = np.log(plot_df["viscosity_value"].astype(float)/1000)

# Use mole_fraction_water to color the water amount
plot_df["water_mole_fraction"] = plot_df["mole_fraction_water"].astype(float)

# We'll use unique discrete values for water mole fraction as hue
plot_df["water_mole_fraction_rounded"] = plot_df["water_mole_fraction"].round(3)
discrete_mole_fractions = np.sort(plot_df["water_mole_fraction_rounded"].unique())

# Set up colormap: Blues colormap, N bins = number of unique mole fractions
N = len(discrete_mole_fractions)
cmap = cm.get_cmap('Blues', N)
color_dict = {mf: cmap(i) for i, mf in enumerate(discrete_mole_fractions)}

plt.figure(figsize=(11,7))
ax = plt.gca()

# Increase font size globally
plt.rcParams.update({'font.size': 14})

# Scatter points for each discrete fraction, so legend can be discrete
for i, mf in enumerate(discrete_mole_fractions):
    subset = plot_df[plot_df["water_mole_fraction_rounded"] == mf]
    ax.scatter(
        subset["inv_RT"], 
        subset["ln_viscosity"], 
        color=color_dict[mf],
        s=55, 
        edgecolor='black',
        linewidth=0.2,
        label=f"{mf:.3f}"
    )

# Linear fit and store slopes per discrete water content, including source_doi
slope_results = []
for mf in discrete_mole_fractions:
    group = plot_df[plot_df["water_mole_fraction_rounded"] == mf]
    # For each unique source_doi in this water content, do a fit for that subset
    for doi in group["source_doi"].unique():
        doi_group = group[group["source_doi"] == doi]
        if len(doi_group) >= 2:
            x = doi_group["inv_RT"].values
            y = doi_group["ln_viscosity"].values
            slope, intercept, r_value, p_value, std_err = linregress(x, y)
            xfit = np.linspace(x.min(), x.max(), 50)
            yfit = intercept + slope * xfit
            # Optionally: plot fits per color, commented
            # ax.plot(xfit, yfit, linestyle='--', linewidth=2, color=color_dict[mf])
            mf_tuple = (tuple(doi_group["mole_fractions"].iloc[0]) if "mole_fractions" in doi_group.columns and isinstance(doi_group["mole_fractions"].iloc[0], (list, tuple)) 
                        else doi_group["mole_fractions"].iloc[0] if "mole_fractions" in doi_group.columns else None)
            slope_results.append({
                "mole_fractions": mf_tuple,
                "water_mole_fraction": float(mf),
                "slope": slope,
                "source_doi": doi,
                "ordinate": intercept,
                "statistic": r_value
            })

# Create secondary x-axis for temperature
ax2 = ax.twiny()

# Get the range of 1/(R*T) values to create corresponding temperature values
inv_RT_min, inv_RT_max = ax.get_xlim()
T_max = 1 / (R * inv_RT_min)  # Higher temperature corresponds to lower 1/(R*T)
T_min = 1 / (R * inv_RT_max)  # Lower temperature corresponds to higher 1/(R*T)

# Set temperature ticks
temp_ticks = np.linspace(T_min, T_max, 6)  # 6 temperature points
inv_RT_ticks = 1 / (R * temp_ticks)

ax2.set_xlim(ax.get_xlim())
ax2.set_xticks(inv_RT_ticks)
ax2.set_xticklabels([f'{T:.0f}' for T in temp_ticks])
ax2.set_xlabel('Temperature / K', fontsize=16)

# Make discrete legend
handles, labels = ax.get_legend_handles_labels()
by_label = dict(zip(labels, handles))
lgd = ax.legend(by_label.values(), by_label.keys(), title="Water mole fraction", bbox_to_anchor=(1.04, 1), loc='upper left', borderaxespad=0., fontsize=12)
lgd.get_title().set_fontsize(14)

plt.title('Arrhenius plot of Glyceline with different water mole fractions', fontsize=15)
ax.set_xlabel('1 (R*T)$^{-1}$ / mol J$^{-1}$', fontsize=16)
ax.set_ylabel('ln(Aₛ) / ln(Pa*s)', fontsize=16)
ax.tick_params(axis='both', which='major', labelsize=12)
ax2.tick_params(axis='x', which='major', labelsize=12)
plt.tight_layout()
plt.show()

import pandas as pd
activation_energy_df = pd.DataFrame(slope_results)
# Rename for clarity
activation_energy_df = activation_energy_df.rename(columns={'slope': 'activation_energy'})
# Ensure 'ordinate' and 'statistic' columns are present (they are, see above)
print("All linear fit activation energies by water mole fraction and source DOI, including ordinate and statistic:")
display(activation_energy_df[["water_mole_fraction", "activation_energy", "source_doi", "ordinate", "statistic"]])

activation_energy_df['measurement'] = 'measured'
activation_energy_df.to_csv('activation_energy_results_measured.csv', index=False)


# Add a column called 'measured' and fill it with 'measured'
df_data_glyceline_ratio_or_pure_water_filtered['measured'] = 'measured'

# Save the activation energy data to CSV
df_data_glyceline_ratio_or_pure_water_filtered.to_csv('df_data_glyceline_ratio_or_pure_water.csv', index=False)
print("Saved activation energy data to 'df_data_glyceline_ratio_or_pure_water.csv'")
# Out:
# /tmp/ipykernel_7996/321941941.py:52: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('Blues', N)
# All linear fit activation energies by water mole fraction and source DOI, including ordinate and statistic:
#     water_mole_fraction  activation_energy                    source_doi  \
# 0                 0.000       46748.108736     10.1016/j.jct.2018.07.031
# 1                 0.000       37401.010918  10.1016/j.molliq.2015.11.032
# 2                 0.000       43647.834764            10.1039/c1cp22554e
# 3                 0.000       45099.537048            10.1039/c0gc00395f
# 4                 0.000       41925.535292   10.1016/j.fluid.2014.01.028
# 5                 0.108       40366.403098   10.1016/j.fluid.2014.01.028
# 6                 0.238       37590.289435   10.1016/j.fluid.2014.01.028
# 7                 0.254       41597.359069     10.1016/j.jct.2018.07.031
# 8                 0.342       34740.693961   10.1016/j.fluid.2014.01.028
# 9                 0.402       33526.414685   10.1016/j.fluid.2014.01.028
# 10                0.598       28874.286184   10.1016/j.fluid.2014.01.028
# 11                0.720       24938.581185   10.1016/j.fluid.2014.01.028
# 12                0.800       22366.546410   10.1016/j.fluid.2014.01.028
# 13                0.857       18893.527986   10.1016/j.fluid.2014.01.028
# 14                0.901       17207.759499   10.1016/j.fluid.2014.01.028
# 15                0.934       16013.872479   10.1016/j.fluid.2014.01.028
# 16                0.960       15546.665223   10.1016/j.fluid.2014.01.028
# 17                0.982       14912.521507   10.1016/j.fluid.2014.01.028
# 18                1.000       13957.939791   10.1016/j.fluid.2014.01.028
#
#      ordinate  statistic
# 0  -26.846532   0.998271
# 1  -23.168710   0.996212
# 2  -25.906119   0.999017
# 3  -26.447968   0.998521
# 4  -24.886946   0.996304
# 5  -24.622199   0.996411
# 6  -23.974194   0.995796
# 7  -25.541719   0.998101
# 8  -23.251774   0.996203
# 9  -23.019817   0.996679
# 10 -22.167398   0.998425
# 11 -21.394706   0.997750
# 12 -20.968165   0.996535
# 13 -20.103317   0.997762
# 14 -19.829755   0.997371
# 15 -19.692201   0.995661
# 16 -19.771642   0.998110
# 17 -19.748993   0.997674
# 18 -19.563329   0.996172
# Saved activation energy data to 'df_data_glyceline_ratio_or_pure_water.csv'

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import cm
from scipy.stats import linregress
import seaborn as sns

# Set a beautiful color palette
plt.style.use('default')
sns.set_palette("husl")

# Make sure required columns exist
required_cols = [
    "viscosity_value", 
    "temperature", 
    "source_doi", 
    "mole_fraction_water",
    "Solvent: Amount ratio of component to other component of binary solvent"
]
for col in required_cols:
    if col not in df_data_glyceline_ratio_or_pure_water.columns:
        raise ValueError(f"Column '{col}' not found in dataframe.")

# Filter on solvent ratio: keep rows where ratio <=2 or ratio is NaN (missing/None)
df_data_glyceline_ratio_or_pure_water_filtered = df_data_glyceline_ratio_or_pure_water[
    (df_data_glyceline_ratio_or_pure_water["Solvent: Amount ratio of component to other component of binary solvent"].isna()) |
    (df_data_glyceline_ratio_or_pure_water["Solvent: Amount ratio of component to other component of binary solvent"] <= 2)
].copy()

# Fill missing/None values in mole_fraction_water with 0
df_data_glyceline_ratio_or_pure_water_filtered["mole_fraction_water"] = (
    df_data_glyceline_ratio_or_pure_water_filtered["mole_fraction_water"]
    .fillna(0)
    .apply(lambda x: 0 if x is None else x)
)

# Clean for missing values in variables used
plot_df = df_data_glyceline_ratio_or_pure_water_filtered[
    df_data_glyceline_ratio_or_pure_water_filtered["viscosity_value"].notnull() &
    df_data_glyceline_ratio_or_pure_water_filtered["temperature"].notnull() &
    df_data_glyceline_ratio_or_pure_water_filtered["source_doi"].notnull()
].copy()

# Calculate ln(viscosity) and 1/(R*T)
R = 8.314  # J/(mol*K)
plot_df["inv_RT"] = 1 / (R * plot_df["temperature"].astype(float))
plot_df["ln_viscosity"] = np.log(plot_df["viscosity_value"].astype(float)/1000)

# Use mole_fraction_water to color the water amount
plot_df["water_mole_fraction"] = plot_df["mole_fraction_water"].astype(float)

# We'll use unique discrete values for source_doi as hue
unique_dois = np.sort(plot_df["source_doi"].unique())

# Set up beautiful colormap: use a curated set of distinct, pleasant colors
N = len(unique_dois)
# Curated beautiful color palette with distinct, pleasant colors
beautiful_colors = [
    '#ffba08',  # Amber Flame
    '#3185fc',  # Azure Blue
    '#8fe388',  # Light Green
    '#d00000',  # Brick Ember
    '#cbff8c',  # Lime Cream
    '#1b998b',  # Verdigris
    '#5d2e8c',  # Rebecca Purple
    '#46237a',  # Indigo Velvet
    '#ff7b9c',  # Petal Rouge
    '#ff9b85',  # Salmon
]

if N <= len(beautiful_colors):
    color_dict = {doi: beautiful_colors[i] for i, doi in enumerate(unique_dois)}
else:
    # Fall back to seaborn color palette for many DOIs
    colors = sns.color_palette("husl", N)
    color_dict = {doi: colors[i] for i, doi in enumerate(unique_dois)}

plt.figure(figsize=(11,7))
ax = plt.gca()

# Increase font size globally
plt.rcParams.update({'font.size': 14})

# Scatter points for each discrete DOI, so legend can be discrete
for i, doi in enumerate(unique_dois):
    subset = plot_df[plot_df["source_doi"] == doi]
    ax.scatter(
        subset["inv_RT"], 
        subset["ln_viscosity"], 
        color=color_dict[doi],
        s=80, 
        edgecolor='white',
        linewidth=1.5,
        alpha=0.8,
        label=f"{doi}"
    )

# Linear fit and store slopes per discrete water content, including source_doi
slope_results = []
# Round water mole fraction for grouping
plot_df["water_mole_fraction_rounded"] = plot_df["water_mole_fraction"].round(3)
discrete_mole_fractions = np.sort(plot_df["water_mole_fraction_rounded"].unique())

for mf in discrete_mole_fractions:
    group = plot_df[plot_df["water_mole_fraction_rounded"] == mf]
    # For each unique source_doi in this water content, do a fit for that subset
    for doi in group["source_doi"].unique():
        doi_group = group[group["source_doi"] == doi]
        if len(doi_group) >= 2:
            x = doi_group["inv_RT"].values
            y = doi_group["ln_viscosity"].values
            slope, intercept, r_value, p_value, std_err = linregress(x, y)
            xfit = np.linspace(x.min(), x.max(), 50)
            yfit = intercept + slope * xfit
            # Optionally: plot fits per color, commented
            # ax.plot(xfit, yfit, linestyle='--', linewidth=2, color=color_dict[doi])
            mf_tuple = (tuple(doi_group["mole_fractions"].iloc[0]) if "mole_fractions" in doi_group.columns and isinstance(doi_group["mole_fractions"].iloc[0], (list, tuple)) 
                        else doi_group["mole_fractions"].iloc[0] if "mole_fractions" in doi_group.columns else None)
            slope_results.append({
                "mole_fractions": mf_tuple,
                "water_mole_fraction": float(mf),
                "slope": slope,
                "source_doi": doi,
                "ordinate": intercept,
                "statistic": r_value,
                "color": color_dict[doi]
            })

# Create secondary x-axis for temperature
ax2 = ax.twiny()

# Get the range of 1/(R*T) values to create corresponding temperature values
inv_RT_min, inv_RT_max = ax.get_xlim()
T_max = 1 / (R * inv_RT_min)  # Higher temperature corresponds to lower 1/(R*T)
T_min = 1 / (R * inv_RT_max)  # Lower temperature corresponds to higher 1/(R*T)

# Set temperature ticks
temp_ticks = np.linspace(T_min, T_max, 6)  # 6 temperature points
inv_RT_ticks = 1 / (R * temp_ticks)

ax2.set_xlim(ax.get_xlim())
ax2.set_xticks(inv_RT_ticks)
ax2.set_xticklabels([f'{T:.0f}' for T in temp_ticks])
ax2.set_xlabel('Temperature (K)', fontsize=16, color='#2C3E50')

# Make discrete legend without shadow
handles, labels = ax.get_legend_handles_labels()
by_label = dict(zip(labels, handles))
lgd = ax.legend(by_label.values(), by_label.keys(), title="Source DOI", 
               bbox_to_anchor=(1.04, 1), loc='upper left', borderaxespad=0., 
               fontsize=12, frameon=True, fancybox=True, shadow=False)
lgd.get_title().set_fontsize(14)
lgd.get_frame().set_facecolor('white')
lgd.get_frame().set_alpha(1.0)

plt.title('Arrhenius plot of Glyceline with different water mole fractions', 
          fontsize=16, color='#2C3E50', pad=20)
ax.set_xlabel('1 (R*T)$^{-1}$ / mol J$^{-1}$', fontsize=16, color='#2C3E50')
ax.set_ylabel('ln(A) / ln(Pa*s)', fontsize=16, color='#2C3E50')
ax.tick_params(axis='both', which='major', labelsize=12, colors='#34495E')
ax2.tick_params(axis='x', which='major', labelsize=12, colors='#34495E')

# Set white background color
ax.set_facecolor('white')
plt.tight_layout()
plt.show()

import pandas as pd
activation_energy_df = pd.DataFrame(slope_results)
# Rename for clarity
activation_energy_df = activation_energy_df.rename(columns={'slope': 'activation_energy'})
# Ensure 'ordinate' and 'statistic' columns are present (they are, see above)
print("All linear fit activation energies by water mole fraction and source DOI, including ordinate and statistic:")
display(activation_energy_df[["water_mole_fraction", "activation_energy", "source_doi", "ordinate", "statistic", "color"]])

activation_energy_df['measurement'] = 'measured'
activation_energy_df.to_csv('activation_energy_results_measured.csv', index=False)

# Add color mapping to the filtered dataframe
df_data_glyceline_ratio_or_pure_water_filtered['color'] = df_data_glyceline_ratio_or_pure_water_filtered['source_doi'].map(color_dict)

# Add a column called 'measured' and fill it with 'measured'
df_data_glyceline_ratio_or_pure_water_filtered['measured'] = 'measured'

# Save the activation energy data to CSV
df_data_glyceline_ratio_or_pure_water_filtered.to_csv('df_data_glyceline_ratio_or_pure_water.csv', index=False)
print("Saved activation energy data to 'df_data_glyceline_ratio_or_pure_water.csv'")
# Out:
# All linear fit activation energies by water mole fraction and source DOI, including ordinate and statistic:
#     water_mole_fraction  activation_energy                    source_doi  \
# 0                 0.000       46748.108736     10.1016/j.jct.2018.07.031
# 1                 0.000       37401.010918  10.1016/j.molliq.2015.11.032
# 2                 0.000       43647.834764            10.1039/c1cp22554e
# 3                 0.000       45099.537048            10.1039/c0gc00395f
# 4                 0.000       41925.535292   10.1016/j.fluid.2014.01.028
# 5                 0.108       40366.403098   10.1016/j.fluid.2014.01.028
# 6                 0.238       37590.289435   10.1016/j.fluid.2014.01.028
# 7                 0.254       41597.359069     10.1016/j.jct.2018.07.031
# 8                 0.342       34740.693961   10.1016/j.fluid.2014.01.028
# 9                 0.402       33526.414685   10.1016/j.fluid.2014.01.028
# 10                0.598       28874.286184   10.1016/j.fluid.2014.01.028
# 11                0.720       24938.581185   10.1016/j.fluid.2014.01.028
# 12                0.800       22366.546410   10.1016/j.fluid.2014.01.028
# 13                0.857       18893.527986   10.1016/j.fluid.2014.01.028
# 14                0.901       17207.759499   10.1016/j.fluid.2014.01.028
# 15                0.934       16013.872479   10.1016/j.fluid.2014.01.028
# 16                0.960       15546.665223   10.1016/j.fluid.2014.01.028
# 17                0.982       14912.521507   10.1016/j.fluid.2014.01.028
# 18                1.000       13957.939791   10.1016/j.fluid.2014.01.028
#
#      ordinate  statistic    color
# 0  -26.846532   0.998271  #8fe388
# 1  -23.168710   0.996212  #d00000
# 2  -25.906119   0.999017  #5d2e8c
# 3  -26.447968   0.998521  #1b998b
# 4  -24.886946   0.996304  #3185fc
# 5  -24.622199   0.996411  #3185fc
# 6  -23.974194   0.995796  #3185fc
# 7  -25.541719   0.998101  #8fe388
# 8  -23.251774   0.996203  #3185fc
# 9  -23.019817   0.996679  #3185fc
# 10 -22.167398   0.998425  #3185fc
# 11 -21.394706   0.997750  #3185fc
# 12 -20.968165   0.996535  #3185fc
# 13 -20.103317   0.997762  #3185fc
# 14 -19.829755   0.997371  #3185fc
# 15 -19.692201   0.995661  #3185fc
# 16 -19.771642   0.998110  #3185fc
# 17 -19.748993   0.997674  #3185fc
# 18 -19.563329   0.996172  #3185fc
# Saved activation energy data to 'df_data_glyceline_ratio_or_pure_water.csv'

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

# Use the color column directly
colors = activation_energy_df['color']

# Convert activation energy from J/mol to kJ/mol
activation_energy_kJ = activation_energy_df['activation_energy'] / 1000

scatter = plt.scatter(
    activation_energy_df['water_mole_fraction'],
    activation_energy_kJ,
    c=colors,
    s=80,
    edgecolor='w'
)

# Calculate mean activation energy for 0 and 1 water fraction (in kJ/mol)
mean_0_water = activation_energy_df[activation_energy_df['water_mole_fraction'] == 0.0]['activation_energy'].mean() / 1000
mean_1_water = activation_energy_df[activation_energy_df['water_mole_fraction'] == 1.0]['activation_energy'].mean() / 1000

# Add red line between the means
plt.plot([0.0, 1.0], [mean_0_water, mean_1_water], 'r--', linewidth=1, label='Mean trend')

# Make a discrete legend per source_doi using the color column
unique_dois = activation_energy_df['source_doi'].unique()
from matplotlib.patches import Patch
legend_handles = []
for doi in unique_dois:
    # Get the color for this DOI from the first occurrence
    color = activation_energy_df[activation_energy_df['source_doi'] == doi]['color'].iloc[0]
    legend_handles.append(Patch(facecolor=color, edgecolor='k', label=f"{doi}"))

plt.legend(handles=legend_handles, title="Source DOI", bbox_to_anchor=(1.04, 1), loc='upper left', fontsize=10)

plt.xlabel('Water Mole Fraction')
plt.ylabel('Activation Energy / kJ/mol')
plt.title('Activation Energy vs Water Mole Fraction, colored by Source DOI')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(10, 6))

# Separate data for water_mole_fraction == 0 and others
zero_water_data = activation_energy_df[activation_energy_df['water_mole_fraction'] == 0.0]
other_data = activation_energy_df[activation_energy_df['water_mole_fraction'] != 0.0]

# Calculate mean activation energy for zero water content (in kJ/mol)
mean_0_water = zero_water_data['activation_energy'].mean() / 1000
mean_1_water = activation_energy_df[activation_energy_df['water_mole_fraction'] == 1.0]['activation_energy'].mean() / 1000

# Calculate the linear trend line values for each data point
water_fractions = activation_energy_df['water_mole_fraction']
trend_line_values = mean_0_water + (mean_1_water - mean_0_water) * water_fractions

# Calculate residues for all data points
activation_energy_kJ = activation_energy_df['activation_energy'] / 1000
residues = activation_energy_kJ - trend_line_values

# Plot zero water content points individually
zero_water_residues = residues[activation_energy_df['water_mole_fraction'] == 0.0]
plt.scatter(
    zero_water_data['water_mole_fraction'],
    zero_water_residues,
    c=zero_water_data['color'],
    s=80,
    edgecolor='w'
)

# For zero water content, also calculate residue for the mean point
zero_water_residue = mean_0_water - mean_0_water  # This will be 0

# Plot the mean point for zero water content
plt.scatter(
    0.0,
    zero_water_residue,
    c='black',
    s=120,
    edgecolor='w',
    marker='D',
    label='Mean (0% water)'
)

# Plot other data points colored by DOI
scatter = plt.scatter(
    other_data['water_mole_fraction'],
    residues[activation_energy_df['water_mole_fraction'] != 0.0],
    c=other_data['color'],
    s=80,
    edgecolor='w'
)

# Make a discrete legend per source_doi using the color column
unique_dois = activation_energy_df['source_doi'].unique()
from matplotlib.patches import Patch
legend_handles = []
for doi in unique_dois:
    # Get the color for this DOI from the first occurrence
    color = activation_energy_df[activation_energy_df['source_doi'] == doi]['color'].iloc[0]
    legend_handles.append(Patch(facecolor=color, edgecolor='k', label=f"{doi}"))

legend_handles.append(Patch(facecolor='black', edgecolor='k', label='Mean of Activation Energy at $\chi_W = 0$'))

plt.legend(handles=legend_handles, title="Source DOI", bbox_to_anchor=(1.04, 1), loc='upper left', fontsize=10)

plt.xlabel('$\chi_W$ / Water Mole Fraction')
plt.ylabel('$\Delta E_a^{excess}$ / kJ/mol')
plt.tight_layout()
plt.show()
# Out:
# <>:64: SyntaxWarning: invalid escape sequence '\c'
# <>:68: SyntaxWarning: invalid escape sequence '\c'
# <>:69: SyntaxWarning: invalid escape sequence '\D'
# <>:64: SyntaxWarning: invalid escape sequence '\c'
# <>:68: SyntaxWarning: invalid escape sequence '\c'
# <>:69: SyntaxWarning: invalid escape sequence '\D'
# /tmp/ipykernel_7996/3696770201.py:64: SyntaxWarning: invalid escape sequence '\c'
#   legend_handles.append(Patch(facecolor='black', edgecolor='k', label='Mean of Activation Energy at $\chi_W = 0$'))
# /tmp/ipykernel_7996/3696770201.py:68: SyntaxWarning: invalid escape sequence '\c'
#   plt.xlabel('$\chi_W$ / Water Mole Fraction')
# /tmp/ipykernel_7996/3696770201.py:69: SyntaxWarning: invalid escape sequence '\D'
#   plt.ylabel('$\Delta E_a^{excess}$ / kJ/mol')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

# Use the color column directly
colors = activation_energy_df['color']

# Convert activation energy from J/mol to kJ/mol
activation_energy_kJ = activation_energy_df['activation_energy'] / 1000

scatter = plt.scatter(
    activation_energy_df['ordinate'],
    activation_energy_kJ,
    c=colors,
    s=60
)

# Make a discrete legend per source_doi using the color column
unique_dois = activation_energy_df['source_doi'].unique()
from matplotlib.patches import Patch
legend_handles = []
for doi in unique_dois:
    # Get the color for this DOI from the first occurrence
    color = activation_energy_df[activation_energy_df['source_doi'] == doi]['color'].iloc[0]
    legend_handles.append(Patch(facecolor=color, label=f"{doi}"))

plt.legend(handles=legend_handles, title="Source DOI", bbox_to_anchor=(1.04, 1), loc='upper left')

plt.xlabel('ln(As)')
plt.ylabel('Activation Energy / kJ/mol')
plt.title('Activation Energy vs ln(As), colored by Source DOI')
plt.tight_layout()
plt.show()

# %%
activation_energy_df_combined = pd.concat([activation_energy_df, activation_energies_pure], ignore_index=True)
if 'mole_fractions' in activation_energy_df_combined.columns:
    activation_energy_df_combined = activation_energy_df_combined.drop(columns=['mole_fractions'])
activation_energy_df_combined['molar_ratio'] = activation_energy_df_combined['molar_ratio'].fillna(2)
activation_energy_df_combined
# Out:
#     water_mole_fraction  activation_energy                    source_doi  \
# 0                 0.000       46748.108736     10.1016/j.jct.2018.07.031
# 1                 0.000       37401.010918  10.1016/j.molliq.2015.11.032
# 2                 0.000       43647.834764            10.1039/c1cp22554e
# 3                 0.000       45099.537048            10.1039/c0gc00395f
# 4                 0.000       41925.535292   10.1016/j.fluid.2014.01.028
# 5                 0.108       40366.403098   10.1016/j.fluid.2014.01.028
# 6                 0.238       37590.289435   10.1016/j.fluid.2014.01.028
# 7                 0.254       41597.359069     10.1016/j.jct.2018.07.031
# 8                 0.342       34740.693961   10.1016/j.fluid.2014.01.028
# 9                 0.402       33526.414685   10.1016/j.fluid.2014.01.028
# 10                0.598       28874.286184   10.1016/j.fluid.2014.01.028
# 11                0.720       24938.581185   10.1016/j.fluid.2014.01.028
# 12                0.800       22366.546410   10.1016/j.fluid.2014.01.028
# 13                0.857       18893.527986   10.1016/j.fluid.2014.01.028
# 14                0.901       17207.759499   10.1016/j.fluid.2014.01.028
# 15                0.934       16013.872479   10.1016/j.fluid.2014.01.028
# 16                0.960       15546.665223   10.1016/j.fluid.2014.01.028
# 17                0.982       14912.521507   10.1016/j.fluid.2014.01.028
# 18                1.000       13957.939791   10.1016/j.fluid.2014.01.028
# 19                0.000       45502.133942            10.1039/c0gc00395f
# 20                0.000       47045.892294            10.1039/c0gc00395f
# 21                0.000       48304.321208            10.1039/c0gc00395f
# 22                0.000       50296.423067            10.1039/c0gc00395f
# 23                0.000       53401.786797            10.1039/c0gc00395f
# 24                0.000       54772.293625            10.1039/c0gc00395f
#
#      ordinate  statistic    color measurement  molar_ratio
# 0  -26.846532   0.998271  #8fe388    measured          2.0
# 1  -23.168710   0.996212  #d00000    measured          2.0
# 2  -25.906119   0.999017  #5d2e8c    measured          2.0
# 3  -26.447968   0.998521  #1b998b    measured          2.0
# 4  -24.886946   0.996304  #3185fc    measured          2.0
# 5  -24.622199   0.996411  #3185fc    measured          2.0
# 6  -23.974194   0.995796  #3185fc    measured          2.0
# 7  -25.541719   0.998101  #8fe388    measured          2.0
# 8  -23.251774   0.996203  #3185fc    measured          2.0
# 9  -23.019817   0.996679  #3185fc    measured          2.0
# 10 -22.167398   0.998425  #3185fc    measured          2.0
# 11 -21.394706   0.997750  #3185fc    measured          2.0
# 12 -20.968165   0.996535  #3185fc    measured          2.0
# 13 -20.103317   0.997762  #3185fc    measured          2.0
# 14 -19.829755   0.997371  #3185fc    measured          2.0
# 15 -19.692201   0.995661  #3185fc    measured          2.0
# 16 -19.771642   0.998110  #3185fc    measured          2.0
# 17 -19.748993   0.997674  #3185fc    measured          2.0
# 18 -19.563329   0.996172  #3185fc    measured          2.0
# 19 -19.587819   0.999903      NaN         NaN          2.3
# 20 -20.124261   0.999625      NaN         NaN          3.0
# 21 -20.543573   0.997493      NaN         NaN          4.0
# 22 -21.256798   0.999803      NaN         NaN          5.7
# 23 -22.208433   0.999157      NaN         NaN          9.0
# 24 -22.513597   0.999573      NaN         NaN         19.0

# %%
fig, ax = plt.subplots(figsize=(13, 6))  # Increase width for full legends

# Map color by 'source_doi'
unique_dois = activation_energy_df_combined['source_doi'].unique()
doi_to_color = {doi: plt.cm.tab10(i % 10) for i, doi in enumerate(unique_dois)}
colors = activation_energy_df_combined['source_doi'].map(doi_to_color)

# Make marker size dependent on molar_ratio (e.g., scale for readability)
sizes = activation_energy_df_combined['molar_ratio'].fillna(2) * 10  # adjust scale factor as needed

# Convert activation energy from J/mol to kJ/mol for plotting
activation_energy_kJ = activation_energy_df_combined["activation_energy"] / 1000

sc = ax.scatter(
    activation_energy_df_combined["water_mole_fraction"],
    activation_energy_kJ,
    c=colors,
    s=sizes,
    alpha=0.8,
    edgecolor='k'
)

# --- Add the red dashed thin line for molar_ratio == 2 and water_mole_fraction 0, 1 ---
df_mr2 = activation_energy_df_combined[activation_energy_df_combined['molar_ratio'] == 2]
wmf_1 = df_mr2[df_mr2['water_mole_fraction'] == 1.0]
wmf_0 = df_mr2[df_mr2['water_mole_fraction'] == 0.0]

if not wmf_1.empty and not wmf_0.empty:
    # Use the mean of activation_energy at wmf==0 (for molar_ratio==2); draw from (0, mean) to (1, val)
    y0_mean = wmf_0['activation_energy'].mean() / 1000  # Convert to kJ/mol
    y1 = wmf_1['activation_energy'].values[0] / 1000  # Convert to kJ/mol
    ax.plot([0, 1], [y0_mean, y1], color='red', linewidth=1, linestyle='--', label='0→1 Red Line (molar_ratio=2)')

from matplotlib.lines import Line2D

# Custom legend for source_doi
legend_elements = [
    Line2D([0], [0], marker='o', color='w', label=str(doi),
           markerfacecolor=doi_to_color[doi], markeredgecolor='k', markersize=10)
    for doi in unique_dois
]
# Add a legend entry for the red line (dashed, no marker, thinner)
legend_elements.append(Line2D([0], [0], color='red', linestyle='--', label="Ideal Mixing\n(molar_ratio=2)", linewidth=1))
legend1 = ax.legend(handles=legend_elements, title="Source DOI", bbox_to_anchor=(1.04, 1), loc="upper left", borderaxespad=0.5, frameon=True)

# New legend for marker size explanation
import numpy as np
molar_ratios_legend = [2, 5, 10, 20]
size_handles = [
    Line2D([0],[0], marker='o', color='w', label=f'molar_ratio={mr}', 
           markerfacecolor='grey', markeredgecolor='k', markersize=np.sqrt(mr*10)) for mr in molar_ratios_legend
]
legend2 = ax.legend(handles=size_handles, bbox_to_anchor=(1.25, 0.47), loc="upper left", title="Marker Size: Molar Ratio", borderaxespad=0.5, frameon=True)

ax.add_artist(legend1)  # ensure first legend shows up

ax.set_xlabel("Water Mole Fraction")
ax.set_ylabel("Activation Energy $E_a$ [kJ/mol]")
ax.set_title("Activation Energy vs Water Mole Fraction (Combined)")
plt.tight_layout(rect=[0,0,0.88,1])  # leave extra right margin for legends
plt.show()

# %%
# Apply the activation energy calculation logic from Cell 11 (lines 1-97) 
# to the data from Cell 15/16 (lines 1-186)
# This splits the data by temperature groups and calculates activation energies

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Use the plot_df from Cell 15/16 (or recreate it if needed)
# Make sure we have the filtered data with inv_RT and ln_viscosity calculated
if 'plot_df' not in locals() and 'plot_df' not in globals():
    # Recreate plot_df from df_data_glyceline_ratio_or_pure_water_filtered if it exists
    if 'df_data_glyceline_ratio_or_pure_water_filtered' in locals() or 'df_data_glyceline_ratio_or_pure_water_filtered' in globals():
        plot_df = df_data_glyceline_ratio_or_pure_water_filtered[
            df_data_glyceline_ratio_or_pure_water_filtered["viscosity_value"].notnull() &
            df_data_glyceline_ratio_or_pure_water_filtered["temperature"].notnull() &
            df_data_glyceline_ratio_or_pure_water_filtered["source_doi"].notnull()
        ].copy()
        
        R = 8.314  # J/(mol*K)
        plot_df["inv_RT"] = 1 / (R * plot_df["temperature"].astype(float))
        plot_df["ln_viscosity"] = np.log(plot_df["viscosity_value"].astype(float)/1000)
    else:
        raise ValueError("plot_df or df_data_glyceline_ratio_or_pure_water_filtered not found. Please run Cell 15/16 first.")

# Create a composition identifier from mole_fractions for grouping
# Convert mole_fractions to tuple for grouping (if it's a list/tuple)
def get_composition_key(mf):
    """Convert mole_fractions to a hashable tuple for grouping."""
    if isinstance(mf, (list, tuple)):
        # Round to 3 decimal places for grouping similar compositions
        return tuple(round(x, 3) for x in mf)
    elif pd.isna(mf):
        return None
    else:
        return (round(float(mf), 3),)

plot_df = plot_df.copy()
plot_df['composition_key'] = plot_df['mole_fractions'].apply(get_composition_key)

# Get unique combinations of DOI and composition
doi_composition_combinations = plot_df[
    plot_df['composition_key'].notna() &
    plot_df['source_doi'].notna() &
    (~plot_df["inv_RT"].isna()) &
    (~plot_df["ln_viscosity"].isna())
][['source_doi', 'composition_key']].drop_duplicates()

# List to store all split data
split_data = []

# Process each valid DOI-composition combination - split into temperature groups (High T and Low T)
for _, row in doi_composition_combinations.iterrows():
    doi = row['source_doi']
    comp_key = row['composition_key']
    
    subset = plot_df[
        (plot_df["source_doi"] == doi) &
        (plot_df["composition_key"] == comp_key) &
        (~plot_df["inv_RT"].isna()) &
        (~plot_df["ln_viscosity"].isna())
    ]
    
    if len(subset) < 2:
        continue  # Not enough points to split
    
    # Sort by temperature (inverse of inv_RT for proper ordering)
    subset_sorted = subset.sort_values('inv_RT')
    
    # Split into two halves based on temperature
    n_points = len(subset_sorted)
    mid_point = n_points // 2
    
    # Lower half (higher temperatures - lower inv_RT values)
    low_temp_group = subset_sorted.iloc[:mid_point].copy()
    low_temp_group['temperature_group'] = 'High T'
    
    # Upper half (lower temperatures - higher inv_RT values)  
    high_temp_group = subset_sorted.iloc[mid_point:].copy()
    high_temp_group['temperature_group'] = 'Low T'
    
    # Add to split_data list
    split_data.append(low_temp_group)
    split_data.append(high_temp_group)

# Combine all split data into a single DataFrame
split_points_df = pd.concat(split_data, ignore_index=True)

print(f"Split points DataFrame shape: {split_points_df.shape}")
print("\nTemperature group distribution:")
print(split_points_df['temperature_group'].value_counts())
display(split_points_df.head(10))

# Now apply the activation energy calculation logic from Cell 11
R = 8.314462618  # J/mol/K (universal gas constant)

group_activation_energies = []

# Get unique combinations of DOI, composition, and temperature group
doi_comp_temp_combinations = split_points_df[['source_doi', 'composition_key', 'temperature_group']].drop_duplicates()

for _, row in doi_comp_temp_combinations.iterrows():
    doi = row['source_doi']
    comp_key = row['composition_key']
    temp_group = row['temperature_group']
    
    subset = split_points_df[
        (split_points_df['source_doi'] == doi) & 
        (split_points_df['composition_key'] == comp_key) &
        (split_points_df['temperature_group'] == temp_group)
    ]
    
    if len(subset) < 2:
        continue  # Not enough points to fit
    
    # Calculate temperature range for this subset
    temp_min = subset['temperature'].min()
    temp_max = subset['temperature'].max()
    temp_range = f"{temp_min:.0f}-{temp_max:.0f}"
    
    # Fit: ln(viscosity) = slope * inv_RT + intercept
    x = subset["inv_RT"].values
    y = subset["ln_viscosity"].values
    
    # np.polyfit returns [slope, intercept]
    slope, intercept = np.polyfit(x, y, 1)
    E_a = slope * R  # activation energy in J/mol
    
    # Calculate R-squared for goodness of fit
    y_pred = slope * x + intercept
    ss_res = np.sum((y - y_pred) ** 2)
    ss_tot = np.sum((y - np.mean(y)) ** 2)
    r_squared = 1 - (ss_res / ss_tot)
    
    group_activation_energies.append({
        "source_doi": doi,
        "composition_key": comp_key,
        "temperature_group": temp_group,
        "temperature_range": temp_range,
        "activation_energy_J_per_mol": E_a,
        "arrhenius_prefactor_lnA": intercept,
        "r_squared": r_squared,
        "n_points": len(subset)
    })

# Also calculate activation energy for full temperature range for each DOI-composition combination
doi_comp_combinations = split_points_df[['source_doi', 'composition_key']].drop_duplicates()

for _, row in doi_comp_combinations.iterrows():
    doi = row['source_doi']
    comp_key = row['composition_key']
    subset = split_points_df[
        (split_points_df['source_doi'] == doi) &
        (split_points_df['composition_key'] == comp_key)
    ]
    
    if len(subset) < 2:
        continue  # Not enough points to fit
    
    # Calculate temperature range for this subset
    temp_min = subset['temperature'].min()
    temp_max = subset['temperature'].max()
    temp_range = f"{temp_min:.0f}-{temp_max:.0f}"
    
    # Fit: ln(viscosity) = slope * inv_RT + intercept
    x = subset["inv_RT"].values
    y = subset["ln_viscosity"].values
    
    # np.polyfit returns [slope, intercept]
    slope, intercept = np.polyfit(x, y, 1)
    E_a = slope * R  # activation energy in J/mol
    
    # Calculate R-squared for goodness of fit
    y_pred = slope * x + intercept
    ss_res = np.sum((y - y_pred) ** 2)
    ss_tot = np.sum((y - np.mean(y)) ** 2)
    r_squared = 1 - (ss_res / ss_tot)
    
    group_activation_energies.append({
        "source_doi": doi,
        "composition_key": comp_key,
        "temperature_group": "Full Range",
        "temperature_range": temp_range,
        "activation_energy_J_per_mol": E_a,
        "arrhenius_prefactor_lnA": intercept,
        "r_squared": r_squared,
        "n_points": len(subset)
    })

# Convert to DataFrame for summary display
group_activation_energy_df = pd.DataFrame(group_activation_energies)

print("\nActivation energies (E_a) and Arrhenius prefactor by DOI and temperature group:")
display(group_activation_energy_df)
# Out:
# Split points DataFrame shape: (203, 26)
#
# Temperature group distribution:
# temperature_group
# Low T     110
# High T     93
# Name: count, dtype: int64
#                        fluid_compounds property_type  property_value  \
# 0                              [Water]     viscosity        0.000331
# 1                              [Water]     viscosity        0.000386
# 2                              [Water]     viscosity        0.000435
# 3                              [Water]     viscosity        0.000477
# 4                              [Water]     viscosity        0.000549
# 5                              [Water]     viscosity        0.000649
# 6                              [Water]     viscosity        0.000791
# 7                              [Water]     viscosity        0.000984
# 8                              [Water]     viscosity        0.001274
# 9  [Choline Chloride, Glycerol, Water]     viscosity        0.000386
#
#    uncertainty  temperature                            mole_fractions  \
# 0     0.000002       363.15                                     [1.0]
# 1     0.000002       353.15                                     [1.0]
# 2     0.000002       343.15                                     [1.0]
# 3     0.000002       333.15                                     [1.0]
# 4     0.000003       323.15                                     [1.0]
# 5     0.000003       313.15                                     [1.0]
# 6     0.000004       303.15                                     [1.0]
# 7     0.000005       293.15                                     [1.0]
# 8     0.000006       283.15                                     [1.0]
# 9     0.000002       363.15  [0.006033333333, 0.012066666667, 0.9819]
#
#                          measurement_id                   source_doi  \
# 0  04303413-6bb9-42ac-b6fc-7719729a8fdc  10.1016/j.fluid.2014.01.028
# 1  13ff5c56-ea5e-4abd-ad7b-89afe6e6b1f5  10.1016/j.fluid.2014.01.028
# 2  ef092765-8fd3-4441-bc29-853b72e79d44  10.1016/j.fluid.2014.01.028
# 3  0b84e36d-ec7c-4fb1-8495-be4fa84ad99e  10.1016/j.fluid.2014.01.028
# 4  25cf85fb-f720-45b8-9488-7b8f57112fc5  10.1016/j.fluid.2014.01.028
# 5  f0162dfb-0d87-4c95-8321-988db358ce05  10.1016/j.fluid.2014.01.028
# 6  875bd6be-feb0-4169-987f-74fcaa03800b  10.1016/j.fluid.2014.01.028
# 7  15066af3-838d-4b8e-b80c-bc9ab630296a  10.1016/j.fluid.2014.01.028
# 8  5546497f-309a-44a8-8fe3-f367ffbeff24  10.1016/j.fluid.2014.01.028
# 9  7a0bdad8-c31f-425e-9062-dcd8aeaba518  10.1016/j.fluid.2014.01.028
#
#    Mole fraction  Temperature  ...  \
# 0         1.0000       363.15  ...
# 1         1.0000       353.15  ...
# 2         1.0000       343.15  ...
# 3         1.0000       333.15  ...
# 4         1.0000       323.15  ...
# 5         1.0000       313.15  ...
# 6         1.0000       303.15  ...
# 7         1.0000       293.15  ...
# 8         1.0000       283.15  ...
# 9         0.9819       363.15  ...
#
#                                  composition_temp_id viscosity_value  \
# 0  ((Water,), 363.15, 04303413-6bb9-42ac-b6fc-771...        0.000331
# 1  ((Water,), 353.15, 13ff5c56-ea5e-4abd-ad7b-89a...        0.000386
# 2  ((Water,), 343.15, ef092765-8fd3-4441-bc29-853...        0.000435
# 3  ((Water,), 333.15, 0b84e36d-ec7c-4fb1-8495-be4...        0.000477
# 4  ((Water,), 323.15, 25cf85fb-f720-45b8-9488-7b8...        0.000549
# 5  ((Water,), 313.15, f0162dfb-0d87-4c95-8321-988...        0.000649
# 6  ((Water,), 303.15, 875bd6be-feb0-4169-987f-74f...        0.000791
# 7  ((Water,), 293.15, 15066af3-838d-4b8e-b80c-bc9...        0.000984
# 8  ((Water,), 283.15, 5546497f-309a-44a8-8fe3-f36...        0.001274
# 9  ((Choline Chloride, Glycerol, Water), 363.15, ...        0.000386
#
#   viscosity_uncertainty  mole_fraction_water    inv_RT  ln_viscosity  \
# 0              0.000002               1.0000  0.000331    -14.922357
# 1              0.000002               1.0000  0.000341    -14.767428
# 2              0.000002               1.0000  0.000351    -14.647001
# 3              0.000002               1.0000  0.000361    -14.555749
# 4              0.000003               1.0000  0.000372    -14.415714
# 5              0.000003               1.0000  0.000384    -14.247525
# 6              0.000004               1.0000  0.000397    -14.049462
# 7              0.000005               1.0000  0.000410    -13.832047
# 8              0.000006               1.0000  0.000425    -13.573427
# 9              0.000002               0.9819  0.000331    -14.766910
#
#   water_mole_fraction water_mole_fraction_rounded        composition_key  \
# 0              1.0000                       1.000                 (1.0,)
# 1              1.0000                       1.000                 (1.0,)
# 2              1.0000                       1.000                 (1.0,)
# 3              1.0000                       1.000                 (1.0,)
# 4              1.0000                       1.000                 (1.0,)
# 5              1.0000                       1.000                 (1.0,)
# 6              1.0000                       1.000                 (1.0,)
# 7              1.0000                       1.000                 (1.0,)
# 8              1.0000                       1.000                 (1.0,)
# 9              0.9819                       0.982  (0.006, 0.012, 0.982)
#
#    temperature_group
# 0             High T
# 1             High T
# 2             High T
# 3             High T
# 4              Low T
# 5              Low T
# 6              Low T
# 7              Low T
# 8              Low T
# 9             High T
#
# [10 rows x 26 columns]
# Activation energies (E_a) and Arrhenius prefactor by DOI and temperature group:
#                       source_doi        composition_key temperature_group  \
# 0    10.1016/j.fluid.2014.01.028                 (1.0,)            High T
# 1    10.1016/j.fluid.2014.01.028                 (1.0,)             Low T
# 2    10.1016/j.fluid.2014.01.028  (0.006, 0.012, 0.982)            High T
# 3    10.1016/j.fluid.2014.01.028  (0.006, 0.012, 0.982)             Low T
# 4    10.1016/j.fluid.2014.01.028   (0.013, 0.027, 0.96)            High T
# 5    10.1016/j.fluid.2014.01.028   (0.013, 0.027, 0.96)             Low T
# 6    10.1016/j.fluid.2014.01.028  (0.022, 0.044, 0.933)            High T
# 7    10.1016/j.fluid.2014.01.028  (0.022, 0.044, 0.933)             Low T
# 8    10.1016/j.fluid.2014.01.028  (0.033, 0.066, 0.901)            High T
# 9    10.1016/j.fluid.2014.01.028  (0.033, 0.066, 0.901)             Low T
# 10   10.1016/j.fluid.2014.01.028  (0.048, 0.095, 0.857)            High T
# 11   10.1016/j.fluid.2014.01.028  (0.048, 0.095, 0.857)             Low T
# 12   10.1016/j.fluid.2014.01.028    (0.067, 0.134, 0.8)            High T
# 13   10.1016/j.fluid.2014.01.028    (0.067, 0.134, 0.8)             Low T
# 14   10.1016/j.fluid.2014.01.028   (0.093, 0.187, 0.72)            High T
# 15   10.1016/j.fluid.2014.01.028   (0.093, 0.187, 0.72)             Low T
# 16   10.1016/j.fluid.2014.01.028  (0.134, 0.268, 0.598)            High T
# 17   10.1016/j.fluid.2014.01.028  (0.134, 0.268, 0.598)             Low T
# 18   10.1016/j.fluid.2014.01.028  (0.199, 0.399, 0.402)            High T
# 19   10.1016/j.fluid.2014.01.028  (0.199, 0.399, 0.402)             Low T
# 20   10.1016/j.fluid.2014.01.028  (0.219, 0.438, 0.343)            High T
# 21   10.1016/j.fluid.2014.01.028  (0.219, 0.438, 0.343)             Low T
# 22     10.1016/j.jct.2018.07.031  (0.249, 0.496, 0.254)            High T
# 23     10.1016/j.jct.2018.07.031  (0.249, 0.496, 0.254)             Low T
# 24   10.1016/j.fluid.2014.01.028  (0.254, 0.508, 0.238)            High T
# 25   10.1016/j.fluid.2014.01.028  (0.254, 0.508, 0.238)             Low T
# 26   10.1016/j.fluid.2014.01.028  (0.297, 0.595, 0.108)            High T
# 27   10.1016/j.fluid.2014.01.028  (0.297, 0.595, 0.108)             Low T
# 28     10.1016/j.jct.2018.07.031         (0.333, 0.667)            High T
# 29     10.1016/j.jct.2018.07.031         (0.333, 0.667)             Low T
# 30  10.1016/j.molliq.2015.11.032         (0.333, 0.667)            High T
# 31  10.1016/j.molliq.2015.11.032         (0.333, 0.667)             Low T
# 32            10.1039/c1cp22554e         (0.333, 0.667)            High T
# 33            10.1039/c1cp22554e         (0.333, 0.667)             Low T
# 34            10.1039/c0gc00395f         (0.333, 0.667)            High T
# 35            10.1039/c0gc00395f         (0.333, 0.667)             Low T
# 36   10.1016/j.fluid.2014.01.028         (0.333, 0.667)            High T
# 37   10.1016/j.fluid.2014.01.028         (0.333, 0.667)             Low T
# 38   10.1016/j.fluid.2014.01.028                 (1.0,)        Full Range
# 39   10.1016/j.fluid.2014.01.028  (0.006, 0.012, 0.982)        Full Range
# 40   10.1016/j.fluid.2014.01.028   (0.013, 0.027, 0.96)        Full Range
# 41   10.1016/j.fluid.2014.01.028  (0.022, 0.044, 0.933)        Full Range
# 42   10.1016/j.fluid.2014.01.028  (0.033, 0.066, 0.901)        Full Range
# 43   10.1016/j.fluid.2014.01.028  (0.048, 0.095, 0.857)        Full Range
# 44   10.1016/j.fluid.2014.01.028    (0.067, 0.134, 0.8)        Full Range
# 45   10.1016/j.fluid.2014.01.028   (0.093, 0.187, 0.72)        Full Range
# 46   10.1016/j.fluid.2014.01.028  (0.134, 0.268, 0.598)        Full Range
# 47   10.1016/j.fluid.2014.01.028  (0.199, 0.399, 0.402)        Full Range
# 48   10.1016/j.fluid.2014.01.028  (0.219, 0.438, 0.343)        Full Range
# 49     10.1016/j.jct.2018.07.031  (0.249, 0.496, 0.254)        Full Range
# 50   10.1016/j.fluid.2014.01.028  (0.254, 0.508, 0.238)        Full Range
# 51   10.1016/j.fluid.2014.01.028  (0.297, 0.595, 0.108)        Full Range
# 52     10.1016/j.jct.2018.07.031         (0.333, 0.667)        Full Range
# 53  10.1016/j.molliq.2015.11.032         (0.333, 0.667)        Full Range
# 54            10.1039/c1cp22554e         (0.333, 0.667)        Full Range
# 55            10.1039/c0gc00395f         (0.333, 0.667)        Full Range
# 56   10.1016/j.fluid.2014.01.028         (0.333, 0.667)        Full Range
#
#    temperature_range  activation_energy_J_per_mol  arrhenius_prefactor_lnA  \
# 0            333-363                101695.136754               -18.953111
# 1            283-323                133132.417941               -20.390559
# 2            333-363                105119.756356               -18.955922
# 3            283-323                137545.277392               -20.403829
# 4            333-363                114367.397427               -19.143367
# 5            283-323                142224.808230               -20.398552
# 6            333-363                 99792.999151               -18.297748
# 7            283-323                149777.367780               -20.493235
# 8            333-363                118438.775165               -18.795659
# 9            283-323                159518.939645               -20.623797
# 10           333-363                132925.025838               -19.088292
# 11           283-323                173877.421576               -20.914108
# 12           333-363                151250.892043               -19.508936
# 13           283-323                211117.252600               -22.183226
# 14           333-363                170335.978045               -19.843770
# 15           283-323                229212.013338               -22.449241
# 16           333-363                208204.553583               -20.832521
# 17           283-323                258428.841940               -23.052607
# 18           333-363                230877.698525               -21.004683
# 19           283-323                316097.429152               -24.824707
# 20           333-363                232105.481004               -20.867058
# 21           283-323                329435.944320               -25.212296
# 22           311-338                301300.469121               -23.545124
# 23           278-308                383539.127214               -27.410501
# 24           333-363                252286.238248               -21.438635
# 25           283-323                358875.721970               -26.213364
# 26           333-363                264528.538656               -21.640839
# 27           283-323                380006.817022               -26.764020
# 28           311-338                341482.325215               -24.731097
# 29           278-308                429262.201796               -28.859227
# 30           328-353                246465.431804               -20.433029
# 31           298-323                338645.258291               -24.452841
# 32           318-328                328528.652847               -24.359436
# 33           298-313                391038.205495               -27.243596
# 34           313-328                330717.556990               -24.450184
# 35           293-308                410422.012304               -28.154312
# 36           333-363                281692.449895               -22.073655
# 37           283-323                398398.132053               -27.293675
# 38           283-363                116052.768618               -19.563329
# 39           283-363                123989.602614               -19.748993
# 40           283-363                129262.166830               -19.771642
# 41           283-363                133146.744099               -19.692201
# 42           283-363                143073.273096               -19.829755
# 43           283-363                157089.532165               -20.103317
# 44           283-363                185965.814018               -20.968165
# 45           283-363                207350.901005               -21.394706
# 46           283-363                240074.173100               -22.167398
# 47           283-363                278754.121612               -23.019817
# 48           283-363                288850.201259               -23.251774
# 49           278-338                345859.686986               -25.541719
# 50           283-363                312543.056303               -23.974194
# 51           283-363                335624.949584               -24.622199
# 52           278-338                388685.402546               -26.846532
# 53           298-353                310969.307155               -23.168710
# 54           298-328                362908.290504               -25.906119
# 55           293-328                374978.414878               -26.447968
# 56           283-363                348588.295926               -24.886946
#
#     r_squared  n_points
# 0    0.979997         4
# 1    0.998242         5
# 2    0.998417         4
# 3    0.998425         5
# 4    0.998282         4
# 5    0.998025         5
# 6    0.970668         4
# 7    0.998321         5
# 8    0.998875         4
# 9    0.998529         5
# 10   0.999440         4
# 11   0.998520         5
# 12   0.999648         4
# 13   0.997896         5
# 14   0.999579         4
# 15   0.999828         5
# 16   0.996061         4
# 17   0.997602         5
# 18   0.999521         4
# 19   0.997636         5
# 20   0.999297         4
# 21   0.997555         5
# 22   0.999275        12
# 23   0.998958        13
# 24   0.999396         4
# 25   0.996352         5
# 26   0.998983         4
# 27   0.998302         5
# 28   0.999330        12
# 29   0.998993        13
# 30   0.975107         6
# 31   0.997972         6
# 32   0.998239         3
# 33   0.999912         4
# 34   0.999304         4
# 35   0.998481         4
# 36   0.999022         4
# 37   0.998612         5
# 38   0.992359         9
# 39   0.995354         9
# 40   0.996224         9
# 41   0.991342         9
# 42   0.994749         9
# 43   0.995529         9
# 44   0.993082         9
# 45   0.995505         9
# 46   0.996852         9
# 47   0.993368         9
# 48   0.992421         9
# 49   0.996206        25
# 50   0.991610         9
# 51   0.992835         9
# 52   0.996546        25
# 53   0.992438        12
# 54   0.998036         7
# 55   0.997044         8
# 56   0.992622         9

# %%
# Plot activation_energy_J_per_mol vs arrhenius_prefactor_lnA from group_activation_energy_df
# Color by temperature group with regression lines
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress

# Check if group_activation_energy_df exists
if 'group_activation_energy_df' not in locals() and 'group_activation_energy_df' not in globals():
    raise ValueError("group_activation_energy_df not found. Please run the previous cell first.")

# Create the plot
fig, ax = plt.subplots(figsize=(10, 7))

# Get unique temperature groups for coloring
temp_groups = group_activation_energy_df['temperature_group'].unique()
colors_map = {'High T': '#E74C3C', 'Low T': '#3498DB', 'Full Range': '#2ECC71'}
markers_map = {'High T': 'o', 'Low T': 's', 'Full Range': '^'}

# Plot each temperature group with different colors and markers
for temp_group in temp_groups:
    subset = group_activation_energy_df[group_activation_energy_df['temperature_group'] == temp_group]
    if len(subset) > 0:
        ax.scatter(
            subset['arrhenius_prefactor_lnA'],
            subset['activation_energy_J_per_mol'],
            c=colors_map.get(temp_group, '#95A5A6'),
            marker=markers_map.get(temp_group, 'o'),
            s=100,
            alpha=0.7,
            edgecolor='black',
            linewidth=1,
            label=temp_group
        )

# Add regression lines for each temperature group
for temp_group in temp_groups:
    subset = group_activation_energy_df[group_activation_energy_df['temperature_group'] == temp_group]
    
    if len(subset) >= 2:
        x = subset['arrhenius_prefactor_lnA'].values
        y = subset['activation_energy_J_per_mol'].values
        
        # Perform linear regression
        slope, intercept, r_value, p_value, std_err = linregress(x, y)
        
        # Create x values for the regression line
        x_line = np.linspace(x.min(), x.max(), 100)
        y_line = slope * x_line + intercept
        
        # Plot regression line with same color as the scatter points
        ax.plot(x_line, y_line, 
               linestyle='-',
               linewidth=2.5,
               color=colors_map.get(temp_group, '#95A5A6'),
               alpha=0.8,
               label=f'{temp_group} fit (R²={r_value**2:.3f})')

# Customize the plot
ax.set_xlabel('Arrhenius Prefactor ln(As) / ln(Pa·s)', fontsize=14)
ax.set_ylabel('Activation Energy $E_a$ / kJ/mol', fontsize=14)
ax.set_title('Activation Energy vs Arrhenius Prefactor\nby Temperature Group (with Regression Lines)', 
             fontsize=16, fontweight='bold')
ax.legend(title='Temperature Group', fontsize=12, frameon=True, fancybox=True, shadow=True)
ax.grid(True, alpha=0.3, linestyle='--')

# Format y-axis to show values in scientific notation if needed
ax.ticklabel_format(style='scientific', axis='y', scilimits=(0,0))

# Increase tick label font size
ax.tick_params(axis='both', which='major', labelsize=12)

plt.tight_layout()
plt.show()

# Display summary statistics and regression statistics
print("\nSummary Statistics by Temperature Group:")
print("=" * 70)
for temp_group in temp_groups:
    subset = group_activation_energy_df[group_activation_energy_df['temperature_group'] == temp_group]
    if len(subset) > 0:
        print(f"\n{temp_group}:")
        print(f"  Number of data points: {len(subset)}")
        print(f"  Activation Energy - Mean: {subset['activation_energy_J_per_mol'].mean():.2e} J/mol")
        print(f"  Activation Energy - Std: {subset['activation_energy_J_per_mol'].std():.2e} J/mol")
        print(f"  Arrhenius Prefactor - Mean: {subset['arrhenius_prefactor_lnA'].mean():.2f}")
        print(f"  Arrhenius Prefactor - Std: {subset['arrhenius_prefactor_lnA'].std():.2f}")
        
        # Regression statistics
        if len(subset) >= 2:
            x = subset['arrhenius_prefactor_lnA'].values
            y = subset['activation_energy_J_per_mol'].values
            slope, intercept, r_value, p_value, std_err = linregress(x, y)
            print(f"  Regression - Slope: {slope:.2e}")
            print(f"  Regression - Intercept: {intercept:.2f}")
            print(f"  Regression - R²: {r_value**2:.4f}")
            print(f"  Regression - P-value: {p_value:.4e}")
            print(f"  Regression - Std error: {std_err:.2e}")
# Out:
# Summary Statistics by Temperature Group:
# ======================================================================
#
# High T:
#   Number of data points: 19
#   Activation Energy - Mean: 2.11e+05 J/mol
#   Activation Energy - Std: 8.49e+04 J/mol
#   Arrhenius Prefactor - Mean: -20.95
#   Arrhenius Prefactor - Std: 2.07
#   Regression - Slope: -3.96e+04
#   Regression - Intercept: -617473.74
#   Regression - R²: 0.9270
#   Regression - P-value: 4.3067e-11
#   Regression - Std error: 2.69e+03
#
# Low T:
#   Number of data points: 19
#   Activation Energy - Mean: 2.81e+05 J/mol
#   Activation Energy - Std: 1.08e+05 J/mol
#   Arrhenius Prefactor - Mean: -24.07
#   Arrhenius Prefactor - Std: 3.05
#   Regression - Slope: -3.52e+04
#   Regression - Intercept: -566350.98
#   Regression - R²: 0.9817
#   Regression - P-value: 3.3054e-16
#   Regression - Std error: 1.17e+03
#
# Full Range:
#   Number of data points: 19
#   Activation Energy - Mean: 2.52e+05 J/mol
#   Activation Energy - Std: 9.77e+04 J/mol
#   Arrhenius Prefactor - Mean: -22.68
#   Arrhenius Prefactor - Std: 2.54
#   Regression - Slope: -3.79e+04
#   Regression - Intercept: -608001.03
#   Regression - R²: 0.9737
#   Regression - P-value: 7.1408e-15
#   Regression - Std error: 1.51e+03

# %%
# Plot activation_energy_J_per_mol vs arrhenius_prefactor_lnA
# Color by DOI, shape by temperature group (High T, Low T, Full Range)
import matplotlib.pyplot as plt
import numpy as np

# Check if group_activation_energy_df exists
if 'group_activation_energy_df' not in locals() and 'group_activation_energy_df' not in globals():
    raise ValueError("group_activation_energy_df not found. Please run the previous cell first.")

# Create the plot
fig, ax = plt.subplots(figsize=(12, 8))

# Get unique DOIs for coloring
unique_dois = group_activation_energy_df['source_doi'].unique()
n_dois = len(unique_dois)

# Use consistent colors from the previous cell/analysis
# These colors match the activation_energy_df color mapping
doi_color_map = {
    '10.1016/j.jct.2018.07.031': '#8fe388',
    '10.1016/j.molliq.2015.11.032': '#d00000',
    '10.1039/c1cp22554e': '#5d2e8c',
    '10.1039/c0gc00395f': '#1b998b',
    '10.1016/j.fluid.2014.01.028': '#3185fc'
}

# For any DOIs not in the predefined map, use a default color scheme
default_colors = plt.cm.tab20(np.linspace(0, 1, 20))
for i, doi in enumerate(unique_dois):
    if doi not in doi_color_map:
        # Use a default color if not in the predefined map
        doi_color_map[doi] = default_colors[i % len(default_colors)]

# Define markers for temperature groups
marker_map = {
    'High T': 'o',      # circle
    'Low T': 's',       # square
    'Full Range': '^'    # triangle
}

# Plot each combination
for temp_group in ['High T', 'Low T', 'Full Range']:
    if temp_group not in group_activation_energy_df['temperature_group'].values:
        continue
    
    subset = group_activation_energy_df[group_activation_energy_df['temperature_group'] == temp_group]
    
    for _, row in subset.iterrows():
        doi = row['source_doi']
        ax.scatter(
            row['arrhenius_prefactor_lnA'],
            row['activation_energy_J_per_mol'],
            c=[doi_color_map[doi]],
            marker=marker_map[temp_group],
            s=120,
            alpha=0.7,
            edgecolor='black',
            linewidth=1.2,
            label=None  # We'll create custom legend
        )

# Create custom legend
from matplotlib.patches import Patch
from matplotlib.lines import Line2D

# Legend for DOIs (colors)
doi_legend_elements = [
    Patch(facecolor=doi_color_map[doi], edgecolor='black', label=doi)
    for doi in unique_dois
]

# Legend for temperature groups (markers)
temp_legend_elements = [
    Line2D([0], [0], marker=marker_map['High T'], color='w', 
           markerfacecolor='gray', markeredgecolor='black', 
           markersize=12, label='High T', linestyle='None'),
    Line2D([0], [0], marker=marker_map['Low T'], color='w', 
           markerfacecolor='gray', markeredgecolor='black', 
           markersize=12, label='Low T', linestyle='None'),
    Line2D([0], [0], marker=marker_map['Full Range'], color='w', 
           markerfacecolor='gray', markeredgecolor='black', 
           markersize=12, label='Full Range', linestyle='None')
]

# Create two separate legends
legend1 = ax.legend(handles=doi_legend_elements, title='Source DOI', 
                   bbox_to_anchor=(1.02, 1), loc='upper left', 
                   fontsize=10, frameon=True, fancybox=True, shadow=True)
legend1.get_frame().set_facecolor('white')

legend2 = ax.legend(handles=temp_legend_elements, title='Temperature Group', 
                   bbox_to_anchor=(1.02, 0.3), loc='upper left', 
                   fontsize=12, frameon=True, fancybox=True, shadow=True)
legend2.get_frame().set_facecolor('white')

# Add the first legend back (matplotlib only keeps the last one by default)
ax.add_artist(legend1)

# Customize the plot
ax.set_xlabel('Arrhenius Prefactor ln(A) [ln(Pa·s)]', fontsize=14)
ax.set_ylabel('Activation Energy E_a [J/mol]', fontsize=14)
ax.set_title('Activation Energy vs Arrhenius Prefactor\n(Color by DOI, Shape by Temperature Group)', 
             fontsize=16, fontweight='bold')
ax.grid(True, alpha=0.3, linestyle='--')

# Format y-axis to show values in scientific notation if needed
ax.ticklabel_format(style='scientific', axis='y', scilimits=(0,0))

# Increase tick label font size
ax.tick_params(axis='both', which='major', labelsize=12)

plt.tight_layout()
plt.show()

# Display summary statistics
print("\nSummary Statistics by Temperature Group:")
print("=" * 70)
for temp_group in ['High T', 'Low T', 'Full Range']:
    subset = group_activation_energy_df[group_activation_energy_df['temperature_group'] == temp_group]
    if len(subset) > 0:
        print(f"\n{temp_group}:")
        print(f"  Number of data points: {len(subset)}")
        print(f"  Activation Energy - Mean: {subset['activation_energy_J_per_mol'].mean():.2e} J/mol")
        print(f"  Activation Energy - Std: {subset['activation_energy_J_per_mol'].std():.2e} J/mol")
        print(f"  Arrhenius Prefactor - Mean: {subset['arrhenius_prefactor_lnA'].mean():.2f}")
        print(f"  Arrhenius Prefactor - Std: {subset['arrhenius_prefactor_lnA'].std():.2f}")
# Out:
# Summary Statistics by Temperature Group:
# ======================================================================
#
# High T:
#   Number of data points: 19
#   Activation Energy - Mean: 2.11e+05 J/mol
#   Activation Energy - Std: 8.49e+04 J/mol
#   Arrhenius Prefactor - Mean: -20.95
#   Arrhenius Prefactor - Std: 2.07
#
# Low T:
#   Number of data points: 19
#   Activation Energy - Mean: 2.81e+05 J/mol
#   Activation Energy - Std: 1.08e+05 J/mol
#   Arrhenius Prefactor - Mean: -24.07
#   Arrhenius Prefactor - Std: 3.05
#
# Full Range:
#   Number of data points: 19
#   Activation Energy - Mean: 2.52e+05 J/mol
#   Activation Energy - Std: 9.77e+04 J/mol
#   Arrhenius Prefactor - Mean: -22.68
#   Arrhenius Prefactor - Std: 2.54

# %%
# Plot activation_energy_J_per_mol vs arrhenius_prefactor_lnA with regression lines
# Color by DOI, shape by temperature group, with regression lines for each temperature group
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress

# Check if group_activation_energy_df exists
if 'group_activation_energy_df' not in locals() and 'group_activation_energy_df' not in globals():
    raise ValueError("group_activation_energy_df not found. Please run the previous cell first.")

# Create the plot
fig, ax = plt.subplots(figsize=(12, 8))

# Get unique DOIs for coloring
unique_dois = group_activation_energy_df['source_doi'].unique()
n_dois = len(unique_dois)

# Use consistent colors from the previous cell/analysis
# These colors match the activation_energy_df color mapping
doi_color_map = {
    '10.1016/j.jct.2018.07.031': '#8fe388',
    '10.1016/j.molliq.2015.11.032': '#d00000',
    '10.1039/c1cp22554e': '#5d2e8c',
    '10.1039/c0gc00395f': '#1b998b',
    '10.1016/j.fluid.2014.01.028': '#3185fc'
}

# For any DOIs not in the predefined map, use a default color scheme
default_colors = plt.cm.tab20(np.linspace(0, 1, 20))
for i, doi in enumerate(unique_dois):
    if doi not in doi_color_map:
        # Use a default color if not in the predefined map
        doi_color_map[doi] = default_colors[i % len(default_colors)]

# Define markers for temperature groups
marker_map = {
    'High T': 'o',      # circle
    'Low T': 's',       # square
    'Full Range': '^'    # triangle
}

# Plot each combination
for temp_group in ['High T', 'Low T', 'Full Range']:
    if temp_group not in group_activation_energy_df['temperature_group'].values:
        continue
    
    subset = group_activation_energy_df[group_activation_energy_df['temperature_group'] == temp_group]
    
    for _, row in subset.iterrows():
        doi = row['source_doi']
        ax.scatter(
            row['arrhenius_prefactor_lnA'],
            row['activation_energy_J_per_mol'],
            c=[doi_color_map[doi]],
            marker=marker_map[temp_group],
            s=120,
            alpha=0.7,
            edgecolor='black',
            linewidth=1.2,
            label=None  # We'll create custom legend
        )

# Add regression lines for each temperature group
for temp_group in ['High T', 'Low T', 'Full Range']:
    if temp_group not in group_activation_energy_df['temperature_group'].values:
        continue
    
    subset = group_activation_energy_df[group_activation_energy_df['temperature_group'] == temp_group]
    
    if len(subset) >= 2:
        x = subset['arrhenius_prefactor_lnA'].values
        y = subset['activation_energy_J_per_mol'].values
        
        # Perform linear regression
        slope, intercept, r_value, p_value, std_err = linregress(x, y)
        
        # Create x values for the regression line
        x_line = np.linspace(x.min(), x.max(), 100)
        y_line = slope * x_line + intercept
        
        # Plot regression line with appropriate style
        linestyle_map = {
            'High T': '-',           # solid line
            'Low T': '--',            # dashed line
            'Full Range': ':'         # dotted line
        }
        
        linewidth_map = {
            'High T': 2.5,
            'Low T': 2.5,
            'Full Range': 3.0
        }
        
        ax.plot(x_line, y_line, 
               linestyle=linestyle_map[temp_group],
               linewidth=linewidth_map[temp_group],
               color='gray',
               alpha=0.8,
               label=f'{temp_group} fit (R²={r_value**2:.3f})')

# Create custom legend
from matplotlib.patches import Patch
from matplotlib.lines import Line2D

# Legend for DOIs (colors)
doi_legend_elements = [
    Patch(facecolor=doi_color_map[doi], edgecolor='black', label=doi)
    for doi in unique_dois
]

# Legend for temperature groups (markers)
temp_legend_elements = [
    Line2D([0], [0], marker=marker_map['High T'], color='w', 
           markerfacecolor='gray', markeredgecolor='black', 
           markersize=12, label='High T', linestyle='None'),
    Line2D([0], [0], marker=marker_map['Low T'], color='w', 
           markerfacecolor='gray', markeredgecolor='black', 
           markersize=12, label='Low T', linestyle='None'),
    Line2D([0], [0], marker=marker_map['Full Range'], color='w', 
           markerfacecolor='gray', markeredgecolor='black', 
           markersize=12, label='Full Range', linestyle='None')
]

# Legend for regression lines
regression_legend_elements = [
    Line2D([0], [0], color='gray', linestyle='-', linewidth=2.5, label='High T fit'),
    Line2D([0], [0], color='gray', linestyle='--', linewidth=2.5, label='Low T fit'),
    Line2D([0], [0], color='gray', linestyle=':', linewidth=3.0, label='Full Range fit')
]

# Create three separate legends
legend1 = ax.legend(handles=doi_legend_elements, title='Source DOI', 
                   bbox_to_anchor=(1.02, 1), loc='upper left', 
                   fontsize=10, frameon=True, fancybox=True, shadow=True)
legend1.get_frame().set_facecolor('white')

legend2 = ax.legend(handles=temp_legend_elements, title='Temperature Group', 
                   bbox_to_anchor=(1.02, 0.65), loc='upper left', 
                   fontsize=12, frameon=True, fancybox=True, shadow=True)
legend2.get_frame().set_facecolor('white')

legend3 = ax.legend(handles=regression_legend_elements, title='Regression Lines', 
                   bbox_to_anchor=(1.02, 0.3), loc='upper left', 
                   fontsize=12, frameon=True, fancybox=True, shadow=True)
legend3.get_frame().set_facecolor('white')

# Add the first two legends back (matplotlib only keeps the last one by default)
ax.add_artist(legend1)
ax.add_artist(legend2)

# Customize the plot
ax.set_xlabel('Arrhenius Prefactor ln(As) [ln(Pa·s)]', fontsize=14)
ax.set_ylabel('Activation Energy $E_a$ [KJ/mol]', fontsize=14)
ax.set_title('Activation Energy vs Arrhenius Prefactor', 
             fontsize=16, fontweight='bold')
ax.grid(True, alpha=0.3, linestyle='--')

# Format y-axis to show values in scientific notation if needed
ax.ticklabel_format(style='scientific', axis='y', scilimits=(0,0))

# Increase tick label font size
ax.tick_params(axis='both', which='major', labelsize=12)

plt.tight_layout()
plt.show()

# Display regression statistics
print("\nRegression Statistics by Temperature Group:")
print("=" * 70)
for temp_group in ['High T', 'Low T', 'Full Range']:
    subset = group_activation_energy_df[group_activation_energy_df['temperature_group'] == temp_group]
    if len(subset) >= 2:
        x = subset['arrhenius_prefactor_lnA'].values
        y = subset['activation_energy_J_per_mol'].values
        slope, intercept, r_value, p_value, std_err = linregress(x, y)
        print(f"\n{temp_group}:")
        print(f"  Number of data points: {len(subset)}")
        print(f"  Slope: {slope:.2e}")
        print(f"  Intercept: {intercept:.2f}")
        print(f"  R-squared: {r_value**2:.4f}")
        print(f"  P-value: {p_value:.4e}")
        print(f"  Standard error: {std_err:.2e}")
# Out:
# Regression Statistics by Temperature Group:
# ======================================================================
#
# High T:
#   Number of data points: 19
#   Slope: -3.96e+04
#   Intercept: -617473.74
#   R-squared: 0.9270
#   P-value: 4.3067e-11
#   Standard error: 2.69e+03
#
# Low T:
#   Number of data points: 19
#   Slope: -3.52e+04
#   Intercept: -566350.98
#   R-squared: 0.9817
#   P-value: 3.3054e-16
#   Standard error: 1.17e+03
#
# Full Range:
#   Number of data points: 19
#   Slope: -3.79e+04
#   Intercept: -608001.03
#   R-squared: 0.9737
#   P-value: 7.1408e-15
#   Standard error: 1.51e+03
