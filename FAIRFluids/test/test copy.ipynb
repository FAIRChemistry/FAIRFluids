# %%
from mdmodels import DataModel
my_model = DataModel.from_markdown("/home/sga/Code/FAIRFluids/FAIRFluids/specifications/model.md")
my_model.info()
# Out:
#             Version
# ┏━━━━━━━━━━━━━━┳━━━━━━┳━━━━━━━┓
# ┃ Field        ┃ Type ┃ Adder ┃
# ┡━━━━━━━━━━━━━━╇━━━━━━╇━━━━━━━┩
# │ versionMajor │ int  │       │
# │ versionMinor │ int  │       │
# └──────────────┴──────┴───────┘
#             Author
# ┏━━━━━━━━━━━━━┳━━━━━━┳━━━━━━━┓
# ┃ Field       ┃ Type ┃ Adder ┃
# ┡━━━━━━━━━━━━━╇━━━━━━╇━━━━━━━┩
# │ given_name  │ str  │       │
# │ family_name │ str  │       │
# └─────────────┴──────┴───────┘
#                 Citation
# ┏━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Field  ┃ Type         ┃ Adder         ┃
# ┡━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Type   │ str          │               │
# │ author │ list[Author] │ add_to_author │
# └────────┴──────────────┴───────────────┘
#               Compound
# ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━┳━━━━━━━┓
# ┃ Field              ┃ Type ┃ Adder ┃
# ┡━━━━━━━━━━━━━━━━━━━━╇━━━━━━╇━━━━━━━┩
# │ pubChemID          │ int  │       │
# │ compund_identifier │ str  │       │
# │ commonName         │ str  │       │
# │ SELFIE             │ str  │       │
# │ name_IUPAC         │ str  │       │
# │ standard_InChI     │ str  │       │
# │ standard_InChI_key │ str  │       │
# └────────────────────┴──────┴───────┘
#          Property_Group
# ┏━━━━━━━━━━━━━━━┳━━━━━━┳━━━━━━━┓
# ┃ Field         ┃ Type ┃ Adder ┃
# ┡━━━━━━━━━━━━━━━╇━━━━━━╇━━━━━━━┩
# │ group         │ str  │       │
# │ method        │ str  │       │
# │ property_name │ str  │       │
# └───────────────┴──────┴───────┘
#                  Property
# ┏━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Field          ┃ Type           ┃ Adder ┃
# ┡━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━┩
# │ propertyID     │ str            │       │
# │ property_group │ Property_Group │       │
# └────────────────┴────────────────┴───────┘
#                   ConstraintVariableType
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Field                   ┃ Type                  ┃ Adder ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━┩
# │ e_bio_variables         │ eBioVariables         │       │
# │ e_component_composition │ eComponentComposition │       │
# │ e_miscellaneous         │ eMiscellaneous        │       │
# │ e_participant_amount    │ eParticipantAmount    │       │
# │ e_pressure              │ ePressure             │       │
# │ e_solvent_composition   │ eSolventComposition   │       │
# │ e_temperature           │ eTemperature          │       │
# └─────────────────────────┴───────────────────────┴───────┘
#                     Variable
# ┏━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Field        ┃ Type                   ┃ Adder ┃
# ┡━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━┩
# │ variableID   │ str                    │       │
# │ variableType │ ConstraintVariableType │       │
# │ variableName │ str                    │       │
# │ componentID  │ int                    │       │
# └──────────────┴────────────────────────┴───────┘
#                       Constraint
# ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Field             ┃ Type                   ┃ Adder ┃
# ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━┩
# │ constraint_type   │ ConstraintVariableType │       │
# │ constraint_digits │ int                    │       │
# │ constraint_value  │ float                  │       │
# │ constraint_number │ int                    │       │
# └───────────────────┴────────────────────────┴───────┘
#          PropertyValue
# ┏━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃ Field       ┃ Type  ┃ Adder ┃
# ┡━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ propDigits  │ int   │       │
# │ propNumber  │ str   │       │
# │ propValue   │ float │       │
# │ uncertainty │ float │       │
# └─────────────┴───────┴───────┘
#         VariableValue
# ┏━━━━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃ Field     ┃ Type  ┃ Adder ┃
# ┡━━━━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ varDigits │ int   │       │
# │ varNumber │ str   │       │
# │ varValue  │ float │       │
# └───────────┴───────┴───────┘
#                 NumValue
# ┏━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Field         ┃ Type          ┃ Adder ┃
# ┡━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━┩
# │ propertyValue │ PropertyValue │       │
# │ variableValue │ VariableValue │       │
# └───────────────┴───────────────┴───────┘
#                         Fluid
# ┏━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Field      ┃ Type             ┃ Adder             ┃
# ┡━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ components │ list[str]        │                   │
# │ source_doi │ str              │                   │
# │ property   │ Property         │                   │
# │ variable   │ Variable         │                   │
# │ constraint │ list[Constraint] │ add_to_constraint │
# │ num_value  │ NumValue         │                   │
# └────────────┴──────────────────┴───────────────────┘
#               FAIRFluidsDocument
# ┏━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Field    ┃ Type           ┃ Adder           ┃
# ┡━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ version  │ Version        │                 │
# │ citation │ Citation       │                 │
# │ compound │ list[Compound] │ add_to_compound │
# │ fluid    │ list[Fluid]    │ add_to_fluid    │
# └──────────┴────────────────┴─────────────────┘

# %%
class ExtendedFAIRFluidsDocument(my_model.FAIRFluidsDocument):
    def sum_num_values(self):
        """Sum all numerical property values across all fluids and store in compound 1's SELFIES field"""
        total = 0.0
        if hasattr(self, 'fluid') and self.fluid:
            for fluid in self.fluid:
                if fluid.num_value and fluid.num_value.propertyValue:
                    total += fluid.num_value.propertyValue.propValue
        
        
    def add_selfies_to_compound(self, compound_id, selfies_string):
        """Add SELFIES string to compound"""
        if hasattr(self, 'compound') and self.compound and len(self.compound) > 0:
            self.compound[compound_id].SELFIE = selfies_string
        
        
    def get_data_from_cml(self, path_to_cml):
        """Create FAIRFluids document from CML file"""
        import xml.etree.ElementTree as ET
        
        # Parse XML file
        tree = ET.parse(path_to_cml)
        root = tree.getroot()
        
        # Create dictionary to store DOIs and their associated properties
        doi_properties = {}

        # Find all experiment modules
        for experiment in root.findall(".//{http://www.xml-cml.org/schema}module[@dictRef='des:experiment']"):
            # Get properties list
            properties = {}
            for prop in experiment.find(".//{http://www.xml-cml.org/schema}propertyList"):
                prop_type = prop.get('dictRef').split(':')[1]
                scalar = prop.find(".//{http://www.xml-cml.org/schema}scalar")
                if scalar is not None:
                    properties[prop_type] = scalar.text
            
            # Get parameters which will become constraints
            parameters = {}
            param_list = experiment.find(".//{http://www.xml-cml.org/schema}parameterList")
            if param_list is not None:
                for param in param_list:
                    param_type = param.get('dictRef').split(':')[1]
                    scalar = param.find(".//{http://www.xml-cml.org/schema}scalar")
                    if scalar is not None:
                        parameters[param_type] = scalar.text

            # Add to doi_properties dictionary
            doi = properties.get('DOI')
            if doi:
                if doi not in doi_properties:
                    doi_properties[doi] = []
                doi_properties[doi].append({**properties, **parameters})

        # Create a fluid for each DOI
        for doi, experiments in doi_properties.items():
            for exp in experiments:
                constraints = []
                
                # Dynamically create constraints from parameters
                for param_name, param_value in exp.items():
                    if param_name == 'temperature':
                        constraints.append(my_model.Constraint(
                            constraint_type=my_model.ConstraintVariableType(
                                e_Temperature="Temperature, K"
                            ),
                            constraint_digits=3,
                            constraint_value=float(param_value),
                            constraint_number=len(constraints) + 1
                        ))
                    elif param_name == 'molar_ratio_of_DES':
                        # Create two instances for molar ratio
                        constraints.append(my_model.Constraint(
                            constraint_type=my_model.ConstraintVariableType(
                                e_component_composition= "'Mole fraction'"
                            ),
                            constraint_digits=3,
                            constraint_value=float(param_value),
                            constraint_number=len(constraints) + 1
                        ))
                        constraints.append(my_model.Constraint(
                            constraint_type=my_model.ConstraintVariableType(
                                e_component_composition="'Mole fraction'"
                            ),
                            constraint_digits=3,
                            constraint_value=float(param_value) ** -1,
                            constraint_number=len(constraints) + 1
                        ))
                    elif param_name == 'mole_fraction_of_water':
                        constraints.append(my_model.Constraint(
                            constraint_type=my_model.ConstraintVariableType(
                                e_component_composition="'Mole fraction'"
                            ),
                            constraint_digits=3,
                            constraint_value=float(param_value),
                            constraint_number=len(constraints) + 1
                        ))

                self.add_to_fluid(
                    source_doi=doi,
                    property=my_model.Property(
                        propertyID=f"viscosity_{exp.get('ID', '001')}",
                        property_group=my_model.Property_Group(
                            group="TransportProp",
                            method="experimental",
                            property_name="Dynamic viscosity, mPa·s"
                        )
                    ),
                    constraint=constraints,
                    num_value=my_model.NumValue(
                        propertyValue=my_model.PropertyValue(
                            propDigits=4,
                            propNumber=f"prop_{exp.get('ID', '001')}",
                            propValue=float(exp.get('value_viscosity', 0)),
                            uncertainty=float(exp.get('error_viscosity', 0)) if exp.get('error_viscosity') != 'NG' else 0
                        ),
                        variableValue=my_model.VariableValue(
                            varDigits=2,
                            varNumber=f"var_{exp.get('ID', '001')}",
                            varValue=float(exp.get('temperature', 0))
                        )
                    )
                )
        
        return self

# %%
class ExtendedFAIRFluidsDocument(my_model.FAIRFluidsDocument):
    def sum_num_values(self):
        """Sum all numerical property values across all fluids and store in compound 1's SELFIES field"""
        total = 0.0
        if hasattr(self, 'fluid') and self.fluid:
            for fluid in self.fluid:
                if fluid.num_value and fluid.num_value.propertyValue:
                    total += fluid.num_value.propertyValue.propValue
        
        
    def add_selfies_to_compound(self, compound_id, selfies_string):
        """Add SELFIES string to compound"""
        if hasattr(self, 'compound') and self.compound and len(self.compound) > 0:
            self.compound[compound_id].SELFIE = selfies_string
            
    def _parse_cml_file(self, path_to_cml):
        """Parse CML file and return root element"""
        import xml.etree.ElementTree as ET
        tree = ET.parse(path_to_cml)
        return tree.getroot()
        
    def _extract_properties(self, experiment):
        """Extract properties from experiment module"""
        properties = {}
        for prop in experiment.find(".//{http://www.xml-cml.org/schema}propertyList"):
            prop_type = prop.get('dictRef').split(':')[1]
            scalar = prop.find(".//{http://www.xml-cml.org/schema}scalar")
            if scalar is not None:
                properties[prop_type] = scalar.text
        return properties
        
    def _extract_parameters(self, experiment):
        """Extract parameters from experiment module"""
        parameters = {}
        param_list = experiment.find(".//{http://www.xml-cml.org/schema}parameterList")
        if param_list is not None:
            for param in param_list:
                param_type = param.get('dictRef').split(':')[1]
                scalar = param.find(".//{http://www.xml-cml.org/schema}scalar")
                if scalar is not None:
                    parameters[param_type] = scalar.text
        return parameters
        
    def _create_temperature_constraint(self, param_value, constraint_number):
        """Create temperature constraint"""
        return my_model.Constraint(
            constraint_type=my_model.ConstraintVariableType(
                e_Temperature="Temperature, K"
            ),
            constraint_digits=3,
            constraint_value=float(param_value),
            constraint_number=constraint_number
        )
        
    def _create_molar_ratio_constraints(self, param_value, constraint_number):
        """Create molar ratio constraints"""
        constraints = []
        constraints.append(my_model.Constraint(
            constraint_type=my_model.ConstraintVariableType(
                e_component_composition="'Mole fraction'"
            ),
            constraint_digits=3,
            constraint_value=float(param_value),
            constraint_number=constraint_number
        ))
        constraints.append(my_model.Constraint(
            constraint_type=my_model.ConstraintVariableType(
                e_component_composition="'Mole fraction'"
            ),
            constraint_digits=3,
            constraint_value=float(param_value) ** -1,
            constraint_number=constraint_number + 1
        ))
        return constraints
        
    def _create_water_fraction_constraint(self, param_value, constraint_number):
        """Create water fraction constraint"""
        return my_model.Constraint(
            constraint_type=my_model.ConstraintVariableType(
                e_component_composition="'Mole fraction'"
            ),
            constraint_digits=3,
            constraint_value=float(param_value),
            constraint_number=constraint_number
        )
        
    def _create_constraints(self, exp):
        """Create all constraints from experiment parameters"""
        constraints = []
        for param_name, param_value in exp.items():
            if param_name == 'temperature':
                constraints.append(self._create_temperature_constraint(param_value, len(constraints) + 1))
            elif param_name == 'molar_ratio_of_DES':
                constraints.extend(self._create_molar_ratio_constraints(param_value, len(constraints) + 1))
            elif param_name == 'mole_fraction_of_water':
                constraints.append(self._create_water_fraction_constraint(param_value, len(constraints) + 1))
        return constraints
        
    def _add_fluid_data(self, doi, exp, constraints):
        """Add fluid data to document"""
        self.add_to_fluid(
            source_doi=doi,
            property=my_model.Property(
                propertyID=f"viscosity_{exp.get('ID', '001')}",
                property_group=my_model.Property_Group(
                    group="TransportProp",
                    method="experimental",
                    property_name="Dynamic viscosity, mPa·s"
                )
            ),
            constraint=constraints,
            num_value=my_model.NumValue(
                propertyValue=my_model.PropertyValue(
                    propDigits=4,
                    propNumber=f"prop_{exp.get('ID', '001')}",
                    propValue=float(exp.get('value_viscosity', 0)),
                    uncertainty=float(exp.get('error_viscosity', 0)) if exp.get('error_viscosity') != 'NG' else 0
                ),
                variableValue=my_model.VariableValue(
                    varDigits=2,
                    varNumber=f"var_{exp.get('ID', '001')}",
                    varValue=float(exp.get('temperature', 0))
                )
            )
        )
        
    def get_data_from_cml(self, path_to_cml):
        """Create FAIRFluids document from CML file"""
        root = self._parse_cml_file(path_to_cml)
        
        # Create dictionary to store DOIs and their associated properties
        doi_properties = {}

        # Find all experiment modules
        for experiment in root.findall(".//{http://www.xml-cml.org/schema}module[@dictRef='des:experiment']"):
            properties = self._extract_properties(experiment)
            parameters = self._extract_parameters(experiment)

            # Add to doi_properties dictionary
            doi = properties.get('DOI')
            if doi:
                if doi not in doi_properties:
                    doi_properties[doi] = []
                doi_properties[doi].append({**properties, **parameters})

        # Create a fluid for each DOI
        for doi, experiments in doi_properties.items():
            for exp in experiments:
                constraints = self._create_constraints(exp)
                self._add_fluid_data(doi, exp, constraints)
        
        return self

# %% [markdown]
# # Create Document

# %%
# Test the extended class
doc = ExtendedFAIRFluidsDocument(
    version=my_model.Version(
        versionMajor=1,
        versionMinor=0
    )
)

# Add same data as example
doc.citation = my_model.Citation(Type="journal")
doc.citation.add_to_author(given_name="John", family_name="Doe")

# Add compounds and fluid data
doc.add_to_compound(
    pubChemID=962,
    commonName="Water",
    name_IUPAC="oxidane", 
    standard_InChI="InChI=1S/H2O/h1H2",
    standard_InChI_key="XLYOFNOQVPJJNP-UHFFFAOYSA-N"
)

doc.add_to_compound(
    pubChemID= 123345647789,
    commonName="CholinChloride",
    name_IUPAC="CholinChloride", 
    standard_InChI="InChI=1S/C5H11ClNO2/c1"
)

doc.add_to_compound(
    pubChemID=1128,
    commonName="Glycerol",
    name_IUPAC="glycerol",
    standard_InChI="InChI=1S/C3H8O3/c1-2-3-4/h2-3H,1H3",
    standard_InChI_key="XLYOFNOQVPJJNP-UHFFFAOYSA-N"
)

doc.add_to_fluid(
    components=["1"],
    property=my_model.Property(
        propertyID="density_001",
        property_group=my_model.Property_Group(
            group="volumetricProp",
            method="experimental", 
            property_name="Mass density, kg/m3"
        )
    ),
    variable=my_model.Variable(
        variableID="temp_001",
        variableName="Temperature, K",
        componentID=1
    ),
    num_value=my_model.NumValue(
        propertyValue=my_model.PropertyValue(
            propDigits=4,
            propNumber="prop_001", 
            propValue=998.2,
            uncertainty=0.1
        ),
        variableValue=my_model.VariableValue(
            varDigits=2,
            varNumber="var_001",
            varValue=293.15
        )
    )
)

doc.get_data_from_cml("../data/cml_xml/ChCl_glycerol.xml")
print(f"Sum of all numerical property values: {doc.sum_num_values()}")

# Save model to JSON file
with open('fairfluids_model.json', 'w') as f:
    f.write(doc.model_dump_json(indent=2))
# Out:
# Sum of all numerical property values: None

# %%
# Load JSON and validate with model
with open('fairfluids_model.json', 'r') as f:
    json_data = f.read()
    
# Create new document from JSON and validate
validated_doc = my_model.FAIRFluidsDocument.model_validate_json(json_data)


# Find viscosity values and corresponding temperatures and mole fractions
results = []
for fluid in validated_doc.fluid:
    # Check if property is viscosity
    if fluid.property.property_group.property_name == "Dynamic viscosity, mPa·s":
        temp = None
        mole_fractions = []
        viscosity = fluid.num_value.propertyValue.propValue
        
        # Get temperature and mole fraction constraints
        for constraint in fluid.constraint:
            # Check for temperature constraint
            if (constraint.constraint_type and 
                constraint.constraint_type.e_temperature == "Temperature, K"):
                temp = constraint.constraint_value
            # Check for mole fraction constraint
            elif (constraint.constraint_type and 
                  constraint.constraint_type.e_component_composition == "'Mole fraction'"):
                mole_fractions.append(constraint.constraint_value)
                
        results.append({
            'temperature': temp,
            'mole_fractions': mole_fractions,
            'viscosity': viscosity
        })

# Print results
for result in results:
    print(f"Temperature: {result['temperature']}K")
    print(f"Mole fractions: {result['mole_fractions']}")
    print(f"Viscosity: {result['viscosity']} mPa·s")
    print("---")
# Out:
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 60.2 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 1.2739 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 0.9836 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 0.7914 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 0.6492 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 0.5487 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 0.477 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 0.4354 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 0.386 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 0.3306 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 1.5754 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 1.2065 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 0.9611 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 0.7902 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 0.6578 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 0.5652 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 0.4876 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 0.4353 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 0.3862 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 2.0141 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 1.5294 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 1.2059 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 0.9808 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 0.8193 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 0.6999 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 0.6006 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 0.5212 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 0.4654 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 2.6941 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 2.0191 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 1.5742 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 1.2652 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 1.0444 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 0.8829 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 0.7359 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 0.6654 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 0.6145 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 3.8894 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 2.8657 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 2.1977 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 1.7433 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 1.4169 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 1.1824 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 1.004 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 0.8822 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 0.7702 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 6.0668 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 4.3516 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 3.2576 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 2.5277 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 2.0196 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 1.6547 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 1.3842 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 1.1855 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 1.0262 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 11.3182 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 7.6483 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 5.6438 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 3.8621 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 3.0075 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 2.4063 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 1.9711 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 1.6472 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 1.3986 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 21.8137 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 14.3726 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 10.0548 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 7.0999 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 5.076 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 3.9458 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 3.1519 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 2.5717 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 2.1426 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 54.6306 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 32.8956 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 21.3567 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 14.735 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 10.6386 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 7.7082 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 5.6748 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 4.4946 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 3.6385 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 177.9621 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 95.9405 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 56.4675 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 35.8177 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 24.0906 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 17.1371 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 12.6879 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 9.5736 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 7.5048 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 239.0806 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 125.9387 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 72.1121 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 44.9472 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 29.7991 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 20.8106 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 15.2347 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 11.586 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 9.0466 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 397.1261 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 200.4529 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 105.3949 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 63.6328 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 41.6544 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 28.2346 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 20.1102 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 14.9828 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 11.4031 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 669.9038 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 322.6054 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 172.8659 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 97.607 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 60.8033 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 39.3459 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 27.497 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 20.0963 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 15.2351 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 1003.9428 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 472.9671 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 246.7928 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 133.3749 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 81.5895 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 53.8117 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 36.7409 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 26.3331 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 19.5866 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 594.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 488.1 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 404.4 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 337.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 282.3 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 238.6 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 203.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 172.6 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 147.8 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 128.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 111.3 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 97.13 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 85.25 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 75.14 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 66.48 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 59.01 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 52.61 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 47.12 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 42.48 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 38.28 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 34.66 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 31.47 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 28.66 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 26.14 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 23.94 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 1511.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 1211.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 982.4 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 801.5 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 658.4 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 543.7 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 452.6 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 378.5 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 319.7 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 271.4 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 232.1 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 199.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 171.6 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 149.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 130.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 113.8 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 100.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 88.43 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 78.39 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 69.46 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 62.06 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 55.63 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 50.05 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 45.19 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 40.94 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 337.764 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 253.648 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 189.501 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 155.27 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 121.029 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 91.795 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 72.517 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 58.245 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 48.952 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 44.656 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 40.35 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 31.056 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 998.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 790.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 548.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 503.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 450.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 401.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 376.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 998.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 654.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 450.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 314.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 222.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 163.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 120.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 90.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 790.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 503.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 349.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 247.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 180.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 132.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 98.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 74.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 548.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 380.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 270.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 194.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 140.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 107.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 80.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 60.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 503.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 350.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 246.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 178.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 132.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 98.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 86.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 57.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 450.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 320.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 229.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 169.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 126.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 95.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 73.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 58.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 401.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 295.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 213.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 160.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 120.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 91.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 71.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 55.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 376.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 259.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 188.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 140.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 104.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 82.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 64.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 52.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 259.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 188.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 140.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 104.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 82.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 64.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 52.0 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 64.87 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 86.707 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 129.312 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 170.685 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 213.443 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 311.565 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 314.245 mPa·s
# ---
# Temperature: NoneK
# Mole fractions: []
# Viscosity: 330.824 mPa·s
# ---

# %%
results
# Out:
# [{'temperature': None, 'mole_fractions': [], 'viscosity': 60.2},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 1.2739},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 0.9836},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 0.7914},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 0.6492},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 0.5487},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 0.477},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 0.4354},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 0.386},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 0.3306},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 1.5754},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 1.2065},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 0.9611},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 0.7902},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 0.6578},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 0.5652},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 0.4876},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 0.4353},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 0.3862},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 2.0141},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 1.5294},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 1.2059},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 0.9808},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 0.8193},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 0.6999},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 0.6006},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 0.5212},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 0.4654},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 2.6941},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 2.0191},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 1.5742},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 1.2652},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 1.0444},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 0.8829},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 0.7359},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 0.6654},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 0.6145},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 3.8894},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 2.8657},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 2.1977},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 1.7433},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 1.4169},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 1.1824},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 1.004},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 0.8822},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 0.7702},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 6.0668},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 4.3516},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 3.2576},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 2.5277},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 2.0196},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 1.6547},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 1.3842},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 1.1855},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 1.0262},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 11.3182},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 7.6483},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 5.6438},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 3.8621},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 3.0075},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 2.4063},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 1.9711},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 1.6472},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 1.3986},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 21.8137},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 14.3726},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 10.0548},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 7.0999},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 5.076},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 3.9458},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 3.1519},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 2.5717},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 2.1426},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 54.6306},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 32.8956},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 21.3567},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 14.735},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 10.6386},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 7.7082},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 5.6748},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 4.4946},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 3.6385},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 177.9621},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 95.9405},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 56.4675},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 35.8177},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 24.0906},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 17.1371},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 12.6879},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 9.5736},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 7.5048},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 239.0806},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 125.9387},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 72.1121},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 44.9472},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 29.7991},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 20.8106},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 15.2347},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 11.586},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 9.0466},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 397.1261},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 200.4529},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 105.3949},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 63.6328},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 41.6544},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 28.2346},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 20.1102},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 14.9828},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 11.4031},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 669.9038},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 322.6054},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 172.8659},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 97.607},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 60.8033},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 39.3459},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 27.497},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 20.0963},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 15.2351},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 1003.9428},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 472.9671},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 246.7928},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 133.3749},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 81.5895},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 53.8117},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 36.7409},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 26.3331},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 19.5866},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 594.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 488.1},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 404.4},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 337.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 282.3},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 238.6},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 203.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 172.6},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 147.8},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 128.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 111.3},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 97.13},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 85.25},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 75.14},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 66.48},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 59.01},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 52.61},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 47.12},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 42.48},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 38.28},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 34.66},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 31.47},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 28.66},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 26.14},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 23.94},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 1511.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 1211.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 982.4},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 801.5},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 658.4},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 543.7},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 452.6},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 378.5},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 319.7},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 271.4},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 232.1},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 199.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 171.6},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 149.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 130.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 113.8},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 100.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 88.43},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 78.39},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 69.46},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 62.06},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 55.63},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 50.05},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 45.19},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 40.94},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 337.764},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 253.648},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 189.501},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 155.27},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 121.029},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 91.795},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 72.517},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 58.245},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 48.952},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 44.656},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 40.35},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 31.056},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 998.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 790.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 548.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 503.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 450.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 401.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 376.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 998.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 654.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 450.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 314.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 222.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 163.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 120.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 90.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 790.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 503.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 349.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 247.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 180.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 132.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 98.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 74.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 548.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 380.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 270.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 194.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 140.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 107.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 80.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 60.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 503.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 350.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 246.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 178.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 132.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 98.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 86.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 57.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 450.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 320.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 229.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 169.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 126.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 95.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 73.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 58.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 401.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 295.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 213.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 160.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 120.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 91.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 71.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 55.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 376.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 259.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 188.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 140.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 104.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 82.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 64.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 52.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 259.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 188.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 140.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 104.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 82.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 64.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 52.0},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 64.87},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 86.707},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 129.312},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 170.685},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 213.443},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 311.565},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 314.245},
#  {'temperature': None, 'mole_fractions': [], 'viscosity': 330.824}]

# %%
print(validated_doc.model_dump_json(indent=2))
# Out:
# {
#   "version": {
#     "versionMajor": 1,
#     "versionMinor": 0
#   },
#   "citation": {
#     "Type": "journal",
#     "author": [
#       {
#         "given_name": "John",
#         "family_name": "Doe"
#       }
#     ]
#   },
#   "compound": [
#     {
#       "pubChemID": 962,
#       "compund_identifier": null,
#       "commonName": "Water",
#       "SELFIE": null,
#       "name_IUPAC": "oxidane",
#       "standard_InChI": "InChI=1S/H2O/h1H2",
#       "standard_InChI_key": "XLYOFNOQVPJJNP-UHFFFAOYSA-N"
#     },
#     {
#       "pubChemID": 123345647789,
#       "compund_identifier": null,
#       "commonName": "CholinChloride",
#       "SELFIE": null,
#       "name_IUPAC": "CholinChloride",
#       "standard_InChI": "InChI=1S/C5H11ClNO2/c1",
#       "standard_InChI_key": null
#     },
#     {
#       "pubChemID": 1128,
#       "compund_identifier": null,
#       "commonName": "Glycerol",
#       "SELFIE": null,
#       "name_IUPAC": "glycerol",
#       "standard_InChI": "InChI=1S/C3H8O3/c1-2-3-4/h2-3H,1H3",
#       "standard_InChI_key": "XLYOFNOQVPJJNP-UHFFFAOYSA-N"
#     }
#   ],
#   "fluid": [
#     {
#       "components": [
#         "1"
#       ],
#       "source_doi": null,
#       "property": {
#         "propertyID": "density_001",
#         "property_group": {
#           "group": "volumetricProp",
#           "method": "experimental",
#           "property_name": "Mass density, kg/m3"
#         }
#       },
#       "variable": {
#         "variableID": "temp_001",
#         "variableType": null,
#         "variableName": "Temperature, K",
#         "componentID": 1
#       },
#       "constraint": [],
#       "num_value": {
#         "propertyValue": {
#           "propDigits": 4,
#           "propNumber": "prop_001",
#           "propValue": 998.2,
#           "uncertainty": 0.1
#         },
#         "variableValue": {
#           "varDigits": 2,
#           "varNumber": "var_001",
#           "varValue": 293.15
#         }
#       }
#     },
#     {
#       "components": [],
#       "source_doi": "10.1016/j.aca.2012.12.019",
#       "property": {
#         "propertyID": "viscosity_1",
#         "property_group": {
#           "group": "TransportProp",
#           "method": "experimental",
#           "property_name": "Dynamic viscosity, mPa·s"
#         }
#       },
#       "variable": null,
#       "constraint": [
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 0.5,
#           "constraint_number": 1
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 2.0,
#           "constraint_number": 2
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 0.249765513,
#           "constraint_number": 3
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": null,
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 313.15,
#           "constraint_number": 4
#         }
#       ],
#       "num_value": {
#         "propertyValue": {
#           "propDigits": 4,
#           "propNumber": "prop_1",
#           "propValue": 60.2,
#           "uncertainty": 0.0
#         },
#         "variableValue": {
#           "varDigits": 2,
#           "varNumber": "var_1",
#           "varValue": 313.15
#         }
#       }
#     },
#     {
#       "components": [],
#       "source_doi": "10.1016/j.fluid.2014.01.028",
#       "property": {
#         "propertyID": "viscosity_2",
#         "property_group": {
#           "group": "TransportProp",
#           "method": "experimental",
#           "property_name": "Dynamic viscosity, mPa·s"
#         }
#       },
#       "variable": null,
#       "constraint": [
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 0.5,
#           "constraint_number": 1
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 2.0,
#           "constraint_number": 2
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 1.0,
#           "constraint_number": 3
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": null,
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 283.15,
#           "constraint_number": 4
#         }
#       ],
#       "num_value": {
#         "propertyValue": {
#           "propDigits": 4,
#           "propNumber": "prop_2",
#           "propValue": 1.2739,
#           "uncertainty": 0.0063695
#         },
#         "variableValue": {
#           "varDigits": 2,
#           "varNumber": "var_2",
#           "varValue": 283.15
#         }
#       }
#     },
#     {
#       "components": [],
#       "source_doi": "10.1016/j.fluid.2014.01.028",
#       "property": {
#         "propertyID": "viscosity_3",
#         "property_group": {
#           "group": "TransportProp",
#           "method": "experimental",
#           "property_name": "Dynamic viscosity, mPa·s"
#         }
#       },
#       "variable": null,
#       "constraint": [
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 0.5,
#           "constraint_number": 1
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 2.0,
#           "constraint_number": 2
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 1.0,
#           "constraint_number": 3
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": null,
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 293.15,
#           "constraint_number": 4
#         }
#       ],
#       "num_value": {
#         "propertyValue": {
#           "propDigits": 4,
#           "propNumber": "prop_3",
#           "propValue": 0.9836,
#           "uncertainty": 0.004918
#         },
#         "variableValue": {
#           "varDigits": 2,
#           "varNumber": "var_3",
#           "varValue": 293.15
#         }
#       }
#     },
#     {
#       "components": [],
#       "source_doi": "10.1016/j.fluid.2014.01.028",
#       "property": {
#         "propertyID": "viscosity_4",
#         "property_group": {
#           "group": "TransportProp",
#           "method": "experimental",
#           "property_name": "Dynamic viscosity, mPa·s"
#         }
#       },
#       "variable": null,
#       "constraint": [
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 0.5,
#           "constraint_number": 1
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 2.0,
#           "constraint_number": 2
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 1.0,
#           "constraint_number": 3
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": null,
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 303.15,
#           "constraint_number": 4
#         }
#       ],
#       "num_value": {
#         "propertyValue": {
#           "propDigits": 4,
#           "propNumber": "prop_4",
#           "propValue": 0.7914,
#           "uncertainty": 0.003957
#         },
#         "variableValue": {
#           "varDigits": 2,
#           "varNumber": "var_4",
#           "varValue": 303.15
#         }
#       }
#     },
#     {
#       "components": [],
#       "source_doi": "10.1016/j.fluid.2014.01.028",
#       "property": {
#         "propertyID": "viscosity_5",
#         "property_group": {
#           "group": "TransportProp",
#           "method": "experimental",
#           "property_name": "Dynamic viscosity, mPa·s"
#         }
#       },
#       "variable": null,
#       "constraint": [
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 0.5,
#           "constraint_number": 1
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 2.0,
#           "constraint_number": 2
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 1.0,
#           "constraint_number": 3
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": null,
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 313.15,
#           "constraint_number": 4
#         }
#       ],
#       "num_value": {
#         "propertyValue": {
#           "propDigits": 4,
#           "propNumber": "prop_5",
#           "propValue": 0.6492,
#           "uncertainty": 0.003246
#         },
#         "variableValue": {
#           "varDigits": 2,
#           "varNumber": "var_5",
#           "varValue": 313.15
#         }
#       }
#     },
#     {
#       "components": [],
#       "source_doi": "10.1016/j.fluid.2014.01.028",
#       "property": {
#         "propertyID": "viscosity_6",
#         "property_group": {
#           "group": "TransportProp",
#           "method": "experimental",
#           "property_name": "Dynamic viscosity, mPa·s"
#         }
#       },
#       "variable": null,
#       "constraint": [
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 0.5,
#           "constraint_number": 1
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 2.0,
#           "constraint_number": 2
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 1.0,
#           "constraint_number": 3
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": null,
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 323.15,
#           "constraint_number": 4
#         }
#       ],
#       "num_value": {
#         "propertyValue": {
#           "propDigits": 4,
#           "propNumber": "prop_6",
#           "propValue": 0.5487,
#           "uncertainty": 0.0027435
#         },
#         "variableValue": {
#           "varDigits": 2,
#           "varNumber": "var_6",
#           "varValue": 323.15
#         }
#       }
#     },
#     {
#       "components": [],
#       "source_doi": "10.1016/j.fluid.2014.01.028",
#       "property": {
#         "propertyID": "viscosity_7",
#         "property_group": {
#           "group": "TransportProp",
#           "method": "experimental",
#           "property_name": "Dynamic viscosity, mPa·s"
#         }
#       },
#       "variable": null,
#       "constraint": [
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 0.5,
#           "constraint_number": 1
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 2.0,
#           "constraint_number": 2
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 1.0,
#           "constraint_number": 3
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": null,
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 333.15,
#           "constraint_number": 4
#         }
#       ],
#       "num_value": {
#         "propertyValue": {
#           "propDigits": 4,
#           "propNumber": "prop_7",
#           "propValue": 0.477,
#           "uncertainty": 0.002385
#         },
#         "variableValue": {
#           "varDigits": 2,
#           "varNumber": "var_7",
#           "varValue": 333.15
#         }
#       }
#     },
#     {
#       "components": [],
#       "source_doi": "10.1016/j.fluid.2014.01.028",
#       "property": {
#         "propertyID": "viscosity_8",
#         "property_group": {
#           "group": "TransportProp",
#           "method": "experimental",
#           "property_name": "Dynamic viscosity, mPa·s"
#         }
#       },
#       "variable": null,
#       "constraint": [
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 0.5,
#           "constraint_number": 1
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 2.0,
#           "constraint_number": 2
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 1.0,
#           "constraint_number": 3
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": null,
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 343.15,
#           "constraint_number": 4
#         }
#       ],
#       "num_value": {
#         "propertyValue": {
#           "propDigits": 4,
#           "propNumber": "prop_8",
#           "propValue": 0.4354,
#           "uncertainty": 0.002177
#         },
#         "variableValue": {
#           "varDigits": 2,
#           "varNumber": "var_8",
#           "varValue": 343.15
#         }
#       }
#     },
#     {
#       "components": [],
#       "source_doi": "10.1016/j.fluid.2014.01.028",
#       "property": {
#         "propertyID": "viscosity_9",
#         "property_group": {
#           "group": "TransportProp",
#           "method": "experimental",
#           "property_name": "Dynamic viscosity, mPa·s"
#         }
#       },
#       "variable": null,
#       "constraint": [
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 0.5,
#           "constraint_number": 1
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 2.0,
#           "constraint_number": 2
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 1.0,
#           "constraint_number": 3
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": null,
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 353.15,
#           "constraint_number": 4
#         }
#       ],
#       "num_value": {
#         "propertyValue": {
#           "propDigits": 4,
#           "propNumber": "prop_9",
#           "propValue": 0.386,
#           "uncertainty": 0.00193
#         },
#         "variableValue": {
#           "varDigits": 2,
#           "varNumber": "var_9",
#           "varValue": 353.15
#         }
#       }
#     },
#     {
#       "components": [],
#       "source_doi": "10.1016/j.fluid.2014.01.028",
#       "property": {
#         "propertyID": "viscosity_10",
#         "property_group": {
#           "group": "TransportProp",
#           "method": "experimental",
#           "property_name": "Dynamic viscosity, mPa·s"
#         }
#       },
#       "variable": null,
#       "constraint": [
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 0.5,
#           "constraint_number": 1
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 2.0,
#           "constraint_number": 2
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 1.0,
#           "constraint_number": 3
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": null,
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 363.15,
#           "constraint_number": 4
#         }
#       ],
#       "num_value": {
#         "propertyValue": {
#           "propDigits": 4,
#           "propNumber": "prop_10",
#           "propValue": 0.3306,
#           "uncertainty": 0.001653
#         },
#         "variableValue": {
#           "varDigits": 2,
#           "varNumber": "var_10",
#           "varValue": 363.15
#         }
#       }
#     },
#     {
#       "components": [],
#       "source_doi": "10.1016/j.fluid.2014.01.028",
#       "property": {
#         "propertyID": "viscosity_11",
#         "property_group": {
#           "group": "TransportProp",
#           "method": "experimental",
#           "property_name": "Dynamic viscosity, mPa·s"
#         }
#       },
#       "variable": null,
#       "constraint": [
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 0.5,
#           "constraint_number": 1
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 2.0,
#           "constraint_number": 2
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 0.9819,
#           "constraint_number": 3
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": null,
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 283.15,
#           "constraint_number": 4
#         }
#       ],
#       "num_value": {
#         "propertyValue": {
#           "propDigits": 4,
#           "propNumber": "prop_11",
#           "propValue": 1.5754,
#           "uncertainty": 0.007877
#         },
#         "variableValue": {
#           "varDigits": 2,
#           "varNumber": "var_11",
#           "varValue": 283.15
#         }
#       }
#     },
#     {
#       "components": [],
#       "source_doi": "10.1016/j.fluid.2014.01.028",
#       "property": {
#         "propertyID": "viscosity_12",
#         "property_group": {
#           "group": "TransportProp",
#           "method": "experimental",
#           "property_name": "Dynamic viscosity, mPa·s"
#         }
#       },
#       "variable": null,
#       "constraint": [
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 0.5,
#           "constraint_number": 1
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 2.0,
#           "constraint_number": 2
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 0.9819,
#           "constraint_number": 3
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": null,
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 293.15,
#           "constraint_number": 4
#         }
#       ],
#       "num_value": {
#         "propertyValue": {
#           "propDigits": 4,
#           "propNumber": "prop_12",
#           "propValue": 1.2065,
#           "uncertainty": 0.0060325
#         },
#         "variableValue": {
#           "varDigits": 2,
#           "varNumber": "var_12",
#           "varValue": 293.15
#         }
#       }
#     },
#     {
#       "components": [],
#       "source_doi": "10.1016/j.fluid.2014.01.028",
#       "property": {
#         "propertyID": "viscosity_13",
#         "property_group": {
#           "group": "TransportProp",
#           "method": "experimental",
#           "property_name": "Dynamic viscosity, mPa·s"
#         }
#       },
#       "variable": null,
#       "constraint": [
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 0.5,
#           "constraint_number": 1
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 2.0,
#           "constraint_number": 2
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 0.9819,
#           "constraint_number": 3
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": null,
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 303.15,
#           "constraint_number": 4
#         }
#       ],
#       "num_value": {
#         "propertyValue": {
#           "propDigits": 4,
#           "propNumber": "prop_13",
#           "propValue": 0.9611,
#           "uncertainty": 0.0048055
#         },
#         "variableValue": {
#           "varDigits": 2,
#           "varNumber": "var_13",
#           "varValue": 303.15
#         }
#       }
#     },
#     {
#       "components": [],
#       "source_doi": "10.1016/j.fluid.2014.01.028",
#       "property": {
#         "propertyID": "viscosity_14",
#         "property_group": {
#           "group": "TransportProp",
#           "method": "experimental",
#           "property_name": "Dynamic viscosity, mPa·s"
#         }
#       },
#       "variable": null,
#       "constraint": [
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 0.5,
#           "constraint_number": 1
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 2.0,
#           "constraint_number": 2
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 0.9819,
#           "constraint_number": 3
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": null,
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 313.15,
#           "constraint_number": 4
#         }
#       ],
#       "num_value": {
#         "propertyValue": {
#           "propDigits": 4,
#           "propNumber": "prop_14",
#           "propValue": 0.7902,
#           "uncertainty": 0.003951
#         },
#         "variableValue": {
#           "varDigits": 2,
#           "varNumber": "var_14",
#           "varValue": 313.15
#         }
#       }
#     },
#     {
#       "components": [],
#       "source_doi": "10.1016/j.fluid.2014.01.028",
#       "property": {
#         "propertyID": "viscosity_15",
#         "property_group": {
#           "group": "TransportProp",
#           "method": "experimental",
#           "property_name": "Dynamic viscosity, mPa·s"
#         }
#       },
#       "variable": null,
#       "constraint": [
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 0.5,
#           "constraint_number": 1
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 2.0,
#           "constraint_number": 2
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 0.9819,
#           "constraint_number": 3
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": null,
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 323.15,
#           "constraint_number": 4
#         }
#       ],
#       "num_value": {
#         "propertyValue": {
#           "propDigits": 4,
#           "propNumber": "prop_15",
#           "propValue": 0.6578,
#           "uncertainty": 0.003289
#         },
#         "variableValue": {
#           "varDigits": 2,
#           "varNumber": "var_15",
#           "varValue": 323.15
#         }
#       }
#     },
#     {
#       "components": [],
#       "source_doi": "10.1016/j.fluid.2014.01.028",
#       "property": {
#         "propertyID": "viscosity_16",
#         "property_group": {
#           "group": "TransportProp",
#           "method": "experimental",
#           "property_name": "Dynamic viscosity, mPa·s"
#         }
#       },
#       "variable": null,
#       "constraint": [
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 0.5,
#           "constraint_number": 1
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 2.0,
#           "constraint_number": 2
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 0.9819,
#           "constraint_number": 3
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": null,
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 333.15,
#           "constraint_number": 4
#         }
#       ],
#       "num_value": {
#         "propertyValue": {
#           "propDigits": 4,
#           "propNumber": "prop_16",
#           "propValue": 0.5652,
#           "uncertainty": 0.002826
#         },
#         "variableValue": {
#           "varDigits": 2,
#           "varNumber": "var_16",
#           "varValue": 333.15
#         }
#       }
#     },
#     {
#       "components": [],
#       "source_doi": "10.1016/j.fluid.2014.01.028",
#       "property": {
#         "propertyID": "viscosity_17",
#         "property_group": {
#           "group": "TransportProp",
#           "method": "experimental",
#           "property_name": "Dynamic viscosity, mPa·s"
#         }
#       },
#       "variable": null,
#       "constraint": [
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 0.5,
#           "constraint_number": 1
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 2.0,
#           "constraint_number": 2
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 0.9819,
#           "constraint_number": 3
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": null,
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 343.15,
#           "constraint_number": 4
#         }
#       ],
#       "num_value": {
#         "propertyValue": {
#           "propDigits": 4,
#           "propNumber": "prop_17",
#           "propValue": 0.4876,
#           "uncertainty": 0.002438
#         },
#         "variableValue": {
#           "varDigits": 2,
#           "varNumber": "var_17",
#           "varValue": 343.15
#         }
#       }
#     },
#     {
#       "components": [],
#       "source_doi": "10.1016/j.fluid.2014.01.028",
#       "property": {
#         "propertyID": "viscosity_18",
#         "property_group": {
#           "group": "TransportProp",
#           "method": "experimental",
#           "property_name": "Dynamic viscosity, mPa·s"
#         }
#       },
#       "variable": null,
#       "constraint": [
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 0.5,
#           "constraint_number": 1
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 2.0,
#           "constraint_number": 2
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 0.9819,
#           "constraint_number": 3
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": null,
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 353.15,
#           "constraint_number": 4
#         }
#       ],
#       "num_value": {
#         "propertyValue": {
#           "propDigits": 4,
#           "propNumber": "prop_18",
#           "propValue": 0.4353,
#           "uncertainty": 0.0021765
#         },
#         "variableValue": {
#           "varDigits": 2,
#           "varNumber": "var_18",
#           "varValue": 353.15
#         }
#       }
#     },
#     {
#       "components": [],
#       "source_doi": "10.1016/j.fluid.2014.01.028",
#       "property": {
#         "propertyID": "viscosity_19",
#         "property_group": {
#           "group": "TransportProp",
#           "method": "experimental",
#           "property_name": "Dynamic viscosity, mPa·s"
#         }
#       },
#       "variable": null,
#       "constraint": [
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 0.5,
#           "constraint_number": 1
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 2.0,
#           "constraint_number": 2
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
# ...
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 0.47105621,
#           "constraint_number": 3
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": null,
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 293.15,
#           "constraint_number": 4
#         }
#       ],
#       "num_value": {
#         "propertyValue": {
#           "propDigits": 4,
#           "propNumber": "prop_261",
#           "propValue": 86.707,
#           "uncertainty": 0.0
#         },
#         "variableValue": {
#           "varDigits": 2,
#           "varNumber": "var_261",
#           "varValue": 293.15
#         }
#       }
#     },
#     {
#       "components": [],
#       "source_doi": "10.1039/c5cp01493j",
#       "property": {
#         "propertyID": "viscosity_262",
#         "property_group": {
#           "group": "TransportProp",
#           "method": "experimental",
#           "property_name": "Dynamic viscosity, mPa·s"
#         }
#       },
#       "variable": null,
#       "constraint": [
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 0.5,
#           "constraint_number": 1
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 2.0,
#           "constraint_number": 2
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 0.359851027,
#           "constraint_number": 3
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": null,
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 293.15,
#           "constraint_number": 4
#         }
#       ],
#       "num_value": {
#         "propertyValue": {
#           "propDigits": 4,
#           "propNumber": "prop_262",
#           "propValue": 129.312,
#           "uncertainty": 0.0
#         },
#         "variableValue": {
#           "varDigits": 2,
#           "varNumber": "var_262",
#           "varValue": 293.15
#         }
#       }
#     },
#     {
#       "components": [],
#       "source_doi": "10.1039/c5cp01493j",
#       "property": {
#         "propertyID": "viscosity_263",
#         "property_group": {
#           "group": "TransportProp",
#           "method": "experimental",
#           "property_name": "Dynamic viscosity, mPa·s"
#         }
#       },
#       "variable": null,
#       "constraint": [
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 0.5,
#           "constraint_number": 1
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 2.0,
#           "constraint_number": 2
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 0.291284081,
#           "constraint_number": 3
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": null,
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 293.15,
#           "constraint_number": 4
#         }
#       ],
#       "num_value": {
#         "propertyValue": {
#           "propDigits": 4,
#           "propNumber": "prop_263",
#           "propValue": 170.685,
#           "uncertainty": 0.0
#         },
#         "variableValue": {
#           "varDigits": 2,
#           "varNumber": "var_263",
#           "varValue": 293.15
#         }
#       }
#     },
#     {
#       "components": [],
#       "source_doi": "10.1039/c5cp01493j",
#       "property": {
#         "propertyID": "viscosity_264",
#         "property_group": {
#           "group": "TransportProp",
#           "method": "experimental",
#           "property_name": "Dynamic viscosity, mPa·s"
#         }
#       },
#       "variable": null,
#       "constraint": [
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 0.5,
#           "constraint_number": 1
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 2.0,
#           "constraint_number": 2
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 0.210533018,
#           "constraint_number": 3
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": null,
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 293.15,
#           "constraint_number": 4
#         }
#       ],
#       "num_value": {
#         "propertyValue": {
#           "propDigits": 4,
#           "propNumber": "prop_264",
#           "propValue": 213.443,
#           "uncertainty": 0.0
#         },
#         "variableValue": {
#           "varDigits": 2,
#           "varNumber": "var_264",
#           "varValue": 293.15
#         }
#       }
#     },
#     {
#       "components": [],
#       "source_doi": "10.1039/c5cp01493j",
#       "property": {
#         "propertyID": "viscosity_265",
#         "property_group": {
#           "group": "TransportProp",
#           "method": "experimental",
#           "property_name": "Dynamic viscosity, mPa·s"
#         }
#       },
#       "variable": null,
#       "constraint": [
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 0.5,
#           "constraint_number": 1
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 2.0,
#           "constraint_number": 2
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 0.115156984,
#           "constraint_number": 3
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": null,
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 293.15,
#           "constraint_number": 4
#         }
#       ],
#       "num_value": {
#         "propertyValue": {
#           "propDigits": 4,
#           "propNumber": "prop_265",
#           "propValue": 311.565,
#           "uncertainty": 0.0
#         },
#         "variableValue": {
#           "varDigits": 2,
#           "varNumber": "var_265",
#           "varValue": 293.15
#         }
#       }
#     },
#     {
#       "components": [],
#       "source_doi": "10.1039/c5cp01493j",
#       "property": {
#         "propertyID": "viscosity_266",
#         "property_group": {
#           "group": "TransportProp",
#           "method": "experimental",
#           "property_name": "Dynamic viscosity, mPa·s"
#         }
#       },
#       "variable": null,
#       "constraint": [
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 0.5,
#           "constraint_number": 1
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 2.0,
#           "constraint_number": 2
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 0.04915693,
#           "constraint_number": 3
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": null,
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 293.15,
#           "constraint_number": 4
#         }
#       ],
#       "num_value": {
#         "propertyValue": {
#           "propDigits": 4,
#           "propNumber": "prop_266",
#           "propValue": 314.245,
#           "uncertainty": 0.0
#         },
#         "variableValue": {
#           "varDigits": 2,
#           "varNumber": "var_266",
#           "varValue": 293.15
#         }
#       }
#     },
#     {
#       "components": [],
#       "source_doi": "10.1039/c5cp01493j",
#       "property": {
#         "propertyID": "viscosity_267",
#         "property_group": {
#           "group": "TransportProp",
#           "method": "experimental",
#           "property_name": "Dynamic viscosity, mPa·s"
#         }
#       },
#       "variable": null,
#       "constraint": [
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 0.5,
#           "constraint_number": 1
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 2.0,
#           "constraint_number": 2
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": "'Mole fraction'",
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 0.024856622,
#           "constraint_number": 3
#         },
#         {
#           "constraint_type": {
#             "e_bio_variables": null,
#             "e_component_composition": null,
#             "e_miscellaneous": null,
#             "e_participant_amount": null,
#             "e_pressure": null,
#             "e_solvent_composition": null,
#             "e_temperature": null
#           },
#           "constraint_digits": 3,
#           "constraint_value": 293.15,
#           "constraint_number": 4
#         }
#       ],
#       "num_value": {
#         "propertyValue": {
#           "propDigits": 4,
#           "propNumber": "prop_267",
#           "propValue": 330.824,
#           "uncertainty": 0.0
#         },
#         "variableValue": {
#           "varDigits": 2,
#           "varNumber": "var_267",
#           "varValue": 293.15
#         }
#       }
#     }
#   ]
# }
