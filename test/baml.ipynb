# %%
import pymupdf4llm

# %%
md_text = pymupdf4llm.to_markdown("/home/sga/Code/FAIRFluids/pdf/sarmad2017screening.pdf")

print(md_text)

md_read = pymupdf4llm.LlamaMarkdownReader()
data = md_read.load_data("/home/sga/Code/FAIRFluids/pdf/sarmad2017screening.pdf")
# Out:
# # NJC
#
# |Col1|Col2|Col3|
# |---|---|---|
# ||APER<br>**View Article Online**<br>||
# ||**View Journal | View Issue**||
#
#
#
# Cite this: _New J. Chem.,_ 2017,
#
# 41, 290
#
#
# Received (in Montpellier, France)
# 7th October 2016,
# Accepted 28th November 2016
#
#
# DOI: 10.1039/c6nj03140d
#
#
# www.rsc.org/njc
#
# ### 1. Introduction
#
#
# ## Screening of deep eutectic solvents (DESs) as green CO 2 sorbents: from solubility to viscosity†
#
# Shokat Sarmad,* [a] Yujiao Xie, [a] Jyri-Pekka Mikkola [bc] and Xiaoyan Ji [a]
#
#
# Deep eutectic solvents (DESs) as ionic liquid (IL) analogues show great potential for CO 2 capture. They
#
#
# exhibit favorable solvent properties and are considered to be economical alternatives to conventional
#
# ILs. In this study, we prepare 35 DESs and screen them in terms of their CO 2 solubility and viscosity,
#
#
# both crucial factors to be considered when designing efficient CO 2 sorbents. The influence of salt and
#
#
# ...

# %%
print(data)
# Out:
# [Document(id_='dc0f7272-c9df-4725-b371-06f84cb173a6', embedding=None, metadata={'format': 'PDF 1.3', 'title': 'Screening of deep eutectic solvents (DESs) as green CO2 sorbents: from solubility to viscosity', 'author': 'Shokat Sarmad', 'subject': 'New Journal of Chemistry (2017), 41, 290-301, doi:10.1039/C6NJ03140D', 'keywords': '', 'creator': '', 'producer': 'iTextSharp™ 5.5.11 ©2000-2017 iText Group NV (AGPL-version)', 'creationDate': "D:20161215153617+05'30'", 'modDate': "D:20250703113951+01'00'", 'trapped': '', 'encryption': None, 'page': 1, 'total_pages': 12, 'file_path': '/home/sga/Code/FAIRFluids/pdf/sarmad2017screening.pdf'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='# NJC\n\n|Col1|Col2|Col3|\n|---|---|---|\n||APER<br>**View Article Online**<br>||\n||**View Journal | View Issue**||\n\n\n\nCite this: _New J. Chem.,_ 2
# ...
