# %%
import sys
sys.path.append('/home/sga/Code/FAIRFluids')
from FAIRFluids.core.lib import FAIRFluidsDocument, Version, Citation
from FAIRFluids.core.functionalities import FAIRFluidsCMLParser

# %%
# Test the extended class
doc = FAIRFluidsDocument(
    version=Version(
        versionMajor=1,
        versionMinor=0
    )
)

# Add same data as example
doc.citation = Citation(Type="journal")
doc.citation.add_to_author(given_name="John", family_name="Doe")

# Add compounds and fluid data
doc.add_to_compound(
    compoundID="2",
    pubChemID=962,
    commonName="Water",
    name_IUPAC="oxidane", 
    standard_InChI="InChI=1S/H2O/h1H2",
    standard_InChI_key="XLYOFNOQVPJJNP-UHFFFAOYSA-N"
)

doc.add_to_compound(
    compoundID="3",
    pubChemID= 123345647789,
    commonName="CholinChloride",
    name_IUPAC="CholinChloride", 
    standard_InChI="InChI=1S/C5H11ClNO2/c1"
)

doc.add_to_compound(
    compoundID="1",
    pubChemID=1128,
    commonName="Glycerol",
    name_IUPAC="glycerol",
    standard_InChI="InChI=1S/C3H8O3/c1-2-3-4/h2-3H,1H3",
    standard_InChI_key="XLYOFNOQVPJJNP-UHFFFAOYSA-N"
)

parser = FAIRFluidsCMLParser("/home/sga/Code/FAIRFluids/FAIRFluids/data/cml_xml/gygli/ChCl_glycerol.xml", document=doc)
doc = parser.parse()

print(doc.model_dump_json(indent=2))
# Save model to JSON file
with open('fairfluids_model.json', 'w') as f:
    f.write(doc.model_dump_json(indent=2))
# Out:
# {
#   "version": {
#     "versionMajor": 1,
#     "versionMinor": 0
#   },
#   "citation": {
#     "litType": null,
#     "author": [
#       {
#         "given_name": "John",
#         "family_name": "Doe",
#         "email": null,
#         "orcid": null,
#         "affiliation": null
#       }
#     ],
#     "doi": null,
#     "page": null,
#     "pub_name": null,
#     "title": null,
#     "lit_volume_num": null,
#     "url_citation": null,
#     "publication_year": null
#   },
#   "compound": [
#     {
#       "compoundID": "2",
#       "pubChemID": 962,
#       "commonName": "Water",
#       "SELFIE": null,
#       "name_IUPAC": "oxidane",
#       "standard_InChI": "InChI=1S/H2O/h1H2",
#       "standard_InChI_key": "XLYOFNOQVPJJNP-UHFFFAOYSA-N"
#     },
#     {
#       "compoundID": "3",
#       "pubChemID": 123345647789,
#       "commonName": "CholinChloride",
#       "SELFIE": null,
#       "name_IUPAC": "CholinChloride",
#       "standard_InChI": "InChI=1S/C5H11ClNO2/c1",
#       "standard_InChI_key": null
#     },
#     {
#       "compoundID": "1",
#       "pubChemID": 1128,
#       "commonName": "Glycerol",
#       "SELFIE": null,
#       "name_IUPAC": "glycerol",
#       "standard_InChI": "InChI=1S/C3H8O3/c1-2-3-4/h2-3H,1H3",
#       "standard_InChI_key": "XLYOFNOQVPJJNP-UHFFFAOYSA-N"
#     }
#   ],
#   "fluid": [
#     {
#       "compounds": [
#         "2",
#         "3",
#         "1"
#       ],
#       "property": [
#         {
#           "propertyID": "viscosity",
#           "properties": "viscosity",
#           "unit": {
#             "unitID": "mPa·s",
#             "name": "milliPascal second",
#             "base_units": []
#           }
#         }
#       ],
#       "parameter": [
#         {
#           "parameterID": "x_water",
#           "parameter": "Mole fraction",
#           "unit": {
#             "unitID": "1",
#             "name": "dimensionless",
#             "base_units": [
#               {
#                 "kind": null,
#                 "exponent": null,
#                 "multiplier": 1.0,
#                 "scale": 0.0
#               }
#             ]
#           },
#           "associated_compound": "2"
#         },
#         {
#           "parameterID": "x_cholinchloride",
#           "parameter": "Mole fraction",
#           "unit": {
#             "unitID": "1",
#             "name": "dimensionless",
#             "base_units": [
#               {
#                 "kind": null,
#                 "exponent": null,
#                 "multiplier": 1.0,
#                 "scale": 0.0
#               }
#             ]
#           },
#           "associated_compound": "3"
#         },
#         {
#           "parameterID": "x_glycerol",
#           "parameter": "Mole fraction",
#           "unit": {
#             "unitID": "1",
#             "name": "dimensionless",
#             "base_units": [
#               {
#                 "kind": null,
#                 "exponent": null,
#                 "multiplier": 1.0,
#                 "scale": 0.0
#               }
#             ]
#           },
#           "associated_compound": "1"
#         },
#         {
#           "parameterID": "T_4",
#           "parameter": "Temperature, K",
#           "unit": {
#             "unitID": "K",
#             "name": "kelvin",
#             "base_units": [
#               {
#                 "kind": null,
#                 "exponent": null,
#                 "multiplier": 1.0,
#                 "scale": 0.0
#               }
#             ]
#           },
#           "associated_compound": null
#         }
#       ],
#       "measurement": [
#         {
#           "measurement_id": "meas_1",
#           "source_doi": "10.1016/j.aca.2012.12.019",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 60.2,
#               "uncertainty": null
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.2500781623333333,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.5001563246666667,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 0.249765513,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 313.15,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_2",
#           "source_doi": "10.1016/j.fluid.2014.01.028",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 1.2739,
#               "uncertainty": 0.0063695
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.0,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.0,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 1.0,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 283.15,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_3",
#           "source_doi": "10.1016/j.fluid.2014.01.028",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 0.9836,
#               "uncertainty": 0.004918
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.0,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.0,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 1.0,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 293.15,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_4",
#           "source_doi": "10.1016/j.fluid.2014.01.028",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 0.7914,
#               "uncertainty": 0.003957
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.0,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.0,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 1.0,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 303.15,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_5",
#           "source_doi": "10.1016/j.fluid.2014.01.028",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 0.6492,
#               "uncertainty": 0.003246
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.0,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.0,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 1.0,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 313.15,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_6",
#           "source_doi": "10.1016/j.fluid.2014.01.028",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 0.5487,
#               "uncertainty": 0.0027435
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.0,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.0,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 1.0,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 323.15,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_7",
#           "source_doi": "10.1016/j.fluid.2014.01.028",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 0.477,
#               "uncertainty": 0.002385
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.0,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.0,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 1.0,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 333.15,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_8",
#           "source_doi": "10.1016/j.fluid.2014.01.028",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 0.4354,
#               "uncertainty": 0.002177
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.0,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.0,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 1.0,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 343.15,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_9",
#           "source_doi": "10.1016/j.fluid.2014.01.028",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 0.386,
#               "uncertainty": 0.00193
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.0,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.0,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 1.0,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 353.15,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_10",
#           "source_doi": "10.1016/j.fluid.2014.01.028",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 0.3306,
#               "uncertainty": 0.001653
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.0,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.0,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 1.0,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 363.15,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_11",
#           "source_doi": "10.1016/j.fluid.2014.01.028",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 1.5754,
#               "uncertainty": 0.007877
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.006033333333333335,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.01206666666666667,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 0.9819,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 283.15,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_12",
#           "source_doi": "10.1016/j.fluid.2014.01.028",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 1.2065,
#               "uncertainty": 0.0060325
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.006033333333333335,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.01206666666666667,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 0.9819,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 293.15,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_13",
#           "source_doi": "10.1016/j.fluid.2014.01.028",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 0.9611,
#               "uncertainty": 0.0048055
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.006033333333333335,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.01206666666666667,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 0.9819,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 303.15,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_14",
#           "source_doi": "10.1016/j.fluid.2014.01.028",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 0.7902,
#               "uncertainty": 0.003951
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.006033333333333335,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.01206666666666667,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 0.9819,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 313.15,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_15",
#           "source_doi": "10.1016/j.fluid.2014.01.028",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 0.6578,
#               "uncertainty": 0.003289
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.006033333333333335,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.01206666666666667,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 0.9819,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 323.15,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_16",
#           "source_doi": "10.1016/j.fluid.2014.01.028",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 0.5652,
#               "uncertainty": 0.002826
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.006033333333333335,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.01206666666666667,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 0.9819,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 333.15,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_17",
#           "source_doi": "10.1016/j.fluid.2014.01.028",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 0.4876,
#               "uncertainty": 0.002438
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.006033333333333335,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.01206666666666667,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 0.9819,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 343.15,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_18",
#           "source_doi": "10.1016/j.fluid.2014.01.028",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 0.4353,
#               "uncertainty": 0.0021765
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.006033333333333335,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.01206666666666667,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 0.9819,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 353.15,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_19",
#           "source_doi": "10.1016/j.fluid.2014.01.028",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 0.3862,
#               "uncertainty": 0.001931
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.006033333333333335,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.01206666666666667,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 0.9819,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 363.15,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_20",
#           "source_doi": "10.1016/j.fluid.2014.01.028",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 2.0141,
#               "uncertainty": 0.0100705
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.013266666666666649,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.026533333333333298,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 0.9602,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 283.15,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_21",
#           "source_doi": "10.1016/j.fluid.2014.01.028",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 1.5294,
#               "uncertainty": 0.007647
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.013266666666666649,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.026533333333333298,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 0.9602,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 293.15,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_22",
#           "source_doi": "10.1016/j.fluid.2014.01.028",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 1.2059,
#               "uncertainty": 0.0060295
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.013266666666666649,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.026533333333333298,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 0.9602,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 303.15,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_23",
#           "source_doi": "10.1016/j.fluid.2014.01.028",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 0.9808,
#               "uncertainty": 0.004904
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.013266666666666649,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.026533333333333298,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 0.9602,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 313.15,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_24",
#           "source_doi": "10.1016/j.fluid.2014.01.028",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 0.8193,
#               "uncertainty": 0.0040965
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.013266666666666649,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.026533333333333298,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 0.9602,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 323.15,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_25",
#           "source_doi": "10.1016/j.fluid.2014.01.028",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 0.6999,
#               "uncertainty": 0.0034995
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.013266666666666649,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.026533333333333298,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 0.9602,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 333.15,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_26",
#           "source_doi": "10.1016/j.fluid.2014.01.028",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 0.6006,
#               "uncertainty": 0.003003
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.013266666666666649,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.026533333333333298,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 0.9602,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 343.15,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_27",
#           "source_doi": "10.1016/j.fluid.2014.01.028",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 0.5212,
#               "uncertainty": 0.002606
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.013266666666666649,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.026533333333333298,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 0.9602,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 353.15,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_28",
#           "source_doi": "10.1016/j.fluid.2014.01.028",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 0.4654,
#               "uncertainty": 0.002327
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.013266666666666649,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.026533333333333298,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 0.9602,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 363.15,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_29",
#           "source_doi": "10.1016/j.fluid.2014.01.028",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 2.6941,
#               "uncertainty": 0.0134705
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.022166666666666668,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.044333333333333336,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 0.9335,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 283.15,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_30",
#           "source_doi": "10.1016/j.fluid.2014.01.028",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 2.0191,
#               "uncertainty": 0.0100955
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.022166666666666668,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.044333333333333336,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 0.9335,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 293.15,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_31",
#           "source_doi": "10.1016/j.fluid.2014.01.028",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 1.5742,
#               "uncertainty": 0.007871
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.022166666666666668,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.044333333333333336,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 0.9335,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 303.15,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_32",
#           "source_doi": "10.1016/j.fluid.2014.01.028",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 1.2652,
#               "uncertainty": 0.006326
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.022166666666666668,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.044333333333333336,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 0.9335,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 313.15,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_33",
#           "source_doi": "10.1016/j.fluid.2014.01.028",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 1.0444,
#               "uncertainty": 0.005222
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.022166666666666668,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.044333333333333336,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 0.9335,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 323.15,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_34",
#           "source_doi": "10.1016/j.fluid.2014.01.028",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 0.8829,
#               "uncertainty": 0.0044145
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.022166666666666668,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.044333333333333336,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 0.9335,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 333.15,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_35",
#           "source_doi": "10.1016/j.fluid.2014.01.028",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 0.7359,
#               "uncertainty": 0.0036795
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.022166666666666668,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.044333333333333336,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 0.9335,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 343.15,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_36",
#           "source_doi": "10.1016/j.fluid.2014.01.028",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 0.6654,
#               "uncertainty": 0.003327
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.022166666666666668,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.044333333333333336,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 0.9335,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 353.15,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_37",
#           "source_doi": "10.1016/j.fluid.2014.01.028",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 0.6145,
#               "uncertainty": 0.0030725
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.022166666666666668,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.044333333333333336,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 0.9335,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 363.15,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_38",
#           "source_doi": "10.1016/j.fluid.2014.01.028",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 3.8894,
#               "uncertainty": 0.019447
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.03310000000000002,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.06620000000000004,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 0.9007,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 283.15,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_39",
#           "source_doi": "10.1016/j.fluid.2014.01.028",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 2.8657,
#               "uncertainty": 0.0143285
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.03310000000000002,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.06620000000000004,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 0.9007,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 293.15,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_40",
#           "source_doi": "10.1016/j.fluid.2014.01.028",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 2.1977,
#               "uncertainty": 0.0109885
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.03310000000000002,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.06620000000000004,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 0.9007,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 303.15,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_41",
#           "source_doi": "10.1016/j.fluid.2014.01.028",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 1.7433,
#               "uncertainty": 0.0087165
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.03310000000000002,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.06620000000000004,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 0.9007,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 313.15,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_42",
#           "source_doi": "10.1016/j.fluid.2014.01.028",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 1.4169,
#               "uncertainty": 0.0070845
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.03310000000000002,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.06620000000000004,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 0.9007,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 323.15,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_43",
#           "source_doi": "10.1016/j.fluid.2014.01.028",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 1.1824,
#               "uncertainty": 0.005912
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.03310000000000002,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.06620000000000004,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 0.9007,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 333.15,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_44",
#           "source_doi": "10.1016/j.fluid.2014.01.028",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 1.004,
#               "uncertainty": 0.00502
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.03310000000000002,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.06620000000000004,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 0.9007,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 343.15,
# ...
#               "propValue": 52.0,
#               "uncertainty": 1.56
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.3333333333333333,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.6666666666666667,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 0.0,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 328.15,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_253",
#           "source_doi": "10.1039/c1cp22554e",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 259.0,
#               "uncertainty": 5.18
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.3333333333333333,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.6666666666666667,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 0.0,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 298.0,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_254",
#           "source_doi": "10.1039/c1cp22554e",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 188.0,
#               "uncertainty": 3.76
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.3333333333333333,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.6666666666666667,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 0.0,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 303.0,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_255",
#           "source_doi": "10.1039/c1cp22554e",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 140.0,
#               "uncertainty": 2.8
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.3333333333333333,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.6666666666666667,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 0.0,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 308.0,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_256",
#           "source_doi": "10.1039/c1cp22554e",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 104.0,
#               "uncertainty": 2.08
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.3333333333333333,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.6666666666666667,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 0.0,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 313.0,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_257",
#           "source_doi": "10.1039/c1cp22554e",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 82.0,
#               "uncertainty": 1.64
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.3333333333333333,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.6666666666666667,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 0.0,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 318.0,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_258",
#           "source_doi": "10.1039/c1cp22554e",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 64.0,
#               "uncertainty": 1.28
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.3333333333333333,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.6666666666666667,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 0.0,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 323.0,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_259",
#           "source_doi": "10.1039/c1cp22554e",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 52.0,
#               "uncertainty": 1.04
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.3333333333333333,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.6666666666666667,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 0.0,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 328.0,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_260",
#           "source_doi": "10.1039/c5cp01493j",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 64.87,
#               "uncertainty": null
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.147363363,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.29472672600000005,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 0.557909911,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 293.15,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_261",
#           "source_doi": "10.1039/c5cp01493j",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 86.707,
#               "uncertainty": null
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.17631459666666668,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.3526291933333333,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 0.47105621,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 293.15,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_262",
#           "source_doi": "10.1039/c5cp01493j",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 129.312,
#               "uncertainty": null
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.21338299100000002,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.42676598200000004,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 0.359851027,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 293.15,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_263",
#           "source_doi": "10.1039/c5cp01493j",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 170.685,
#               "uncertainty": null
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.2362386396666667,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.4724772793333334,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 0.291284081,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 293.15,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_264",
#           "source_doi": "10.1039/c5cp01493j",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 213.443,
#               "uncertainty": null
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.2631556606666667,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.5263113213333332,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 0.210533018,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 293.15,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_265",
#           "source_doi": "10.1039/c5cp01493j",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 311.565,
#               "uncertainty": null
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.294947672,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.5898953440000001,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 0.115156984,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 293.15,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_266",
#           "source_doi": "10.1039/c5cp01493j",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 314.245,
#               "uncertainty": null
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.31694769,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.63389538,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 0.04915693,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 293.15,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         },
#         {
#           "measurement_id": "meas_267",
#           "source_doi": "10.1039/c5cp01493j",
#           "propertyValue": [
#             {
#               "propertyID": "viscosity",
#               "propValue": 330.824,
#               "uncertainty": null
#             }
#           ],
#           "parameterValue": [
#             {
#               "parameterID": "x_water",
#               "paramValue": 0.32504779266666667,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_cholinchloride",
#               "paramValue": 0.6500955853333332,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "x_glycerol",
#               "paramValue": 0.024856622,
#               "uncertainty": null
#             },
#             {
#               "parameterID": "T_4",
#               "paramValue": 293.15,
#               "uncertainty": null
#             }
#           ],
#           "method": "literature",
#           "method_description": "Experimental measurement"
#         }
#       ]
#     }
#   ]
# }

# %%
with open('/home/sga/Code/FAIRFluids/FAIRFluids/test/fairfluids_model.json', 'r') as f:
    json_data = f.read()
    
validated_doc = FAIRFluidsDocument.model_validate_json(json_data)

# %%
from FAIRFluids.core.visualization import *

plot_viscosity_vs_temperature(doc, "Water", fit_arrhenius=True, print_table=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 3
#       1 from FAIRFluids.core.visualization import *
# ----> 3 plot_viscosity_vs_temperature(doc, "Water", fit_arrhenius=True, print_table=True)
#
# File ~/Code/FAIRFluids/FAIRFluids/core/visualization.py:107, in plot_viscosity_vs_temperature(doc, component_name, fit_arrhenius, print_table, save_fig)
#      85 def plot_viscosity_vs_temperature(doc, component_name, fit_arrhenius=False, print_table=False, save_fig=False):
#      86     """
#      87     Create a plot of ln(viscosity) vs 1/RT for a FAIRFluids document.
#      88     Groups data points by mole fraction of the selected component.
#    (...)    105         save_fig: If True, save the figure to 'viscosity_plot.png'
#     106     """
# --> 107     viscosity_data = doc.get_viscosity_data()
#     108     compounds = viscosity_data[0]['compound_identifiers']
#     110     activation_energies, mole_frac_groups = calculate_activation_energies(doc, component_name)
#
# File ~/Applications/miniconda3/envs/xyz/lib/python3.13/site-packages/pydantic/main.py:991, in BaseModel.__getattr__(self, item)
#     988     return super().__getattribute__(item)  # Raises AttributeError if appropriate
#     989 else:
#     990     # this is the current error
# --> 991     raise AttributeError(f'{type(self).__name__!r} object has no attribute {item!r}')
#
# AttributeError: 'FAIRFluidsDocument' object has no attribute 'get_viscosity_data'

# %%
from FAIRFluids.core.visualization import plot_viscosity_vs_temperature

# plot_viscosity_vs_temperature(doc, "Water", fit_arrhenius=True, print_table=True)
# Out:
# Activation Energies:
#  Mole Fraction  Activation Energy (kJ/mol)
#          0.000                      44.965
#          0.108                      40.366
#          0.238                      37.590
#          0.254                      41.597
#          0.343                      34.741
#          0.402                      33.526
#          0.598                      28.874
#          0.720                      24.939
#          0.800                      22.367
#          0.857                      18.894
#          0.901                      17.208
#          0.933                      16.014
#          0.960                      15.547
#          0.982                      14.913
#          1.000                      13.958

# %%
calculate_activation_energies(validated_doc, "Water")
# Get activation energies and convert to kJ/mol
activation_energies = calculate_activation_energies(validated_doc, "Water")
water_fractions = list(activation_energies.keys())
E_values = [E/1000 for E in activation_energies.values()]

# Calculate ideal fluid activation energy
# Using linear combination rule: E_act = x_water * E_water + (1-x_water) * E_DES
E_water = 17.0  # Activation energy of pure water in kJ/mol
E_DES = max(E_values)  # Use highest activation energy (pure DES) as reference

# Generate smooth line for ideal behavior
x_water_ideal = np.linspace(0, 1, 100)
E_ideal = [x*E_water + (1-x)*E_DES for x in x_water_ideal]

# Add ideal line to previous plot
plt.figure(figsize=(8,7), dpi=300)
plt.scatter(water_fractions, E_values, label="Eη/Water")

plt.plot(x_water_ideal, E_ideal, 'r--', label='Ideal Mixing')
plt.xlabel('Water Mole Fraction')
plt.ylabel('Activation Energy (kJ/mol)')
plt.title('Cholinchlorid-Urea-Water')
plt.savefig('3.png', dpi=300)
plt.grid(True)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 4
#       2 # Get activation energies and convert to kJ/mol
#       3 activation_energies = calculate_activation_energies(validated_doc, "Water")
# ----> 4 water_fractions = list(activation_energies.keys())
#       5 E_values = [E/1000 for E in activation_energies.values()]
#       7 # Calculate ideal fluid activation energy
#       8 # Using linear combination rule: E_act = x_water * E_water + (1-x_water) * E_DES
#
# AttributeError: 'tuple' object has no attribute 'keys'

# %%
urea_doc = myFAIRFluidsDocument(version=Version(versionMajor=1, versionMinor=0))

# Add citation
urea_doc.citation = Citation(Type="journal")
urea_doc.citation.add_to_author(given_name="John", family_name="Doe")


# Add compounds and fluid data
urea_doc.add_to_compound(
    compound_identifier=C_id(c_id="Water"),  # Note: it's "compund_identifier" not "compound_identifier"
    pubChemID=962,
    commonName="Water",
    name_IUPAC="water", 
    standard_InChI="InChI=1S/H2O/h1H2",
    standard_InChI_key="XLYOFNOQVPJJNP-UHFFFAOYSA-N"
)


urea_doc.add_to_compound(
    compound_identifier=C_id(c_id="CholinChloride"),  # Note: it's "compund_identifier" not "compound_identifier"
    pubChemID=17789,
    commonName="CholinChloride",
    name_IUPAC="CholinChloride", 
    standard_InChI="InChI=1S/C5H11ClNO2/c1"
)

urea_doc.add_to_compound(
    compound_identifier=C_id(c_id="Urea"),  # Note: it's "compund_identifier" not "compound_identifier"
    pubChemID=1128,
    commonName="Glycerol",
    name_IUPAC="glycerol",
    standard_InChI="InChI=1S/C3H8O3/c1-2-3-4/h2-3H,1H3",
    standard_InChI_key="XLYOFNOQVPJJNP-UHFFFAOYSA-N"
)





urea_doc.get_data_from_cml("data/cml_xml/ChCl_urea.xml")
print(f"Sum of all numerical property values: {urea_doc.sum_num_values()}")

# Save model to JSON file
with open('ChCl_urea_model.json', 'w') as f:
    f.write(urea_doc.model_dump_json(indent=2))
# Out:
# Sum of all numerical property values: 12331.6081374

# %%
# Load JSON and validate with model
with open('ChCl_urea_model.json', 'r') as f:
    json_data = f.read()
    
# Create new document from JSON and validate
chcl_urea_doc = myFAIRFluidsDocument.model_validate_json(json_data)


chcl_urea_doc.get_viscosity_data()
# Out:
# [{'temperature': 313.15,
#   'mole_fractions': [0.0, 0.3333333333333333, 0.6666666666666667],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 169.0},
#  {'temperature': 318.026111,
#   'mole_fractions': [0.0, 0.3333333333333333, 0.6666666666666667],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 122.103044},
#  {'temperature': 315.555369,
#   'mole_fractions': [0.0, 0.3333333333333333, 0.6666666666666667],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 144.945703},
#  {'temperature': 313.07244,
#   'mole_fractions': [0.0, 0.3333333333333333, 0.6666666666666667],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 172.061696},
#  {'temperature': 310.529327,
#   'mole_fractions': [0.0, 0.3333333333333333, 0.6666666666666667],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 204.250466},
#  {'temperature': 308.075872,
#   'mole_fractions': [0.0, 0.3333333333333333, 0.6666666666666667],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 245.248957},
#  {'temperature': 305.565069,
#   'mole_fractions': [0.0, 0.3333333333333333, 0.6666666666666667],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 297.862986},
#  {'temperature': 303.00065,
#   'mole_fractions': [0.0, 0.3333333333333333, 0.6666666666666667],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 365.924228},
#  {'temperature': 293.15,
#   'mole_fractions': [0.0, 0.3333333333333333, 0.6666666666666667],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 1371.9719},
#  {'temperature': 303.15,
#   'mole_fractions': [0.0, 0.3333333333333333, 0.6666666666666667],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 527.2786},
#  {'temperature': 313.15,
#   'mole_fractions': [0.0, 0.3333333333333333, 0.6666666666666667],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 238.0763},
#  {'temperature': 323.15,
#   'mole_fractions': [0.0, 0.3333333333333333, 0.6666666666666667],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 119.8049},
#  {'temperature': 333.15,
#   'mole_fractions': [0.0, 0.3333333333333333, 0.6666666666666667],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 68.6478},
#  {'temperature': 343.15,
#   'mole_fractions': [0.0, 0.3333333333333333, 0.6666666666666667],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 41.9612},
#  {'temperature': 353.15,
#   'mole_fractions': [0.0, 0.3333333333333333, 0.6666666666666667],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 28.1053},
#  {'temperature': 363.15,
#   'mole_fractions': [0.0, 0.3333333333333333, 0.6666666666666667],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 19.949},
#  {'temperature': 293.15,
#   'mole_fractions': [0.03663423, 0.32112192333333334, 0.6422438466666667],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 436.1138},
#  {'temperature': 303.15,
#   'mole_fractions': [0.03663423, 0.32112192333333334, 0.6422438466666667],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 200.6193},
#  {'temperature': 313.15,
#   'mole_fractions': [0.03663423, 0.32112192333333334, 0.6422438466666667],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 104.0292},
#  {'temperature': 323.15,
#   'mole_fractions': [0.03663423, 0.32112192333333334, 0.6422438466666667],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 61.1854},
#  {'temperature': 333.15,
#   'mole_fractions': [0.03663423, 0.32112192333333334, 0.6422438466666667],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 38.2495},
#  {'temperature': 343.15,
#   'mole_fractions': [0.03663423, 0.32112192333333334, 0.6422438466666667],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 25.8876},
#  {'temperature': 353.15,
#   'mole_fractions': [0.03663423, 0.32112192333333334, 0.6422438466666667],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 18.4986},
#  {'temperature': 363.15,
#   'mole_fractions': [0.03663423, 0.32112192333333334, 0.6422438466666667],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 13.705},
#  {'temperature': 293.15,
#   'mole_fractions': [0.076878702, 0.30770709933333334, 0.6154141986666666],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 169.4133},
#  {'temperature': 303.15,
#   'mole_fractions': [0.076878702, 0.30770709933333334, 0.6154141986666666],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 89.4403},
#  {'temperature': 313.15,
#   'mole_fractions': [0.076878702, 0.30770709933333334, 0.6154141986666666],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 52.3574},
#  {'temperature': 323.15,
#   'mole_fractions': [0.076878702, 0.30770709933333334, 0.6154141986666666],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 33.2125},
#  {'temperature': 333.15,
#   'mole_fractions': [0.076878702, 0.30770709933333334, 0.6154141986666666],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 22.5795},
#  {'temperature': 343.15,
#   'mole_fractions': [0.076878702, 0.30770709933333334, 0.6154141986666666],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 16.2228},
#  {'temperature': 353.15,
#   'mole_fractions': [0.076878702, 0.30770709933333334, 0.6154141986666666],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 12.1228},
#  {'temperature': 363.15,
#   'mole_fractions': [0.076878702, 0.30770709933333334, 0.6154141986666666],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 9.295},
#  {'temperature': 293.15,
#   'mole_fractions': [0.125625626, 0.2914581246666667, 0.5829162493333333],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 73.3357},
#  {'temperature': 303.15,
#   'mole_fractions': [0.125625626, 0.2914581246666667, 0.5829162493333333],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 43.4958},
#  {'temperature': 313.15,
#   'mole_fractions': [0.125625626, 0.2914581246666667, 0.5829162493333333],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 28.0056},
#  {'temperature': 323.15,
#   'mole_fractions': [0.125625626, 0.2914581246666667, 0.5829162493333333],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 19.2941},
#  {'temperature': 333.15,
#   'mole_fractions': [0.125625626, 0.2914581246666667, 0.5829162493333333],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 13.9586},
#  {'temperature': 343.15,
#   'mole_fractions': [0.125625626, 0.2914581246666667, 0.5829162493333333],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 10.323},
#  {'temperature': 363.15,
#   'mole_fractions': [0.125625626, 0.2914581246666667, 0.5829162493333333],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 6.1852},
#  {'temperature': 293.15,
#   'mole_fractions': [0.182066206, 0.272644598, 0.5452891959999999],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 34.5047},
#  {'temperature': 303.15,
#   'mole_fractions': [0.182066206, 0.272644598, 0.5452891959999999],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 22.6048},
#  {'temperature': 313.15,
#   'mole_fractions': [0.182066206, 0.272644598, 0.5452891959999999],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 15.8076},
#  {'temperature': 323.15,
#   'mole_fractions': [0.182066206, 0.272644598, 0.5452891959999999],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 11.6217},
#  {'temperature': 333.15,
#   'mole_fractions': [0.182066206, 0.272644598, 0.5452891959999999],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 8.2652},
#  {'temperature': 343.15,
#   'mole_fractions': [0.182066206, 0.272644598, 0.5452891959999999],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 6.4745},
#  {'temperature': 353.15,
#   'mole_fractions': [0.182066206, 0.272644598, 0.5452891959999999],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 5.203},
#  {'temperature': 363.15,
#   'mole_fractions': [0.182066206, 0.272644598, 0.5452891959999999],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 4.2758},
#  {'temperature': 293.15,
#   'mole_fractions': [0.254147813, 0.24861739566666666, 0.49723479133333337],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 17.589},
#  {'temperature': 303.15,
#   'mole_fractions': [0.254147813, 0.24861739566666666, 0.49723479133333337],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 12.2515},
#  {'temperature': 313.15,
#   'mole_fractions': [0.254147813, 0.24861739566666666, 0.49723479133333337],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 8.9032},
#  {'temperature': 323.15,
#   'mole_fractions': [0.254147813, 0.24861739566666666, 0.49723479133333337],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 6.5254},
#  {'temperature': 333.15,
#   'mole_fractions': [0.254147813, 0.24861739566666666, 0.49723479133333337],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 5.1376},
#  {'temperature': 343.15,
#   'mole_fractions': [0.254147813, 0.24861739566666666, 0.49723479133333337],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 4.156},
#  {'temperature': 353.15,
#   'mole_fractions': [0.254147813, 0.24861739566666666, 0.49723479133333337],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 3.4372},
#  {'temperature': 363.15,
#   'mole_fractions': [0.254147813, 0.24861739566666666, 0.49723479133333337],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 2.8964},
#  {'temperature': 293.15,
#   'mole_fractions': [0.33333, 0.22222333333333333, 0.44444666666666666],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 9.1829},
#  {'temperature': 303.15,
#   'mole_fractions': [0.33333, 0.22222333333333333, 0.44444666666666666],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 6.7782},
#  {'temperature': 313.15,
#   'mole_fractions': [0.33333, 0.22222333333333333, 0.44444666666666666],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 5.1982},
#  {'temperature': 323.15,
#   'mole_fractions': [0.33333, 0.22222333333333333, 0.44444666666666666],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 4.1152},
#  {'temperature': 333.15,
#   'mole_fractions': [0.33333, 0.22222333333333333, 0.44444666666666666],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 3.3415},
#  {'temperature': 343.15,
#   'mole_fractions': [0.33333, 0.22222333333333333, 0.44444666666666666],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 2.7739},
#  {'temperature': 353.15,
#   'mole_fractions': [0.33333, 0.22222333333333333, 0.44444666666666666],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 2.3461},
#  {'temperature': 363.15,
#   'mole_fractions': [0.33333, 0.22222333333333333, 0.44444666666666666],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 2.0167},
#  {'temperature': 293.15,
#   'mole_fractions': [0.438438438, 0.18718718733333337, 0.3743743746666667],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 5.0645},
#  {'temperature': 303.15,
#   'mole_fractions': [0.438438438, 0.18718718733333337, 0.3743743746666667],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 3.9093},
#  {'temperature': 313.15,
#   'mole_fractions': [0.438438438, 0.18718718733333337, 0.3743743746666667],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 3.1117},
#  {'temperature': 323.15,
#   'mole_fractions': [0.438438438, 0.18718718733333337, 0.3743743746666667],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 2.5381},
#  {'temperature': 333.15,
#   'mole_fractions': [0.438438438, 0.18718718733333337, 0.3743743746666667],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 2.1172},
#  {'temperature': 343.15,
#   'mole_fractions': [0.438438438, 0.18718718733333337, 0.3743743746666667],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 1.7978},
#  {'temperature': 353.15,
#   'mole_fractions': [0.438438438, 0.18718718733333337, 0.3743743746666667],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 1.5515},
#  {'temperature': 363.15,
#   'mole_fractions': [0.438438438, 0.18718718733333337, 0.3743743746666667],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 1.3576},
#  {'temperature': 293.15,
#   'mole_fractions': [0.571, 0.14300000000000002, 0.28600000000000003],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 2.8436},
#  {'temperature': 303.15,
#   'mole_fractions': [0.571, 0.14300000000000002, 0.28600000000000003],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 2.2654},
#  {'temperature': 313.15,
#   'mole_fractions': [0.571, 0.14300000000000002, 0.28600000000000003],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 1.8509},
#  {'temperature': 323.15,
#   'mole_fractions': [0.571, 0.14300000000000002, 0.28600000000000003],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 1.5403},
#  {'temperature': 333.15,
#   'mole_fractions': [0.571, 0.14300000000000002, 0.28600000000000003],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 1.3049},
#  {'temperature': 343.15,
#   'mole_fractions': [0.571, 0.14300000000000002, 0.28600000000000003],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 1.1287},
#  {'temperature': 353.15,
#   'mole_fractions': [0.571, 0.14300000000000002, 0.28600000000000003],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 0.9911},
#  {'temperature': 363.15,
#   'mole_fractions': [0.571, 0.14300000000000002, 0.28600000000000003],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 0.8788},
#  {'temperature': 293.15,
#   'mole_fractions': [0.75, 0.08333333333333333, 0.16666666666666669],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 1.6178},
#  {'temperature': 303.15,
#   'mole_fractions': [0.75, 0.08333333333333333, 0.16666666666666669],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 1.3125},
#  {'temperature': 313.15,
#   'mole_fractions': [0.75, 0.08333333333333333, 0.16666666666666669],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 1.0858},
#  {'temperature': 323.15,
#   'mole_fractions': [0.75, 0.08333333333333333, 0.16666666666666669],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 0.9234},
#  {'temperature': 333.15,
#   'mole_fractions': [0.75, 0.08333333333333333, 0.16666666666666669],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 0.798},
#  {'temperature': 343.15,
#   'mole_fractions': [0.75, 0.08333333333333333, 0.16666666666666669],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 0.701},
#  {'temperature': 353.15,
#   'mole_fractions': [0.75, 0.08333333333333333, 0.16666666666666669],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 0.6265},
#  {'temperature': 363.15,
#   'mole_fractions': [0.75, 0.08333333333333333, 0.16666666666666669],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 0.5735},
#  {'temperature': 293.15,
#   'mole_fractions': [1.0, 0.0, 0.0],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 0.9968},
#  {'temperature': 303.15,
#   'mole_fractions': [1.0, 0.0, 0.0],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 0.8012},
#  {'temperature': 313.15,
#   'mole_fractions': [1.0, 0.0, 0.0],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 0.665},
#  {'temperature': 323.15,
#   'mole_fractions': [1.0, 0.0, 0.0],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 0.5518},
#  {'temperature': 333.15,
#   'mole_fractions': [1.0, 0.0, 0.0],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 0.4791},
#  {'temperature': 343.15,
#   'mole_fractions': [1.0, 0.0, 0.0],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 0.4246},
#  {'temperature': 353.15,
#   'mole_fractions': [1.0, 0.0, 0.0],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 0.4042},
#  {'temperature': 363.15,
#   'mole_fractions': [1.0, 0.0, 0.0],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 0.3821},
#  {'temperature': 293.15,
#   'mole_fractions': [0.0, 0.3333333333333333, 0.6666666666666667],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 1075.0},
#  {'temperature': 303.15,
#   'mole_fractions': [0.0, 0.3333333333333333, 0.6666666666666667],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 447.5},
#  {'temperature': 313.15,
#   'mole_fractions': [0.0, 0.3333333333333333, 0.6666666666666667],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 207.5},
#  {'temperature': 323.15,
#   'mole_fractions': [0.0, 0.3333333333333333, 0.6666666666666667],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 110.0},
#  {'temperature': 298.0,
#   'mole_fractions': [0.0, 0.3333333333333333, 0.6666666666666667],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 750.0},
#  {'temperature': 303.0,
#   'mole_fractions': [0.0, 0.3333333333333333, 0.6666666666666667],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 449.0},
#  {'temperature': 308.0,
#   'mole_fractions': [0.0, 0.3333333333333333, 0.6666666666666667],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 330.0},
#  {'temperature': 313.0,
#   'mole_fractions': [0.0, 0.3333333333333333, 0.6666666666666667],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 231.0},
#  {'temperature': 318.0,
#   'mole_fractions': [0.0, 0.3333333333333333, 0.6666666666666667],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 161.0},
#  {'temperature': 323.0,
#   'mole_fractions': [0.0, 0.3333333333333333, 0.6666666666666667],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 119.0},
#  {'temperature': 328.0,
#   'mole_fractions': [0.0, 0.3333333333333333, 0.6666666666666667],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 95.0},
#  {'temperature': 293.15,
#   'mole_fractions': [0.018202691, 0.32726576966666665, 0.6545315393333333],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 700.689655},
#  {'temperature': 293.15,
#   'mole_fractions': [0.037339053, 0.32088698233333335, 0.6417739646666667],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 595.862069},
#  {'temperature': 293.15,
#   'mole_fractions': [0.091372242, 0.3028759193333333, 0.6057518386666667],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 564.597701},
#  {'temperature': 293.15,
#   'mole_fractions': [0.17270949, 0.2757635033333333, 0.5515270066666667],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 264.827586},
#  {'temperature': 293.15,
#   'mole_fractions': [0.244484005, 0.251838665, 0.5036773299999999],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 154.482759},
#  {'temperature': 293.15,
#   'mole_fractions': [0.307388395, 0.230870535, 0.46174107],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 99.3103448},
#  {'temperature': 293.15,
#   'mole_fractions': [0.413833762, 0.195388746, 0.390777492],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 51.4942529},
#  {'temperature': 293.15,
#   'mole_fractions': [0.500056115, 0.16664796166666665, 0.33329592333333335],
#   'compound_identifiers': ['Water', 'CholinChloride', 'Urea'],
#   'viscosity': 38.6206897}]

# %%
plot_viscosity_vs_temperature(chcl_urea_doc, "Water", fit_arrhenius=True, print_table=True)
# Out:
# Activation Energies:
#  Mole Fraction  Activation Energy (kJ/mol)
#          0.000                      51.154
#          0.037                      46.051
#          0.077                      36.353
#          0.126                      31.094
#          0.182                      26.490
#          0.254                      22.824
#          0.333                      19.092
#          0.438                      16.600
#          0.571                      14.839
#          0.750                      13.175
#          1.000                      12.396
